# %%
# Parameters
name      = ""
fits_path = ""

# %%
# Parameters
name = "MUSE-M42-S-bin2"
fits_path = "fits_ready/MUSE-M42-S-bin2.fits"

# %% [raw]
# name      = 'MUSE-Dor-H'
# fits_path = "fits_ready/" + name + ".fits"

# %%
import time
start_time=time.time()

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import sys
from pathlib import Path
import astropy.units as u
from matplotlib import pyplot as plt
import corner
import json
from astropy.io import fits
from lmfit.model import save_modelresult


# Add path to py_modules 
sys.path.append(str(Path().resolve() / 'py_modules')) # 1 level up = project root

#import strucfunc                   
import strucfunc
import fit_structure_function
import ci_results_compiler
import bfunc
import bplot

# %% [markdown]
# # Velocity Field

# %%
# Loading obs
hdul = fits.open(fits_path)
hdr = hdul[0].header
print(hdul.info())
print(hdr)
sb = hdul['MOM0'].data.astype(float)
vv= hdul['MOM1'].data.astype(float)
# Out:
# Filename: fits_ready/MUSE-M42-S-bin2.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      23   ()
#   1  MOM0          1 ImageHDU         8   (441, 369)   float64
#   2  MOM1          1 ImageHDU         8   (441, 369)   float64
#   3  MASK          1 ImageHDU         8   (441, 369)   uint8
# None
# SIMPLE  =                    T / conforms to FITS standard                      BITPIX  =                    8 / array data type                                NAXIS   =                    0 / number of array dimensions                     EXTEND  =                    T                                                  FILE    = 'S_III-9069'         / Fits file name                                 NAME_ID = 'MUSE-M42-S-bin2'    / pipeline identifier                            REG     = 'M 42    '           / Region catalog name                            NAME_REG= 'Orion   '           / Region name                                    REG_ID  = 'M42     '           / Region identifier                              TYPE_OBJ= 'H II region'        / Type object                                    DIST    =                  410 / Distance in parsecs                            INSTR   = 'MUSE    '           / Instrument                                     LINE    = '[S III] $\lambda$9069' / Emission line name                          LINE_ID = 'S       '           / Emission line identifier                       L_REST  =               9069.1 / Emission line name                             SIG     =   2.7834228248730866 / Standard deviation vel map                     SIG2    =    7.747442622024473 / Vel Variance map                               S0      = 0.000759644366579272 / Atmospheric seeing                             BOX_SIZE=    0.641477146051788 / Observational box_size                         PC      = 0.001987736092549097 / parsec convertion                              PIX     =                  0.8 / Instrument pixel scale                         BINSIZE =                    2 / Spatial binning factor                         AUTHOR  = 'J. Garcia-Vazquez'  / File creator                                   END

# %%
with fits.open(fits_path) as hdul:
    hdr = hdul[0].header

hdr
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# FILE    = 'S_III-9069'         / Fits file name
# NAME_ID = 'MUSE-M42-S-bin2'    / pipeline identifier
# REG     = 'M 42    '           / Region catalog name
# NAME_REG= 'Orion   '           / Region name
# REG_ID  = 'M42     '           / Region identifier
# TYPE_OBJ= 'H II region'        / Type object
# DIST    =                  410 / Distance in parsecs
# INSTR   = 'MUSE    '           / Instrument
# LINE    = '[S III] $\lambda$9069' / Emission line name
# LINE_ID = 'S       '           / Emission line identifier
# L_REST  =               9069.1 / Emission line name
# SIG     =   2.7834228248730866 / Standard deviation vel map
# SIG2    =    7.747442622024473 / Vel Variance map
# S0      = 0.000759644366579272 / Atmospheric seeing
# BOX_SIZE=    0.641477146051788 / Observational box_size
# PC      = 0.001987736092549097 / parsec convertion
# PIX     =                  0.8 / Instrument pixel scale
# BINSIZE =                    2 / Spatial binning factor
# AUTHOR  = 'J. Garcia-Vazquez'  / File creator

# %%
#m3D      = hdul[0].header['M3D']
#ra       = hdul[0].header['RA']
sig      = hdul[0].header['SIG']
sig2     = hdul[0].header['SIG2']
s0       = hdul[0].header['S0']
#noise    = hdul[0].header['NOISE']
box_size = hdul[0].header['BOX_SIZE']
pc       = hdul[0].header['PC']
pix      = hdul[0].header['PIX']
line     = hdul[0].header['LINE']
binsize  = hdul[0].header['BINSIZE']

# %%
fig, (ax, axx) = plt.subplots(
    1,
    2,
    sharey=True,
    figsize=(10, 4),
)
imshow_kwds = dict(origin="lower", cmap="RdBu_r")
imshow_kwds2 = dict(origin="lower", cmap="magma")
im = ax.imshow(vv, **imshow_kwds)
cbar = fig.colorbar(im, ax=[ax])
cbar.set_label("$\sigma$ (-)", rotation=270, labelpad=15)
im = axx.imshow(sb, **imshow_kwds2)
cbar = fig.colorbar(im, ax=[axx])
cbar.set_label("rad. vel. (km/s)", rotation=270, labelpad=15)

ax.set_xlabel("pix")
ax.set_ylabel("pix")
axx.set_xlabel("pix")
ax.set_title("Moment 1")
axx.set_title("Moment 0")
# Out:
# Text(0.5, 1.0, 'Moment 0')

# %% [markdown]
# # Structure function

# %%
rslt = strucfunc.strucfunc_numba_parallel(vv, wmap=sb, dlogr=0.05)
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# /Users/javier/MUSE_orion/py_modules/strucfunc.py:83: RuntimeWarning: invalid value encountered in divide
#   'Unweighted B(r)': sf/nsf,
# /Users/javier/MUSE_orion/py_modules/strucfunc.py:84: RuntimeWarning: invalid value encountered in divide
#   'Weighted B(r)': wsf/weight}

# %%
rslt_ = pd.DataFrame(rslt)

# %%
rslt["Unweighted mean velocity"] = np.mean(vv)
rslt["Unweighted sigma^2"] = np.var(vv)
v0w = rslt["Weighted mean velocity"] = np.average(vv, weights=sb)
rslt["Weighted sigma^2"] = np.average((vv - v0w)**2, weights=sb)

# %%
b2    = rslt['Unweighted B(r)']
b2w   = rslt['Weighted B(r)']
e_b2  = b2  *.1
e_b2w = b2w  *.1

s     = 10**rslt['log10 r'] * pix * pc
e_s   = s  *.1
sig2  = rslt['Unweighted sigma^2']
sig2w = rslt['Weighted sigma^2']

sig   = sig2**0.5

# %%
r0    = np.interp(sig2, b2[1:35], s[1:35])
ra = r0
m     = 1
noise = 0

rgrid = np.linspace(s[0], s[:-1])

fig, ax = plt.subplots(figsize=(8, 6))

ax.errorbar(s, b2, yerr=e_b2, xerr=e_s, fmt='o', alpha=0.4,color="blue")
ax.errorbar(s, b2w, yerr=e_b2w, xerr=e_s, fmt='x', alpha=0.4,color="green")

ax.axhline(sig2, ls='-')
ax.axvline(r0, ls='-')

ax.plot(rgrid, bfunc.bfunc00s(rgrid, r0, sig2, m), color="0.8")
ax.plot(rgrid, bfunc.bfunc03s(rgrid, r0, sig2, m, s0, noise), color="black")
#ax.plot(rgrid, bfunc.bfunc04s(rgrid, r0, sig2, m, s0, noise, box_size), color="black")


ax.set(xscale='log', yscale='log', 
       xlabel='separation,pc',
       ylabel=r'$b^2,\ \mathrm{km^2\ s^{-2}}$'
      )
None

plt.show()

# %% [markdown]
# # Export

# %%
from astropy.table import Table


df =  rslt_.copy()

# Flatten MultiIndex columns like ('s','count') -> "s_count"
if isinstance(df.columns, pd.MultiIndex):
    df.columns = ["_".join(map(str, col)).strip() for col in df.columns.to_flat_index()]
else:
    df.columns = [str(c) for c in df.columns]

# (Optional) drop index to avoid it becoming an extra column
df = df.reset_index(drop=True)

t = Table.from_pandas(df)
new_hdu = fits.BinTableHDU(t, name="TABLE")

# %%
with fits.open(fits_path, mode="readonly") as hdul:
    hdus = [h.copy() for h in hdul]   # copy existing HDUs

hdus.append(new_hdu)
fits.HDUList(hdus).writeto(fits_path, overwrite=True)

# %%
# Test import

from astropy.table import Table
t = Table.read(fits_path, hdu="TABLE")
df_loaded = t.to_pandas()
df_loaded
# Out:
#     log10 r      Sum dv^
# 40     2.00  6.992901e+09  1.386227e+07  2.563716e+08   446456978
# 41     2.05  8.636907e+09  1.590867e+07  2.950127e+08   529519680
# 42     2.10  1.058084e+10  1.823545e+07  3.325531e+08   631543675
# 43     2.15  1.280267e+10  2.021932e+07  3.636411e+08   737380308
# 44     2.20  1.538627e+10  2.157485e+07  3.874752e+08   850704096
# 45     2.25  1.787540e+10  2.194199e+07  3.900484e+08   967528560
# 46     2.30  1.992444e+10  2.087681e+07  3.776500e+08  1073242509
# 47     2.35  2.115047e+10  1.843663e+07  3.223886e+08  1161083951
# 48     2.40  2.000575e+10  1.472805e+07  2.235304e+08  1198919307
# 49     2.45  1.791774e+10  1.021245e+07  1.455313e+08  1161415103
# 50     2.50  1.388726e+10  5.823475e+06  7.434171e+07  1003787157
# 51     2.55  8.700293e+09  2.444439e+06  2.572710e+07   698086317
# 52     2.60  4.234983e+09  7.659607e+05  6.684898e+06   361004679
# 53     2.65  1.059429e+09  1.358614e+05  1.075134e+06    94462314
# 54     2.70  7.360029e+07  8.296253e+03  4.270102e+04     9655389
#
#     Unweighted B(r)  Weighted B(r)
# 0          0.712736       0.625158
# 1               NaN            NaN
# 2               NaN            NaN
# 3          0.932472       0.968934
# 4               NaN            NaN
# 5               NaN            NaN
# 6          1.080950       1.328250
# 7               NaN            NaN
# 8               NaN            NaN
# 9          1.227637       1.641292
# 10         1.319091       1.826580
# 11         1.439033       2.066146
# 12         1.540119       2.243618
# 13         1.699443       2.534538
# 14         1.832457       2.747409
# 15         1.942074       2.980145
# 16         2.135653       3.313581
# 17         2.330204       3.649239
# 18         2.510713       3.939657
# 19         2.741701       4.323904
# 20         3.010502       4.760842
# 21         3.314205       5.233795
# 22         3.610844       5.697339
# 23         3.992233       6.249339
# 24         4.384893       6.820265
# 25         4.824883       7.404683
# 26         5.314243       8.059309
# 27         5.868367       8.749591
# 28         6.443932       9.499189
# 29         7.062699      10.256095
# 30         7.717174      10.988574
# 31         8.398334      11.715537
# 32         9.115951      12.466893
# 33         9.896892      13.267028
# 34        10.716017      14.095840
# 35        11.554909      14.978323
# 36        12.409829      15.932295
# 37        13.269658      16.841303
# 38        14.143462      17.649303
# 39        14.932227      18.169958
# 40        15.663101      18.494196
# 41        16.310833      18.544149
# 42        16.753932      18.236627
# 43        17.362368      17.984828
# 44        18.086507      17.959578
# 45        18.475324      17.776345
# 46        18.564714      18.089450
# 47        18.216143      17.486309
# 48        16.686486      15.177190
# 49        15.427505      14.250387
# 50        13.834866      12.765867
# 51        12.463062      10.524745
# 52        11.731102       8.727469
# 53        11.215366       7.913463
# 54         7.622716       5.147025

# %%
print("--- %s seconds ---" % (time.time()-start_time))
# Out:
# --- 18.55790901184082 seconds ---
