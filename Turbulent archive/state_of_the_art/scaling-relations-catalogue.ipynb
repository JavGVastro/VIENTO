# %% [markdown]
# This is Will's edit of a notebook originally written by Javier.
#
# # Correlations between H II region parameters
#
# We look at correlations between 6 principal measurements that fall into two groups:
#
# * Basic parameters:
#     * Size: $S$
#     * Ionizing luminosity: $L(\mathrm{H\alpha})$
#     * Distance: $d$
#     * Velocity dispersion on line of sigth: $\sigma_{\text{los}}$
# * Velocity structure function parameters:
#     * Velocity dispersion on plane of sky: $\sigma_{\text{pos}}$
#     * Velocity autocorrelation length scale: $r_0$
#     * Structure function slope in inertial range: $m$

# %%
from pathlib import Path


import time
start_time=time.time()
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import os
import lmfit
import statsmodels.api as sm
import linmix
from scipy.stats import pearsonr
import pickle
import math
import itertools
import json
from logerr import logify
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd

# %% [markdown]
# Load Table with physical properties

# %%
physical_data = pd.read_table('property-regions-data.csv', delimiter=',')
#physical_data = physical_data.drop(physical_data .index[[5,7]])

# %% [markdown]
# Path names

# %%
datapath_names = Path(open("path-name-list.txt", "r").read()).expanduser()

# %%
samples=pd.read_csv(str(datapath_names) +'//sample-names-corr.csv',header=None)
Names=pd.read_csv(str(datapath_names) +'//formal-names-corr.csv',header=None)

# %% [markdown]
# Load Results

# %%
datapath_res = Path(open("path-results.txt", "r").read()).expanduser()

# %%
data = {}
Results = {}

for i in range(len(samples)):
    data[samples[0][i]] = json.load(open(str(datapath_res) + '/' + samples[0][i] + ".json"))

# %%
#sigma
sig = [[0]*(1) for i in range(len(samples))]
siger = [[0]*(1) for i in range(len(samples))]

#velocity dispersion with 2-sig intervals
sig2 = [[0]*(1) for i in range(len(samples))]
#sig2er = [[0]*(1) for i in range(len(samples))]
sig2s2 = [[0]*(1) for i in range(len(samples))]
sig2s2p = [[0]*(1) for i in range(len(samples))]
sig2s2m = [[0]*(1) for i in range(len(samples))]

#correlation length with 2-sig intervals
r0 = [[0]*(1) for i in range(len(samples))]
#r0er = [[0]*(1) for i in range(len(samples))]
r0s2 = [[0]*(1) for i in range(len(samples))]
r0s2p = [[0]*(1) for i in range(len(samples))]
r0s2m = [[0]*(1) for i in range(len(samples))]

#power-law
m = [[0]*(1) for i in range(len(samples))]
#mer = [[0]*(1) for i in range(len(samples))]
ms2 = [[0]*(1) for i in range(len(samples))]
ms2p = [[0]*(1) for i in range(len(samples))]
ms2m = [[0]*(1) for i in range(len(samples))]

#noise with 2-sig intervals
bn = [[0]*(1) for i in range(len(samples))]
#ner = [[0]*(1) for i in range(len(samples))]
bns2 = [[0]*(1) for i in range(len(samples))]
bns2p = [[0]*(1) for i in range(len(samples))]
bns2m = [[0]*(1) for i in range(len(samples))]

#seeing with 2-sig intervals
s0 = [[0]*(1) for i in range(len(samples))]
#s0er = [[0]*(1) for i in range(len(samples))]
s0s2 = [[0]*(1) for i in range(len(samples))]
s0s2p = [[0]*(1) for i in range(len(samples))]
s0s2m = [[0]*(1) for i in range(len(samples))]

pc = [[0]*(1) for i in range(len(samples))]
box_size = [[0]*(1) for i in range(len(samples))]

# %%
for i in range(len(samples)):    
    
    sig2[i] = data[samples[0][i]]['results_2sig']['sig2'][0]
    sig2s2p[i] = data[samples[0][i]]['results_2sig']['sig2'][1]
    sig2s2m[i] = data[samples[0][i]]['results_2sig']['sig2'][2]
    
    r0[i]    = data[samples[0][i]]['results_2sig']['r0'][0]
    r0s2p[i] = data[samples[0][i]]['results_2sig']['r0'][1]
    r0s2m[i] = data[samples[0][i]]['results_2sig']['r0'][2]
    
    m[i]    = data[samples[0][i]]['results_2sig']['m'][0]
    ms2p[i] = data[samples[0][i]]['results_2sig']['m'][1]
    ms2m[i] = data[samples[0][i]]['results_2sig']['m'][2]
    
    bn[i]    = data[samples[0][i]]['results_2sig']['noise'][0]
    bns2p[i] = data[samples[0][i]]['results_2sig']['noise'][1]
    bns2m[i] = data[samples[0][i]]['results_2sig']['noise'][2]
    
    s0[i]    = data[samples[0][i]]['results_2sig']['s0'][0]
    s0s2p[i] = data[samples[0][i]]['results_2sig']['s0'][1]
    s0s2m[i] = data[samples[0][i]]['results_2sig']['s0'][2]
    
    box_size[i] = data[samples[0][i]]['properties']['box_size']
    pc[i] = data[samples[0][i]]['properties']['pc']

# %%
s0f = pd.DataFrame(
    {
        "s0 [RMS]":s0,
        "s0+[RMS]": s0s2p,
        "s0-[RMS]": s0s2m,  
       "s0 [FWHM]": np.array(s0)*2.35/np.array(pc),
       "s0- [FWHM]": np.array(s0s2m)*2.35/np.array(pc),
       "s0+ [FWHM]": np.array(s0s2p)*2.35/np.array(pc),
        "bn ":bn,
        "bn+": bns2p,
        "bn- ": bns2m,     
    }
)

s0f.insert(loc=0, column='Region', value=Names[0])


s0f.round(4)
# Out:
#      Region  s0 [RMS]  s0+[RMS]  s0-[RMS]  s0 [FWHM]  s0- [FWHM]  s0+ [FWHM]  \
# 0   NGC 604    2.1078    1.0353    0.7852     1.2163      0.4531      0.5974
# 1   NGC 595    0.4072    0.6191   -0.0056     0.2350     -0.0032      0.3573
# 2  Hubble X    0.3624    0.3295    0.1063     0.3513      0.1030      0.3194
# 3  Hubble V    0.3412    0.5341    0.0602     0.3307      0.0584      0.5177
# 4    30 Dor    0.1577    0.0874    0.0452     1.5288      0.4383      0.8477
# 5    Carina    0.0075    0.0076    0.0061     1.7042      1.3811      1.7389
# 6   NGC 346    0.1115    0.0266    0.0182     0.8718      0.1422      0.2080
# 7        M8    0.0070    0.0019    0.0062     2.7083      2.3923      0.7335
# 8     Orion    0.0020    0.0003    0.0002     2.3995      0.2473      0.3104
#
#       bn      bn+    bn-
# 0  0.3275  0.7014  0.3071
# 1  1.5372  1.7052  1.0506
# 2  0.3211  0.4153  0.2794
# 3  0.0000  0.6539 -0.0098
# 4  6.1556  1.5788  1.5700
# 5  2.2569  2.4231  1.9776
# 6  0.8402  0.0701  0.0694
# 7  0.4367  0.2088  0.3035
# 8  0.0252  0.0049  0.0049

# %%
s1f = pd.DataFrame(
    {
        "sig2":sig2,
        "sig2+": sig2s2p,
        "sig2-": sig2s2m,
        "r0":r0,
        "r0+": r0s2p,
        "r0-": r0s2m,
        "m":m,
        "m+": ms2p,
        "m-": ms2m,
       
    }
)

s1f.insert(loc=0, column='Region', value=Names[0])


s1f.round(4)
# Out:
#      Region      sig2    sig2+    sig2-       r0     r0+     r0-       m  \
# 0   NGC 604   85.8687  20.4180  11.4636  12.0876  6.4431  3.9551  0.7751
# 1   NGC 595   53.2064   4.6434   1.9165  11.2117  0.7392  0.8512  1.3764
# 2  Hubble X   14.8123   2.6723   0.6829   4.0994  0.3259  0.1877  1.0161
# 3  Hubble V    9.8240   3.5344   0.5024   3.5620  0.4514  1.2700  0.8104
# 4    30 Dor  297.5367  39.6113  18.5188   3.8579  1.0645  0.4682  0.8520
# 5    Carina   18.1376   1.3939   1.5275   0.5505  0.0822  0.0659  1.1584
# 6   NGC 346   33.0228   2.5681   1.4874   2.3737  0.2938  0.1596  0.9564
# 7        M8    7.3852   1.2428   0.7439   1.0347  0.2365  0.1228  1.2639
# 8     Orion   12.6480   0.7428   0.5220   0.0680  0.0061  0.0041  1.0734
#
#        m+      m-
# 0  0.2074  0.2267
# 1  0.0880  0.1493
# 2  0.0806  0.2222
# 3  0.0933  0.2830
# 4  0.0778  0.1389
# 5  0.2763  0.1749
# 6  0.0478  0.0708
# 7  0.1764  0.1929
# 8  0.0312  0.0390

# %%
physical_data
# Out:
#      Region           LHa         LHaer       SFR     n  L [pc]  Ler [pc]  \
# 0   NGC 604  2.630000e+39  2.630000e+38  0.005300  0.35     400      40.0
# 1   NGC 595  8.910000e+38  8.910000e+37  0.002600  1.66     400      40.0
# 2  Hubble X  1.620000e+38  1.620000e+37  0.000310  0.35     160      16.0
# 3  Hubble V  1.990000e+38  1.990000e+37  0.000150  0.11     130      13.0
# 4     30Dor  2.930000e+39  2.930000e+38  0.013000  6.16     370      37.0
# 5    Carina  1.020000e+39  1.020000e+38  0.010000  2.26     200      20.0
# 6   NGC 346  6.000000e+38  6.000000e+37  0.002100  1.20     220      22.0
# 7        M8  3.000000e+37  3.000000e+36  0.000100  0.44      25       2.5
# 8    OrionS  1.510000e+37  1.510000e+36  0.000053  0.03       5       0.5
#
#    Dist [kpc]  Dister [kpc]  siglos [km/s]  sigloser [km/s]  Diam [pc]  \
# 0      840.00         30.00          17.51             0.30        400
# 1      840.00         30.00          16.52             0.09        400
# 2      500.00         40.00          10.00             0.02        160
# 3      500.00         40.00           9.79             0.03        130
# 4       50.00          0.19          21.77             2.20        370
# 5        2.35          0.05          18.60             3.30        200
# 6       61.70          1.10           9.58             1.00        220
# 7        1.25          0.10          11.25             1.60         25
# 8        0.40          0.02           9.90             1.20          5
#
#    Diamer [pc]
# 0         40.0
# 1         40.0
# 2         16.0
# 3         13.0
# 4         37.0
# 5         20.0
# 6         22.0
# 7          2.5
# 8          0.5

# %%
data = pd.DataFrame(
    {
       "Region": physical_data.Region,
       "LHa": physical_data.LHa,
       "LHaer": physical_data.LHaer,
       "SFR": physical_data.SFR,
       "n": physical_data.n,
       "L [pc]": physical_data['Diam [pc]'],
       "Ler [pc]": physical_data['Diamer [pc]'],
       "Dist [kpc]": physical_data['Dist [kpc]'],
       "Dister [kpc]": physical_data['Dister [kpc]'],
        
       "sig2 [km/s]": sig2,
       "sig2er": sig2s2p,
        "sig [km/s]": np.array(sig2)**0.5,
       "siger": np.array(sig2s2p)**0.5,
        "m": m,
       "mer": ms2p,
       "r0 [pc]": r0,
       "r0er": r0s2p,
        
       "siglos [km/s]": physical_data['siglos [km/s]'],
       "sigloser [km/s]": physical_data['sigloser [km/s]'],
      
    },
)

# %%
data.dtypes
# Out:
# Region              object
# LHa                float64
# LHaer              float64
# SFR                float64
# n                  float64
# L [pc]               int64
# Ler [pc]           float64
# Dist [kpc]         float64
# Dister [kpc]       float64
# sig2 [km/s]        float64
# sig2er             float64
# sig [km/s]         float64
# siger              float64
# m                  float64
# mer                float64
# r0 [pc]            float64
# r0er               float64
# siglos [km/s]      float64
# sigloser [km/s]    float64
# dtype: object

# %%
data.round(4)
# Out:
#      Region           LHa         LHaer     SFR     n  L [pc]  Ler [pc]  \
# 0   NGC 604  2.630000e+39  2.630000e+38  0.0053  0.35     400      40.0
# 1   NGC 595  8.910000e+38  8.910000e+37  0.0026  1.66     400      40.0
# 2  Hubble X  1.620000e+38  1.620000e+37  0.0003  0.35     160      16.0
# 3  Hubble V  1.990000e+38  1.990000e+37  0.0001  0.11     130      13.0
# 4     30Dor  2.930000e+39  2.930000e+38  0.0130  6.16     370      37.0
# 5    Carina  1.020000e+39  1.020000e+38  0.0100  2.26     200      20.0
# 6   NGC 346  6.000000e+38  6.000000e+37  0.0021  1.20     220      22.0
# 7        M8  3.000000e+37  3.000000e+36  0.0001  0.44      25       2.5
# 8    OrionS  1.510000e+37  1.510000e+36  0.0001  0.03       5       0.5
#
#    Dist [kpc]  Dister [kpc]  sig2 [km/s]   sig2er  sig [km/s]   siger       m  \
# 0      840.00         30.00      85.8687  20.4180      9.2665  4.5186  0.7751
# 1      840.00         30.00      53.2064   4.6434      7.2943  2.1548  1.3764
# 2      500.00         40.00      14.8123   2.6723      3.8487  1.6347  1.0161
# 3      500.00         40.00       9.8240   3.5344      3.1343  1.8800  0.8104
# 4       50.00          0.19     297.5367  39.6113     17.2493  6.2938  0.8520
# 5        2.35          0.05      18.1376   1.3939      4.2588  1.1806  1.1584
# 6       61.70          1.10      33.0228   2.5681      5.7465  1.6025  0.9564
# 7        1.25          0.10       7.3852   1.2428      2.7176  1.1148  1.2639
# 8        0.40          0.02      12.6480   0.7428      3.5564  0.8619  1.0734
#
#       mer  r0 [pc]    r0er  siglos [km/s]  sigloser [km/s]
# 0  0.2074  12.0876  6.4431          17.51             0.30
# 1  0.0880  11.2117  0.7392          16.52             0.09
# 2  0.0806   4.0994  0.3259          10.00             0.02
# 3  0.0933   3.5620  0.4514           9.79             0.03
# 4  0.0778   3.8579  1.0645          21.77             2.20
# 5  0.2763   0.5505  0.0822          18.60             3.30
# 6  0.0478   2.3737  0.2938           9.58             1.00
# 7  0.1764   1.0347  0.2365          11.25             1.60
# 8  0.0312   0.0680  0.0061           9.90             1.20

# %%
cols = data.columns
logdata = data.copy()
for col in cols:
    if col not in ["Region", "m", "mer", "r0er", "siger",  "sig2er", "Ler [pc]", "Dister [kpc]","LHaer","sigloser [km/s]"]:
        logdata[col] = np.round(np.log10(logdata[col]), 2)
        logdata.rename(columns={col: f"log {col}"}, inplace=True)
# Some minor changes to column names
logdata.rename(
    columns={
        "log LHa": "log L(H) [erg s^-1]",
        }, 
    inplace=True)
logdata
# Out:
#      Region  log L(H) [erg s^-1]         LHaer  log SFR  log n  log L [pc]  \
# 0   NGC 604                39.42  2.630000e+38    -2.28  -0.46        2.60
# 1   NGC 595                38.95  8.910000e+37    -2.59   0.22        2.60
# 2  Hubble X                38.21  1.620000e+37    -3.51  -0.46        2.20
# 3  Hubble V                38.30  1.990000e+37    -3.82  -0.96        2.11
# 4     30Dor                39.47  2.930000e+38    -1.89   0.79        2.57
# 5    Carina                39.01  1.020000e+38    -2.00   0.35        2.30
# 6   NGC 346                38.78  6.000000e+37    -2.68   0.08        2.34
# 7        M8                37.48  3.000000e+36    -4.00  -0.36        1.40
# 8    OrionS                37.18  1.510000e+36    -4.28  -1.52        0.70
#
#    Ler [pc]  log Dist [kpc]  Dister [kpc]  log sig2 [km/s]     sig2er  \
# 0      40.0            2.92         30.00             1.93  20.418004
# 1      40.0            2.92         30.00             1.73   4.643371
# 2      16.0            2.70         40.00             1.17   2.672278
# 3      13.0            2.70         40.00             0.99   3.534439
# 4      37.0            1.70          0.19             2.47  39.611347
# 5      20.0            0.37          0.05             1.26   1.393893
# 6      22.0            1.79          1.10             1.52   2.568073
# 7       2.5            0.10          0.10             0.87   1.242835
# 8       0.5           -0.40          0.02             1.10   0.742833
#
#    log sig [km/s]     siger         m       mer  log r0 [pc]      r0er  \
# 0            0.97  4.518629  0.775075  0.207397         1.08  6.443078
# 1            0.86  2.154848  1.376368  0.087961         1.05  0.739236
# 2            0.59  1.634710  1.016097  0.080615         0.61  0.325858
# 3            0.50  1.880010  0.810433  0.093346         0.55  0.451416
# 4            1.24  6.293755  0.851961  0.077782         0.59  1.064497
# 5            0.63  1.180632  1.158353  0.276279        -0.26  0.082150
# 6            0.76  1.602521  0.956389  0.047801         0.38  0.293811
# 7            0.43  1.114825  1.263906  0.176361         0.01  0.236500
# 8            0.55  0.861878  1.073374  0.031151        -1.17  0.006121
#
#    log siglos [km/s]  sigloser [km/s]
# 0               1.24             0.30
# 1               1.22             0.09
# 2               1.00             0.02
# 3               0.99             0.03
# 4               1.34             2.20
# 5               1.27             3.30
# 6               0.98             1.00
# 7               1.05             1.60
# 8               1.00             1.20

# %% [markdown]
# Uncertainties Log Space

# %%
logdata['Ler [pc]']=(data['Ler [pc]']/data['L [pc]'])*0.434
logdata['sigloser [km/s]']=(data['sigloser [km/s]']/data['siglos [km/s]'])*0.434
logdata['LHaer']=(data['LHaer']/data['LHa'])*0.434
logdata['Dister [kpc]']=(data['Dister [kpc]']/data['Dist [kpc]'])*0.434
logdata['mer']=(data['mer']/data['m'])*0.434
logdata['r0er']=(data['r0er']/data['r0 [pc]'])*0.434
logdata['siger']=(data['siger']/data['sig [km/s]'])*0.434
logdata['sig2er']=(data['sig2er']/data['sig2 [km/s]'])*0.434

# %%
#logify(data['L [pc]'],data['Ler [pc]'])

# %% [markdown]
# Make the label text bigger on the figures

# %%
sns.set_context("talk")

# %%
selected_vars = [ "log L [pc]","log L(H) [erg s^-1]", "log Dist [kpc]", "m", "log r0 [pc]", "log sig [km/s]", "log siglos [km/s]"]
plotdata = logdata[selected_vars].rename(
    columns={
        # Switch column names to use latex formatting to improve axis labels
        "log L [pc]": r"$\log_{10}\ L$ [pc]", 
        "log L(H) [erg s^-1]": r"$\log_{10}\ L(\mathrm{H})$ [erg s$^{-1}$]", 
        "m": "$m$", 
        "log r0 [pc]": r"$\log_{10}\ r_0$ [pc]", 
        "log sig [km/s]": r"$\log_{10}\ \sigma$ [km/s]", 
        "log Dist [kpc]": r"$\log_{10}\ D$ [kpc]",
    },
)

sns.pairplot(plotdata, 
             hue=r"$\log_{10}\ D$ [kpc]",
             plot_kws=dict(alpha=0.75, s=200, edgecolor="k"), 
             diag_kind='hist',
             diag_kws= dict(multiple='stack'),
             );

figname = "strucfunc-correlations"
# Save PDF and JPG versions of the figure
#plt.gcf().savefig(f"{figname}.pdf")
#plt.gcf().savefig(f"{figname}.jpg")

# %% [markdown]
# ## Comparion previous work

# %% [markdown]
# ## L vs Sig

# %%
sns.set_context("talk", font_scale=1.2)

# %%
path_previous = 'data-previous-scaling-relations'

# %%
Ostin = pd.read_csv(path_previous+'//Ostin2001.csv')
Blasco = pd.read_csv(path_previous+'//Blasco2013.csv')
Rozas = pd.read_csv(path_previous+'//Rozas2006.csv')
Ars = pd.read_csv(path_previous+'//ArsRoy1986.csv')
Wis = pd.read_csv(path_previous+'//Wis2012.csv')
Gal = pd.read_csv(path_previous+'//Gallagher1983.csv')
Fer = pd.read_csv(path_previous+'//Fernandez2018.csv')
TM81 = pd.read_csv(path_previous + '//TM1981.csv')
Ch14 = pd.read_csv(path_previous + '//Chavez2014.csv')
Moiseev = pd.read_csv(path_previous+'//Moiseev2015.csv')

MoiLV = pd.read_csv(path_previous+'//MoiLV2015.csv')
MoiXMD = pd.read_csv(path_previous+'//MoiXMD2015.csv')
MoiBCDG = pd.read_csv(path_previous+'//MoiBCDG2015.csv')

# %%
logdata['log siglos [km/s]']
# Out:
# 0    1.24
# 1    1.22
# 2    1.00
# 3    0.99
# 4    1.34
# 5    1.27
# 6    0.98
# 7    1.05
# 8    1.00
# Name: log siglos [km/s], dtype: float64

# %%
fig, ax=plt.subplots(figsize=(10,10))

#plt.scatter(Fer.L,10**(Fer.sig),label='Fernandez 2018',marker='.',alpha=0.95,color='darkgray')
#plt.scatter(logdata['log L(H) [erg s^-1]'],10**(logdata['log siglos [km/s]']),marker='v',label='SigLOS',color='black',s=(logdata['log Dist [kpc]']+1.0)*70)

#HB
plt.scatter(Ch14.sig,Ch14.L,label='Galaxias HII',marker='.',alpha=0.95,color='blue')
plt.scatter(np.log10(TM81.sig),TM81.L,label='GEHRs',marker='.',alpha=0.95,color='red')
#Ha
plt.scatter(np.log10(MoiLV.sig),MoiLV.L-0.45,label='Galaxias enanas',marker='.',alpha=0.75,color='orange')
plt.scatter(np.log10(MoiXMD.sig),MoiXMD.L-0.45,label='Galaxias XMD' ,marker='X',alpha=0.75,color='orange')
plt.scatter(np.log10(MoiBCDG.sig),MoiBCDG.L-0.45,label='BCDG',marker='^',alpha=0.75,color='orange')
plt.scatter(np.log10(Wis.sig),Wis.L-0.45,label='clumps',marker='o',alpha=0.75,color='lime')
plt.scatter(logdata['log sig [km/s]'],logdata['log L(H) [erg s^-1]']-0.45,marker='o',label='$σ_{pos}$',color='black')
plt.scatter(logdata['log siglos [km/s]'],logdata['log L(H) [erg s^-1]']-0.45,marker='x',label='$σ_{los}$',color='black')
#plt.scatter(Rozas.sig,Rozas.L-0.45,label='Rozas 2006',marker='.',alpha=0.95,color='darkgray')


ax.set(
#    ylim  = [36, 43],
#    xlim  = [1, 150],
)
#ax.set_facecolor('whitesmoke')
#plt.yscale('log')

ax.set(ylabel='Log(L$_{Hβ}$) [erg/s]', xlabel='Log $σ$ [km s$^{-1}$]')
plt.legend()
fig.savefig('plots//l_vs_s_global.pdf', bbox_inches='tight')

# %%
global_sig = pd.concat([Ch14.sig,np.log10(TM81.sig),np.log10(MoiLV.sig),np.log10(MoiXMD.sig),np.log10(MoiBCDG.sig),np.log10(Wis.sig),logdata['log sig [km/s]']], axis = 0)
global_L = pd.concat([Ch14.L,TM81.L,MoiLV.L-0.45,MoiXMD.L-0.45,MoiBCDG.L-0.45,Wis.L-0.45,logdata['log L(H) [erg s^-1]']-0.45], axis = 0)

# %%
global_sig_er = (global_sig *.05)/global_sig 
global_L_er = (global_L *.05)/global_L

# %%
X, Xe, Y, Ye = [global_sig, global_sig_er, global_L, global_L_er]
lm = linmix.LinMix(X, Y, Xe, Ye, K=2)
lm.run_mcmc()
# Out:
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99091136 0.9912221  0.99986082 0.99670698 1.01882325 1.01046841]
#
# Iteration:  200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00012022 0.99846639 0.9964932  0.99638752 0.99739186 0.99767075]
#
# Iteration:  300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00139177 0.99968911 0.99785708 0.99970567 0.99682143 0.99702353]
#
# Iteration:  400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00460845 1.00262515 0.99945444 0.99890603 0.99805487 0.99824554]
#
# Iteration:  500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00651625 1.00592983 0.99927317 0.99977717 0.99862847 1.00103169]
#
# Iteration:  600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00515705 1.00500639 0.99932575 0.99993647 0.99926657 1.0023668 ]
#
# Iteration:  700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00368715 1.00352656 0.99942371 0.99924495 0.99917514 1.00223459]
#
# Iteration:  800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00239689 1.00213766 0.99925814 0.99903869 0.99915965 1.000726  ]
#
# Iteration:  900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00168081 1.00175321 0.99944553 0.99940865 0.99908352 0.99985941]
#
# Iteration:  1000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00201826 1.00168701 1.00026699 0.99951286 0.99915602 1.0000414 ]
#
# Iteration:  1100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00102241 1.00073966 0.99994453 1.00016852 0.99921064 0.99963606]
#
# Iteration:  1200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00079127 1.00065683 0.99989587 1.00041544 0.999428   0.99979603]
#
# Iteration:  1300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00111957 1.0009755  0.99993634 1.00026318 0.99972022 0.9998976 ]
#
# Iteration:  1400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00105711 1.00086949 1.00051398 0.99998811 0.99968596 1.00054826]
#
# Iteration:  1500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00117442 1.00109628 1.00070244 1.00060014 0.99972946 1.00083329]
#
# Iteration:  1600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00128488 1.00132989 1.00029509 1.00024416 0.99974475 1.00072658]
#
# Iteration:  1700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00167677 1.00178237 1.00109935 0.99990212 0.9996664  1.00107929]
#
# Iteration:  1800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00120348 1.00125565 1.0005285  0.99985121 0.99970283 1.00093395]
#
# Iteration:  1900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00131266 1.00139398 1.00048857 1.00012155 0.9997563  1.00133116]
#
# Iteration:  2000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00120051 1.00125766 1.00051086 1.00023785 0.9997889  1.00104878]
#
# Iteration:  2100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00132146 1.00129071 1.00090298 1.00006103 0.99979746 1.00131262]
#
# Iteration:  2200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00108798 1.00113127 1.00052458 1.00023723 0.99986366 1.00093708]
#
# Iteration:  2300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00035266 1.00038162 1.00024217 1.0004161  0.99986367 1.0005068 ]
#
# Iteration:  2400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00045678 1.0004636  1.00000401 1.00051572 0.99988451 1.0004532 ]
#
# Iteration:  2500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00058901 1.00059807 1.0000829  1.0004089  0.99998779 1.00076184]
#
# Iteration:  2600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00070097 1.00072155 1.0001682  1.00038228 1.00018971 1.00095726]
#
# Iteration:  2700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00073718 1.0007951  1.00023975 1.00057872 1.00006446 1.00091401]
#
# Iteration:  2800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00048346 1.00052042 1.00019144 1.00032246 1.00006013 1.00074635]
#
# Iteration:  2900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00040452 1.00042252 1.00018853 1.00027868 1.00002994 1.00058819]
#
# Iteration:  3000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0002797  1.00030948 1.00006903 1.00023693 0.9999586  1.00044675]
#
# Iteration:  3100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00029672 1.00031809 1.0001023  1.00026026 0.99996505 1.0004475 ]
#
# Iteration:  3200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00020987 1.00024232 1.00008673 1.00026279 0.99988904 1.00031888]
#
# Iteration:  3300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00017319 1.00016409 0.99993229 1.00019715 0.99989237 1.00017949]
#
# Iteration:  3400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00027241 1.00027583 1.00005489 1.00030069 0.99985307 1.00018423]
#
# Iteration:  3500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00025929 1.00026201 1.00004177 1.00034344 0.99978478 1.00011983]
#
# Iteration:  3600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00040643 1.00038815 1.00012372 1.00025271 0.99980162 1.00022412]
#
# Iteration:  3700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00036547 1.00034175 1.00009565 1.0002863  0.99982351 1.00016307]
#
# Iteration:  3800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00031202 1.00029574 1.00009703 1.00015447 0.9998367  1.00015582]
#
# Iteration:  3900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00031038 1.00029757 1.00015389 1.00011191 0.99981014 1.00019439]
#
# Iteration:  4000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00039641 1.00038505 1.00015807 1.00017278 0.99980015 1.00026155]
#
# Iteration:  4100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00038179 1.00037498 1.00021198 1.00025225 0.9997679  1.00025195]
#
# Iteration:  4200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00037063 1.00037301 1.00023518 1.00026094 0.99978416 1.00025263]
#
# Iteration:  4300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00035796 1.00034022 1.000275   1.00031879 0.9997883  1.00020067]
#
# Iteration:  4400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00053563 1.00051529 1.00021941 1.00047227 0.99978353 1.00017649]
#
# Iteration:  4500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00048876 1.00048657 1.0002107  1.00044114 0.99980411 1.00024886]
#
# Iteration:  4600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00056545 1.00055536 1.00018009 1.00031573 0.99980403 1.00023581]
#
# Iteration:  4700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0003864  1.00037193 1.00012298 1.00027976 0.99980519 1.00019514]
#
# Iteration:  4800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0003805  1.00036311 1.00016847 1.00016221 0.99981177 1.00019795]
#
# Iteration:  4900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00048717 1.00047648 1.00020785 1.00012872 0.99980829 1.00023739]
#
# Iteration:  5000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00046781 1.00043953 1.00014747 1.00008753 0.9998368  1.00023572]

# %%
dfchain = pd.DataFrame.from_records(
    lm.chain.tolist(), 
    columns=lm.chain.dtype.names
)
#dfchain

# %%
pearsonr(X, Y)
# Out:
# (0.8521883118251596, 1.890392782320552e-58)

# %%
pd.DataFrame({"X": X, "Xe": Xe, "Y": Y, "Ye": Ye}).describe()
# Out:
#                 X            Xe           Y            Ye
# count  203.000000  2.030000e+02  203.000000  2.030000e+02
# mean     1.427586  5.000000e-02   40.101689  5.000000e-02
# std      0.262036  4.848385e-17    1.307772  4.918184e-17
# min      0.430000  5.000000e-02   36.730000  5.000000e-02
# 25%      1.274152  5.000000e-02   39.115000  5.000000e-02
# 50%      1.437751  5.000000e-02   40.326880  5.000000e-02
# 75%      1.590660  5.000000e-02   41.192580  5.000000e-02
# max      2.153357  5.000000e-02   42.172000  5.000000e-02

# %%
vmin, vmax = 0.25, 2.5
xgrid = np.linspace(vmin, vmax, 200)


fig, ax = plt.subplots(figsize=(10, 10))

ax.errorbar(X, Y, xerr=Xe, yerr=Ye, ls=" ", elinewidth=0.4, alpha=1.0, c="k")
ax.scatter(X, Y, marker=".", s=20/np.hypot(Xe, Ye))
# The original fit
ax.plot(xgrid, dfchain["alpha"].mean() + xgrid*dfchain["beta"].mean(), 
        '-', c="k")


for samp in lm.chain[::100]:
    ax.plot(xgrid, samp["alpha"] + xgrid*samp["beta"], 
        '-', c="r", alpha=0.15, lw=0.35,zorder=0)
    
ax.text(.05, .95,'log  (L$_{Hβ}$)= (' 
        + str(np.round(dfchain["beta"].mean(),3)) + '$\pm$' + str(np.round(dfchain["beta"].std(),3))
        + ')log $\sigma$+('
        + str(np.round(dfchain["alpha"].mean(),3)) + '$\pm$' + str(np.round(dfchain["alpha"].std(),3))
        + ')',  color='k', transform=ax.transAxes)
    
ax.set(xlim=[0.25, 2.5], ylim=[36, 44],ylabel='Log(L$_{Hβ}$) [erg/s]', xlabel='Log $σ$ [km s$^{-1}$]')
fig.savefig('plots//global_L_s.pdf', bbox_inches='tight')

# %% [markdown]
# ## D vs Sig

# %%
MelDS = pd.read_csv(path_previous+'//MelDS1977.csv')
LarDS = pd.read_csv(path_previous+'//LarDS1981.csv')
TMDS = pd.read_csv(path_previous+'//TMDS1981.csv')
TMDSEG = pd.read_csv(path_previous+'//TMDS1981EG.csv')
ARDSA = pd.read_csv(path_previous+'//ARDS1988.csv')
WDS = pd.read_csv(path_previous+'//WisDS2012.csv')

# %%
fig, ax=plt.subplots(figsize=(10,10))

plt.scatter(MelDS.sig,MelDS.D,label='GEHRs',marker='.',alpha=0.95,color='blue')
plt.scatter(LarDS.sig,LarDS.D,label='MCs',marker='.',alpha=0.95,color='red')
plt.scatter(TMDS.sig,TMDS.D,label='GEHRs',marker='s',alpha=0.95,color='orange')
plt.scatter(TMDSEG.sig,TMDSEG.D,label='EG',marker='.',alpha=0.95,color='orange')
plt.scatter(ARDSA.sig,ARDSA.D,label='GEHRs',marker='.',alpha=0.95,color='green')
plt.scatter(np.log10(WDS.sig),np.log10(WDS.D),label='clumps',marker='.',alpha=0.95,color='lime')

plt.scatter(logdata['log sig [km/s]'],logdata['log L [pc]'],marker='o',label='$σ_{pos}$',color='black')
plt.scatter(logdata['log siglos [km/s]'],logdata['log L [pc]'],marker='x',label='$σ_{los}$',color='black')


ax.set(
#    ylim  = [36, 43],
#    xlim  = [1, 150],
)
#ax.set_facecolor('whitesmoke')
#plt.yscale('log')

ax.set(ylabel='Log D [pc]', xlabel='Log $σ$ [km s$^{-1}$]')
plt.legend()
fig.savefig('plots//d_vs_s_global.pdf', bbox_inches='tight')

# %%
global_sig = pd.concat([MelDS.sig,LarDS.sig,TMDS.sig,TMDSEG.sig,ARDSA.sig,np.log10(WDS.sig),logdata['log sig [km/s]']], axis = 0)
global_D = pd.concat([MelDS.D,LarDS.D,TMDS.D,TMDSEG.D,ARDSA.D,np.log10(WDS.D),logdata['log L [pc]']], axis = 0)

# %%
global_sig_er = (global_sig *.05)/global_sig 
global_D_er = (global_D *.05)/global_D

# %%
X, Xe, Y, Ye = [global_sig, global_sig_er, global_D, global_D_er]
lm = linmix.LinMix(X, Y, Xe, Ye, K=2)
lm.run_mcmc()
# Out:
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99301106 0.99329723 1.00766721 1.03335658 1.00283205 0.99713189]
#
# Iteration:  200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99975488 0.99835804 1.01175529 1.02385936 1.00360458 1.00391038]
#
# Iteration:  300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00062075 0.99917871 1.01292804 1.01498937 1.0035846  1.0029469 ]
#
# Iteration:  400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.000353   1.00023502 1.00851667 1.01259696 1.00269093 1.00054543]
#
# Iteration:  500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00099345 1.00051884 1.00596474 1.01336742 1.00276836 1.00139103]
#
# Iteration:  600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00026448 0.99968593 1.00569879 1.01148692 1.0009219  1.0004506 ]
#
# Iteration:  700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00142733 1.00072111 1.00691624 1.01205228 1.0014997  1.00158161]
#
# Iteration:  800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00093124 0.99974648 1.00687916 1.01497251 1.00051363 1.00071328]
#
# Iteration:  900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00136447 1.00012388 1.00460932 1.01587831 1.00058191 1.00007498]
#
# Iteration:  1000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00190402 1.00085243 1.00348888 1.01364571 0.99968347 1.00066381]
#
# Iteration:  1100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00188244 1.00100242 1.00363099 1.01089329 0.99947872 1.00122638]
#
# Iteration:  1200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00235712 1.0009476  1.00403796 1.00743215 0.99997425 1.00184456]
#
# Iteration:  1300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00303554 1.0015223  1.00421661 1.00632382 1.00010002 1.00248987]
#
# Iteration:  1400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00214127 1.00127482 1.00564133 1.00532972 0.99981343 1.0027523 ]
#
# Iteration:  1500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00224721 1.00126609 1.00670253 1.00364579 0.99992476 1.00320088]
#
# Iteration:  1600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00152795 1.00073668 1.00771758 1.00317196 0.99982417 1.00379682]
#
# Iteration:  1700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00158411 1.00095073 1.00715417 1.00243114 0.99967089 1.00378543]
#
# Iteration:  1800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00153646 1.00086387 1.00672659 1.00225499 0.99981109 1.00376848]
#
# Iteration:  1900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00150837 1.00097103 1.00519792 1.00213231 0.99973298 1.00262775]
#
# Iteration:  2000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00137312 1.00095424 1.00496399 1.00211896 0.999867   1.00246144]
#
# Iteration:  2100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00154346 1.00090243 1.00474226 1.00172034 0.99973955 1.0024429 ]
#
# Iteration:  2200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00155875 1.00109783 1.00472241 1.00173194 0.99974613 1.0026328 ]
#
# Iteration:  2300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00179875 1.00107784 1.00463993 1.00184466 0.99975035 1.0027405 ]
#
# Iteration:  2400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00141834 1.00065518 1.00471244 1.00235238 0.99979001 1.00258851]
#
# Iteration:  2500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00155803 1.00070095 1.00449114 1.00274484 0.99987675 1.0023403 ]
#
# Iteration:  2600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00186273 1.00085391 1.00448756 1.00253685 0.99991743 1.0026813 ]
#
# Iteration:  2700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00175824 1.00071837 1.00415596 1.0026647  0.99982339 1.00222186]
#
# Iteration:  2800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00139876 1.00052332 1.00352154 1.00251551 0.99984816 1.00206189]
#
# Iteration:  2900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00118079 1.00039332 1.00358558 1.00278214 0.9998921  1.00212134]
#
# Iteration:  3000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00100011 1.00030789 1.00363176 1.00249921 0.99987011 1.0021015 ]
#
# Iteration:  3100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00097703 1.00037978 1.00341867 1.00250725 0.99990676 1.00211783]
#
# Iteration:  3200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00094555 1.00048432 1.00363765 1.00242545 0.99988594 1.00247152]
#
# Iteration:  3300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00082063 1.0004236  1.0036213  1.00215303 0.99997376 1.00272468]
#
# Iteration:  3400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00054372 1.00028425 1.00334178 1.00238605 0.99992671 1.00248852]
#
# Iteration:  3500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00040395 1.00010269 1.00356839 1.00249984 0.99994837 1.00244927]
#
# Iteration:  3600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00045541 1.00010877 1.00374808 1.00309829 0.99999248 1.00264234]
#
# Iteration:  3700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00042736 1.00014687 1.00343923 1.00310098 1.00000524 1.00260229]
#
# Iteration:  3800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00041567 1.00019567 1.0035822  1.0034301  0.99999194 1.00278128]
#
# Iteration:  3900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00030866 1.00013761 1.00383195 1.00351065 0.99996539 1.00307216]
#
# Iteration:  4000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00036314 1.0001627  1.00374621 1.00388905 1.0000104  1.00310157]
#
# Iteration:  4100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00045533 1.00019738 1.00362943 1.00398596 0.99995948 1.00290789]
#
# Iteration:  4200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00053985 1.00025369 1.00314063 1.00450125 1.00001183 1.00253333]
#
# Iteration:  4300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0006518  1.00028871 1.00311165 1.00439908 0.99995889 1.00238047]
#
# Iteration:  4400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00057653 1.00030378 1.0030319  1.0044532  0.99997317 1.00247709]
#
# Iteration:  4500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00068667 1.00033547 1.00292756 1.00471772 1.00004186 1.00231018]
#
# Iteration:  4600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00070948 1.00032264 1.00277338 1.00508087 0.99997829 1.00206857]
#
# Iteration:  4700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.0006934  1.00022598 1.00288245 1.00524255 0.99993222 1.0021326 ]
#
# Iteration:  4800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00060741 1.00024889 1.00294817 1.00511521 0.9999302  1.002203  ]
#
# Iteration:  4900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00051912 1.0002105  1.00273496 1.0051789  0.99997258 1.00210927]
#
# Iteration:  5000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00046184 1.00022107 1.00276507 1.00552032 0.99998001 1.00212969]

# %%
dfchain = pd.DataFrame.from_records(
    lm.chain.tolist(), 
    columns=lm.chain.dtype.names
)
#dfchain

# %%
pearsonr(X, Y)
# Out:
# (0.9500653563098451, 1.6129375654644667e-96)

# %%
pd.DataFrame({"X": X, "Xe": Xe, "Y": Y, "Ye": Ye}).describe()
# Out:
#                 X            Xe           Y            Ye
# count  189.000000  1.890000e+02  189.000000  1.890000e+02
# mean     1.212655  5.000000e-02    2.176320  5.000000e-02
# std      0.751532  7.333663e-18    1.338076  7.210400e-18
# min     -0.453990  5.000000e-02   -0.990260  5.000000e-02
# 25%      0.630000  5.000000e-02    1.233170  5.000000e-02
# 50%      1.321450  5.000000e-02    2.396970  5.000000e-02
# 75%      1.502715  5.000000e-02    2.821210  5.000000e-02
# max      2.684320  5.000000e-02    4.907080  5.000000e-02

# %%
vmin, vmax = -0.5, 3.0
xgrid = np.linspace(vmin, vmax, 200)


fig, ax = plt.subplots(figsize=(10, 10))

ax.errorbar(X, Y, xerr=Xe, yerr=Ye, ls=" ", elinewidth=0.4, alpha=1.0, c="k")
ax.scatter(X, Y, marker=".", s=20/np.hypot(Xe, Ye))
# The original fit
ax.plot(xgrid, dfchain["alpha"].mean() + xgrid*dfchain["beta"].mean(), 
        '-', c="k")


for samp in lm.chain[::100]:
    ax.plot(xgrid, samp["alpha"] + xgrid*samp["beta"], 
        '-', c="r", alpha=0.15, lw=0.35,zorder=0)
    
ax.text(.05, .95,'log  D= (' 
        + str(np.round(dfchain["beta"].mean(),3)) + '$\pm$' + str(np.round(dfchain["beta"].std(),3))
        + ')log $\sigma$+('
        + str(np.round(dfchain["alpha"].mean(),3)) + '$\pm$' + str(np.round(dfchain["alpha"].std(),3))
        + ')',  color='k', transform=ax.transAxes)
    
ax.set(ylabel='Log D [pc]', xlabel='Log $σ$ [km s$^{-1}$]')
fig.savefig('plots//global_d_s.pdf', bbox_inches='tight')

# %% [markdown]
# ## other stuff

# %%
fig, ax=plt.subplots(figsize=(9,9))

plt.scatter(Gal.L,Gal.sig,label='Gallagher 1983',marker='x',alpha=0.85,color='dimgray')
plt.scatter(Ars.L,10**Ars.sig,label='Arsenault 1988',marker='+',alpha=0.85,color='dimgray')
plt.scatter(Ostin.L,Ostin.sig,label='Ostin 2001',marker='o',alpha=0.95,color='darkgray')
plt.scatter(Rozas.L,10**(Rozas.sig),label='Rozas 2006',marker='.',alpha=0.95,color='darkgray')
plt.scatter(Wis.L,Wis.sig,label='Wisnioski 2012',marker='s',alpha=0.75,color='silver')
plt.scatter(Blasco.L,Blasco.sig,label='Blasco 2013',marker='D',alpha=0.75,color='silver')
plt.scatter(Moiseev.L,Moiseev.sig,label='Moiseev 2015',marker='^',alpha=0.75,color='silver')

plt.scatter(logdata['log L(H) [erg s^-1]'],10**(logdata['log sig [km/s]']),marker='o',label='SigPOS',color='black',s=(logdata['log Dist [kpc]']+1.0)*70)
plt.scatter(logdata['log L(H) [erg s^-1]'],10**(logdata['log siglos [km/s]']),marker='v',label='SigLOS',color='black',s=(logdata['log Dist [kpc]']+1.0)*70)

plt.yscale('log')

ax.set(
#    ylim  = [36, 43],
#    xlim  = [1, 150],
)
#ax.set_facecolor('whitesmoke')
ax.set(xlabel='Log(L$_{Hα}$) [erg/s]', ylabel='$σ$ [km s$^{-1}$]')
plt.legend()

# %%
globalL= pd.concat([Moiseev.L, Ostin.L.dropna(),Blasco.L.dropna(),Rozas.L.dropna(),Ars.L.dropna(),Wis.L.dropna(),Gal.L.dropna()], axis=0)
globalS= pd.concat([Moiseev.sig, Ostin.sig.dropna(),Blasco.sig.dropna(),10**Rozas.sig.dropna(),10**Ars.sig.dropna(),Wis.sig.dropna(),Gal.sig.dropna()],  axis=0)
GL=np.concatenate((np.array(globalL), np.array(logdata['log L(H) [erg s^-1]'])))
GS=np.concatenate((np.array(globalS), np.array(10**(logdata['log siglos [km/s]']))))

# %%
GSer = (GS*.05)/GS

# %%
GLer = (GL*.05)/GL

# %%
X, Xe, Y, Ye = [GL, GLer, np.log10(GS), GSer]
lm = linmix.LinMix(X, Y, Xe, Ye, K=2)
lm.run_mcmc()
# Out:
# Iteration:  100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00038942 0.99979515 0.99258132 0.99738327 1.00929217 0.99763094]
#
# Iteration:  200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99860085 0.99854305 0.99983779 1.00362915 0.99764003 0.99727701]
#
# Iteration:  300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99754397 0.99760917 1.00149495 1.01529115 0.99689871 0.99798233]
#
# Iteration:  400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99817317 0.99821458 1.00071093 1.01675795 0.99811726 0.99799088]
#
# Iteration:  500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99827765 0.99829739 0.99873373 1.01753558 0.99942481 0.99891045]
#
# Iteration:  600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99878626 0.99881169 1.00031707 1.01665041 0.9988283  0.99876502]
#
# Iteration:  700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99922628 0.99926112 0.99927508 1.01381567 0.99905317 0.9990848 ]
#
# Iteration:  800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99911342 0.99912169 0.99897571 1.01284153 0.99943858 0.99920325]
#
# Iteration:  900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99953194 0.99954539 0.9989183  1.01644463 0.99920448 0.9992662 ]
#
# Iteration:  1000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99938977 0.99939812 0.99919715 1.01590411 0.99952013 0.99935365]
#
# Iteration:  1100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99937916 0.99939077 0.99996766 1.01368313 0.9996037  0.99933081]
#
# Iteration:  1200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99920568 0.99921348 1.000573   1.01150959 0.9995553  0.99951814]
#
# Iteration:  1300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99930119 0.99930735 1.00030091 1.00833711 0.99989329 0.99946506]
#
# Iteration:  1400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9995942  0.99958409 1.00050654 1.00730986 0.99983316 0.99960532]
#
# Iteration:  1500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99974299 0.99972864 1.00049505 1.00623575 0.99995186 0.99954501]
#
# Iteration:  1600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99968463 0.99967373 1.00063841 1.00624471 1.00014987 0.99955451]
#
# Iteration:  1700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.9996638  0.999657   0.99997162 1.005768   1.00020983 0.99949105]
#
# Iteration:  1800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99992129 0.99991088 0.99983371 1.00610304 1.00054236 0.99950427]
#
# Iteration:  1900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99996753 0.9999565  0.99998883 1.00631944 1.00089759 0.9996663 ]
#
# Iteration:  2000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99973808 0.99973494 0.99998332 1.00595673 1.00109842 0.9999068 ]
#
# Iteration:  2100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99983391 0.99982798 1.00024535 1.00564319 1.00141027 1.00011077]
#
# Iteration:  2200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00003584 1.00001965 1.0003053  1.00600943 1.00157861 1.00021285]
#
# Iteration:  2300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00005356 1.00003035 1.00055838 1.00547415 1.00119835 1.00039064]
#
# Iteration:  2400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00024077 1.00021017 1.00038831 1.0051255  1.00121604 1.00017105]
#
# Iteration:  2500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99994111 0.99992407 1.00056736 1.00539701 1.00126733 1.00028428]
#
# Iteration:  2600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99997475 0.99995322 1.00045528 1.00510494 1.00127453 1.00003512]
#
# Iteration:  2700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99988949 0.99987159 1.00045233 1.00509238 1.00111583 1.00009517]
#
# Iteration:  2800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99990854 0.99989192 1.00036398 1.0052529  1.00110221 1.00007652]
#
# Iteration:  2900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99987004 0.99985858 1.00043962 1.0050613  1.00121186 1.00011078]
#
# Iteration:  3000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99988715 0.99987645 1.00065017 1.00485006 1.00136551 1.00009221]
#
# Iteration:  3100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99995082 0.99994243 1.00057885 1.00481937 1.00139097 1.00009612]
#
# Iteration:  3200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99989551 0.99988933 1.00039564 1.00446331 1.00153007 1.00006228]
#
# Iteration:  3300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99990356 0.99989801 1.000239   1.00493317 1.00144464 0.99989114]
#
# Iteration:  3400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00000953 1.00000339 1.00025401 1.00519179 1.00113772 0.999907  ]
#
# Iteration:  3500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00003986 1.00003407 1.0002358  1.00531326 1.00111802 0.99986349]
#
# Iteration:  3600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00005716 1.00004836 1.00029806 1.00550015 1.00109734 0.99982837]
#
# Iteration:  3700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00010232 1.00009468 1.00024633 1.00545377 1.00107313 0.9998236 ]
#
# Iteration:  3800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00010667 1.00009983 1.00018996 1.00520956 1.00096273 0.99981905]
#
# Iteration:  3900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00011245 1.00010549 1.00017539 1.0051947  1.00088886 0.99984081]
#
# Iteration:  4000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00011675 1.00010932 1.00033101 1.00520742 1.00079105 0.99988254]
#
# Iteration:  4100
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00007556 1.00006896 1.00044815 1.00512856 1.00072353 0.99993361]
#
# Iteration:  4200
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00006805 1.00006254 1.00053596 1.00477184 1.00063006 0.99995299]
#
# Iteration:  4300
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00006138 1.00005376 1.00074749 1.00477138 1.00042483 1.00004267]
#
# Iteration:  4400
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00003305 1.00002758 1.00072996 1.00387706 1.00048749 1.00001036]
#
# Iteration:  4500
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99996927 0.99996641 1.00076235 1.00349915 1.00049421 1.00001592]
#
# Iteration:  4600
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99995157 0.99995097 1.0006819  1.00331972 1.00046988 0.99998791]
#
# Iteration:  4700
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99996282 0.99996164 1.00079384 1.00293278 1.00049027 1.00004578]
#
# Iteration:  4800
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [0.99997376 0.99997114 1.00074628 1.00280717 1.00044423 1.00001108]
#
# Iteration:  4900
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00003952 1.00003619 1.00076625 1.0028135  1.0003698  1.00007076]
#
# Iteration:  5000
# Rhat values for alpha, beta, log(sigma^2), mean(xi), log(var(xi)), atanh(corr(xi, eta)):
# [1.00011956 1.00011505 1.00066126 1.00259705 1.00031168 1.00003341]

# %%
dfchain = pd.DataFrame.from_records(
    lm.chain.tolist(), 
    columns=lm.chain.dtype.names
)
#dfchain

# %%
pearsonr(X, Y)
# Out:
# (0.7695051445501992, 5.232292945471508e-41)

# %%
a = pearsonr(X, Y)

# %%
pd.DataFrame({"X": X, "Xe": Xe, "Y": Y, "Ye": Ye}).describe()
# Out:
#                 X            Xe           Y            Ye
# count  203.000000  2.030000e+02  203.000000  2.030000e+02
# mean    39.752955  5.000000e-02    1.360670  5.000000e-02
# std      1.096698  4.192149e-17    0.206423  4.189020e-17
# min     37.170000  5.000000e-02    0.506911  5.000000e-02
# 25%     39.097000  5.000000e-02    1.252367  5.000000e-02
# 50%     39.620000  5.000000e-02    1.346400  5.000000e-02
# 75%     40.157000  5.000000e-02    1.459998  5.000000e-02
# max     42.622000  5.000000e-02    2.153357  5.000000e-02

# %%
vmin, vmax = 36, 44
xgrid = np.linspace(vmin, vmax, 200)


fig, ax = plt.subplots(figsize=(10, 10))

ax.errorbar(X, Y, xerr=Xe, yerr=Ye, ls=" ", elinewidth=0.4, alpha=1.0, c="k")
ax.scatter(X, Y, marker=".", s=20/np.hypot(Xe, Ye))
# The original fit
ax.plot(xgrid, dfchain["alpha"].mean() + xgrid*dfchain["beta"].mean(), 
        '-', c="k")
for samp in lm.chain[::20]:
    ax.plot(xgrid, samp["alpha"] + xgrid*samp["beta"], 
        '-', c="r", alpha=0.2, lw=0.1)
    
ax.text(.05, .95,'log $\sigma$ = (' 
        + str(np.round(dfchain["beta"].mean(),3)) + '$\pm$' + str(np.round(dfchain["beta"].std(),3))
        + ')log L(H)+('
        + str(np.round(dfchain["alpha"].mean(),3)) + '$\pm$' + str(np.round(dfchain["alpha"].std(),3))
        + ')',  color='k', transform=ax.transAxes)
    
ax.set(
#    xlim=[-0.2, 0.8], ylim=[-0.2, 0.8],
    xlabel=r"log L(H) [erg s^-1]", ylabel=r"log $\sigma$ [km/s]",
)
# Out:
# [Text(0.5, 0, 'log L(H) [erg s^-1]'), Text(0, 0.5, 'log $\\sigma$ [km/s]')]

# %%
print("--- %s seconds ---" % (time.time()-start_time))
# Out:
# --- 90.57937955856323 seconds ---

# %%
# !jupyter nbconvert --to script --no-prompt scaling-relations-catalogue.ipynb
# Out:
# [NbConvertApp] Converting notebook scaling-relations-catalogue.ipynb to script
# [NbConvertApp] Writing 17835 bytes to scaling-relations-catalogue.py
