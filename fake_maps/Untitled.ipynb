# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# $$e^{-\dfrac{1}{2 \pi k r_0}}$$

# %%
x = np.linspace(0,1,100)

# %%
r0 = 32
plt.scatter(x, np.exp(-1/(x*r0)))
# Out:
# C:\Users\javas\AppData\Local\Temp\ipykernel_28480\488976863.py:2: RuntimeWarning: divide by zero encountered in divide
#   plt.scatter(x, np.exp(-1/(x*r0)))
