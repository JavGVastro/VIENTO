# %%
# Parameters
name      = ""
fits_path = ""

# %%
# Parameters
name = "fake_cube_mod_finite_sigE1_m330_r128_N1024_bin1"
fits_path = "fits_ready/fake_cube_mod_finite_sigE1_m330_r128_N1024_bin1.fits"

# %% [raw]
# name      = 'fake_map_mod_finite_m285_r1_N256_bin0'
# fits_path = "fits_ready/" + name + ".fits"

# %%
import time
start_time=time.time()

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import sys
from pathlib import Path
import astropy.units as u
from matplotlib import pyplot as plt
import corner
import json
from astropy.io import fits
from lmfit.model import save_modelresult


# Add path to py_modules 
sys.path.append(str(Path().resolve() / 'py_modules')) # 1 level up = project root

#import strucfunc                   
import strucfunc
import fit_structure_function
import ci_results_compiler
import bfunc
import bplot

# %% [markdown]
# # Velocity Field

# %%
# Loading obs
hdul = fits.open(fits_path)
hdr = hdul[0].header
print(hdul.info())
print(hdr)
sb = hdul['MOM0'].data.astype(float)
vv= hdul['MOM1'].data.astype(float)
# Out:
# Filename: fits_ready/fake_cube_mod_finite_sigE1_m330_r128_N1024_bin1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      28   ()
#   1  MOM0          1 ImageHDU         8   (512, 512)   float64
#   2  MOM1          1 ImageHDU         8   (512, 512)   float64
# None
# SIMPLE  =                    T / conforms to FITS standard                      BITPIX  =                    8 / array data type                                NAXIS   =                    0 / number of array dimensions                     EXTEND  =                    T                                                  FILE    = 'fake_cube_mod_finite_sigE1_m330_r128_N1024_bin1' / Fits file name    NAME_ID = 'fake_cube_mod_finite_sigE1_m330_r128_N1024_bin1' / pipeline identifieREG     = 'Synthetic 3D map'   / Region catalog name                            NAME_REG= 'Synthetic 3D map'   / Region name                                    REG_ID  = 'Synthetic 3D map'   / Region identifier                              TYPE_OBJ= 'NaN     '           / Type object                                    DIST    =                    1 / Distance in parsecs                            INSTR   = 'NaN     '           / Instrument                                     LINE    = 'NaN     '           / Emission line name                             LINE_ID = 'NaN     '           / Emission line identifier                       L_REST  =                    0 / Emission line name                             SIG     =  0.19899108725839257 / Standard deviation vel map                     SIG2    =  0.03959745280827721 / Vel Variance map                               S0      =                    0 / Atmospheric seeing                             BOX_SIZE=               1024.0 / Observational box_size                         PC      =                    1 / parsec convertion                              PIX     =                    2 / Instrument pixel scale                         BINSIZE =                    1 / Spatial binning factor                         NOISE   =                    0 / Instrumental noise                             M3D     =                  0.3 / k = 3 + m3D                                    RA      =                128.0 / Artificial correlation length                  SEED1   =             18940425 / Random seed velocity                           SEED2   =             19390501 / Random seed surfavebrightness                  AUTHOR  = 'J. Garcia-Vazquez'  / File creator                                   END

# %%
with fits.open(fits_path) as hdul:
    hdr = hdul[0].header

hdr
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# FILE    = 'fake_cube_mod_finite_sigE1_m330_r128_N1024_bin1' / Fits file name
# NAME_ID = 'fake_cube_mod_finite_sigE1_m330_r128_N1024_bin1' / pipeline identifie
# REG     = 'Synthetic 3D map'   / Region catalog name
# NAME_REG= 'Synthetic 3D map'   / Region name
# REG_ID  = 'Synthetic 3D map'   / Region identifier
# TYPE_OBJ= 'NaN     '           / Type object
# DIST    =                    1 / Distance in parsecs
# INSTR   = 'NaN     '           / Instrument
# LINE    = 'NaN     '           / Emission line name
# LINE_ID = 'NaN     '           / Emission line identifier
# L_REST  =                    0 / Emission line name
# SIG     =  0.19899108725839257 / Standard deviation vel map
# SIG2    =  0.03959745280827721 / Vel Variance map
# S0      =                    0 / Atmospheric seeing
# BOX_SIZE=               1024.0 / Observational box_size
# PC      =                    1 / parsec convertion
# PIX     =                    2 / Instrument pixel scale
# BINSIZE =                    1 / Spatial binning factor
# NOISE   =                    0 / Instrumental noise
# M3D     =                  0.3 / k = 3 + m3D
# RA      =                128.0 / Artificial correlation length
# SEED1   =             18940425 / Random seed velocity
# SEED2   =             19390501 / Random seed surfavebrightness
# AUTHOR  = 'J. Garcia-Vazquez'  / File creator

# %%
m3D      = hdul[0].header['M3D']
ra       = hdul[0].header['RA']
sig      = hdul[0].header['SIG']
sig2     = hdul[0].header['SIG2']
s0       = hdul[0].header['S0']
noise    = hdul[0].header['NOISE']
box_size = hdul[0].header['BOX_SIZE']
pc       = hdul[0].header['PC']
pix      = hdul[0].header['PIX']
line     = hdul[0].header['LINE']
binsize  = hdul[0].header['BINSIZE']

# %%
fig, (ax, axx) = plt.subplots(
    1,
    2,
    sharey=True,
    figsize=(10, 4),
)
imshow_kwds = dict(origin="lower", cmap="RdBu_r")
imshow_kwds2 = dict(origin="lower", cmap="magma")
im = ax.imshow(vv, **imshow_kwds)
cbar = fig.colorbar(im, ax=[ax])
cbar.set_label("$\sigma$ (-)", rotation=270, labelpad=15)
im = axx.imshow(sb, **imshow_kwds2)
cbar = fig.colorbar(im, ax=[axx])
cbar.set_label("rad. vel. (km/s)", rotation=270, labelpad=15)

ax.set_xlabel("pix")
ax.set_ylabel("pix")
axx.set_xlabel("pix")
ax.set_title("Moment 1")
axx.set_title("Moment 0")
# Out:
# Text(0.5, 1.0, 'Moment 0')

# %% [markdown]
# # Structure function

# %%
rslt = strucfunc.strucfunc_numba_parallel(vv, dlogr=0.05)
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# /Users/javier/fake_binning_1024/py_modules/strucfunc.py:83: RuntimeWarning: invalid value encountered in divide
#   'Unweighted B(r)': sf/nsf,
# /Users/javier/fake_binning_1024/py_modules/strucfunc.py:84: RuntimeWarning: invalid value encountered in divide
#   'Weighted B(r)': wsf/weight}

# %%
rslt_ = pd.DataFrame(rslt)

# %%
rslt["Unweighted mean velocity"] = np.mean(vv)
rslt["Unweighted sigma^2"] = np.var(vv)
#v0w = rslt["Weighted mean velocity"] = np.average(vv, weights=sb)
#rslt["Weighted sigma^2"] = np.average((vv - v0w)**2, weights=sb)

# %%
b2    = rslt['Unweighted B(r)']
#b2w   = rslt['Weighted B(r)']
e_b2  = b2  *.1
#e_b2w = b2w  *.1

s     = 10**rslt['log10 r'] * pix * pc
e_s   = s  *.1
sig2  = rslt['Unweighted sigma^2']
#sig2w = rslt['Weighted sigma^2']

sig   = sig2**0.5

# %%
#r0    = np.interp(sig2, b2[1:35], s[1:35])
r0    = ra
m     = m3D

rgrid = np.linspace(s[0], s[:-1])

fig, ax = plt.subplots(figsize=(8, 6))

ax.errorbar(s, b2, yerr=e_b2, xerr=e_s, fmt='o', alpha=0.4,color="blue")
#ax.errorbar(s, b2w, yerr=e_b2w, xerr=e_s, fmt='x', alpha=0.4,color="green")

ax.axhline(sig2, ls='-')
ax.axvline(r0, ls='-')

ax.plot(rgrid, bfunc.bfunc00s(rgrid, r0, sig2, m), color="0.8")
ax.plot(rgrid, bfunc.bfunc03s(rgrid, r0, sig2, m, s0, noise), color="black")
#ax.plot(rgrid, bfunc.bfunc04s(rgrid, r0, sig2, m, s0, noise, box_size), color="black")


ax.set(xscale='log', yscale='log', 
       xlabel='separation,pc',
       ylabel=r'$b^2,\ \mathrm{km^2\ s^{-2}}$'
      )
None

plt.show()

# %% [markdown]
# # Export

# %%
from astropy.table import Table


df =  rslt_.copy()

# Flatten MultiIndex columns like ('s','count') -> "s_count"
if isinstance(df.columns, pd.MultiIndex):
    df.columns = ["_".join(map(str, col)).strip() for col in df.columns.to_flat_index()]
else:
    df.columns = [str(c) for c in df.columns]

# (Optional) drop index to avoid it becoming an extra column
df = df.reset_index(drop=True)

t = Table.from_pandas(df)
new_hdu = fits.BinTableHDU(t, name="TABLE")

# %%
with fits.open(fits_path, mode="readonly") as hdul:
    hdus = [h.copy() for h in hdul]   # copy existing HDUs

hdus.append(new_hdu)
fits.HDUList(hdus).writeto(fits_path, overwrite=True)

# %%
# Test import

from astropy.table import Table
t = Table.read(fits_path, hdu="TABLE")
df_loaded = t.to_pandas()
df_loaded
# Out:
#     log10 r      Sum dv^2   Sum weights  Sum w * dv^2     N pairs  \
# 0      0.00  4.032037e+02  2.616320e+05  4.032037e+02      261632
# 1      0.05  0.000000e+00  0.000000e+00  0.000000e+00           0
# 2      0.10  0.000000e+00  0.000000e+00  0.000000e+00           0
# 3      0.15  1.493495e+03  5.222420e+05  1.493495e+03      522242
# 4      0.20  0.000000e+00  0.000000e+00  0.000000e+00           0
# 5      0.25  0.000000e+00  0.000000e+00  0.000000e+00           0
# 6      0.30  6.336822e+03  1.303560e+06  6.336822e+03     1303560
# 7      0.35  0.000000e+00  0.000000e+00  0.000000e+00           0
# 8      0.40  0.000000e+00  0.000000e+00  0.000000e+00           0
# 9      0.45  5.087837e+03  7.808080e+05  5.087837e+03      780808
# 10     0.50  7.807605e+03  1.040396e+06  7.807605e+03     1040396
# 11     0.55  8.924760e+03  1.038360e+06  8.924760e+03     1038360
# 12     0.60  1.771485e+04  1.816610e+06  1.771485e+04     1816610
# 13     0.65  2.609561e+04  2.330192e+06  2.609561e+04     2330192
# 14     0.70  2.586681e+04  2.070588e+06  2.586681e+04     2070588
# 15     0.75  3.917781e+04  2.841716e+06  3.917781e+04     2841716
# 16     0.80  7.594644e+04  4.897558e+06  7.594644e+04     4897558
# 17     0.85  7.074845e+04  4.112740e+06  7.074845e+04     4112740
# 18     0.90  1.106960e+05  5.904900e+06  1.106960e+05     5904900
# 19     0.95  1.642061e+05  7.936402e+06  1.642061e+05     7936402
# 20     1.00  2.685219e+05  1.174631e+07  2.685219e+05    11746312
# 21     1.05  3.001226e+05  1.195235e+07  3.001226e+05    11952348
# 22     1.10  4.139961e+05  1.521031e+07  4.139961e+05    15210306
# 23     1.15  6.355173e+05  2.144552e+07  6.355173e+05    21445522
# 24     1.20  7.730486e+05  2.412130e+07  7.730486e+05    24121296
# 25     1.25  1.086811e+06  3.148390e+07  1.086811e+06    31483902
# 26     1.30  1.525104e+06  4.100620e+07  1.525104e+06    41006198
# 27     1.35  2.005929e+06  5.008448e+07  2.005929e+06    50084482
# 28     1.40  2.646395e+06  6.148407e+07  2.646395e+06    61484074
# 29     1.45  3.509223e+06  7.601512e+07  3.509223e+06    76015122
# 30     1.50  4.935252e+06  9.958252e+07  4.935252e+06    99582516
# 31     1.55  6.188324e+06  1.166074e+08  6.188324e+06   116607374
# 32     1.60  8.664451e+06  1.530802e+08  8.664451e+06   153080172
# 33     1.65  1.116303e+07  1.860125e+08  1.116303e+07   186012540
# 34     1.70  1.473323e+07  2.333250e+08  1.473323e+07   233325004
# 35     1.75  1.895352e+07  2.872972e+08  1.895352e+07   287297180
# 36     1.80  2.406181e+07  3.523751e+08  2.406181e+07   352375078
# 37     1.85  3.082739e+07  4.403311e+08  3.082739e+07   440331122
# 38     1.90  3.801715e+07  5.326063e+08  3.801715e+07   532606296
# 39     1.95  4.738309e+07  6.519142e+08  4.738309e+07   651914158
# 40     2.00  5.960001e+07  7.991930e+08  5.960001e+07   799193018
# 41     2.05  7.419404e+07  9.614501e+08  7.419404e+07   961450074
# 42     2.10  9.383449e+07  1.165692e+09  9.383449e+07  1165692238
# 43     2.15  1.166680e+08  1.389348e+09  1.166680e+08  1389348240
# 44     2.20  1.424519e+08  1.644328e+09  1.424519e+08  1644328386
# 45     2.25  1.708990e+08  1.930905e+09  1.708990e+08  1930904948
# 46     2.30  1.978862e+08  2.231925e+09  1.978862e+08  2231925484
# 47     2.35  2.216844e+08  2.550682e+09  2.216844e+08  2550682108
# 48     2.40  2.428388e+08  2.841899e+09  2.428388e+08  2841898542
# 49     2.45  2.571689e+08  3.083079e+09  2.571689e+08  3083078552
# 50     2.50  2.479867e+08  3.213664e+09  2.479867e+08  3213663986
# 51     2.55  2.385183e+08  3.157833e+09  2.385183e+08  3157833012
# 52     2.60  2.113578e+08  2.799031e+09  2.113578e+08  2799031286
# 53     2.65  1.488934e+08  1.993622e+09  1.488934e+08  1993621954
# 54     2.70  5.896648e+07  8.326328e+08  5.896648e+07   832632808
# 55     2.75  1.270128e+07  2.360935e+08  1.270128e+07   236093508
# 56     2.80  1.603701e+06  2.669131e+07  1.603701e+06    26691314
#
#     Unweighted B(r)  Weighted B(r)
# 0          0.001541       0.001541
# 1               NaN            NaN
# 2               NaN            NaN
# 3          0.002860       0.002860
# 4               NaN            NaN
# 5               NaN            NaN
# 6          0.004861       0.004861
# 7               NaN            NaN
# 8               NaN            NaN
# 9          0.006516       0.006516
# 10         0.007504       0.007504
# 11         0.008595       0.008595
# 12         0.009752       0.009752
# 13         0.011199       0.011199
# 14         0.012492       0.012492
# 15         0.013787       0.013787
# 16         0.015507       0.015507
# 17         0.017202       0.017202
# 18         0.018746       0.018746
# 19         0.020690       0.020690
# 20         0.022860       0.022860
# 21         0.025110       0.025110
# 22         0.027218       0.027218
# 23         0.029634       0.029634
# 24         0.032048       0.032048
# 25         0.034520       0.034520
# 26         0.037192       0.037192
# 27         0.040051       0.040051
# 28         0.043042       0.043042
# 29         0.046165       0.046165
# 30         0.049559       0.049559
# 31         0.053070       0.053070
# 32         0.056601       0.056601
# 33         0.060012       0.060012
# 34         0.063145       0.063145
# 35         0.065972       0.065972
# 36         0.068285       0.068285
# 37         0.070010       0.070010
# 38         0.071379       0.071379
# 39         0.072683       0.072683
# 40         0.074575       0.074575
# 41         0.077169       0.077169
# 42         0.080497       0.080497
# 43         0.083973       0.083973
# 44         0.086632       0.086632
# 45         0.088507       0.088507
# 46         0.088662       0.088662
# 47         0.086912       0.086912
# 48         0.085449       0.085449
# 49         0.083413       0.083413
# 50         0.077166       0.077166
# 51         0.075532       0.075532
# 52         0.075511       0.075511
# 53         0.074685       0.074685
# 54         0.070819       0.070819
# 55         0.053798       0.053798
# 56         0.060083       0.060083

# %%
print("--- %s seconds ---" % (time.time()-start_time))
# Out:
# --- 21.862102031707764 seconds ---
