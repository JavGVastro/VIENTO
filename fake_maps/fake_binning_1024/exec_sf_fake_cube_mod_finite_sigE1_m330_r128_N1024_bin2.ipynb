# %%
# Parameters
name      = ""
fits_path = ""

# %%
# Parameters
name = "fake_cube_mod_finite_sigE1_m330_r128_N1024_bin2"
fits_path = "fits_ready/fake_cube_mod_finite_sigE1_m330_r128_N1024_bin2.fits"

# %% [raw]
# name      = 'fake_map_mod_finite_m285_r1_N256_bin0'
# fits_path = "fits_ready/" + name + ".fits"

# %%
import time
start_time=time.time()

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import sys
from pathlib import Path
import astropy.units as u
from matplotlib import pyplot as plt
import corner
import json
from astropy.io import fits
from lmfit.model import save_modelresult


# Add path to py_modules 
sys.path.append(str(Path().resolve() / 'py_modules')) # 1 level up = project root

#import strucfunc                   
import strucfunc
import fit_structure_function
import ci_results_compiler
import bfunc
import bplot

# %% [markdown]
# # Velocity Field

# %%
# Loading obs
hdul = fits.open(fits_path)
hdr = hdul[0].header
print(hdul.info())
print(hdr)
sb = hdul['MOM0'].data.astype(float)
vv= hdul['MOM1'].data.astype(float)
# Out:
# Filename: fits_ready/fake_cube_mod_finite_sigE1_m330_r128_N1024_bin2.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      28   ()
#   1  MOM0          1 ImageHDU         8   (256, 256)   float64
#   2  MOM1          1 ImageHDU         8   (256, 256)   float64
# None
# SIMPLE  =                    T / conforms to FITS standard                      BITPIX  =                    8 / array data type                                NAXIS   =                    0 / number of array dimensions                     EXTEND  =                    T                                                  FILE    = 'fake_cube_mod_finite_sigE1_m330_r128_N1024_bin2' / Fits file name    NAME_ID = 'fake_cube_mod_finite_sigE1_m330_r128_N1024_bin2' / pipeline identifieREG     = 'Synthetic 3D map'   / Region catalog name                            NAME_REG= 'Synthetic 3D map'   / Region name                                    REG_ID  = 'Synthetic 3D map'   / Region identifier                              TYPE_OBJ= 'NaN     '           / Type object                                    DIST    =                    1 / Distance in parsecs                            INSTR   = 'NaN     '           / Instrument                                     LINE    = 'NaN     '           / Emission line name                             LINE_ID = 'NaN     '           / Emission line identifier                       L_REST  =                    0 / Emission line name                             SIG     =  0.19703309880767958 / Standard deviation vel map                     SIG2    =  0.03882204202575682 / Vel Variance map                               S0      =                    0 / Atmospheric seeing                             BOX_SIZE=               1024.0 / Observational box_size                         PC      =                    1 / parsec convertion                              PIX     =                    4 / Instrument pixel scale                         BINSIZE =                    2 / Spatial binning factor                         NOISE   =                    0 / Instrumental noise                             M3D     =                  0.3 / k = 3 + m3D                                    RA      =                128.0 / Artificial correlation length                  SEED1   =             18940425 / Random seed velocity                           SEED2   =             19390501 / Random seed surfavebrightness                  AUTHOR  = 'J. Garcia-Vazquez'  / File creator                                   END

# %%
with fits.open(fits_path) as hdul:
    hdr = hdul[0].header

hdr
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# FILE    = 'fake_cube_mod_finite_sigE1_m330_r128_N1024_bin2' / Fits file name
# NAME_ID = 'fake_cube_mod_finite_sigE1_m330_r128_N1024_bin2' / pipeline identifie
# REG     = 'Synthetic 3D map'   / Region catalog name
# NAME_REG= 'Synthetic 3D map'   / Region name
# REG_ID  = 'Synthetic 3D map'   / Region identifier
# TYPE_OBJ= 'NaN     '           / Type object
# DIST    =                    1 / Distance in parsecs
# INSTR   = 'NaN     '           / Instrument
# LINE    = 'NaN     '           / Emission line name
# LINE_ID = 'NaN     '           / Emission line identifier
# L_REST  =                    0 / Emission line name
# SIG     =  0.19703309880767958 / Standard deviation vel map
# SIG2    =  0.03882204202575682 / Vel Variance map
# S0      =                    0 / Atmospheric seeing
# BOX_SIZE=               1024.0 / Observational box_size
# PC      =                    1 / parsec convertion
# PIX     =                    4 / Instrument pixel scale
# BINSIZE =                    2 / Spatial binning factor
# NOISE   =                    0 / Instrumental noise
# M3D     =                  0.3 / k = 3 + m3D
# RA      =                128.0 / Artificial correlation length
# SEED1   =             18940425 / Random seed velocity
# SEED2   =             19390501 / Random seed surfavebrightness
# AUTHOR  = 'J. Garcia-Vazquez'  / File creator

# %%
m3D      = hdul[0].header['M3D']
ra       = hdul[0].header['RA']
sig      = hdul[0].header['SIG']
sig2     = hdul[0].header['SIG2']
s0       = hdul[0].header['S0']
noise    = hdul[0].header['NOISE']
box_size = hdul[0].header['BOX_SIZE']
pc       = hdul[0].header['PC']
pix      = hdul[0].header['PIX']
line     = hdul[0].header['LINE']
binsize  = hdul[0].header['BINSIZE']

# %%
fig, (ax, axx) = plt.subplots(
    1,
    2,
    sharey=True,
    figsize=(10, 4),
)
imshow_kwds = dict(origin="lower", cmap="RdBu_r")
imshow_kwds2 = dict(origin="lower", cmap="magma")
im = ax.imshow(vv, **imshow_kwds)
cbar = fig.colorbar(im, ax=[ax])
cbar.set_label("$\sigma$ (-)", rotation=270, labelpad=15)
im = axx.imshow(sb, **imshow_kwds2)
cbar = fig.colorbar(im, ax=[axx])
cbar.set_label("rad. vel. (km/s)", rotation=270, labelpad=15)

ax.set_xlabel("pix")
ax.set_ylabel("pix")
axx.set_xlabel("pix")
ax.set_title("Moment 1")
axx.set_title("Moment 0")
# Out:
# Text(0.5, 1.0, 'Moment 0')

# %% [markdown]
# # Structure function

# %%
rslt = strucfunc.strucfunc_numba_parallel(vv, dlogr=0.05)
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# /Users/javier/fake_binning_1024/py_modules/strucfunc.py:83: RuntimeWarning: invalid value encountered in divide
#   'Unweighted B(r)': sf/nsf,
# /Users/javier/fake_binning_1024/py_modules/strucfunc.py:84: RuntimeWarning: invalid value encountered in divide
#   'Weighted B(r)': wsf/weight}

# %%
rslt_ = pd.DataFrame(rslt)

# %%
rslt["Unweighted mean velocity"] = np.mean(vv)
rslt["Unweighted sigma^2"] = np.var(vv)
#v0w = rslt["Weighted mean velocity"] = np.average(vv, weights=sb)
#rslt["Weighted sigma^2"] = np.average((vv - v0w)**2, weights=sb)

# %%
b2    = rslt['Unweighted B(r)']
#b2w   = rslt['Weighted B(r)']
e_b2  = b2  *.1
#e_b2w = b2w  *.1

s     = 10**rslt['log10 r'] * pix * pc
e_s   = s  *.1
sig2  = rslt['Unweighted sigma^2']
#sig2w = rslt['Weighted sigma^2']

sig   = sig2**0.5

# %%
#r0    = np.interp(sig2, b2[1:35], s[1:35])
r0    = ra
m     = m3D

rgrid = np.linspace(s[0], s[:-1])

fig, ax = plt.subplots(figsize=(8, 6))

ax.errorbar(s, b2, yerr=e_b2, xerr=e_s, fmt='o', alpha=0.4,color="blue")
#ax.errorbar(s, b2w, yerr=e_b2w, xerr=e_s, fmt='x', alpha=0.4,color="green")

ax.axhline(sig2, ls='-')
ax.axvline(r0, ls='-')

ax.plot(rgrid, bfunc.bfunc00s(rgrid, r0, sig2, m), color="0.8")
ax.plot(rgrid, bfunc.bfunc03s(rgrid, r0, sig2, m, s0, noise), color="black")
#ax.plot(rgrid, bfunc.bfunc04s(rgrid, r0, sig2, m, s0, noise, box_size), color="black")


ax.set(xscale='log', yscale='log', 
       xlabel='separation,pc',
       ylabel=r'$b^2,\ \mathrm{km^2\ s^{-2}}$'
      )
None

plt.show()

# %% [markdown]
# # Export

# %%
from astropy.table import Table


df =  rslt_.copy()

# Flatten MultiIndex columns like ('s','count') -> "s_count"
if isinstance(df.columns, pd.MultiIndex):
    df.columns = ["_".join(map(str, col)).strip() for col in df.columns.to_flat_index()]
else:
    df.columns = [str(c) for c in df.columns]

# (Optional) drop index to avoid it becoming an extra column
df = df.reset_index(drop=True)

t = Table.from_pandas(df)
new_hdu = fits.BinTableHDU(t, name="TABLE")

# %%
with fits.open(fits_path, mode="readonly") as hdul:
    hdus = [h.copy() for h in hdul]   # copy existing HDUs

hdus.append(new_hdu)
fits.HDUList(hdus).writeto(fits_path, overwrite=True)

# %%
# Test import

from astropy.table import Table
t = Table.read(fits_path, hdu="TABLE")
df_loaded = t.to_pandas()
df_loaded
# Out:
#     log10 r      Sum dv^2  Sum weights  Sum w * dv^2    N pairs  \
# 0      0.00  1.811600e+02      65280.0  1.811600e+02      65280
# 1      0.05  0.000000e+00          0.0  0.000000e+00          0
# 2      0.10  0.000000e+00          0.0  0.000000e+00          0
# 3      0.15  6.830558e+02     130050.0  6.830558e+02     130050
# 4      0.20  0.000000e+00          0.0  0.000000e+00          0
# 5      0.25  0.000000e+00          0.0  0.000000e+00          0
# 6      0.30  2.845787e+03     324104.0  2.845787e+03     324104
# 7      0.35  0.000000e+00          0.0  0.000000e+00          0
# 8      0.40  0.000000e+00          0.0  0.000000e+00          0
# 9      0.45  2.237374e+03     193800.0  2.237374e+03     193800
# 10     0.50  3.445759e+03     258060.0  3.445759e+03     258060
# 11     0.55  3.884417e+03     257048.0  3.884417e+03     257048
# 12     0.60  7.614539e+03     449570.0  7.614539e+03     449570
# 13     0.65  1.104433e+04     575312.0  1.104433e+04     575312
# 14     0.70  1.087710e+04     511036.0  1.087710e+04     511036
# 15     0.75  1.619057e+04     700020.0  1.619057e+04     700020
# 16     0.80  3.086152e+04    1203734.0  3.086152e+04    1203734
# 17     0.85  2.828947e+04    1007972.0  2.828947e+04    1007972
# 18     0.90  4.350708e+04    1445380.0  4.350708e+04    1445380
# 19     0.95  6.330334e+04    1937042.0  6.330334e+04    1937042
# 20     1.00  1.015449e+05    2859272.0  1.015449e+05    2859272
# 21     1.05  1.115070e+05    2897116.0  1.115070e+05    2897116
# 22     1.10  1.518015e+05    3674690.0  1.518015e+05    3674690
# 23     1.15  2.299089e+05    5155474.0  2.299089e+05    5155474
# 24     1.20  2.772120e+05    5773520.0  2.772120e+05    5773520
# 25     1.25  3.854787e+05    7491838.0  3.854787e+05    7491838
# 26     1.30  5.344562e+05    9701238.0  5.344562e+05    9701238
# 27     1.35  6.877331e+05   11757186.0  6.877331e+05   11757186
# 28     1.40  8.830401e+05   14320938.0  8.830401e+05   14320938
# 29     1.45  1.129639e+06   17540114.0  1.129639e+06   17540114
# 30     1.50  1.516817e+06   22734900.0  1.516817e+06   22734900
# 31     1.55  1.799980e+06   26303374.0  1.799980e+06   26303374
# 32     1.60  2.377624e+06   34062188.0  2.377624e+06   34062188
# 33     1.65  2.898109e+06   40733820.0  2.898109e+06   40733820
# 34     1.70  3.661708e+06   50149068.0  3.661708e+06   50149068
# 35     1.75  4.571315e+06   60431004.0  4.571315e+06   60431004
# 36     1.80  5.709400e+06   72289830.0  5.709400e+06   72289830
# 37     1.85  7.233106e+06   87731826.0  7.233106e+06   87731826
# 38     1.90  8.720945e+06  102476376.0  8.720945e+06  102476376
# 39     1.95  1.046261e+07  120332462.0  1.046261e+07  120332462
# 40     2.00  1.221868e+07  140368314.0  1.221868e+07  140368314
# 41     2.05  1.354246e+07  158782298.0  1.354246e+07  158782298
# 42     2.10  1.495794e+07  178392398.0  1.495794e+07  178392398
# 43     2.15  1.576676e+07  192781200.0  1.576676e+07  192781200
# 44     2.20  1.514419e+07  200564162.0  1.514419e+07  200564162
# 45     2.25  1.458205e+07  196929652.0  1.458205e+07  196929652
# 46     2.30  1.285672e+07  173862636.0  1.285672e+07  173862636
# 47     2.35  9.021069e+06  123283452.0  9.021069e+06  123283452
# 48     2.40  3.508579e+06   50816154.0  3.508579e+06   50816154
# 49     2.45  7.421990e+05   14282052.0  7.421990e+05   14282052
# 50     2.50  9.164705e+04    1557090.0  9.164705e+04    1557090
#
#     Unweighted B(r)  Weighted B(r)
# 0          0.002775       0.002775
# 1               NaN            NaN
# 2               NaN            NaN
# 3          0.005252       0.005252
# 4               NaN            NaN
# 5               NaN            NaN
# 6          0.008780       0.008780
# 7               NaN            NaN
# 8               NaN            NaN
# 9          0.011545       0.011545
# 10         0.013353       0.013353
# 11         0.015112       0.015112
# 12         0.016937       0.016937
# 13         0.019197       0.019197
# 14         0.021284       0.021284
# 15         0.023129       0.023129
# 16         0.025638       0.025638
# 17         0.028066       0.028066
# 18         0.030101       0.030101
# 19         0.032680       0.032680
# 20         0.035514       0.035514
# 21         0.038489       0.038489
# 22         0.041310       0.041310
# 23         0.044595       0.044595
# 24         0.048014       0.048014
# 25         0.051453       0.051453
# 26         0.055092       0.055092
# 27         0.058495       0.058495
# 28         0.061661       0.061661
# 29         0.064403       0.064403
# 30         0.066718       0.066718
# 31         0.068432       0.068432
# 32         0.069802       0.069802
# 33         0.071147       0.071147
# 34         0.073016       0.073016
# 35         0.075645       0.075645
# 36         0.078979       0.078979
# 37         0.082446       0.082446
# 38         0.085102       0.085102
# 39         0.086948       0.086948
# 40         0.087047       0.087047
# 41         0.085289       0.085289
# 42         0.083849       0.083849
# 43         0.081786       0.081786
# 44         0.075508       0.075508
# 45         0.074047       0.074047
# 46         0.073948       0.073948
# 47         0.073173       0.073173
# 48         0.069045       0.069045
# 49         0.051967       0.051967
# 50         0.058858       0.058858

# %%
print("--- %s seconds ---" % (time.time()-start_time))
# Out:
# --- 5.166173934936523 seconds ---
