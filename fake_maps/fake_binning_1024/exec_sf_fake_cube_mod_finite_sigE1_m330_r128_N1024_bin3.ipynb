# %%
# Parameters
name      = ""
fits_path = ""

# %%
# Parameters
name = "fake_cube_mod_finite_sigE1_m330_r128_N1024_bin3"
fits_path = "fits_ready/fake_cube_mod_finite_sigE1_m330_r128_N1024_bin3.fits"

# %% [raw]
# name      = 'fake_map_mod_finite_m285_r1_N256_bin0'
# fits_path = "fits_ready/" + name + ".fits"

# %%
import time
start_time=time.time()

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import sys
from pathlib import Path
import astropy.units as u
from matplotlib import pyplot as plt
import corner
import json
from astropy.io import fits
from lmfit.model import save_modelresult


# Add path to py_modules 
sys.path.append(str(Path().resolve() / 'py_modules')) # 1 level up = project root

#import strucfunc                   
import strucfunc
import fit_structure_function
import ci_results_compiler
import bfunc
import bplot

# %% [markdown]
# # Velocity Field

# %%
# Loading obs
hdul = fits.open(fits_path)
hdr = hdul[0].header
print(hdul.info())
print(hdr)
sb = hdul['MOM0'].data.astype(float)
vv= hdul['MOM1'].data.astype(float)
# Out:
# Filename: fits_ready/fake_cube_mod_finite_sigE1_m330_r128_N1024_bin3.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      28   ()
#   1  MOM0          1 ImageHDU         8   (128, 128)   float64
#   2  MOM1          1 ImageHDU         8   (128, 128)   float64
# None
# SIMPLE  =                    T / conforms to FITS standard                      BITPIX  =                    8 / array data type                                NAXIS   =                    0 / number of array dimensions                     EXTEND  =                    T                                                  FILE    = 'fake_cube_mod_finite_sigE1_m330_r128_N1024_bin3' / Fits file name    NAME_ID = 'fake_cube_mod_finite_sigE1_m330_r128_N1024_bin3' / pipeline identifieREG     = 'Synthetic 3D map'   / Region catalog name                            NAME_REG= 'Synthetic 3D map'   / Region name                                    REG_ID  = 'Synthetic 3D map'   / Region identifier                              TYPE_OBJ= 'NaN     '           / Type object                                    DIST    =                    1 / Distance in parsecs                            INSTR   = 'NaN     '           / Instrument                                     LINE    = 'NaN     '           / Emission line name                             LINE_ID = 'NaN     '           / Emission line identifier                       L_REST  =                    0 / Emission line name                             SIG     =  0.19340651458187832 / Standard deviation vel map                     SIG2    = 0.037406079882710316 / Vel Variance map                               S0      =                    0 / Atmospheric seeing                             BOX_SIZE=               1024.0 / Observational box_size                         PC      =                    1 / parsec convertion                              PIX     =                    8 / Instrument pixel scale                         BINSIZE =                    3 / Spatial binning factor                         NOISE   =                    0 / Instrumental noise                             M3D     =                  0.3 / k = 3 + m3D                                    RA      =                128.0 / Artificial correlation length                  SEED1   =             18940425 / Random seed velocity                           SEED2   =             19390501 / Random seed surfavebrightness                  AUTHOR  = 'J. Garcia-Vazquez'  / File creator                                   END

# %%
with fits.open(fits_path) as hdul:
    hdr = hdul[0].header

hdr
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# FILE    = 'fake_cube_mod_finite_sigE1_m330_r128_N1024_bin3' / Fits file name
# NAME_ID = 'fake_cube_mod_finite_sigE1_m330_r128_N1024_bin3' / pipeline identifie
# REG     = 'Synthetic 3D map'   / Region catalog name
# NAME_REG= 'Synthetic 3D map'   / Region name
# REG_ID  = 'Synthetic 3D map'   / Region identifier
# TYPE_OBJ= 'NaN     '           / Type object
# DIST    =                    1 / Distance in parsecs
# INSTR   = 'NaN     '           / Instrument
# LINE    = 'NaN     '           / Emission line name
# LINE_ID = 'NaN     '           / Emission line identifier
# L_REST  =                    0 / Emission line name
# SIG     =  0.19340651458187832 / Standard deviation vel map
# SIG2    = 0.037406079882710316 / Vel Variance map
# S0      =                    0 / Atmospheric seeing
# BOX_SIZE=               1024.0 / Observational box_size
# PC      =                    1 / parsec convertion
# PIX     =                    8 / Instrument pixel scale
# BINSIZE =                    3 / Spatial binning factor
# NOISE   =                    0 / Instrumental noise
# M3D     =                  0.3 / k = 3 + m3D
# RA      =                128.0 / Artificial correlation length
# SEED1   =             18940425 / Random seed velocity
# SEED2   =             19390501 / Random seed surfavebrightness
# AUTHOR  = 'J. Garcia-Vazquez'  / File creator

# %%
m3D      = hdul[0].header['M3D']
ra       = hdul[0].header['RA']
sig      = hdul[0].header['SIG']
sig2     = hdul[0].header['SIG2']
s0       = hdul[0].header['S0']
noise    = hdul[0].header['NOISE']
box_size = hdul[0].header['BOX_SIZE']
pc       = hdul[0].header['PC']
pix      = hdul[0].header['PIX']
line     = hdul[0].header['LINE']
binsize  = hdul[0].header['BINSIZE']

# %%
fig, (ax, axx) = plt.subplots(
    1,
    2,
    sharey=True,
    figsize=(10, 4),
)
imshow_kwds = dict(origin="lower", cmap="RdBu_r")
imshow_kwds2 = dict(origin="lower", cmap="magma")
im = ax.imshow(vv, **imshow_kwds)
cbar = fig.colorbar(im, ax=[ax])
cbar.set_label("$\sigma$ (-)", rotation=270, labelpad=15)
im = axx.imshow(sb, **imshow_kwds2)
cbar = fig.colorbar(im, ax=[axx])
cbar.set_label("rad. vel. (km/s)", rotation=270, labelpad=15)

ax.set_xlabel("pix")
ax.set_ylabel("pix")
axx.set_xlabel("pix")
ax.set_title("Moment 1")
axx.set_title("Moment 0")
# Out:
# Text(0.5, 1.0, 'Moment 0')

# %% [markdown]
# # Structure function

# %%
rslt = strucfunc.strucfunc_numba_parallel(vv, dlogr=0.05)
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# /Users/javier/fake_binning_1024/py_modules/strucfunc.py:83: RuntimeWarning: invalid value encountered in divide
#   'Unweighted B(r)': sf/nsf,
# /Users/javier/fake_binning_1024/py_modules/strucfunc.py:84: RuntimeWarning: invalid value encountered in divide
#   'Weighted B(r)': wsf/weight}

# %%
rslt_ = pd.DataFrame(rslt)

# %%
rslt["Unweighted mean velocity"] = np.mean(vv)
rslt["Unweighted sigma^2"] = np.var(vv)
#v0w = rslt["Weighted mean velocity"] = np.average(vv, weights=sb)
#rslt["Weighted sigma^2"] = np.average((vv - v0w)**2, weights=sb)

# %%
b2    = rslt['Unweighted B(r)']
#b2w   = rslt['Weighted B(r)']
e_b2  = b2  *.1
#e_b2w = b2w  *.1

s     = 10**rslt['log10 r'] * pix * pc
e_s   = s  *.1
sig2  = rslt['Unweighted sigma^2']
#sig2w = rslt['Weighted sigma^2']

sig   = sig2**0.5

# %%
#r0    = np.interp(sig2, b2[1:35], s[1:35])
r0    = ra
m     = m3D

rgrid = np.linspace(s[0], s[:-1])

fig, ax = plt.subplots(figsize=(8, 6))

ax.errorbar(s, b2, yerr=e_b2, xerr=e_s, fmt='o', alpha=0.4,color="blue")
#ax.errorbar(s, b2w, yerr=e_b2w, xerr=e_s, fmt='x', alpha=0.4,color="green")

ax.axhline(sig2, ls='-')
ax.axvline(r0, ls='-')

ax.plot(rgrid, bfunc.bfunc00s(rgrid, r0, sig2, m), color="0.8")
ax.plot(rgrid, bfunc.bfunc03s(rgrid, r0, sig2, m, s0, noise), color="black")
#ax.plot(rgrid, bfunc.bfunc04s(rgrid, r0, sig2, m, s0, noise, box_size), color="black")


ax.set(xscale='log', yscale='log', 
       xlabel='separation,pc',
       ylabel=r'$b^2,\ \mathrm{km^2\ s^{-2}}$'
      )
None

plt.show()

# %% [markdown]
# # Export

# %%
from astropy.table import Table


df =  rslt_.copy()

# Flatten MultiIndex columns like ('s','count') -> "s_count"
if isinstance(df.columns, pd.MultiIndex):
    df.columns = ["_".join(map(str, col)).strip() for col in df.columns.to_flat_index()]
else:
    df.columns = [str(c) for c in df.columns]

# (Optional) drop index to avoid it becoming an extra column
df = df.reset_index(drop=True)

t = Table.from_pandas(df)
new_hdu = fits.BinTableHDU(t, name="TABLE")

# %%
with fits.open(fits_path, mode="readonly") as hdul:
    hdus = [h.copy() for h in hdul]   # copy existing HDUs

hdus.append(new_hdu)
fits.HDUList(hdus).writeto(fits_path, overwrite=True)

# %%
# Test import

from astropy.table import Table
t = Table.read(fits_path, hdu="TABLE")
df_loaded = t.to_pandas()
df_loaded
# Out:
#     log10 r       Sum dv^2  Sum weights   Sum w * dv^2   N pairs  \
# 0      0.00      78.606250      16256.0      78.606250     16256
# 1      0.05       0.000000          0.0       0.000000         0
# 2      0.10       0.000000          0.0       0.000000         0
# 3      0.15     298.528702      32258.0     298.528702     32258
# 4      0.20       0.000000          0.0       0.000000         0
# 5      0.25       0.000000          0.0       0.000000         0
# 6      0.30    1197.255451      80136.0    1197.255451     80136
# 7      0.35       0.000000          0.0       0.000000         0
# 8      0.40       0.000000          0.0       0.000000         0
# 9      0.45     908.598683      47752.0     908.598683     47752
# 10     0.50    1394.244208      63500.0    1394.244208     63500
# 11     0.55    1540.862319      63000.0    1540.862319     63000
# 12     0.60    2951.108360     110114.0    2951.108360    110114
# 13     0.65    4187.438467     140240.0    4187.438467    140240
# 14     0.70    4065.336106     124476.0    4065.336106    124476
# 15     0.75    5956.118883     169844.0    5956.118883    169844
# 16     0.80   11173.286815     290710.0   11173.286815    290710
# 17     0.85   10083.762059     242020.0   10083.762059    242020
# 18     0.90   15439.897362     346116.0   15439.897362    346116
# 19     0.95   22221.385327     461074.0   22221.385327    461074
# 20     1.00   35247.413543     676744.0   35247.413543    676744
# 21     1.05   37771.095688     679644.0   37771.095688    679644
# 22     1.10   50141.218508     856002.0   50141.218508    856002
# 23     1.15   73076.877304    1188370.0   73076.877304   1188370
# 24     1.20   84183.028787    1318224.0   84183.028787   1318224
# 25     1.25  110637.831213    1688958.0  110637.831213   1688958
# 26     1.30  144595.527135    2158838.0  144595.527135   2158838
# 27     1.35  175500.919855    2571394.0  175500.919855   2571394
# 28     1.40  216152.483532    3076522.0  216152.483532   3076522
# 29     1.45  268331.509282    3687186.0  268331.509282   3687186
# 30     1.50  354787.298676    4660020.0  354787.298676   4660020
# 31     1.55  416722.131982    5235854.0  416722.131982   5235854
# 32     1.60  538709.760201    6551148.0  538709.760201   6551148
# 33     1.65  631700.372867    7514364.0  631700.372867   7514364
# 34     1.70  739799.169156    8794444.0  739799.169156   8794444
# 35     1.75  820249.183265    9961628.0  820249.183265   9961628
# 36     1.80  893938.013443   11037862.0  893938.013443  11037862
# 37     1.85  957614.160380   12144626.0  957614.160380  12144626
# 38     1.90  903663.901952   12454104.0  903663.901952  12454104
# 39     1.95  871814.378228   12221230.0  871814.378228  12221230
# 40     2.00  771501.657891   10857146.0  771501.657891  10857146
# 41     2.05  534339.569349    7582938.0  534339.569349   7582938
# 42     2.10  205108.454990    3109190.0  205108.454990   3109190
# 43     2.15   42116.018911     864104.0   42116.018911    864104
# 44     2.20    5111.428119      91086.0    5111.428119     91086
#
#     Unweighted B(r)  Weighted B(r)
# 0          0.004836       0.004836
# 1               NaN            NaN
# 2               NaN            NaN
# 3          0.009254       0.009254
# 4               NaN            NaN
# 5               NaN            NaN
# 6          0.014940       0.014940
# 7               NaN            NaN
# 8               NaN            NaN
# 9          0.019027       0.019027
# 10         0.021957       0.021957
# 11         0.024458       0.024458
# 12         0.026800       0.026800
# 13         0.029859       0.029859
# 14         0.032660       0.032660
# 15         0.035068       0.035068
# 16         0.038434       0.038434
# 17         0.041665       0.041665
# 18         0.044609       0.044609
# 19         0.048195       0.048195
# 20         0.052084       0.052084
# 21         0.055575       0.055575
# 22         0.058576       0.058576
# 23         0.061493       0.061493
# 24         0.063861       0.063861
# 25         0.065507       0.065507
# 26         0.066978       0.066978
# 27         0.068251       0.068251
# 28         0.070259       0.070259
# 29         0.072774       0.072774
# 30         0.076134       0.076134
# 31         0.079590       0.079590
# 32         0.082231       0.082231
# 33         0.084066       0.084066
# 34         0.084121       0.084121
# 35         0.082341       0.082341
# 36         0.080988       0.080988
# 37         0.078851       0.078851
# 38         0.072560       0.072560
# 39         0.071336       0.071336
# 40         0.071059       0.071059
# 41         0.070466       0.070466
# 42         0.065968       0.065968
# 43         0.048740       0.048740
# 44         0.056117       0.056117

# %%
print("--- %s seconds ---" % (time.time()-start_time))
# Out:
# --- 4.096538066864014 seconds ---
