# %%
# Parameters
name      = ""
fits_path = ""

# %%
# Parameters
name = "fake_cube_mod_finite_sigE1_m330_r16_N512_bin1"
fits_path = "fits_ready/fake_cube_mod_finite_sigE1_m330_r16_N512_bin1.fits"

# %% [raw]
# name      = 'fake_map_mod_finite_m285_r1_N256_bin0'
# fits_path = "fits_ready/" + name + ".fits"

# %%
import time
start_time=time.time()

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import sys
from pathlib import Path
import astropy.units as u
from matplotlib import pyplot as plt
import corner
import json
from astropy.io import fits
from lmfit.model import save_modelresult


# Add path to py_modules 
sys.path.append(str(Path().resolve() / 'py_modules')) # 1 level up = project root

#import strucfunc                   
import strucfunc
import fit_structure_function
import ci_results_compiler
import bfunc
import bplot

# %% [markdown]
# # Velocity Field

# %%
# Loading obs
hdul = fits.open(fits_path)
hdr = hdul[0].header
print(hdul.info())
print(hdr)
sb = hdul['MOM0'].data.astype(float)
vv= hdul['MOM1'].data.astype(float)
# Out:
# Filename: fits_ready/fake_cube_mod_finite_sigE1_m330_r16_N512_bin1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      28   ()
#   1  MOM0          1 ImageHDU         8   (256, 256)   float64
#   2  MOM1          1 ImageHDU         8   (256, 256)   float64
# None
# SIMPLE  =                    T / conforms to FITS standard                      BITPIX  =                    8 / array data type                                NAXIS   =                    0 / number of array dimensions                     EXTEND  =                    T                                                  FILE    = 'fake_cube_mod_finite_sigE1_m330_r16_N512_bin0' / Fits file name      NAME_ID = 'sigE1_m330_r16_N512_bin0' / pipeline identifier                      REG     = 'Synthetic 3D map'   / Region catalog name                            NAME_REG= 'Synthetic 3D map'   / Region name                                    REG_ID  = 'Synthetic 3D map'   / Region identifier                              TYPE_OBJ= 'NaN     '           / Type object                                    DIST    =                    1 / Distance in parsecs                            INSTR   = 'NaN     '           / Instrument                                     LINE    = 'NaN     '           / Emission line name                             LINE_ID = 'NaN     '           / Emission line identifier                       L_REST  =                    0 / Emission line name                             SIG     =   0.9488985294359011 / Standard deviation vel map                     SIG2    =   0.9004084191656158 / Vel Variance map                               S0      =                    0 / Atmospheric seeing                             BOX_SIZE=                512.0 / Observational box_size                         PC      =                    1 / parsec convertion                              PIX     =                    2 / Instrument pixel scale                         BINSIZE =                    1 / Spatial binning factor                         NOISE   =                    0 / Instrumental noise                             M3D     =                  0.3 / k = 3 + m3D                                    RA      =                 16.0 / Artificial correlation length                  SEED1   =             18940425 / Random seed velocity                           SEED2   =             19390501 / Random seed surfavebrightness                  AUTHOR  = 'J. Garcia-Vazquez'  / File creator                                   END

# %%
with fits.open(fits_path) as hdul:
    hdr = hdul[0].header

hdr
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# FILE    = 'fake_cube_mod_finite_sigE1_m330_r16_N512_bin0' / Fits file name
# NAME_ID = 'sigE1_m330_r16_N512_bin0' / pipeline identifier
# REG     = 'Synthetic 3D map'   / Region catalog name
# NAME_REG= 'Synthetic 3D map'   / Region name
# REG_ID  = 'Synthetic 3D map'   / Region identifier
# TYPE_OBJ= 'NaN     '           / Type object
# DIST    =                    1 / Distance in parsecs
# INSTR   = 'NaN     '           / Instrument
# LINE    = 'NaN     '           / Emission line name
# LINE_ID = 'NaN     '           / Emission line identifier
# L_REST  =                    0 / Emission line name
# SIG     =   0.9488985294359011 / Standard deviation vel map
# SIG2    =   0.9004084191656158 / Vel Variance map
# S0      =                    0 / Atmospheric seeing
# BOX_SIZE=                512.0 / Observational box_size
# PC      =                    1 / parsec convertion
# PIX     =                    2 / Instrument pixel scale
# BINSIZE =                    1 / Spatial binning factor
# NOISE   =                    0 / Instrumental noise
# M3D     =                  0.3 / k = 3 + m3D
# RA      =                 16.0 / Artificial correlation length
# SEED1   =             18940425 / Random seed velocity
# SEED2   =             19390501 / Random seed surfavebrightness
# AUTHOR  = 'J. Garcia-Vazquez'  / File creator

# %%
m3D      = hdul[0].header['M3D']
ra       = hdul[0].header['RA']
sig      = hdul[0].header['SIG']
sig2     = hdul[0].header['SIG2']
s0       = hdul[0].header['S0']
noise    = hdul[0].header['NOISE']
box_size = hdul[0].header['BOX_SIZE']
pc       = hdul[0].header['PC']
pix      = hdul[0].header['PIX']
line     = hdul[0].header['LINE']
binsize  = hdul[0].header['BINSIZE']

# %%
fig, (ax, axx) = plt.subplots(
    1,
    2,
    sharey=True,
    figsize=(10, 4),
)
imshow_kwds = dict(origin="lower", cmap="RdBu_r")
imshow_kwds2 = dict(origin="lower", cmap="magma")
im = ax.imshow(vv, **imshow_kwds)
cbar = fig.colorbar(im, ax=[ax])
cbar.set_label("$\sigma$ (-)", rotation=270, labelpad=15)
im = axx.imshow(sb, **imshow_kwds2)
cbar = fig.colorbar(im, ax=[axx])
cbar.set_label("rad. vel. (km/s)", rotation=270, labelpad=15)

ax.set_xlabel("pix")
ax.set_ylabel("pix")
axx.set_xlabel("pix")
ax.set_title("Moment 1")
axx.set_title("Moment 0")
# Out:
# Text(0.5, 1.0, 'Moment 0')

# %% [markdown]
# # Structure function

# %%
rslt = strucfunc.strucfunc_numba_parallel(vv, dlogr=0.05)
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# /Users/javier/fake_binning/py_modules/strucfunc.py:83: RuntimeWarning: invalid value encountered in divide
#   'Unweighted B(r)': sf/nsf,
# /Users/javier/fake_binning/py_modules/strucfunc.py:84: RuntimeWarning: invalid value encountered in divide
#   'Weighted B(r)': wsf/weight}

# %%
rslt_ = pd.DataFrame(rslt)

# %%
rslt["Unweighted mean velocity"] = np.mean(vv)
rslt["Unweighted sigma^2"] = np.var(vv)
#v0w = rslt["Weighted mean velocity"] = np.average(vv, weights=sb)
#rslt["Weighted sigma^2"] = np.average((vv - v0w)**2, weights=sb)

# %%
b2    = rslt['Unweighted B(r)']
#b2w   = rslt['Weighted B(r)']
e_b2  = b2  *.1
#e_b2w = b2w  *.1

s     = 10**rslt['log10 r'] * pix * pc
e_s   = s  *.1
sig2  = rslt['Unweighted sigma^2']
#sig2w = rslt['Weighted sigma^2']

sig   = sig2**0.5

# %%
#r0    = np.interp(sig2, b2[1:35], s[1:35])
r0    = ra
m     = m3D

rgrid = np.linspace(s[0], s[:-1])

fig, ax = plt.subplots(figsize=(8, 6))

ax.errorbar(s, b2, yerr=e_b2, xerr=e_s, fmt='o', alpha=0.4,color="blue")
#ax.errorbar(s, b2w, yerr=e_b2w, xerr=e_s, fmt='x', alpha=0.4,color="green")

ax.axhline(sig2, ls='-')
ax.axvline(r0, ls='-')

ax.plot(rgrid, bfunc.bfunc00s(rgrid, r0, sig2, m), color="0.8")
ax.plot(rgrid, bfunc.bfunc03s(rgrid, r0, sig2, m, s0, noise), color="black")
#ax.plot(rgrid, bfunc.bfunc04s(rgrid, r0, sig2, m, s0, noise, box_size), color="black")


ax.set(xscale='log', yscale='log', 
       xlabel='separation,pc',
       ylabel=r'$b^2,\ \mathrm{km^2\ s^{-2}}$'
      )
None

plt.show()

# %% [markdown]
# # Export

# %%
from astropy.table import Table


df =  rslt_.copy()

# Flatten MultiIndex columns like ('s','count') -> "s_count"
if isinstance(df.columns, pd.MultiIndex):
    df.columns = ["_".join(map(str, col)).strip() for col in df.columns.to_flat_index()]
else:
    df.columns = [str(c) for c in df.columns]

# (Optional) drop index to avoid it becoming an extra column
df = df.reset_index(drop=True)

t = Table.from_pandas(df)
new_hdu = fits.BinTableHDU(t, name="TABLE")

# %%
with fits.open(fits_path, mode="readonly") as hdul:
    hdus = [h.copy() for h in hdul]   # copy existing HDUs

hdus.append(new_hdu)
fits.HDUList(hdus).writeto(fits_path, overwrite=True)

# %%
# Test import

from astropy.table import Table
t = Table.read(fits_path, hdu="TABLE")
df_loaded = t.to_pandas()
df_loaded
# Out:
#     log10 r      Sum dv^2  Sum weights  Sum w * dv^2    N pairs  \
# 0      0.00  1.881875e+04      65280.0  1.881875e+04      65280
# 1      0.05  0.000000e+00          0.0  0.000000e+00          0
# 2      0.10  0.000000e+00          0.0  0.000000e+00          0
# 3      0.15  6.752271e+04     130050.0  6.752271e+04     130050
# 4      0.20  0.000000e+00          0.0  0.000000e+00          0
# 5      0.25  0.000000e+00          0.0  0.000000e+00          0
# 6      0.30  2.492144e+05     324104.0  2.492144e+05     324104
# 7      0.35  0.000000e+00          0.0  0.000000e+00          0
# 8      0.40  0.000000e+00          0.0  0.000000e+00          0
# 9      0.45  1.806598e+05     193800.0  1.806598e+05     193800
# 10     0.50  2.714612e+05     258060.0  2.714612e+05     258060
# 11     0.55  2.942243e+05     257048.0  2.942243e+05     257048
# 12     0.60  5.492514e+05     449570.0  5.492514e+05     449570
# 13     0.65  7.606725e+05     575312.0  7.606725e+05     575312
# 14     0.70  7.230389e+05     511036.0  7.230389e+05     511036
# 15     0.75  1.031506e+06     700020.0  1.031506e+06     700020
# 16     0.80  1.879055e+06    1203734.0  1.879055e+06    1203734
# 17     0.85  1.654405e+06    1007972.0  1.654405e+06    1007972
# 18     0.90  2.448104e+06    1445380.0  2.448104e+06    1445380
# 19     0.95  3.414536e+06    1937042.0  3.414536e+06    1937042
# 20     1.00  5.216008e+06    2859272.0  5.216008e+06    2859272
# 21     1.05  5.447400e+06    2897116.0  5.447400e+06    2897116
# 22     1.10  7.054488e+06    3674690.0  7.054488e+06    3674690
# 23     1.15  1.012151e+07    5155474.0  1.012151e+07    5155474
# 24     1.20  1.149031e+07    5773520.0  1.149031e+07    5773520
# 25     1.25  1.503067e+07    7491838.0  1.503067e+07    7491838
# 26     1.30  1.950679e+07    9701238.0  1.950679e+07    9701238
# 27     1.35  2.372110e+07   11757186.0  2.372110e+07   11757186
# 28     1.40  2.895527e+07   14320938.0  2.895527e+07   14320938
# 29     1.45  3.541968e+07   17540114.0  3.541968e+07   17540114
# 30     1.50  4.576600e+07   22734900.0  4.576600e+07   22734900
# 31     1.55  5.278523e+07   26303374.0  5.278523e+07   26303374
# 32     1.60  6.847682e+07   34062188.0  6.847682e+07   34062188
# 33     1.65  8.239630e+07   40733820.0  8.239630e+07   40733820
# 34     1.70  1.020492e+08   50149068.0  1.020492e+08   50149068
# 35     1.75  1.225891e+08   60431004.0  1.225891e+08   60431004
# 36     1.80  1.460353e+08   72289830.0  1.460353e+08   72289830
# 37     1.85  1.770700e+08   87731826.0  1.770700e+08   87731826
# 38     1.90  2.063287e+08  102476376.0  2.063287e+08  102476376
# 39     1.95  2.427926e+08  120332462.0  2.427926e+08  120332462
# 40     2.00  2.808584e+08  140368314.0  2.808584e+08  140368314
# 41     2.05  3.178134e+08  158782298.0  3.178134e+08  158782298
# 42     2.10  3.601469e+08  178392398.0  3.601469e+08  178392398
# 43     2.15  3.867265e+08  192781200.0  3.867265e+08  192781200
# 44     2.20  3.985574e+08  200564162.0  3.985574e+08  200564162
# 45     2.25  3.907791e+08  196929652.0  3.907791e+08  196929652
# 46     2.30  3.481172e+08  173862636.0  3.481172e+08  173862636
# 47     2.35  2.430803e+08  123283452.0  2.430803e+08  123283452
# 48     2.40  9.916495e+07   50816154.0  9.916495e+07   50816154
# 49     2.45  2.837321e+07   14282052.0  2.837321e+07   14282052
# 50     2.50  2.957791e+06    1557090.0  2.957791e+06    1557090
#
#     Unweighted B(r)  Weighted B(r)
# 0          0.288277       0.288277
# 1               NaN            NaN
# 2               NaN            NaN
# 3          0.519206       0.519206
# 4               NaN            NaN
# 5               NaN            NaN
# 6          0.768934       0.768934
# 7               NaN            NaN
# 8               NaN            NaN
# 9          0.932197       0.932197
# 10         1.051930       1.051930
# 11         1.144628       1.144628
# 12         1.221726       1.221726
# 13         1.322191       1.322191
# 14         1.414849       1.414849
# 15         1.473537       1.473537
# 16         1.561022       1.561022
# 17         1.641320       1.641320
# 18         1.693744       1.693744
# 19         1.762758       1.762758
# 20         1.824243       1.824243
# 21         1.880284       1.880284
# 22         1.919751       1.919751
# 23         1.963255       1.963255
# 24         1.990174       1.990174
# 25         2.006273       2.006273
# 26         2.010753       2.010753
# 27         2.017583       2.017583
# 28         2.021883       2.021883
# 29         2.019353       2.019353
# 30         2.013029       2.013029
# 31         2.006786       2.006786
# 32         2.010347       2.010347
# 33         2.022798       2.022798
# 34         2.034917       2.034917
# 35         2.028579       2.028579
# 36         2.020137       2.020137
# 37         2.018309       2.018309
# 38         2.013427       2.013427
# 39         2.017681       2.017681
# 40         2.000868       2.000868
# 41         2.001567       2.001567
# 42         2.018847       2.018847
# 43         2.006039       2.006039
# 44         1.987181       1.987181
# 45         1.984359       1.984359
# 46         2.002254       2.002254
# 47         1.971719       1.971719
# 48         1.951445       1.951445
# 49         1.986634       1.986634
# 50         1.899564       1.899564

# %%
print("--- %s seconds ---" % (time.time()-start_time))
# Out:
# --- 5.165586233139038 seconds ---
