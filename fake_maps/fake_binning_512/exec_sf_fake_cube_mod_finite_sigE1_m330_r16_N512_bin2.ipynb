# %%
# Parameters
name      = ""
fits_path = ""

# %%
# Parameters
name = "fake_cube_mod_finite_sigE1_m330_r16_N512_bin2"
fits_path = "fits_ready/fake_cube_mod_finite_sigE1_m330_r16_N512_bin2.fits"

# %% [raw]
# name      = 'fake_map_mod_finite_m285_r1_N256_bin0'
# fits_path = "fits_ready/" + name + ".fits"

# %%
import time
start_time=time.time()

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import sys
from pathlib import Path
import astropy.units as u
from matplotlib import pyplot as plt
import corner
import json
from astropy.io import fits
from lmfit.model import save_modelresult


# Add path to py_modules 
sys.path.append(str(Path().resolve() / 'py_modules')) # 1 level up = project root

#import strucfunc                   
import strucfunc
import fit_structure_function
import ci_results_compiler
import bfunc
import bplot

# %% [markdown]
# # Velocity Field

# %%
# Loading obs
hdul = fits.open(fits_path)
hdr = hdul[0].header
print(hdul.info())
print(hdr)
sb = hdul['MOM0'].data.astype(float)
vv= hdul['MOM1'].data.astype(float)
# Out:
# Filename: fits_ready/fake_cube_mod_finite_sigE1_m330_r16_N512_bin2.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      28   ()
#   1  MOM0          1 ImageHDU         8   (128, 128)   float64
#   2  MOM1          1 ImageHDU         8   (128, 128)   float64
# None
# SIMPLE  =                    T / conforms to FITS standard                      BITPIX  =                    8 / array data type                                NAXIS   =                    0 / number of array dimensions                     EXTEND  =                    T                                                  FILE    = 'fake_cube_mod_finite_sigE1_m330_r16_N512_bin1' / Fits file name      NAME_ID = 'fake_cube_mod_finite_sigE1_m330_r16_N512_bin1' / pipeline identifier REG     = 'Synthetic 3D map'   / Region catalog name                            NAME_REG= 'Synthetic 3D map'   / Region name                                    REG_ID  = 'Synthetic 3D map'   / Region identifier                              TYPE_OBJ= 'NaN     '           / Type object                                    DIST    =                    1 / Distance in parsecs                            INSTR   = 'NaN     '           / Instrument                                     LINE    = 'NaN     '           / Emission line name                             LINE_ID = 'NaN     '           / Emission line identifier                       L_REST  =                    0 / Emission line name                             SIG     =  0.10887254718711185 / Standard deviation vel map                     SIG2    = 0.011853231531009898 / Vel Variance map                               S0      =                    0 / Atmospheric seeing                             BOX_SIZE=                512.0 / Observational box_size                         PC      =                    1 / parsec convertion                              PIX     =                    4 / Instrument pixel scale                         BINSIZE =                    2 / Spatial binning factor                         NOISE   =                    0 / Instrumental noise                             M3D     =                  0.3 / k = 3 + m3D                                    RA      =                 16.0 / Artificial correlation length                  SEED1   =             18940425 / Random seed velocity                           SEED2   =             19390501 / Random seed surfavebrightness                  AUTHOR  = 'J. Garcia-Vazquez'  / File creator                                   END

# %%
with fits.open(fits_path) as hdul:
    hdr = hdul[0].header

hdr
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# FILE    = 'fake_cube_mod_finite_sigE1_m330_r16_N512_bin1' / Fits file name
# NAME_ID = 'fake_cube_mod_finite_sigE1_m330_r16_N512_bin1' / pipeline identifier
# REG     = 'Synthetic 3D map'   / Region catalog name
# NAME_REG= 'Synthetic 3D map'   / Region name
# REG_ID  = 'Synthetic 3D map'   / Region identifier
# TYPE_OBJ= 'NaN     '           / Type object
# DIST    =                    1 / Distance in parsecs
# INSTR   = 'NaN     '           / Instrument
# LINE    = 'NaN     '           / Emission line name
# LINE_ID = 'NaN     '           / Emission line identifier
# L_REST  =                    0 / Emission line name
# SIG     =  0.10887254718711185 / Standard deviation vel map
# SIG2    = 0.011853231531009898 / Vel Variance map
# S0      =                    0 / Atmospheric seeing
# BOX_SIZE=                512.0 / Observational box_size
# PC      =                    1 / parsec convertion
# PIX     =                    4 / Instrument pixel scale
# BINSIZE =                    2 / Spatial binning factor
# NOISE   =                    0 / Instrumental noise
# M3D     =                  0.3 / k = 3 + m3D
# RA      =                 16.0 / Artificial correlation length
# SEED1   =             18940425 / Random seed velocity
# SEED2   =             19390501 / Random seed surfavebrightness
# AUTHOR  = 'J. Garcia-Vazquez'  / File creator

# %%
m3D      = hdul[0].header['M3D']
ra       = hdul[0].header['RA']
sig      = hdul[0].header['SIG']
sig2     = hdul[0].header['SIG2']
s0       = hdul[0].header['S0']
noise    = hdul[0].header['NOISE']
box_size = hdul[0].header['BOX_SIZE']
pc       = hdul[0].header['PC']
pix      = hdul[0].header['PIX']
line     = hdul[0].header['LINE']
binsize  = hdul[0].header['BINSIZE']

# %%
fig, (ax, axx) = plt.subplots(
    1,
    2,
    sharey=True,
    figsize=(10, 4),
)
imshow_kwds = dict(origin="lower", cmap="RdBu_r")
imshow_kwds2 = dict(origin="lower", cmap="magma")
im = ax.imshow(vv, **imshow_kwds)
cbar = fig.colorbar(im, ax=[ax])
cbar.set_label("$\sigma$ (-)", rotation=270, labelpad=15)
im = axx.imshow(sb, **imshow_kwds2)
cbar = fig.colorbar(im, ax=[axx])
cbar.set_label("rad. vel. (km/s)", rotation=270, labelpad=15)

ax.set_xlabel("pix")
ax.set_ylabel("pix")
axx.set_xlabel("pix")
ax.set_title("Moment 1")
axx.set_title("Moment 0")
# Out:
# Text(0.5, 1.0, 'Moment 0')

# %% [markdown]
# # Structure function

# %%
rslt = strucfunc.strucfunc_numba_parallel(vv, dlogr=0.05)
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# /Users/javier/fake_binning/py_modules/strucfunc.py:83: RuntimeWarning: invalid value encountered in divide
#   'Unweighted B(r)': sf/nsf,
# /Users/javier/fake_binning/py_modules/strucfunc.py:84: RuntimeWarning: invalid value encountered in divide
#   'Weighted B(r)': wsf/weight}

# %%
rslt_ = pd.DataFrame(rslt)

# %%
rslt["Unweighted mean velocity"] = np.mean(vv)
rslt["Unweighted sigma^2"] = np.var(vv)
#v0w = rslt["Weighted mean velocity"] = np.average(vv, weights=sb)
#rslt["Weighted sigma^2"] = np.average((vv - v0w)**2, weights=sb)

# %%
b2    = rslt['Unweighted B(r)']
#b2w   = rslt['Weighted B(r)']
e_b2  = b2  *.1
#e_b2w = b2w  *.1

s     = 10**rslt['log10 r'] * pix * pc
e_s   = s  *.1
sig2  = rslt['Unweighted sigma^2']
#sig2w = rslt['Weighted sigma^2']

sig   = sig2**0.5

# %%
#r0    = np.interp(sig2, b2[1:35], s[1:35])
r0    = ra
m     = m3D

rgrid = np.linspace(s[0], s[:-1])

fig, ax = plt.subplots(figsize=(8, 6))

ax.errorbar(s, b2, yerr=e_b2, xerr=e_s, fmt='o', alpha=0.4,color="blue")
#ax.errorbar(s, b2w, yerr=e_b2w, xerr=e_s, fmt='x', alpha=0.4,color="green")

ax.axhline(sig2, ls='-')
ax.axvline(r0, ls='-')

ax.plot(rgrid, bfunc.bfunc00s(rgrid, r0, sig2, m), color="0.8")
ax.plot(rgrid, bfunc.bfunc03s(rgrid, r0, sig2, m, s0, noise), color="black")
#ax.plot(rgrid, bfunc.bfunc04s(rgrid, r0, sig2, m, s0, noise, box_size), color="black")


ax.set(xscale='log', yscale='log', 
       xlabel='separation,pc',
       ylabel=r'$b^2,\ \mathrm{km^2\ s^{-2}}$'
      )
None

plt.show()

# %% [markdown]
# # Export

# %%
from astropy.table import Table


df =  rslt_.copy()

# Flatten MultiIndex columns like ('s','count') -> "s_count"
if isinstance(df.columns, pd.MultiIndex):
    df.columns = ["_".join(map(str, col)).strip() for col in df.columns.to_flat_index()]
else:
    df.columns = [str(c) for c in df.columns]

# (Optional) drop index to avoid it becoming an extra column
df = df.reset_index(drop=True)

t = Table.from_pandas(df)
new_hdu = fits.BinTableHDU(t, name="TABLE")

# %%
with fits.open(fits_path, mode="readonly") as hdul:
    hdus = [h.copy() for h in hdul]   # copy existing HDUs

hdus.append(new_hdu)
fits.HDUList(hdus).writeto(fits_path, overwrite=True)

# %%
# Test import

from astropy.table import Table
t = Table.read(fits_path, hdu="TABLE")
df_loaded = t.to_pandas()
df_loaded
# Out:
#     log10 r      Sum dv^2  Sum weights  Sum w * dv^2   N pairs  \
# 0      0.00  6.960224e+03      16256.0  6.960224e+03     16256
# 1      0.05  0.000000e+00          0.0  0.000000e+00         0
# 2      0.10  0.000000e+00          0.0  0.000000e+00         0
# 3      0.15  2.555890e+04      32258.0  2.555890e+04     32258
# 4      0.20  0.000000e+00          0.0  0.000000e+00         0
# 5      0.25  0.000000e+00          0.0  0.000000e+00         0
# 6      0.30  8.966179e+04      80136.0  8.966179e+04     80136
# 7      0.35  0.000000e+00          0.0  0.000000e+00         0
# 8      0.40  0.000000e+00          0.0  0.000000e+00         0
# 9      0.45  6.194337e+04      47752.0  6.194337e+04     47752
# 10     0.50  9.253052e+04      63500.0  9.253052e+04     63500
# 11     0.55  9.763484e+04      63000.0  9.763484e+04     63000
# 12     0.60  1.774194e+05     110114.0  1.774194e+05    110114
# 13     0.65  2.393502e+05     140240.0  2.393502e+05    140240
# 14     0.70  2.237995e+05     124476.0  2.237995e+05    124476
# 15     0.75  3.118377e+05     169844.0  3.118377e+05    169844
# 16     0.80  5.533461e+05     290710.0  5.533461e+05    290710
# 17     0.85  4.739008e+05     242020.0  4.739008e+05    242020
# 18     0.90  6.850935e+05     346116.0  6.850935e+05    346116
# 19     0.95  9.236751e+05     461074.0  9.236751e+05    461074
# 20     1.00  1.358757e+06     676744.0  1.358757e+06    676744
# 21     1.05  1.374334e+06     679644.0  1.374334e+06    679644
# 22     1.10  1.732361e+06     856002.0  1.732361e+06    856002
# 23     1.15  2.404732e+06    1188370.0  2.404732e+06   1188370
# 24     1.20  2.655360e+06    1318224.0  2.655360e+06   1318224
# 25     1.25  3.394475e+06    1688958.0  3.394475e+06   1688958
# 26     1.30  4.342013e+06    2158838.0  4.342013e+06   2158838
# 27     1.35  5.218974e+06    2571394.0  5.218974e+06   2571394
# 28     1.40  6.280192e+06    3076522.0  6.280192e+06   3076522
# 29     1.45  7.502842e+06    3687186.0  7.502842e+06   3687186
# 30     1.50  9.435419e+06    4660020.0  9.435419e+06   4660020
# 31     1.55  1.059002e+07    5235854.0  1.059002e+07   5235854
# 32     1.60  1.321006e+07    6551148.0  1.321006e+07   6551148
# 33     1.65  1.519164e+07    7514364.0  1.519164e+07   7514364
# 34     1.70  1.760168e+07    8794444.0  1.760168e+07   8794444
# 35     1.75  1.994954e+07    9961628.0  1.994954e+07   9961628
# 36     1.80  2.233203e+07   11037862.0  2.233203e+07  11037862
# 37     1.85  2.437066e+07   12144626.0  2.437066e+07  12144626
# 38     1.90  2.470983e+07   12454104.0  2.470983e+07  12454104
# 39     1.95  2.422046e+07   12221230.0  2.422046e+07  12221230
# 40     2.00  2.171340e+07   10857146.0  2.171340e+07  10857146
# 41     2.05  1.489643e+07    7582938.0  1.489643e+07   7582938
# 42     2.10  6.034350e+06    3109190.0  6.034350e+06   3109190
# 43     2.15  1.711478e+06     864104.0  1.711478e+06    864104
# 44     2.20  1.700909e+05      91086.0  1.700909e+05     91086
#
#     Unweighted B(r)  Weighted B(r)
# 0          0.428163       0.428163
# 1               NaN            NaN
# 2               NaN            NaN
# 3          0.792328       0.792328
# 4               NaN            NaN
# 5               NaN            NaN
# 6          1.118870       1.118870
# 7               NaN            NaN
# 8               NaN            NaN
# 9          1.297189       1.297189
# 10         1.457174       1.457174
# 11         1.549759       1.549759
# 12         1.611233       1.611233
# 13         1.706719       1.706719
# 14         1.797933       1.797933
# 15         1.836024       1.836024
# 16         1.903430       1.903430
# 17         1.958106       1.958106
# 18         1.979375       1.979375
# 19         2.003312       2.003312
# 20         2.007786       2.007786
# 21         2.022138       2.022138
# 22         2.023781       2.023781
# 23         2.023555       2.023555
# 24         2.014347       2.014347
# 25         2.009804       2.009804
# 26         2.011273       2.011273
# 27         2.029628       2.029628
# 28         2.041329       2.041329
# 29         2.034842       2.034842
# 30         2.024759       2.024759
# 31         2.022597       2.022597
# 32         2.016449       2.016449
# 33         2.021681       2.021681
# 34         2.001455       2.001455
# 35         2.002638       2.002638
# 36         2.023221       2.023221
# 37         2.006703       2.006703
# 38         1.984071       1.984071
# 39         1.981835       1.981835
# 40         1.999917       1.999917
# 41         1.964467       1.964467
# 42         1.940811       1.940811
# 43         1.980639       1.980639
# 44         1.867366       1.867366

# %%
print("--- %s seconds ---" % (time.time()-start_time))
# Out:
# --- 4.104815721511841 seconds ---
