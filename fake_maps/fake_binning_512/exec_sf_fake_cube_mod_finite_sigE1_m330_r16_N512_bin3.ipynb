# %%
# Parameters
name      = ""
fits_path = ""

# %%
# Parameters
name = "fake_cube_mod_finite_sigE1_m330_r16_N512_bin3"
fits_path = "fits_ready/fake_cube_mod_finite_sigE1_m330_r16_N512_bin3.fits"

# %% [raw]
# name      = 'fake_map_mod_finite_m285_r1_N256_bin0'
# fits_path = "fits_ready/" + name + ".fits"

# %%
import time
start_time=time.time()

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import sys
from pathlib import Path
import astropy.units as u
from matplotlib import pyplot as plt
import corner
import json
from astropy.io import fits
from lmfit.model import save_modelresult


# Add path to py_modules 
sys.path.append(str(Path().resolve() / 'py_modules')) # 1 level up = project root

#import strucfunc                   
import strucfunc
import fit_structure_function
import ci_results_compiler
import bfunc
import bplot

# %% [markdown]
# # Velocity Field

# %%
# Loading obs
hdul = fits.open(fits_path)
hdr = hdul[0].header
print(hdul.info())
print(hdr)
sb = hdul['MOM0'].data.astype(float)
vv= hdul['MOM1'].data.astype(float)
# Out:
# Filename: fits_ready/fake_cube_mod_finite_sigE1_m330_r16_N512_bin3.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      28   ()
#   1  MOM0          1 ImageHDU         8   (64, 64)   float64
#   2  MOM1          1 ImageHDU         8   (64, 64)   float64
# None
# SIMPLE  =                    T / conforms to FITS standard                      BITPIX  =                    8 / array data type                                NAXIS   =                    0 / number of array dimensions                     EXTEND  =                    T                                                  FILE    = 'fake_cube_mod_finite_sigE1_m330_r16_N512_bin2' / Fits file name      NAME_ID = 'fake_cube_mod_finite_sigE1_m330_r16_N512_bin2' / pipeline identifier REG     = 'Synthetic 3D map'   / Region catalog name                            NAME_REG= 'Synthetic 3D map'   / Region name                                    REG_ID  = 'Synthetic 3D map'   / Region identifier                              TYPE_OBJ= 'NaN     '           / Type object                                    DIST    =                    1 / Distance in parsecs                            INSTR   = 'NaN     '           / Instrument                                     LINE    = 'NaN     '           / Emission line name                             LINE_ID = 'NaN     '           / Emission line identifier                       L_REST  =                    0 / Emission line name                             SIG     =  0.09563752089990911 / Standard deviation vel map                     SIG2    = 0.009146535403880551 / Vel Variance map                               S0      =                    0 / Atmospheric seeing                             BOX_SIZE=                512.0 / Observational box_size                         PC      =                    1 / parsec convertion                              PIX     =                    8 / Instrument pixel scale                         BINSIZE =                    3 / Spatial binning factor                         NOISE   =                    0 / Instrumental noise                             M3D     =                  0.3 / k = 3 + m3D                                    RA      =                 16.0 / Artificial correlation length                  SEED1   =             18940425 / Random seed velocity                           SEED2   =             19390501 / Random seed surfavebrightness                  AUTHOR  = 'J. Garcia-Vazquez'  / File creator                                   END

# %%
with fits.open(fits_path) as hdul:
    hdr = hdul[0].header

hdr
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# FILE    = 'fake_cube_mod_finite_sigE1_m330_r16_N512_bin2' / Fits file name
# NAME_ID = 'fake_cube_mod_finite_sigE1_m330_r16_N512_bin2' / pipeline identifier
# REG     = 'Synthetic 3D map'   / Region catalog name
# NAME_REG= 'Synthetic 3D map'   / Region name
# REG_ID  = 'Synthetic 3D map'   / Region identifier
# TYPE_OBJ= 'NaN     '           / Type object
# DIST    =                    1 / Distance in parsecs
# INSTR   = 'NaN     '           / Instrument
# LINE    = 'NaN     '           / Emission line name
# LINE_ID = 'NaN     '           / Emission line identifier
# L_REST  =                    0 / Emission line name
# SIG     =  0.09563752089990911 / Standard deviation vel map
# SIG2    = 0.009146535403880551 / Vel Variance map
# S0      =                    0 / Atmospheric seeing
# BOX_SIZE=                512.0 / Observational box_size
# PC      =                    1 / parsec convertion
# PIX     =                    8 / Instrument pixel scale
# BINSIZE =                    3 / Spatial binning factor
# NOISE   =                    0 / Instrumental noise
# M3D     =                  0.3 / k = 3 + m3D
# RA      =                 16.0 / Artificial correlation length
# SEED1   =             18940425 / Random seed velocity
# SEED2   =             19390501 / Random seed surfavebrightness
# AUTHOR  = 'J. Garcia-Vazquez'  / File creator

# %%
m3D      = hdul[0].header['M3D']
ra       = hdul[0].header['RA']
sig      = hdul[0].header['SIG']
sig2     = hdul[0].header['SIG2']
s0       = hdul[0].header['S0']
noise    = hdul[0].header['NOISE']
box_size = hdul[0].header['BOX_SIZE']
pc       = hdul[0].header['PC']
pix      = hdul[0].header['PIX']
line     = hdul[0].header['LINE']
binsize  = hdul[0].header['BINSIZE']

# %%
fig, (ax, axx) = plt.subplots(
    1,
    2,
    sharey=True,
    figsize=(10, 4),
)
imshow_kwds = dict(origin="lower", cmap="RdBu_r")
imshow_kwds2 = dict(origin="lower", cmap="magma")
im = ax.imshow(vv, **imshow_kwds)
cbar = fig.colorbar(im, ax=[ax])
cbar.set_label("$\sigma$ (-)", rotation=270, labelpad=15)
im = axx.imshow(sb, **imshow_kwds2)
cbar = fig.colorbar(im, ax=[axx])
cbar.set_label("rad. vel. (km/s)", rotation=270, labelpad=15)

ax.set_xlabel("pix")
ax.set_ylabel("pix")
axx.set_xlabel("pix")
ax.set_title("Moment 1")
axx.set_title("Moment 0")
# Out:
# Text(0.5, 1.0, 'Moment 0')

# %% [markdown]
# # Structure function

# %%
rslt = strucfunc.strucfunc_numba_parallel(vv, dlogr=0.05)
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# /Users/javier/fake_binning/py_modules/strucfunc.py:83: RuntimeWarning: invalid value encountered in divide
#   'Unweighted B(r)': sf/nsf,
# /Users/javier/fake_binning/py_modules/strucfunc.py:84: RuntimeWarning: invalid value encountered in divide
#   'Weighted B(r)': wsf/weight}

# %%
rslt_ = pd.DataFrame(rslt)

# %%
rslt["Unweighted mean velocity"] = np.mean(vv)
rslt["Unweighted sigma^2"] = np.var(vv)
#v0w = rslt["Weighted mean velocity"] = np.average(vv, weights=sb)
#rslt["Weighted sigma^2"] = np.average((vv - v0w)**2, weights=sb)

# %%
b2    = rslt['Unweighted B(r)']
#b2w   = rslt['Weighted B(r)']
e_b2  = b2  *.1
#e_b2w = b2w  *.1

s     = 10**rslt['log10 r'] * pix * pc
e_s   = s  *.1
sig2  = rslt['Unweighted sigma^2']
#sig2w = rslt['Weighted sigma^2']

sig   = sig2**0.5

# %%
#r0    = np.interp(sig2, b2[1:35], s[1:35])
r0    = ra
m     = m3D

rgrid = np.linspace(s[0], s[:-1])

fig, ax = plt.subplots(figsize=(8, 6))

ax.errorbar(s, b2, yerr=e_b2, xerr=e_s, fmt='o', alpha=0.4,color="blue")
#ax.errorbar(s, b2w, yerr=e_b2w, xerr=e_s, fmt='x', alpha=0.4,color="green")

ax.axhline(sig2, ls='-')
ax.axvline(r0, ls='-')

ax.plot(rgrid, bfunc.bfunc00s(rgrid, r0, sig2, m), color="0.8")
ax.plot(rgrid, bfunc.bfunc03s(rgrid, r0, sig2, m, s0, noise), color="black")
#ax.plot(rgrid, bfunc.bfunc04s(rgrid, r0, sig2, m, s0, noise, box_size), color="black")


ax.set(xscale='log', yscale='log', 
       xlabel='separation,pc',
       ylabel=r'$b^2,\ \mathrm{km^2\ s^{-2}}$'
      )
None

plt.show()

# %% [markdown]
# # Export

# %%
from astropy.table import Table


df =  rslt_.copy()

# Flatten MultiIndex columns like ('s','count') -> "s_count"
if isinstance(df.columns, pd.MultiIndex):
    df.columns = ["_".join(map(str, col)).strip() for col in df.columns.to_flat_index()]
else:
    df.columns = [str(c) for c in df.columns]

# (Optional) drop index to avoid it becoming an extra column
df = df.reset_index(drop=True)

t = Table.from_pandas(df)
new_hdu = fits.BinTableHDU(t, name="TABLE")

# %%
with fits.open(fits_path, mode="readonly") as hdul:
    hdus = [h.copy() for h in hdul]   # copy existing HDUs

hdus.append(new_hdu)
fits.HDUList(hdus).writeto(fits_path, overwrite=True)

# %%
# Test import

from astropy.table import Table
t = Table.read(fits_path, hdu="TABLE")
df_loaded = t.to_pandas()
df_loaded
# Out:
#     log10 r      Sum dv^2  Sum weights  Sum w * dv^2  N pairs  \
# 0      0.00  2.497605e+03       4032.0  2.497605e+03     4032
# 1      0.05  0.000000e+00          0.0  0.000000e+00        0
# 2      0.10  0.000000e+00          0.0  0.000000e+00        0
# 3      0.15  9.265773e+03       7938.0  9.265773e+03     7938
# 4      0.20  0.000000e+00          0.0  0.000000e+00        0
# 5      0.25  0.000000e+00          0.0  0.000000e+00        0
# 6      0.30  2.969555e+04      19592.0  2.969555e+04    19592
# 7      0.35  0.000000e+00          0.0  0.000000e+00        0
# 8      0.40  0.000000e+00          0.0  0.000000e+00        0
# 9      0.45  1.960588e+04      11592.0  1.960588e+04    11592
# 10     0.50  2.841770e+04      15372.0  2.841770e+04    15372
# 11     0.55  2.924506e+04      15128.0  2.924506e+04    15128
# 12     0.60  5.120150e+04      26402.0  5.120150e+04    26402
# 13     0.65  6.624377e+04      33296.0  6.624377e+04    33296
# 14     0.70  5.951765e+04      29500.0  5.951765e+04    29500
# 15     0.75  8.042550e+04      39924.0  8.042550e+04    39924
# 16     0.80  1.375536e+05      67670.0  1.375536e+05    67670
# 17     0.85  1.135173e+05      55652.0  1.135173e+05    55652
# 18     0.90  1.598046e+05      79108.0  1.598046e+05    79108
# 19     0.95  2.094152e+05     104018.0  2.094152e+05   104018
# 20     1.00  3.034753e+05     150728.0  3.034753e+05   150728
# 21     1.05  3.035284e+05     148444.0  3.035284e+05   148444
# 22     1.10  3.780057e+05     183938.0  3.780057e+05   183938
# 23     1.15  5.109343e+05     249298.0  5.109343e+05   249298
# 24     1.20  5.494771e+05     270224.0  5.494771e+05   270224
# 25     1.25  6.823034e+05     335806.0  6.823034e+05   335806
# 26     1.30  8.401655e+05     415158.0  8.401655e+05   415158
# 27     1.35  9.589219e+05     472962.0  9.589219e+05   472962
# 28     1.40  1.078886e+06     538602.0  1.078886e+06   538602
# 29     1.45  1.215632e+06     606866.0  1.215632e+06   606866
# 30     1.50  1.441263e+06     709812.0  1.441263e+06   709812
# 31     1.55  1.454727e+06     723214.0  1.454727e+06   723214
# 32     1.60  1.574388e+06     795116.0  1.574388e+06   795116
# 33     1.65  1.502008e+06     759612.0  1.502008e+06   759612
# 34     1.70  1.348431e+06     675468.0  1.348431e+06   675468
# 35     1.75  9.116862e+05     467868.0  9.116862e+05   467868
# 36     1.80  3.581326e+05     187746.0  3.581326e+05   187746
# 37     1.85  1.016555e+05      52362.0  1.016555e+05    52362
# 38     1.90  8.875391e+03       5088.0  8.875391e+03     5088
#
#     Unweighted B(r)  Weighted B(r)
# 0          0.619446       0.619446
# 1               NaN            NaN
# 2               NaN            NaN
# 3          1.167268       1.167268
# 4               NaN            NaN
# 5               NaN            NaN
# 6          1.515698       1.515698
# 7               NaN            NaN
# 8               NaN            NaN
# 9          1.691328       1.691328
# 10         1.848666       1.848666
# 11         1.933174       1.933174
# 12         1.939304       1.939304
# 13         1.989542       1.989542
# 14         2.017548       2.017548
# 15         2.014465       2.014465
# 16         2.032712       2.032712
# 17         2.039770       2.039770
# 18         2.020081       2.020081
# 19         2.013259       2.013259
# 20         2.013397       2.013397
# 21         2.044733       2.044733
# 22         2.055071       2.055071
# 23         2.049492       2.049492
# 24         2.033413       2.033413
# 25         2.031838       2.031838
# 26         2.023725       2.023725
# 27         2.027482       2.027482
# 28         2.003122       2.003122
# 29         2.003130       2.003130
# 30         2.030485       2.030485
# 31         2.011476       2.011476
# 32         1.980073       1.980073
# 33         1.977336       1.977336
# 34         1.996292       1.996292
# 35         1.948597       1.948597
# 36         1.907538       1.907538
# 37         1.941399       1.941399
# 38         1.744377       1.744377

# %%
print("--- %s seconds ---" % (time.time()-start_time))
# Out:
# --- 3.968956232070923 seconds ---
