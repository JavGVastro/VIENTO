# %%
# Parameters
name      = ""
fits_path = ""

# %%
# Parameters
name = "fake_map_mod_finite_m285_r128_N256_bin0"
fits_path = "fits_ready/fake_map_mod_finite_m285_r128_N256_bin0.fits"

# %% [raw]
# name      = 'fake_map_mod_finite_m285_r1_N256_bin0'
# fits_path = "fits_ready/" + name + ".fits"

# %%
import time
start_time=time.time()

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import sys
from pathlib import Path
import astropy.units as u
from matplotlib import pyplot as plt
import corner
import json
from astropy.io import fits
from lmfit.model import save_modelresult


# Add path to py_modules 
sys.path.append(str(Path().resolve() / 'py_modules')) # 1 level up = project root

#import strucfunc                   
import strucfunc
import fit_structure_function
import ci_results_compiler
import bfunc
import bplot

# %% [markdown]
# # Velocity Field

# %%
# Loading obs
hdul = fits.open(fits_path)
hdr = hdul[0].header
print(hdul.info())
print(hdr)
#sb = hdul['MOM0'].data.astype(float)
vv= hdul['MOM1'].data.astype(float)
# Out:
# Filename: fits_ready/fake_map_mod_finite_m285_r128_N256_bin0.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      27   ()
#   1  MOM1          1 ImageHDU         8   (256, 256)   float64
# None
# SIMPLE  =                    T / conforms to FITS standard                      BITPIX  =                    8 / array data type                                NAXIS   =                    0 / number of array dimensions                     EXTEND  =                    T                                                  FILE    = 'fake_map_mod_finite_m285_r128_N256_bin0' / Fits file name            NAME_ID = 'fake_map_mod_finite_m285_r128_N256_bin0' / pipeline identifier       REG     = 'Synthetic 2D map'   / Region catalog name                            NAME_REG= 'Synthetic 2D map'   / Region name                                    REG_ID  = 'Synthetic 2D map'   / Region identifier                              TYPE_OBJ= 'NaN     '           / Type object                                    DIST    =                    1 / Distance in parsecs                            INSTR   = 'NaN     '           / Instrument                                     LINE    = 'Synthetic 2D map'   / Emission line name                             LINE_ID = 'Synthetic 2D map'   / Emission line identifier                       L_REST  =                    0 / Emission line name                             SIG     =   1.9951269145467552 / Standard deviation vel map                     SIG2    =   3.9805314051488554 / Vel Variance map                               S0      =                    0 / Atmospheric seeing                             BOX_SIZE=                  256 / Observational box_size                         PC      =                    1 / parsec convertion                              PIX     =                    1 / Instrument pixel scale                         BINSIZE =                    0 / Spatial binning factor                         NOISE   =                    0 / Instrumental noise                             M2D     =                 0.85 / k = 3 + m3D                                    RA      =                128.0 / Artificial correlation length                  SEED1   =             18940425 / Random seed velocity                           AUTHOR  = 'J. Garcia-Vazquez'  / File creator                                   END

# %%
with fits.open(fits_path) as hdul:
    hdr = hdul[0].header

hdr
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# FILE    = 'fake_map_mod_finite_m285_r128_N256_bin0' / Fits file name
# NAME_ID = 'fake_map_mod_finite_m285_r128_N256_bin0' / pipeline identifier
# REG     = 'Synthetic 2D map'   / Region catalog name
# NAME_REG= 'Synthetic 2D map'   / Region name
# REG_ID  = 'Synthetic 2D map'   / Region identifier
# TYPE_OBJ= 'NaN     '           / Type object
# DIST    =                    1 / Distance in parsecs
# INSTR   = 'NaN     '           / Instrument
# LINE    = 'Synthetic 2D map'   / Emission line name
# LINE_ID = 'Synthetic 2D map'   / Emission line identifier
# L_REST  =                    0 / Emission line name
# SIG     =   1.9951269145467552 / Standard deviation vel map
# SIG2    =   3.9805314051488554 / Vel Variance map
# S0      =                    0 / Atmospheric seeing
# BOX_SIZE=                  256 / Observational box_size
# PC      =                    1 / parsec convertion
# PIX     =                    1 / Instrument pixel scale
# BINSIZE =                    0 / Spatial binning factor
# NOISE   =                    0 / Instrumental noise
# M2D     =                 0.85 / k = 3 + m3D
# RA      =                128.0 / Artificial correlation length
# SEED1   =             18940425 / Random seed velocity
# AUTHOR  = 'J. Garcia-Vazquez'  / File creator

# %%
m2D      = hdul[0].header['M2D']
ra       = hdul[0].header['RA']
sig      = hdul[0].header['SIG']
sig2     = hdul[0].header['SIG2']
s0       = hdul[0].header['S0']
noise    = hdul[0].header['NOISE']
box_size = hdul[0].header['BOX_SIZE']
pc       = hdul[0].header['PC']
pix      = hdul[0].header['PIX']
line     = hdul[0].header['LINE']
binsize  = hdul[0].header['BINSIZE']

# %%
fig, ax = plt.subplots(figsize=(5, 4))

imshow_kwds = dict(origin="lower", cmap="RdBu_r")
im = ax.imshow(vv, **imshow_kwds)

cbar = fig.colorbar(im, ax=ax)
cbar.set_label(r"$\sigma$ (-)", rotation=270, labelpad=15)

ax.set_xlabel("pix")
ax.set_ylabel("pix")
ax.set_title("Moment 1")
# Out:
# Text(0.5, 1.0, 'Moment 1')

# %% [markdown]
# # Structure function

# %%
rslt = strucfunc.strucfunc_numba_parallel(vv, dlogr=0.05)
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# /Users/javier/fake_maps_pipeline_test/py_modules/strucfunc.py:83: RuntimeWarning: invalid value encountered in divide
#   'Unweighted B(r)': sf/nsf,
# /Users/javier/fake_maps_pipeline_test/py_modules/strucfunc.py:84: RuntimeWarning: invalid value encountered in divide
#   'Weighted B(r)': wsf/weight}

# %%
rslt_ = pd.DataFrame(rslt)

# %%
rslt["Unweighted mean velocity"] = np.mean(vv)
rslt["Unweighted sigma^2"] = np.var(vv)
#v0w = rslt["Weighted mean velocity"] = np.average(vv, weights=sb)
#rslt["Weighted sigma^2"] = np.average((vv - v0w)**2, weights=sb)

# %%
b2    = rslt['Unweighted B(r)']
#b2w   = rslt['Weighted B(r)']
e_b2  = b2  *.1
#e_b2w = b2w  *.1

s     = 10**rslt['log10 r'] * pix * pc
e_s   = s  *.1
sig2  = rslt['Unweighted sigma^2']
#sig2w = rslt['Weighted sigma^2']

sig   = sig2**0.5

# %%
#r0    = np.interp(sig2, b2[1:35], s[1:35])
r0    = ra
m     = m2D

rgrid = np.linspace(s[0], s[:-1])

fig, ax = plt.subplots(figsize=(8, 6))

ax.errorbar(s, b2, yerr=e_b2, xerr=e_s, fmt='o', alpha=0.4,color="blue")
#ax.errorbar(s, b2w, yerr=e_b2w, xerr=e_s, fmt='x', alpha=0.4,color="green")

ax.axhline(sig2, ls='-')
ax.axvline(r0, ls='-')

ax.plot(rgrid, bfunc.bfunc00s(rgrid, r0, sig2, m), color="0.8")
ax.plot(rgrid, bfunc.bfunc03s(rgrid, r0, sig2, m, s0, noise), color="black")
#ax.plot(rgrid, bfunc.bfunc04s(rgrid, r0, sig2, m, s0, noise, box_size), color="black")


ax.set(xscale='log', yscale='log', 
       xlabel='separation,pc',
       ylabel=r'$b^2,\ \mathrm{km^2\ s^{-2}}$'
      )
None

plt.show()

# %% [markdown]
# # Export

# %%
from astropy.table import Table


df =  rslt_.copy()

# Flatten MultiIndex columns like ('s','count') -> "s_count"
if isinstance(df.columns, pd.MultiIndex):
    df.columns = ["_".join(map(str, col)).strip() for col in df.columns.to_flat_index()]
else:
    df.columns = [str(c) for c in df.columns]

# (Optional) drop index to avoid it becoming an extra column
df = df.reset_index(drop=True)

t = Table.from_pandas(df)
new_hdu = fits.BinTableHDU(t, name="TABLE")

# %%
with fits.open(fits_path, mode="readonly") as hdul:
    hdus = [h.copy() for h in hdul]   # copy existing HDUs

hdus.append(new_hdu)
fits.HDUList(hdus).writeto(fits_path, overwrite=True)

# %%
# Test import

from astropy.table import Table
t = Table.read(fits_path, hdu="TABLE")
df_loaded = t.to_pandas()
df_loaded
# Out:
#     log10 r      Sum dv^2  Sum weights  Sum w * dv^2    N pairs  \
# 0      0.00  3.154117e+03      65280.0  3.154117e+03      65280
# 1      0.05  0.000000e+00          0.0  0.000000e+00          0
# 2      0.10  0.000000e+00          0.0  0.000000e+00          0
# 3      0.15  1.143998e+04     130050.0  1.143998e+04     130050
# 4      0.20  0.000000e+00          0.0  0.000000e+00          0
# 5      0.25  0.000000e+00          0.0  0.000000e+00          0
# 6      0.30  4.527733e+04     324104.0  4.527733e+04     324104
# 7      0.35  0.000000e+00          0.0  0.000000e+00          0
# 8      0.40  0.000000e+00          0.0  0.000000e+00          0
# 9      0.45  3.452676e+04     193800.0  3.452676e+04     193800
# 10     0.50  5.327582e+04     258060.0  5.327582e+04     258060
# 11     0.55  5.889744e+04     257048.0  5.889744e+04     257048
# 12     0.60  1.166350e+05     449570.0  1.166350e+05     449570
# 13     0.65  1.679682e+05     575312.0  1.679682e+05     575312
# 14     0.70  1.671691e+05     511036.0  1.671691e+05     511036
# 15     0.75  2.494045e+05     700020.0  2.494045e+05     700020
# 16     0.80  4.789149e+05    1203734.0  4.789149e+05    1203734
# 17     0.85  4.414084e+05    1007972.0  4.414084e+05    1007972
# 18     0.90  6.903041e+05    1445380.0  6.903041e+05    1445380
# 19     0.95  1.018379e+06    1937042.0  1.018379e+06    1937042
# 20     1.00  1.663738e+06    2859272.0  1.663738e+06    2859272
# 21     1.05  1.850022e+06    2897116.0  1.850022e+06    2897116
# 22     1.10  2.555601e+06    3674690.0  2.555601e+06    3674690
# 23     1.15  3.920440e+06    5155474.0  3.920440e+06    5155474
# 24     1.20  4.791572e+06    5773520.0  4.791572e+06    5773520
# 25     1.25  6.746140e+06    7491838.0  6.746140e+06    7491838
# 26     1.30  9.490828e+06    9701238.0  9.490828e+06    9701238
# 27     1.35  1.246250e+07   11757186.0  1.246250e+07   11757186
# 28     1.40  1.640709e+07   14320938.0  1.640709e+07   14320938
# 29     1.45  2.162006e+07   17540114.0  2.162006e+07   17540114
# 30     1.50  3.007785e+07   22734900.0  3.007785e+07   22734900
# 31     1.55  3.717278e+07   26303374.0  3.717278e+07   26303374
# 32     1.60  5.116552e+07   34062188.0  5.116552e+07   34062188
# 33     1.65  6.486246e+07   40733820.0  6.486246e+07   40733820
# 34     1.70  8.425423e+07   50149068.0  8.425423e+07   50149068
# 35     1.75  1.062916e+08   60431004.0  1.062916e+08   60431004
# 36     1.80  1.325831e+08   72289830.0  1.325831e+08   72289830
# 37     1.85  1.673553e+08   87731826.0  1.673553e+08   87731826
# 38     1.90  2.027240e+08  102476376.0  2.027240e+08  102476376
# 39     1.95  2.461513e+08  120332462.0  2.461513e+08  120332462
# 40     2.00  2.966410e+08  140368314.0  2.966410e+08  140368314
# 41     2.05  3.429766e+08  158782298.0  3.429766e+08  158782298
# 42     2.10  3.937816e+08  178392398.0  3.937816e+08  178392398
# 43     2.15  4.384125e+08  192781200.0  4.384125e+08  192781200
# 44     2.20  4.641561e+08  200564162.0  4.641561e+08  200564162
# 45     2.25  4.524791e+08  196929652.0  4.524791e+08  196929652
# 46     2.30  3.611847e+08  173862636.0  3.611847e+08  173862636
# 47     2.35  2.147573e+08  123283452.0  2.147573e+08  123283452
# 48     2.40  8.541311e+07   50816154.0  8.541311e+07   50816154
# 49     2.45  2.129239e+07   14282052.0  2.129239e+07   14282052
# 50     2.50  1.171439e+06    1557090.0  1.171439e+06    1557090
#
#     Unweighted B(r)  Weighted B(r)
# 0          0.048317       0.048317
# 1               NaN            NaN
# 2               NaN            NaN
# 3          0.087966       0.087966
# 4               NaN            NaN
# 5               NaN            NaN
# 6          0.139700       0.139700
# 7               NaN            NaN
# 8               NaN            NaN
# 9          0.178157       0.178157
# 10         0.206447       0.206447
# 11         0.229130       0.229130
# 12         0.259437       0.259437
# 13         0.291960       0.291960
# 14         0.327118       0.327118
# 15         0.356282       0.356282
# 16         0.397858       0.397858
# 17         0.437917       0.437917
# 18         0.477594       0.477594
# 19         0.525739       0.525739
# 20         0.581875       0.581875
# 21         0.638574       0.638574
# 22         0.695460       0.695460
# 23         0.760442       0.760442
# 24         0.829922       0.829922
# 25         0.900465       0.900465
# 26         0.978311       0.978311
# 27         1.059990       1.059990
# 28         1.145671       1.145671
# 29         1.232606       1.232606
# 30         1.322981       1.322981
# 31         1.413232       1.413232
# 32         1.502121       1.502121
# 33         1.592349       1.592349
# 34         1.680076       1.680076
# 35         1.758892       1.758892
# 36         1.834049       1.834049
# 37         1.907578       1.907578
# 38         1.978251       1.978251
# 39         2.045593       2.045593
# 40         2.113305       2.113305
# 41         2.160043       2.160043
# 42         2.207390       2.207390
# 43         2.274145       2.274145
# 44         2.314252       2.314252
# 45         2.297669       2.297669
# 46         2.077414       2.077414
# 47         1.741980       1.741980
# 48         1.680826       1.680826
# 49         1.490849       1.490849
# 50         0.752326       0.752326

# %%
print("--- %s seconds ---" % (time.time()-start_time))
# Out:
# --- 4.615951776504517 seconds ---
