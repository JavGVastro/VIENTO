# %%
# Parameters
name      = ""
fits_path = ""

# %%
# Parameters
name = "fake_map_mod_finite_m285_r256_N256_bin0"
fits_path = "fits_ready/fake_map_mod_finite_m285_r256_N256_bin0.fits"

# %% [raw]
# name      = 'fake_map_mod_finite_m285_r1_N256_bin0'
# fits_path = "fits_ready/" + name + ".fits"

# %%
import time
start_time=time.time()

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import sys
from pathlib import Path
import astropy.units as u
from matplotlib import pyplot as plt
import corner
import json
from astropy.io import fits
from lmfit.model import save_modelresult


# Add path to py_modules 
sys.path.append(str(Path().resolve() / 'py_modules')) # 1 level up = project root

#import strucfunc                   
import strucfunc
import fit_structure_function
import ci_results_compiler
import bfunc
import bplot

# %% [markdown]
# # Velocity Field

# %%
# Loading obs
hdul = fits.open(fits_path)
hdr = hdul[0].header
print(hdul.info())
print(hdr)
#sb = hdul['MOM0'].data.astype(float)
vv= hdul['MOM1'].data.astype(float)
# Out:
# Filename: fits_ready/fake_map_mod_finite_m285_r256_N256_bin0.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      27   ()
#   1  MOM1          1 ImageHDU         8   (256, 256)   float64
# None
# SIMPLE  =                    T / conforms to FITS standard                      BITPIX  =                    8 / array data type                                NAXIS   =                    0 / number of array dimensions                     EXTEND  =                    T                                                  FILE    = 'fake_map_mod_finite_m285_r256_N256_bin0' / Fits file name            NAME_ID = 'fake_map_mod_finite_m285_r256_N256_bin0' / pipeline identifier       REG     = 'Synthetic 2D map'   / Region catalog name                            NAME_REG= 'Synthetic 2D map'   / Region name                                    REG_ID  = 'Synthetic 2D map'   / Region identifier                              TYPE_OBJ= 'NaN     '           / Type object                                    DIST    =                    1 / Distance in parsecs                            INSTR   = 'NaN     '           / Instrument                                     LINE    = 'Synthetic 2D map'   / Emission line name                             LINE_ID = 'Synthetic 2D map'   / Emission line identifier                       L_REST  =                    0 / Emission line name                             SIG     =    2.172026482175406 / Standard deviation vel map                     SIG2    =    4.717699039271269 / Vel Variance map                               S0      =                    0 / Atmospheric seeing                             BOX_SIZE=                  256 / Observational box_size                         PC      =                    1 / parsec convertion                              PIX     =                    1 / Instrument pixel scale                         BINSIZE =                    0 / Spatial binning factor                         NOISE   =                    0 / Instrumental noise                             M2D     =                 0.85 / k = 3 + m3D                                    RA      =                256.0 / Artificial correlation length                  SEED1   =             18940425 / Random seed velocity                           AUTHOR  = 'J. Garcia-Vazquez'  / File creator                                   END

# %%
with fits.open(fits_path) as hdul:
    hdr = hdul[0].header

hdr
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# FILE    = 'fake_map_mod_finite_m285_r256_N256_bin0' / Fits file name
# NAME_ID = 'fake_map_mod_finite_m285_r256_N256_bin0' / pipeline identifier
# REG     = 'Synthetic 2D map'   / Region catalog name
# NAME_REG= 'Synthetic 2D map'   / Region name
# REG_ID  = 'Synthetic 2D map'   / Region identifier
# TYPE_OBJ= 'NaN     '           / Type object
# DIST    =                    1 / Distance in parsecs
# INSTR   = 'NaN     '           / Instrument
# LINE    = 'Synthetic 2D map'   / Emission line name
# LINE_ID = 'Synthetic 2D map'   / Emission line identifier
# L_REST  =                    0 / Emission line name
# SIG     =    2.172026482175406 / Standard deviation vel map
# SIG2    =    4.717699039271269 / Vel Variance map
# S0      =                    0 / Atmospheric seeing
# BOX_SIZE=                  256 / Observational box_size
# PC      =                    1 / parsec convertion
# PIX     =                    1 / Instrument pixel scale
# BINSIZE =                    0 / Spatial binning factor
# NOISE   =                    0 / Instrumental noise
# M2D     =                 0.85 / k = 3 + m3D
# RA      =                256.0 / Artificial correlation length
# SEED1   =             18940425 / Random seed velocity
# AUTHOR  = 'J. Garcia-Vazquez'  / File creator

# %%
m2D      = hdul[0].header['M2D']
ra       = hdul[0].header['RA']
sig      = hdul[0].header['SIG']
sig2     = hdul[0].header['SIG2']
s0       = hdul[0].header['S0']
noise    = hdul[0].header['NOISE']
box_size = hdul[0].header['BOX_SIZE']
pc       = hdul[0].header['PC']
pix      = hdul[0].header['PIX']
line     = hdul[0].header['LINE']
binsize  = hdul[0].header['BINSIZE']

# %%
fig, ax = plt.subplots(figsize=(5, 4))

imshow_kwds = dict(origin="lower", cmap="RdBu_r")
im = ax.imshow(vv, **imshow_kwds)

cbar = fig.colorbar(im, ax=ax)
cbar.set_label(r"$\sigma$ (-)", rotation=270, labelpad=15)

ax.set_xlabel("pix")
ax.set_ylabel("pix")
ax.set_title("Moment 1")
# Out:
# Text(0.5, 1.0, 'Moment 1')

# %% [markdown]
# # Structure function

# %%
rslt = strucfunc.strucfunc_numba_parallel(vv, dlogr=0.05)
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# /Users/javier/fake_maps_pipeline_test/py_modules/strucfunc.py:83: RuntimeWarning: invalid value encountered in divide
#   'Unweighted B(r)': sf/nsf,
# /Users/javier/fake_maps_pipeline_test/py_modules/strucfunc.py:84: RuntimeWarning: invalid value encountered in divide
#   'Weighted B(r)': wsf/weight}

# %%
rslt_ = pd.DataFrame(rslt)

# %%
rslt["Unweighted mean velocity"] = np.mean(vv)
rslt["Unweighted sigma^2"] = np.var(vv)
#v0w = rslt["Weighted mean velocity"] = np.average(vv, weights=sb)
#rslt["Weighted sigma^2"] = np.average((vv - v0w)**2, weights=sb)

# %%
b2    = rslt['Unweighted B(r)']
#b2w   = rslt['Weighted B(r)']
e_b2  = b2  *.1
#e_b2w = b2w  *.1

s     = 10**rslt['log10 r'] * pix * pc
e_s   = s  *.1
sig2  = rslt['Unweighted sigma^2']
#sig2w = rslt['Weighted sigma^2']

sig   = sig2**0.5

# %%
#r0    = np.interp(sig2, b2[1:35], s[1:35])
r0    = ra
m     = m2D

rgrid = np.linspace(s[0], s[:-1])

fig, ax = plt.subplots(figsize=(8, 6))

ax.errorbar(s, b2, yerr=e_b2, xerr=e_s, fmt='o', alpha=0.4,color="blue")
#ax.errorbar(s, b2w, yerr=e_b2w, xerr=e_s, fmt='x', alpha=0.4,color="green")

ax.axhline(sig2, ls='-')
ax.axvline(r0, ls='-')

ax.plot(rgrid, bfunc.bfunc00s(rgrid, r0, sig2, m), color="0.8")
ax.plot(rgrid, bfunc.bfunc03s(rgrid, r0, sig2, m, s0, noise), color="black")
#ax.plot(rgrid, bfunc.bfunc04s(rgrid, r0, sig2, m, s0, noise, box_size), color="black")


ax.set(xscale='log', yscale='log', 
       xlabel='separation,pc',
       ylabel=r'$b^2,\ \mathrm{km^2\ s^{-2}}$'
      )
None

plt.show()

# %% [markdown]
# # Export

# %%
from astropy.table import Table


df =  rslt_.copy()

# Flatten MultiIndex columns like ('s','count') -> "s_count"
if isinstance(df.columns, pd.MultiIndex):
    df.columns = ["_".join(map(str, col)).strip() for col in df.columns.to_flat_index()]
else:
    df.columns = [str(c) for c in df.columns]

# (Optional) drop index to avoid it becoming an extra column
df = df.reset_index(drop=True)

t = Table.from_pandas(df)
new_hdu = fits.BinTableHDU(t, name="TABLE")

# %%
with fits.open(fits_path, mode="readonly") as hdul:
    hdus = [h.copy() for h in hdul]   # copy existing HDUs

hdus.append(new_hdu)
fits.HDUList(hdus).writeto(fits_path, overwrite=True)

# %%
# Test import

from astropy.table import Table
t = Table.read(fits_path, hdu="TABLE")
df_loaded = t.to_pandas()
df_loaded
# Out:
#     log10 r      Sum dv^2  Sum weights  Sum w * dv^2    N pairs  \
# 0      0.00  2.687489e+03      65280.0  2.687489e+03      65280
# 1      0.05  0.000000e+00          0.0  0.000000e+00          0
# 2      0.10  0.000000e+00          0.0  0.000000e+00          0
# 3      0.15  9.772005e+03     130050.0  9.772005e+03     130050
# 4      0.20  0.000000e+00          0.0  0.000000e+00          0
# 5      0.25  0.000000e+00          0.0  0.000000e+00          0
# 6      0.30  3.881420e+04     324104.0  3.881420e+04     324104
# 7      0.35  0.000000e+00          0.0  0.000000e+00          0
# 8      0.40  0.000000e+00          0.0  0.000000e+00          0
# 9      0.45  2.968913e+04     193800.0  2.968913e+04     193800
# 10     0.50  4.588205e+04     258060.0  4.588205e+04     258060
# 11     0.55  5.083699e+04     257048.0  5.083699e+04     257048
# 12     0.60  1.008604e+05     449570.0  1.008604e+05     449570
# 13     0.65  1.456583e+05     575312.0  1.456583e+05     575312
# 14     0.70  1.452375e+05     511036.0  1.452375e+05     511036
# 15     0.75  2.172263e+05     700020.0  2.172263e+05     700020
# 16     0.80  4.184119e+05    1203734.0  4.184119e+05    1203734
# 17     0.85  3.868443e+05    1007972.0  3.868443e+05    1007972
# 18     0.90  6.065720e+05    1445380.0  6.065720e+05    1445380
# 19     0.95  8.980554e+05    1937042.0  8.980554e+05    1937042
# 20     1.00  1.472949e+06    2859272.0  1.472949e+06    2859272
# 21     1.05  1.645028e+06    2897116.0  1.645028e+06    2897116
# 22     1.10  2.281621e+06    3674690.0  2.281621e+06    3674690
# 23     1.15  3.517268e+06    5155474.0  3.517268e+06    5155474
# 24     1.20  4.319705e+06    5773520.0  4.319705e+06    5773520
# 25     1.25  6.113764e+06    7491838.0  6.113764e+06    7491838
# 26     1.30  8.649191e+06    9701238.0  8.649191e+06    9701238
# 27     1.35  1.142646e+07   11757186.0  1.142646e+07   11757186
# 28     1.40  1.513474e+07   14320938.0  1.513474e+07   14320938
# 29     1.45  2.007101e+07   17540114.0  2.007101e+07   17540114
# 30     1.50  2.811409e+07   22734900.0  2.811409e+07   22734900
# 31     1.55  3.499000e+07   26303374.0  3.499000e+07   26303374
# 32     1.60  4.851487e+07   34062188.0  4.851487e+07   34062188
# 33     1.65  6.197233e+07   40733820.0  6.197233e+07   40733820
# 34     1.70  8.112292e+07   50149068.0  8.112292e+07   50149068
# 35     1.75  1.031468e+08   60431004.0  1.031468e+08   60431004
# 36     1.80  1.296383e+08   72289830.0  1.296383e+08   72289830
# 37     1.85  1.648259e+08   87731826.0  1.648259e+08   87731826
# 38     1.90  2.010354e+08  102476376.0  2.010354e+08  102476376
# 39     1.95  2.456201e+08  120332462.0  2.456201e+08  120332462
# 40     2.00  2.975966e+08  140368314.0  2.975966e+08  140368314
# 41     2.05  3.460628e+08  158782298.0  3.460628e+08  158782298
# 42     2.10  3.991775e+08  178392398.0  3.991775e+08  178392398
# 43     2.15  4.456296e+08  192781200.0  4.456296e+08  192781200
# 44     2.20  4.722466e+08  200564162.0  4.722466e+08  200564162
# 45     2.25  4.582345e+08  196929652.0  4.582345e+08  196929652
# 46     2.30  3.631061e+08  173862636.0  3.631061e+08  173862636
# 47     2.35  2.144571e+08  123283452.0  2.144571e+08  123283452
# 48     2.40  8.528102e+07   50816154.0  8.528102e+07   50816154
# 49     2.45  2.058340e+07   14282052.0  2.058340e+07   14282052
# 50     2.50  1.053485e+06    1557090.0  1.053485e+06    1557090
#
#     Unweighted B(r)  Weighted B(r)
# 0          0.041169       0.041169
# 1               NaN            NaN
# 2               NaN            NaN
# 3          0.075140       0.075140
# 4               NaN            NaN
# 5               NaN            NaN
# 6          0.119758       0.119758
# 7               NaN            NaN
# 8               NaN            NaN
# 9          0.153195       0.153195
# 10         0.177796       0.177796
# 11         0.197772       0.197772
# 12         0.224349       0.224349
# 13         0.253181       0.253181
# 14         0.284202       0.284202
# 15         0.310314       0.310314
# 16         0.347595       0.347595
# 17         0.383785       0.383785
# 18         0.419663       0.419663
# 19         0.463622       0.463622
# 20         0.515148       0.515148
# 21         0.567816       0.567816
# 22         0.620902       0.620902
# 23         0.682239       0.682239
# 24         0.748193       0.748193
# 25         0.816057       0.816057
# 26         0.891555       0.891555
# 27         0.971871       0.971871
# 28         1.056826       1.056826
# 29         1.144292       1.144292
# 30         1.236605       1.236605
# 31         1.330248       1.330248
# 32         1.424303       1.424303
# 33         1.521397       1.521397
# 34         1.617636       1.617636
# 35         1.706853       1.706853
# 36         1.793314       1.793314
# 37         1.878747       1.878747
# 38         1.961773       1.961773
# 39         2.041179       2.041179
# 40         2.120112       2.120112
# 41         2.179480       2.179480
# 42         2.237637       2.237637
# 43         2.311582       2.311582
# 44         2.354591       2.354591
# 45         2.326895       2.326895
# 46         2.088465       2.088465
# 47         1.739545       1.739545
# 48         1.678227       1.678227
# 49         1.441207       1.441207
# 50         0.676573       0.676573

# %%
print("--- %s seconds ---" % (time.time()-start_time))
# Out:
# --- 4.608905792236328 seconds ---
