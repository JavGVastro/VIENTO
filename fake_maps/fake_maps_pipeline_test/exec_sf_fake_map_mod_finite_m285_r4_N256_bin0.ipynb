# %%
# Parameters
name      = ""
fits_path = ""

# %%
# Parameters
name = "fake_map_mod_finite_m285_r4_N256_bin0"
fits_path = "fits_ready/fake_map_mod_finite_m285_r4_N256_bin0.fits"

# %% [raw]
# name      = 'fake_map_mod_finite_m285_r1_N256_bin0'
# fits_path = "fits_ready/" + name + ".fits"

# %%
import time
start_time=time.time()

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import sys
from pathlib import Path
import astropy.units as u
from matplotlib import pyplot as plt
import corner
import json
from astropy.io import fits
from lmfit.model import save_modelresult


# Add path to py_modules 
sys.path.append(str(Path().resolve() / 'py_modules')) # 1 level up = project root

#import strucfunc                   
import strucfunc
import fit_structure_function
import ci_results_compiler
import bfunc
import bplot

# %% [markdown]
# # Velocity Field

# %%
# Loading obs
hdul = fits.open(fits_path)
hdr = hdul[0].header
print(hdul.info())
print(hdr)
#sb = hdul['MOM0'].data.astype(float)
vv= hdul['MOM1'].data.astype(float)
# Out:
# Filename: fits_ready/fake_map_mod_finite_m285_r4_N256_bin0.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      27   ()
#   1  MOM1          1 ImageHDU         8   (256, 256)   float64
# None
# SIMPLE  =                    T / conforms to FITS standard                      BITPIX  =                    8 / array data type                                NAXIS   =                    0 / number of array dimensions                     EXTEND  =                    T                                                  FILE    = 'fake_map_mod_finite_m285_r4_N256_bin0' / Fits file name              NAME_ID = 'fake_map_mod_finite_m285_r4_N256_bin0' / pipeline identifier         REG     = 'Synthetic 2D map'   / Region catalog name                            NAME_REG= 'Synthetic 2D map'   / Region name                                    REG_ID  = 'Synthetic 2D map'   / Region identifier                              TYPE_OBJ= 'NaN     '           / Type object                                    DIST    =                    1 / Distance in parsecs                            INSTR   = 'NaN     '           / Instrument                                     LINE    = 'Synthetic 2D map'   / Emission line name                             LINE_ID = 'Synthetic 2D map'   / Emission line identifier                       L_REST  =                    0 / Emission line name                             SIG     =    0.515600138781116 / Standard deviation vel map                     SIG2    =  0.26584350311110605 / Vel Variance map                               S0      =                    0 / Atmospheric seeing                             BOX_SIZE=                  256 / Observational box_size                         PC      =                    1 / parsec convertion                              PIX     =                    1 / Instrument pixel scale                         BINSIZE =                    0 / Spatial binning factor                         NOISE   =                    0 / Instrumental noise                             M2D     =                 0.85 / k = 3 + m3D                                    RA      =                  4.0 / Artificial correlation length                  SEED1   =             18940425 / Random seed velocity                           AUTHOR  = 'J. Garcia-Vazquez'  / File creator                                   END

# %%
with fits.open(fits_path) as hdul:
    hdr = hdul[0].header

hdr
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# FILE    = 'fake_map_mod_finite_m285_r4_N256_bin0' / Fits file name
# NAME_ID = 'fake_map_mod_finite_m285_r4_N256_bin0' / pipeline identifier
# REG     = 'Synthetic 2D map'   / Region catalog name
# NAME_REG= 'Synthetic 2D map'   / Region name
# REG_ID  = 'Synthetic 2D map'   / Region identifier
# TYPE_OBJ= 'NaN     '           / Type object
# DIST    =                    1 / Distance in parsecs
# INSTR   = 'NaN     '           / Instrument
# LINE    = 'Synthetic 2D map'   / Emission line name
# LINE_ID = 'Synthetic 2D map'   / Emission line identifier
# L_REST  =                    0 / Emission line name
# SIG     =    0.515600138781116 / Standard deviation vel map
# SIG2    =  0.26584350311110605 / Vel Variance map
# S0      =                    0 / Atmospheric seeing
# BOX_SIZE=                  256 / Observational box_size
# PC      =                    1 / parsec convertion
# PIX     =                    1 / Instrument pixel scale
# BINSIZE =                    0 / Spatial binning factor
# NOISE   =                    0 / Instrumental noise
# M2D     =                 0.85 / k = 3 + m3D
# RA      =                  4.0 / Artificial correlation length
# SEED1   =             18940425 / Random seed velocity
# AUTHOR  = 'J. Garcia-Vazquez'  / File creator

# %%
m2D      = hdul[0].header['M2D']
ra       = hdul[0].header['RA']
sig      = hdul[0].header['SIG']
sig2     = hdul[0].header['SIG2']
s0       = hdul[0].header['S0']
noise    = hdul[0].header['NOISE']
box_size = hdul[0].header['BOX_SIZE']
pc       = hdul[0].header['PC']
pix      = hdul[0].header['PIX']
line     = hdul[0].header['LINE']
binsize  = hdul[0].header['BINSIZE']

# %%
fig, ax = plt.subplots(figsize=(5, 4))

imshow_kwds = dict(origin="lower", cmap="RdBu_r")
im = ax.imshow(vv, **imshow_kwds)

cbar = fig.colorbar(im, ax=ax)
cbar.set_label(r"$\sigma$ (-)", rotation=270, labelpad=15)

ax.set_xlabel("pix")
ax.set_ylabel("pix")
# 33     1.65  8.095590e+07   40733820.0  8.095590e+07   40733820
# 34     1.70  9.978769e+07   50149068.0  9.978769e+07   50149068
# 35     1.75  1.199692e+08   60431004.0  1.199692e+08   60431004
# 36     1.80  1.435874e+08   72289830.0  1.435874e+08   72289830
# 37     1.85  1.740212e+08   87731826.0  1.740212e+08   87731826
# 38     1.90  2.031654e+08  102476376.0  2.031654e+08  102476376
# 39     1.95  2.381043e+08  120332462.0  2.381043e+08  120332462
# 40     2.00  2.789109e+08  140368314.0  2.789109e+08  140368314
# 41     2.05  3.149521e+08  158782298.0  3.149521e+08  158782298
# 42     2.10  3.546582e+08  178392398.0  3.546582e+08  178392398
# 43     2.15  3.855303e+08  192781200.0  3.855303e+08  192781200
# 44     2.20  4.015978e+08  200564162.0  4.015978e+08  200564162
# 45     2.25  3.972612e+08  196929652.0  3.972612e+08  196929652
# 46     2.30  3.507605e+08  173862636.0  3.507605e+08  173862636
# 47     2.35  2.515124e+08  123283452.0  2.515124e+08  123283452
# 48     2.40  1.050502e+08   50816154.0  1.050502e+08   50816154
# 49     2.45  2.972353e+07   14282052.0  2.972353e+07   14282052
# 50     2.50  3.137397e+06    1557090.0  3.137397e+06    1557090
#
#     Unweighted B(r)  Weighted B(r)
# 0          0.487459       0.487459
# 1               NaN            NaN
# 2               NaN            NaN
# 3          0.814808       0.814808
# 4               NaN            NaN
# 5               NaN            NaN
# 6          1.151768       1.151768
# 7               NaN            NaN
# 8               NaN            NaN
# 9          1.333757       1.333757
# 10         1.473030       1.473030
# 11         1.531991       1.531991
# 12         1.641709       1.641709
# 13         1.709096       1.709096
# 14         1.812557       1.812557
# 15         1.847582       1.847582
# 16         1.905206       1.905206
# 17         1.942888       1.942888
# 18         1.983478       1.983478
# 19         2.009320       2.009320
# 20         2.032862       2.032862
# 21         2.036628       2.036628
# 22         2.042288       2.042288
# 23         2.038218       2.038218
# 24         2.037439       2.037439
# 25         2.028697       2.028697
# 26         2.019564       2.019564
# 27         2.008702       2.008702
# 28         2.004932       2.004932
# 29         2.000455       2.000455
# 30         1.993261       1.993261
# 31         1.991804       1.991804
# 32         1.988526       1.988526
# 33         1.987437       1.987437
# 34         1.989821       1.989821
# 35         1.985226       1.985226
# 36         1.986274       1.986274
# 37         1.983559       1.983559
# 38         1.982558       1.982558
# 39         1.978720       1.978720
# 40         1.986993       1.986993
# 41         1.983547       1.983547
# 42         1.988079       1.988079
# 43         1.999834       1.999834
# 44         2.002341       2.002341
# 45         2.017275       2.017275
# 46         2.017458       2.017458
# 47         2.040115       2.040115
# 48         2.067259       2.067259
# 49         2.081181       2.081181
# 50         2.014910       2.014910

# %%
print("--- %s seconds ---" % (time.time()-start_time))
# Out:
# --- 4.636563062667847 seconds ---
