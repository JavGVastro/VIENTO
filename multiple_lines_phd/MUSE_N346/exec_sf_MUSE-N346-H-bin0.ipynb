# %%
# Parameters
name      = ""
fits_path = ""

# %%
# Parameters
name = "MUSE-N346-H-bin0"
fits_path = "fits_ready/MUSE-N346-H-bin0.fits"

# %% [raw]
# name      = 'MUSE-Dor-H'
# fits_path = "fits_ready/" + name + ".fits"

# %%
import time
start_time=time.time()

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import sys
from pathlib import Path
import astropy.units as u
from matplotlib import pyplot as plt
import corner
import json
from astropy.io import fits
from lmfit.model import save_modelresult


# Add path to py_modules 
sys.path.append(str(Path().resolve() / 'py_modules')) # 1 level up = project root

#import strucfunc                   
import strucfunc
import fit_structure_function
import ci_results_compiler
import bfunc
import bplot

# %% [markdown]
# # Velocity Field

# %%
# Loading obs
hdul = fits.open(fits_path)
hdr = hdul[0].header
print(hdul.info())
print(hdr)
sb = hdul['MOM0'].data.astype(float)
vv= hdul['MOM1'].data.astype(float)
# Out:
# Filename: fits_ready/MUSE-N346-H-bin0.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      23   ()
#   1  MOM0          1 ImageHDU         8   (320, 295)   float64
#   2  MOM1          1 ImageHDU         8   (320, 295)   float64
#   3  MOM2          1 ImageHDU         8   (320, 295)   float64
#   4  MASK          1 ImageHDU         8   (320, 295)   uint8
# None
# SIMPLE  =                    T / conforms to FITS standard                      BITPIX  =                    8 / array data type                                NAXIS   =                    0 / number of array dimensions                     EXTEND  =                    T                                                  FILE    = 'MUSE-N346-H'        / Fits file name                                 NAME_ID = 'MUSE-N346-H-bin0'   / pipeline identifier                            REG     = 'NGC 346 '           / Region catalog name                            NAME_REG= 'N346    '           / Region name                                    REG_ID  = 'N346    '           / Region identifier                              TYPE_OBJ= 'H II region'        / Type object                                    DIST    =                62000 / Distance in parsecs                            INSTR   = 'MUSE    '           / Instrument                                     LINE    = 'H$\alpha$'          / Emission line name                             LINE_ID = 'H       '           / Emission line identifier                       L_REST  =               6562.8 / Emission line name                             SIG     =    4.987019677088686 / Standard deviation vel map                     SIG2    =    24.87036525966974 / Vel Variance map                               S0      =  0.27052603405912107 / Atmospheric seeing                             BOX_SIZE=   18.470665744008677 / Observational box_size                         PC      =   0.3005844822879123 / parsec convertion                              PIX     =                  0.2 / Instrument pixel scale                         BINSIZE =                    0 / Spatial binning factor                         AUTHOR  = 'J. Garcia-Vazquez'  / File creator                                   END

# %%
with fits.open(fits_path) as hdul:
    hdr = hdul[0].header

hdr
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# FILE    = 'MUSE-N346-H'        / Fits file name
# NAME_ID = 'MUSE-N346-H-bin0'   / pipeline identifier
# REG     = 'NGC 346 '           / Region catalog name
# NAME_REG= 'N346    '           / Region name
# REG_ID  = 'N346    '           / Region identifier
# TYPE_OBJ= 'H II region'        / Type object
# DIST    =                62000 / Distance in parsecs
# INSTR   = 'MUSE    '           / Instrument
# LINE    = 'H$\alpha$'          / Emission line name
# LINE_ID = 'H       '           / Emission line identifier
# L_REST  =               6562.8 / Emission line name
# SIG     =    4.987019677088686 / Standard deviation vel map
# SIG2    =    24.87036525966974 / Vel Variance map
# S0      =  0.27052603405912107 / Atmospheric seeing
# BOX_SIZE=   18.470665744008677 / Observational box_size
# PC      =   0.3005844822879123 / parsec convertion
# PIX     =                  0.2 / Instrument pixel scale
# BINSIZE =                    0 / Spatial binning factor
# AUTHOR  = 'J. Garcia-Vazquez'  / File creator

# %%
#m3D      = hdul[0].header['M3D']
#ra       = hdul[0].header['RA']
sig      = hdul[0].header['SIG']
sig2     = hdul[0].header['SIG2']
s0       = hdul[0].header['S0']
#noise    = hdul[0].header['NOISE']
box_size = hdul[0].header['BOX_SIZE']
pc       = hdul[0].header['PC']
pix      = hdul[0].header['PIX']
line     = hdul[0].header['LINE']
binsize  = hdul[0].header['BINSIZE']

# %%
fig, (ax, axx) = plt.subplots(
    1,
    2,
    sharey=True,
    figsize=(10, 4),
)
imshow_kwds = dict(origin="lower", cmap="RdBu_r")
imshow_kwds2 = dict(origin="lower", cmap="magma")
im = ax.imshow(vv, **imshow_kwds)
cbar = fig.colorbar(im, ax=[ax])
cbar.set_label("$\sigma$ (-)", rotation=270, labelpad=15)
im = axx.imshow(sb, **imshow_kwds2)
cbar = fig.colorbar(im, ax=[axx])
cbar.set_label("rad. vel. (km/s)", rotation=270, labelpad=15)

ax.set_xlabel("pix")
ax.set_ylabel("pix")
axx.set_xlabel("pix")
ax.set_title("Moment 1")
axx.set_title("Moment 0")
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\s'
# <>:11: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\javas\AppData\Local\Temp\ipykernel_23472\669126516.py:11: SyntaxWarning: invalid escape sequence '\s'
#   cbar.set_label("$\sigma$ (-)", rotation=270, labelpad=15)
# Text(0.5, 1.0, 'Moment 0')

# %% [markdown]
# # Structure function

# %%
rslt = strucfunc.strucfunc_numba_parallel(vv, wmap=sb, dlogr=0.05)
# Out:
# C:\Users\javas\Dropbox\GitHub\VIENTO\multiple_lines_phd\MUSE_N346\py_modules\strucfunc.py:83: RuntimeWarning: invalid value encountered in divide
#   'Unweighted B(r)': sf/nsf,
# C:\Users