# %%
# Parameters
name      = ""
fits_path = ""

# %%
# Parameters
name = "MUSE-N346-S-bin0"
fits_path = "fits_ready/MUSE-N346-S-bin0.fits"

# %% [raw]
# name      = 'MUSE-Dor-H'
# fits_path = "fits_ready/" + name + ".fits"

# %%
import time
start_time=time.time()

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import sys
from pathlib import Path
import astropy.units as u
from matplotlib import pyplot as plt
import corner
import json
from astropy.io import fits
from lmfit.model import save_modelresult


# Add path to py_modules 
sys.path.append(str(Path().resolve() / 'py_modules')) # 1 level up = project root

#import strucfunc                   
import strucfunc
import fit_structure_function
import ci_results_compiler
import bfunc
import bplot

# %% [markdown]
# # Velocity Field

# %%
# Loading obs
hdul = fits.open(fits_path)
hdr = hdul[0].header
print(hdul.info())
print(hdr)
sb = hdul['MOM0'].data.astype(float)
vv= hdul['MOM1'].data.astype(float)
# Out:
# Filename: fits_ready/MUSE-N346-S-bin0.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      23   ()
#   1  MOM0          1 ImageHDU         8   (320, 295)   float64
#   2  MOM1          1 ImageHDU         8   (320, 295)   float64
#   3  MOM2          1 ImageHDU         8   (320, 295)   float64
#   4  MASK          1 ImageHDU         8   (320, 295)   uint8
# None
# SIMPLE  =                    T / conforms to FITS standard                      BITPIX  =                    8 / array data type                                NAXIS   =                    0 / number of array dimensions                     EXTEND  =                    T                                                  FILE    = 'MUSE-N346-S'        / Fits file name                                 NAME_ID = 'MUSE-N346-S-bin0'   / pipeline identifier                            REG     = 'NGC 346 '           / Region catalog name                            NAME_REG= 'N346    '           / Region name                                    REG_ID  = 'N346    '           / Region identifier                              TYPE_OBJ= 'H II region'        / Type object                                    DIST    =                62000 / Distance in parsecs                            INSTR   = 'MUSE    '           / Instrument                                     LINE    = '[S II] $\lambda$ 6731' / Emission line name                          LINE_ID = 'S       '           / Emission line identifier                       L_REST  =               6730.8 / Emission line name                             SIG     =    6.721591733124812 / Standard deviation vel map                     SIG2    =    45.17979542681181 / Vel Variance map                               S0      =  0.27052603405912107 / Atmospheric seeing                             BOX_SIZE=   18.470665744008677 / Observational box_size                         PC      =   0.3005844822879123 / parsec convertion                              PIX     =                  0.2 / Instrument pixel scale                         BINSIZE =                    0 / Spatial binning factor                         AUTHOR  = 'J. Garcia-Vazquez'  / File creator                                   END

# %%
with fits.open(fits_path) as hdul:
    hdr = hdul[0].header

hdr
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# FILE    = 'MUSE-N346-S'        / Fits file name
# NAME_ID = 'MUSE-N346-S-bin0'   / pipeline identifier
# REG     = 'NGC 346 '           / Region catalog name
# NAME_REG= 'N346    '           / Region name
# REG_ID  = 'N346    '           / Region identifier
# TYPE_OBJ= 'H II region'        / Type object
# DIST    =                62000 / Distance in parsecs
# INSTR   = 'MUSE    '           / Instrument
# LINE    = '[S II] $\lambda$ 6731' / Emission line name
# LINE_ID = 'S       '           / Emission line identifier
# L_REST  =               6730.8 / Emission line name
# SIG     =    6.721591733124812 / Standard deviation vel map
# SIG2    =    45.17979542681181 / Vel Variance map
# S0      =  0.27052603405912107 / Atmospheric seeing
# BOX_SIZE=   18.470665744008677 / Observational box_size
# PC      =   0.3005844822879123 / parsec convertion
# PIX     =                  0.2 / Instrument pixel scale
# BINSIZE =                    0 / Spatial binning factor
# AUTHOR  = 'J. Garcia-Vazquez'  / File creator

# %%
#m3D      = hdul[0].header['M3D']
#ra       = hdul[0].header['RA']
sig      = hdul[0].header['SIG']
sig2     = hdul[0].header['SIG2']
s0       = hdul[0].header['S0']
#noise    = hdul[0].header['NOISE']
box_size = hdul[0].header['BOX_SIZE']
pc       = hdul[0].header['PC']
pix      = hdul[0].header['PIX']
line     = hdul[0].header['LINE']
binsize  = hdul[0].header['BINSIZE']

# %%
fig, (ax, axx) = plt.subplots(
    1,
    2,
    sharey=True,
    figsize=(10, 4),
)
imshow_kwds = dict(origin="lower", cmap="RdBu_r")
imshow_kwds2 = dict(origin="lower", cmap="magma")
im = ax.imshow(vv, **imshow_kwds)
cbar = fig.colorbar(im, ax=[ax])
cbar.set_label("$\sigma$ (-)", rotation=270, labelpad=15)
im = axx.imshow(sb, **imshow_kwds2)
cbar = fig.colorbar(im, ax=[axx])
cbar.set_label("rad. vel. (km/s)", rotation=270, labelpad=15)

ax.set_xlabel("pix")
ax.set_ylabel("pix")
axx.set_xlabel("pix")
ax.set_title("Moment 1")
axx.set_title("Moment 0")
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\s'
# <>:11: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\javas\AppData\Local\Temp\ipykernel_7972\669126516.py:11: SyntaxWarning: invalid escape sequence '\s'
#   cbar.set_label("$\sigma$ (-)", rotation=270, labelpad=15)
# Text(0.5, 1.0, 'Moment 0')

# %% [markdown]
# # Structure function

# %%
rslt = strucfunc.strucfunc_numba_parallel(vv, wmap=sb, dlogr=0.05)
# Out:
# C:\Users\javas\Dropbox\GitHub\VIENTO\multiple_lines_phd\MUSE_N346\py_modules\strucfunc.py:83: RuntimeWarning: invalid value encountered in divide
#   'Unweighted B(r)': sf/nsf,
# C:\Users\javas\Dropbox\GitHub\VIENTO\multiple_lines_phd\MUSE_N346\py_modules\strucfunc.py:84: RuntimeWarning: invalid value encountered in divide
#   'Weighted B(r)': wsf/weight}

# %%
rslt_ = pd.DataFrame(rslt)

# %%
rslt["Unweighted mean velocity"] = np.mean(vv)
rslt["Unweighted sigma^2"] = np.var(vv)
v0w = rslt["Weighted mean velocity"] = np.average(vv, weights=sb)
rslt["Weighted sigma^2"] = np.average((vv - v0w)**2, weights=sb)

# %%
b2    = rslt['Unweighted B(r)']
b2w   = rslt['Weighted B(r)']
e_b2  = b2  *.1
e_b2w = b2w  *.1

s     = 10**rslt['log10 r'] * pix * pc
e_s   = s  *.1
sig2  = rslt['Unweighted sigma^2']
sig2w = rslt['Weighted sigma^2']

sig   = sig2**0.5

# %%
r0    = np.interp(sig2, b2[1:35], s[1:35])
ra = r0
m     = 1
noise = 0

rgrid = np.linspace(s[0], s[:-1])

fig, ax = plt.subplots(figsize=(8, 6))

ax.errorbar(s, b2, yerr=e_b2, xerr=e_s, fmt='o', alpha=0.4,color="blue")
ax.errorbar(s, b2w, yerr=e_b2w, xerr=e_s, fmt='x', alpha=0.4,color="green")

ax.axhline(sig2, ls='-')
ax.axvline(r0, ls='-')

ax.plot(rgrid, bfunc.bfunc00s(rgrid, r0, sig2, m), color="0.8")
ax.plot(rgrid, bfunc.bfunc03s(rgrid, r0, sig2, m, s0, noise), color="black")
#ax.plot(rgrid, bfunc.bfunc04s(rgrid, r0, sig2, m, s0, noise, box_size), color="black")


ax.set(xscale='log', yscale='log', 
       xlabel='separation,pc',
       ylabel=r'$b^2,\ \mathrm{km^2\ s^{-2}}$'
      )
None

plt.show()

# %% [markdown]
# # Export

# %%
from astropy.table import Table


df =  rslt_.copy()

# Flatten MultiIndex columns like ('s','count') -> "s_count"
if isinstance(df.columns, pd.MultiIndex):
    df.columns = ["_".join(map(str, col)).strip() for col in df.columns.to_flat_index()]
else:
    df.columns = [str(c) for c in df.columns]

# (Optional) drop index to avoid it becoming an extra column
df = df.reset_index(drop=True)

t = Table.from_pandas(df)
new_hdu = fits.BinTableHDU(t, name="TABLE")

# %%
with fits.open(fits_path, mode="readonly") as hdul:
    hdus = [h.copy() for h in hdul]   # copy existing HDUs

hdus.append(new_hdu)
fits.HDUList(hdus).writeto(fits_path, overwrite=True)

# %%
# Test import

from astropy.table import Table
t = Table.read(fits_path, hdu="TABLE")
df_loaded = t.to_pandas()
df_loaded
# Out:
#     log10 r      Sum dv^2    Sum weights  Sum w * dv^2    N pairs  \
# 0      0.00  1.294613e+06     300.632597  1.048985e+03      89824
# 1      0.05  0.000000e+00       0.000000  0.000000e+00          0
# 2      0.10  0.000000e+00       0.000000  0.000000e+00          0
# 3      0.15  2.944020e+06     594.638709  2.705508e+03     178939
# 4      0.20  0.000000e+00       0.000000  0.000000e+00          0
# 5      0.25  0.000000e+00       0.000000  0.000000e+00          0
# 6      0.30  7.711230e+06    1467.832865  7.855126e+03     445916
# 7      0.35  0.000000e+00       0.000000  0.000000e+00          0
# 8      0.40  0.000000e+00       0.000000  0.000000e+00          0
# 9      0.45  4.715149e+06     868.598366  5.363334e+03     266557
# 10     0.50  6.457140e+06    1148.241486  7.620749e+03     354995
# 11     0.55  6.632505e+06    1132.676193  8.326157e+03     353736
# 12     0.60  1.179708e+07    1964.790274  1.537841e+04     618284
# 13     0.65  1.573389e+07    2479.028996  2.165270e+04     791452
# 14     0.70  1.430417e+07    2179.169862  1.988897e+04     702870
# 15     0.75  2.020414e+07    2946.552583  2.928439e+04     962851
# 16     0.80  3.616910e+07    4978.721820  5.370813e+04    1655840
# 17     0.85  3.155701e+07    4090.315663  4.767627e+04    1387277
# 18     0.90  4.671619e+07    5784.514635  7.032240e+04    1989061
# 19     0.95  6.531440e+07    7595.073550  9.844248e+04    2666918
# 20     1.00  1.007168e+08   10980.010200  1.511066e+05    3938127
# 21     1.05  1.070738e+08   10857.058321  1.597871e+05    3994024
# 22     1.10  1.417846e+08   13503.263458  2.106537e+05    5069971
# 23     1.15  2.087758e+08   18488.787997  3.107350e+05    7122479
# 24     1.20  2.448482e+08   20285.226975  3.671224e+05    7985953
# 25     1.25  3.335882e+08   25738.545293  5.075766e+05   10381089
# 26     1.30  4.531951e+08   32661.671783  7.033205e+05   13467356
# 27     1.35  5.779314e+08   38671.807369  9.141727e+05   16363200
# 28     1.40  7.402884e+08   46110.151703  1.184155e+06   19985395
# 29     1.45  9.566192e+08   55131.627292  1.520909e+06   24555713
# 30     1.50  1.313145e+09   69685.574517  2.059023e+06   31943242
# 31     1.55  1.614847e+09   78684.130999  2.527367e+06   37109032
# 32     1.60  2.231734e+09  100023.475579  3.547372e+06   48271563
# 33     1.65  2.864086e+09  118409.437591  4.632265e+06   58025304
# 34     1.70  3.800505e+09  145109.198785  6.203996e+06   71888566
# 35     1.75  4.944718e+09  174707.462887  8.111642e+06   87257349
# 36     1.80  6.374723e+09  209739.503493  1.055745e+07  105235262
# 37     1.85  8.365973e+09  255803.042412  1.418072e+07  128936989
# 38     1.90  1.065230e+10  299366.396116  1.850385e+07  152364747
# 39     1.95  1.371839e+10  353556.634587  2.422591e+07  181438335
# 40     2.00  1.768132e+10  420691.375513  3.266370e+07  215376871
# 41     2.05  2.208361e+10  488532.593683  4.512924e+07  249431719
# 42     2.10  2.702886e+10  553540.652269  5.897353e+07  289033411
# 43     2.15  3.158533e+10  617312.555246  7.222933e+07  325741073
# 44     2.20  3.572754e+10  679433.567307  8.350420e+07  359309616
# 45     2.25  3.941748e+10  722016.747296  9.569951e+07  384805157
# 46     2.30  4.139919e+10  732370.250263  1.035522e+08  392271373
# 47     2.35  4.234231e+10  678594.893367  9.888111e+07  371530570
# 48     2.40  3.880627e+10  586617.994438  8.859017e+07  305014987
# 49     2.45  2.350469e+10  381498.144927  5.691054e+07  183594814
# 50     2.50  8.025080e+09  154977.368768  1.958825e+07   66719820
# 51     2.55  1.896373e+09   45968.039546  5.979644e+06   14790330
#
#     Unweighted B(r)  Weighted B(r)
# 0         14.412775       3.489261
# 1               NaN            NaN
# 2               NaN            NaN
# 3         16.452647       4.549834
# 4               NaN            NaN
# 5               NaN            NaN
# 6         17.293009       5.351512
# 7               NaN            NaN
# 8               NaN            NaN
# 9         17.689084       6.174700
# 10        18.189382       6.636887
# 11        18.749873       7.350871
# 12        19.080354       7.826997
# 13        19.879782       8.734347
# 14        20.351088       9.126855
# 15        20.983657       9.938525
# 16        21.843354      10.787534
# 17        22.747448      11.655891
# 18        23.486553      12.157010
# 19        24.490593      12.961359
# 20        25.574790      13.761972
# 21        26.808496      14.717344
# 22        27.965566      15.600209
# 23        29.312231      16.806672
# 24        30.659865      18.098018
# 25        32.134221      19.720485
# 26        33.651381      21.533513
# 27        35.318970      23.639254
# 28        37.041472      25.680997
# 29        38.957092      27.586865
# 30        41.108709      29.547338
# 31        43.516291      32.120412
# 32        46.232890      35.465398
# 33        49.359258      39.120745
# 34        52.866617      42.753978
# 35        56.668212      46.429856
# 36        60.575920      50.335993
# 37        64.884194      55.436079
# 38        69.913122      61.810047
# 39        75.609125      68.520598
# 40        82.094815      77.642909
# 41        88.535694      92.377140
# 42        93.514663     106.538745
# 43        96.964534     117.006085
# 44        99.433853     122.902668
# 45       102.434910     132.544726
# 46       105.537121     141.393203
# 47       113.967236     145.714490
# 48       127.227423     151.018504
# 49       128.024783     149.176458
# 50       120.280297     126.394235
# 51       128.217115     130.082631

# %%
print("--- %s seconds ---" % (time.time()-start_time))
# Out:
# --- 23.993205547332764 seconds ---
