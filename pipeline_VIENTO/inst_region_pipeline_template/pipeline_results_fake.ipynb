# %%
from matplotlib import pyplot as plt
import numpy as np

import sys
from pathlib import Path

from lmfit.model import load_modelresult


# Add path to py_modules 
sys.path.append(str(Path().resolve() / 'py_modules')) # 1 level up = project root

#from turb_utils import make_extended, make_3dfield
import bfunc
#import strucfunc                   
import plot_fit_params
import ci_results_compiler

# %% [markdown]
# # Loading Fit and confidence intervals

# %%
name = 'fake_cube_finite_sigE0_m300_N128'

result = load_modelresult("results_fit/" + name +"result_ideal.sav")
result_emcee = load_modelresult("results_fit/" + name +"result_emcee_ideal.sav")

fit_Br = {
    'result' : result,
    'result_emcee' : result_emcee }

non_0 = ci_results_compiler.ci_results_compiler_ideal(fit_Br)

name = 'fake_cube_finite_sigE1_m330_N128'

result = load_modelresult("results_fit/" + name +"result_ideal.sav")
result_emcee = load_modelresult("results_fit/" + name +"result_emcee_ideal.sav")

fit_Br = {
    'result' : result,
    'result_emcee' : result_emcee }

non_1 = ci_results_compiler.ci_results_compiler_ideal(fit_Br)

name = 'fake_cube_finite_sigE2_m355_N128'

result = load_modelresult("results_fit/" + name +"result_ideal.sav")
result_emcee = load_modelresult("results_fit/" + name +"result_emcee_ideal.sav")

fit_Br = {
    'result' : result,
    'result_emcee' : result_emcee }

non_2 = ci_results_compiler.ci_results_compiler_ideal(fit_Br)

# %%
name = 'fake_cube_mod_finite_sigE0_m300_r8_N128'

result = load_modelresult("results_fit/" + name +"result_ideal.sav")
result_emcee = load_modelresult("results_fit/" + name +"result_emcee_ideal.sav")

fit_Br = {
    'result' : result,
    'result_emcee' : result_emcee }

mod_0 = ci_results_compiler.ci_results_compiler_ideal(fit_Br)

name = 'fake_cube_mod_finite_sigE1_m330_r8_N128'

result = load_modelresult("results_fit/" + name +"result_ideal.sav")
result_emcee = load_modelresult("results_fit/" + name +"result_emcee_ideal.sav")

fit_Br = {
    'result' : result,
    'result_emcee' : result_emcee }

mod_1 = ci_results_compiler.ci_results_compiler_ideal(fit_Br)

name = 'fake_cube_mod_finite_sigE2_m355_r8_N128'

result = load_modelresult("results_fit/" + name +"result_ideal.sav")
result_emcee = load_modelresult("results_fit/" + name +"result_emcee_ideal.sav")

fit_Br = {
    'result' : result,
    'result_emcee' : result_emcee }

mod_2 = ci_results_compiler.ci_results_compiler_ideal(fit_Br)

# %%
name = 'fake_cube_mod_finite_noise_sigE0_m300_r8_N128'

result = load_modelresult("results_fit/" + name +"result_ideal.sav")
result_emcee = load_modelresult("results_fit/" + name +"result_emcee_ideal.sav")

fit_Br = {
    'result' : result,
    'result_emcee' : result_emcee }

modn_0 = ci_results_compiler.ci_results_compiler_ideal(fit_Br)

name = 'fake_cube_mod_finite_noise_sigE1_m330_r8_N128'

result = load_modelresult("results_fit/" + name +"result_ideal.sav")
result_emcee = load_modelresult("results_fit/" + name +"result_emcee_ideal.sav")

fit_Br = {
    'result' : result,
    'result_emcee' : result_emcee }

modn_1 = ci_results_compiler.ci_results_compiler_ideal(fit_Br)

name = 'fake_cube_mod_finite_noise_sigE2_m355_r8_N128'

result = load_modelresult("results_fit/" + name +"result_ideal.sav")
result_emcee = load_modelresult("results_fit/" + name +"result_emcee_ideal.sav")

fit_Br = {
    'result' : result,
    'result_emcee' : result_emcee }

modn_2 = ci_results_compiler.ci_results_compiler_ideal(fit_Br)

# %%
samples = [mod_0, mod_1, mod_2]

# %%
labels  = ['sigE0', 'sigE1', 'sigE2','sigE0 mod', 'sigE1 mod', 'sigE2 mod', 'sigE0 modn', 'sigE1 modn', 'sigE2 modn']

# %% [markdown]
# # Plots

# %%
plot_fit_params.plot_param_comp(non_0, non_1, non_2, mod_0, mod_1, mod_2, modn_0, modn_1, modn_2, labels=labels,
                                decimals=4)

# %%
plot_fit_params.plot_param(non_0, non_1, non_2, mod_0, mod_1, mod_2, modn_0, modn_1, modn_2, labels=labels,
                                decimals=4)
