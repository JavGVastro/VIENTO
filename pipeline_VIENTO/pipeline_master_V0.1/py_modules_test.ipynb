# %%
import sys
from pathlib import Path

sys.path.append(str(Path().resolve() / 'py_modules'))

# %% [markdown]
# # astronomical_objects.py

# %%
from astronomical_objects import OBJECTS, print_available_objects

# %%
print_available_objects()
# Out:
# 30Doradus
# Orion
# Carina
# Lagoon
# N346
# N604
# N595
# Helix

# %%
nebula = OBJECTS["N604"]

# %%
nebula
# Out:
# AstronomicalObject(key='N604', catalog_name='NGC 604', common_name='NGC 604', object_id='N604', object_type='H II region', distance_pc=840000, main_reference=None, points_of_interest={})

# %%
nebula.points_of_interest
# Out:
# {}

# %%
nebula.pc_per_arcsec
# Out:
# 4.072434921320102

# %% [markdown]
# # spectral_lines.py

# %%
from spectral_lines import LINES, print_available_lines

# %%
print_available_lines()
# Out:
# Halpha
# NII_6583
# SII_6731
# OIII_5007
# OII_3729
# ArIII_7136
# SIII_9069

# %%
cfg = LINES["Halpha"]

plot_label      = cfg.plot_label
rest_wavelength = cfg.rest_wavelength
wavelength_id    = cfg.wavelength_id
element         = cfg.element
ion             = cfg.ion
transition_id   = cfg.transition_id

# %%
print(plot_label)
print(rest_wavelength)
print(wavelength_id)
print(element)
print(ion)
print(transition_id)
# Out:
# H$\alpha$
# 6562.8
# 6563
# H
# H_I
# H_I-6563

# %% [markdown]
# # astronomical_instruments.py

# %%
from astronomical_instruments import INSTRUMENTS, print_available_instruments

# %%
print_available_instruments()
# Out:
# MUSE
# FLAMES
# KPNO_Echelle
# LVM
# TAURUS2

# %%
instrument = INSTRUMENTS["FLAMES"]

# %%
instrument
# Out:
# AstronomicalInstrument(key='FLAMES', full_name='Fibre Large Array Multi Element Spectrograph', instrument_id='FLA', arcsec_per_pixel=None, site='Paranal', telescope='VLT UT2', focus='Nasmyth A', instrument_type='Multi-object fibre-fed spectrograph', wavelength_coverage='370–950 nm', spectral_resolution='GIRAFFE: R=5500–65100; UVES fibre mode: R~47000', modes=('MEDUSA', 'IFU', 'ARGUS', 'UVES'), notes=None)

# %%
print(instrument.full_name)
print(instrument.instrument_id)
print(instrument.arcsec_per_pixel)
print(instrument.site)
print(instrument.telescope)
print(instrument.wavelength_coverage)
print(instrument.spectral_resolution)
print(instrument.modes)
# Out:
# Fibre Large Array Multi Element Spectrograph
# FLA
# None
# Paranal
# VLT UT2
# 370–950 nm
# GIRAFFE: R=5500–65100; UVES fibre mode: R~47000
# ('MEDUSA', 'IFU', 'ARGUS', 'UVES')
