# %%
from matplotlib import pyplot as plt
import numpy as np

import sys
from pathlib import Path

from lmfit.model import load_modelresult


# Add path to py_modules 
sys.path.append(str(Path().resolve() / 'py_modules')) # 1 level up = project root

#from turb_utils import make_extended, make_3dfield
import bfunc
#import strucfunc                   
import plot_fit_params
import ci_results_compiler

# %% [markdown]
# # Loading Fit and confidence intervals

# %%
name = 'fake_cube_mod_finite_sigE0_m300_r8_N128'

result = load_modelresult("results_fit/" + name +"result_ideal.sav")
result_emcee = load_modelresult("results_fit/" + name +"result_emcee_ideal.sav")

fit_Br = {
    'result' : result,
    'result_emcee' : result_emcee }

sigE0_mod = ci_results_compiler.ci_results_compiler_ideal(fit_Br)

name = 'fake_cube_mod_finite_sigE1_m330_r8_N128'

result = load_modelresult("results_fit/" + name +"result_ideal.sav")
result_emcee = load_modelresult("results_fit/" + name +"result_emcee_ideal.sav")

fit_Br = {
    'result' : result,
    'result_emcee' : result_emcee }

sigE1_mod = ci_results_compiler.ci_results_compiler_ideal(fit_Br)

name = 'fake_cube_mod_finite_sigE2_m355_r8_N128'

result = load_modelresult("results_fit/" + name +"result_ideal.sav")
result_emcee = load_modelresult("results_fit/" + name +"result_emcee_ideal.sav")

fit_Br = {
    'result' : result,
    'result_emcee' : result_emcee }

sigE2_mod = ci_results_compiler.ci_results_compiler_ideal(fit_Br)

# %%
name = 'fake_cube_finite_sigE0_m300_N128'

result = load_modelresult("results_fit/" + name +"result_ideal.sav")
result_emcee = load_modelresult("results_fit/" + name +"result_emcee_ideal.sav")

fit_Br = {
    'result' : result,
    'result_emcee' : result_emcee }

sigE0 = ci_results_compiler.ci_results_compiler_ideal(fit_Br)

name = 'fake_cube_finite_sigE1_m330_N128'

result = load_modelresult("results_fit/" + name +"result_ideal.sav")
result_emcee = load_modelresult("results_fit/" + name +"result_emcee_ideal.sav")

fit_Br = {
    'result' : result,
    'result_emcee' : result_emcee }

sigE1 = ci_results_compiler.ci_results_compiler_ideal(fit_Br)

name = 'fake_cube_finite_sigE2_m355_N128'

result = load_modelresult("results_fit/" + name +"result_ideal.sav")
result_emcee = load_modelresult("results_fit/" + name +"result_emcee_ideal.sav")

fit_Br = {
    'result' : result,
    'result_emcee' : result_emcee }

sigE2 = ci_results_compiler.ci_results_compiler_ideal(fit_Br)

# %%
plot_fit_params.plot_param_comp(sigE0_mod,sigE1_mod,sigE2_mod, sigE0,sigE1,sigE2,
                                labels=['sigE0 mod','sigE1 mod','sigE2 mod','sigE0','sigE1','sigE2'], 
                                decimals=4)

# %%
plot_fit_params.plot_param(sigE0_mod,sigE1_mod,sigE2_mod, sigE0,sigE1,sigE2,
                                labels=['sigE0 mod','sigE1 mod','sigE2 mod','sigE0','sigE1','sigE2'], 
                                decimals=4)
