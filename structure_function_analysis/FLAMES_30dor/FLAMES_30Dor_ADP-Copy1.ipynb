# %%
from astropy.io import fits
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.coordinates import Angle
import astropy.units as u

# %%
fits_path = "archive_30Dor/ADP.2019-09-04T13_34_26.413.fits"

with fits.open(fits_path) as hdul:
    spec = hdul[1].data
    hdr = hdul[0].header

    wave = spec["WAVE"][0]
    flux = spec["FLUX_REDUCED"][0]
    err  = spec["ERR_REDUCED"][0]
    snr  = spec["SNR"][0]

# %%
plt.figure(figsize=(10, 5))
plt.plot(wave, flux)
plt.xlabel("Wavelength [nm]")
plt.ylabel("Reduced Flux [adu]")
plt.title("Reduced Spectrum")
plt.show()

# %%
wmin = 655
wmax = 658

mask = (wave >= wmin) & (wave <= wmax)

plt.figure(figsize=(10, 5))
plt.plot(wave[mask], flux[mask])
plt.xlabel("Wavelength [nm]")
plt.ylabel("Reduced Flux [adu]")
plt.title(f"Spectrum zoom: {wmin}–{wmax} nm")
plt.show()

# %%
keys = [
    "OBJECT",
    "DATE-OBS",
    "MJD-OBS",
    "INSTRUME",
    "TELESCOP",
    "ORIGIN",
    "ARCFILE",
    "RA",
    "DEC",
    "HIERARCH ESO OBS PROG ID",
    "HIERARCH ESO DPR CATG",
    "HIERARCH ESO DPR TYPE",
    "HIERARCH ESO DPR TECH",
    "HIERARCH ESO PRO CATG",
    "HIERARCH ESO PRO TECH"
]

for k in keys:
    print(f"{k}: {hdr.get(k)}")
# Out:
# OBJECT: t48
# DATE-OBS: 2003-12-03T02:19:40.767
# MJD-OBS: 52976.09699962
# INSTRUME: GIRAFFE
# TELESCOP: ESO-VLT-U2
# ORIGIN: ESO
# ARCFILE: ADP.2019-09-04T13:34:26.413.fits
# RA: 84.6594166666653
# DEC: -69.1110833333322
# HIERARCH ESO OBS PROG ID: 072.C-0348(A)
# HIERARCH ESO DPR CATG: None
# HIERARCH ESO DPR TYPE: None
# HIERARCH ESO DPR TECH: None
# HIERARCH ESO PRO CATG: SCIENCE_RBNSPEC_IDP
# HIERARCH ESO PRO TECH: MOS

# %% [markdown]
# # Loading all files

# %%
# --------------------------
# Config
# --------------------------

fits_dir = Path(r"C:\Users\javas\Dropbox\GitHub\VIENTO\structure_function_analysis\FLAMES_30Dor\archive_30Dor")
output_csv = fits_dir / "adp_positions.csv"


# --------------------------
# Helper functions
# --------------------------
def parse_ra_dec_from_header(hdr):
    """
    Try to extract RA/Dec from a FITS header.
    Returns (ra_deg, dec_deg) or (np.nan, np.nan) if not found.

    This first tries direct numeric values in RA/DEC.
    If those fail, it tries string-like sexagesimal forms.
    """
    ra = hdr.get("RA")
    dec = hdr.get("DEC")

    # Case 1: numeric RA/DEC already in degrees
    try:
        if ra is not None and dec is not None:
            ra_deg = float(ra)
            dec_deg = float(dec)
            return ra_deg, dec_deg
    except Exception:
        pass

    # Case 2: sexagesimal strings
    try:
        if ra is not None and dec is not None:
            ra_deg = Angle(str(ra), unit=u.hourangle).degree
            dec_deg = Angle(str(dec), unit=u.deg).degree
            return ra_deg, dec_deg
    except Exception:
        pass

    # Optional fallbacks if needed later
    # Add other header keywords here if some files miss RA/DEC
    return np.nan, np.nan


def read_basic_metadata(fits_path):
    """
    Read one FITS file and extract basic metadata.
    """
    with fits.open(fits_path) as hdul:
        hdr = hdul[0].header

    ra_deg, dec_deg = parse_ra_dec_from_header(hdr)

    row = {
        "filename": fits_path.name,
        "object": hdr.get("OBJECT"),
        "date_obs": hdr.get("DATE-OBS"),
        "mjd_obs": hdr.get("MJD-OBS"),
        "instrument": hdr.get("INSTRUME"),
        "telescope": hdr.get("TELESCOP"),
        "arcfile": hdr.get("ARCFILE"),
        "prog_id": hdr.get("HIERARCH ESO OBS PROG ID"),
        "pro_catg": hdr.get("HIERARCH ESO PRO CATG"),
        "dpr_catg": hdr.get("HIERARCH ESO DPR CATG"),
        "dpr_type": hdr.get("HIERARCH ESO DPR TYPE"),
        "dpr_tech": hdr.get("HIERARCH ESO DPR TECH"),
        "ra_deg": ra_deg,
        "dec_deg": dec_deg,
    }
    return row


# --------------------------
# Load all FITS files
# --------------------------
fits_files = sorted(fits_dir.glob("*.fits"))

rows = []
bad_files = []

for f in fits_files:
    try:
        rows.append(read_basic_metadata(f))
    except Exception as e:
        bad_files.append((f.name, str(e)))

df = pd.DataFrame(rows)

# Save catalog
df.to_csv(output_csv, index=False)

print(f"Read {len(df)} FITS files")
print(f"Saved catalog to: {output_csv}")

if bad_files:
    print("\nFiles with issues:")
    for name, err in bad_files:
        print(f"  {name}: {err}")

print("\nFirst rows:")
print(df.head())
# Out:
# Read 2829 FITS files
# Saved catalog to: C:\Users\javas\Dropbox\GitHub\VIENTO\structure_function_analysis\FLAMES_30Dor\archive_30Dor\adp_positions.csv
#
# First rows:
#                            filename  object                 date_obs  \
# 0  ADP.2015-07-21T08_02_26.550.fits  pos082  2003-12-03T09:05:37.450
# 1  ADP.2015-07-21T08_02_26.837.fits  pos045  2003-12-03T09:05:37.450
# 2  ADP.2015-07-21T08_02_27.470.fits  pos006  2003-12-03T09:05:37.450
# 3  ADP.2015-07-21T08_02_27.477.fits  pos107  2003-12-03T09:05:37.450
# 4  ADP.2015-07-21T08_02_27.590.fits  pos060  2003-12-03T09:05:37.450
#
#         mjd_obs instrument   telescope                           arcfile  \
# 0  52976.378906    GIRAFFE  ESO-VLT-U2  ADP.2015-07-21T08:02:26.550.fits
# 1  52976.378906    GIRAFFE  ESO-VLT-U2  ADP.2015-07-21T08:02:26.837.fits
# 2  52976.378906    GIRAFFE  ESO-VLT-U2  ADP.2015-07-21T08:02:27.470.fits
# 3  52976.378906    GIRAFFE  ESO-VLT-U2  ADP.2015-07-21T08:02:27.477.fits
# 4  52976.378906    GIRAFFE  ESO-VLT-U2  ADP.2015-07-21T08:02:27.590.fits
#
#          prog_id             pro_catg dpr_catg dpr_type dpr_tech     ra_deg  \
# 0  072.C-0348(A)  SCIENCE_RBNSPEC_IDP     None     None     None  84.655292
# 1  072.C-0348(A)  SCIENCE_RBNSPEC_IDP     None     None     None  84.766708
# 2  072.C-0348(A)  SCIENCE_RBNSPEC_IDP     None     None     None  84.725042
# 3  072.C-0348(A)  SCIENCE_RBNSPEC_IDP     None     None     None  84.420458
# 4  072.C-0348(A)  SCIENCE_RBNSPEC_IDP     None     None     None  84.850458
#
#      dec_deg
# 0 -69.060250
# 1 -69.131056
# 2 -69.092389
# 3 -69.116472
# 4 -69.102389

# %%
# Keep only rows with valid coordinates
df_plot = df.dropna(subset=["ra_deg", "dec_deg"]).copy()

# %%
# Keep only rows with valid coordinates
df_plot = df.dropna(subset=["ra_deg", "dec_deg"]).copy()

plt.figure(figsize=(10, 7))
plt.scatter(df_plot["ra_deg"], df_plot["dec_deg"], s=20)

for _, row in df_plot.iterrows():
    plt.text(row["ra_deg"], row["dec_deg"], row["object"] or row["filename"], fontsize=7)

plt.xlabel("RA [deg]")
plt.ylabel("Dec [deg]")
plt.title("Sky positions of ADP FITS files")
plt.gca().invert_xaxis()
plt.grid(True, alpha=0.3)
plt.show()

# %%
from astropy.coordinates import SkyCoord
import astropy.units as u
from astropy.wcs import WCS

c0 = SkyCoord.from_name("Tarantula")
c0
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (84.675, -69.1)>

# %%
fov_deg = 1.0  # Total field of view in degrees (width and height)
pix_scale = 1 / 3600
npix = int(fov_deg / pix_scale)

# Create WCS for TAN projection centered at 'center'
wcs = WCS(naxis=2)
wcs.wcs.ctype = ["RA---TAN", "DEC--TAN"]
wcs.wcs.crval = [c0.ra.deg, c0.dec.deg]
wcs.wcs.crpix = [npix, npix]  # center of your "image"
wcs.wcs.cdelt = [-pix_scale, pix_scale]  # field size / pixel count

# %%
# Keep only rows with valid coordinates
df_plot = df.dropna(subset=["ra_deg", "dec_deg"]).copy()

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(1, 1, 1, projection=wcs)

ax.scatter(
    df_plot["ra_deg"],
    df_plot["dec_deg"],
    s=20,
    transform=ax.get_transform("world")
)

for _, row in df_plot.iterrows():
    label = row["object"] if pd.notna(row["object"]) and row["object"] else row["filename"]
    ax.text(
        row["ra_deg"],
        row["dec_deg"],
        label,
        fontsize=7,
        transform=ax.get_transform("world")
    )

ax.set_title("Sky positions of ADP FITS files")

ax.coords[0].set_axislabel("Right Ascension")
ax.coords[1].set_axislabel("Declination")
ax.grid(color="gray", alpha=0.3, linestyle="--")

plt.show()

# %%
df
# Out:
#                               filename  object                 date_obs  \
# 0     ADP.2015-07-21T08_02_26.550.fits  pos082  2003-12-03T09:05:37.450
# 1     ADP.2015-07-21T08_02_26.837.fits  pos045  2003-12-03T09:05:37.450
# 2     ADP.2015-07-21T08_02_27.470.fits  pos006  2003-12-03T09:05:37.450
# 3     ADP.2015-07-21T08_02_27.477.fits  pos107  2003-12-03T09:05:37.450
# 4     ADP.2015-07-21T08_02_27.590.fits  pos060  2003-12-03T09:05:37.450
# ...                                ...     ...                      ...
# 2824  ADP.2019-09-04T13_34_27.418.fits     t10  2003-12-03T03:14:13.205
# 2825  ADP.2019-09-04T13_34_27.424.fits     u40  2003-12-03T03:14:13.205
# 2826  ADP.2019-09-04T13_34_27.426.fits     u15  2003-12-03T02:41:30.802
# 2827  ADP.2019-09-04T13_34_27.428.fits     t44  2003-12-03T02:52:22.540
# 2828  ADP.2019-09-04T13_34_27.430.fits     u25  2003-12-03T02:52:22.540
#
#            mjd_obs instrument   telescope                           arcfile  \
# 0     52976.378906    GIRAFFE  ESO-VLT-U2  ADP.2015-07-21T08:02:26.550.fits
# 1     52976.378906    GIRAFFE  ESO-VLT-U2  ADP.2015-07-21T08:02:26.837.fits
# 2     52976.378906    GIRAFFE  ESO-VLT-U2  ADP.2015-07-21T08:02:27.470.fits
# 3     52976.378906    GIRAFFE  ESO-VLT-U2  ADP.2015-07-21T08:02:27.477.fits
# 4     52976.378906    GIRAFFE  ESO-VLT-U2  ADP.2015-07-21T08:02:27.590.fits
# ...            ...        ...         ...                               ...
# 2824  52976.134875    GIRAFFE  ESO-VLT-U2  ADP.2019-09-04T13:34:27.418.fits
# 2825  52976.134875    GIRAFFE  ESO-VLT-U2  ADP.2019-09-04T13:34:27.424.fits
# 2826  52976.112162    GIRAFFE  ESO-VLT-U2  ADP.2019-09-04T13:34:27.426.fits
# 2827  52976.119705    GIRAFFE  ESO-VLT-U2  ADP.2019-09-04T13:34:27.428.fits
# 2828  52976.119705    GIRAFFE  ESO-VLT-U2  ADP.2019-09-04T13:34:27.430.fits
#
#             prog_id             pro_catg dpr_catg dpr_type dpr_tech  \
# 0     072.C-0348(A)  SCIENCE_RBNSPEC_IDP     None     None     None
# 1     072.C-0348(A)  SCIENCE_RBNSPEC_IDP     None     None     None
# 2     072.C-0348(A)  SCIENCE_RBNSPEC_IDP     None     None     None
# 3     072.C-0348(A)  SCIENCE_RBNSPEC_IDP     None     None     None
# 4     072.C-0348(A)  SCIENCE_RBNSPEC_IDP     None     None     None
# ...             ...                  ...      ...      ...      ...
# 2824  072.C-0348(A)  SCIENCE_RBNSPEC_IDP     None     None     None
# 2825  072.C-0348(A)  SCIENCE_RBNSPEC_IDP     None     None     None
# 2826  072.C-0348(A)  SCIENCE_RBNSPEC_IDP     None     None     None
# 2827  072.C-0348(A)  SCIENCE_RBNSPEC_IDP     None     None     None
# 2828  072.C-0348(A)  SCIENCE_RBNSPEC_IDP     None     None     None
#
#          ra_deg    dec_deg
# 0     84.655292 -69.060250
# 1     84.766708 -69.131056
# 2     84.725042 -69.092389
# 3     84.420458 -69.116472
# 4     84.850458 -69.102389
# ...         ...        ...
# 2824  84.441375 -69.044417
# 2825  84.908583 -69.088861
# 2826  84.784000 -69.099972
# 2827  84.628250 -69.088861
# 2828  84.815125 -69.099972
#
# [2829 rows x 14 columns]

# %%
from pathlib import Path
from astropy.io import fits

fits_files = sorted(fits_dir.glob("*.fits"))

spectra = []

for f in fits_files:
    try:
        with fits.open(f) as hdul:
            hdr = hdul[0].header
            tab = hdul[1].data

            wave = tab["WAVE"][0]
            flux = tab["FLUX_REDUCED"][0]
            err  = tab["ERR_REDUCED"][0]
           # snr  = tab["SNR"][0]

            spectra.append({
                "filename": f.name,
                "object": hdr.get("OBJECT"),
                "ra_deg": hdr.get("RA"),
                "dec_deg": hdr.get("DEC"),
                "wave": wave,
                "flux": flux,
                "err": err,
                "snr": snr,
            })

    except Exception as e:
        print(f"Could not read {f.name}: {e}")

print(f"Loaded {len(spectra)} spectra")
# Out:
# Loaded 2829 spectra

# %%
import numpy as np
import pandas as pd

obj = df["object"].astype(str).str.strip().str.lower()

conditions = [
    obj.str.fullmatch(r"[a-z]\d{2}"),      # t10, u50
    obj.str.fullmatch(r"pos\d+"),          # pos082, pos07
    obj.str.fullmatch(r"\d+"),          # 7,58,123, 4567, etc.
]

choices = [
    "letter_two_digits",
    "pos_digits",
    "digits_only",
]

df["object_group"] = np.select(conditions, choices, default="other")

# %%
print(df["object_group"].value_counts())
# Out:
# object_group
# digits_only          1214
# letter_two_digits    1020
# pos_digits            595
# Name: count, dtype: int64

# %%
df_letter = df[df["object_group"] == "letter_two_digits"].copy()
df_pos    = df[df["object_group"] == "pos_digits"].copy()
df_num    = df[df["object_group"] == "digits_only"].copy()
#df_other  = df[df["object_group"] == "other"].copy()

# %%
import matplotlib.pyplot as plt

groups = df.dropna(subset=["ra_deg", "dec_deg"]).groupby("object_group")

for group_name, subdf in groups:
    plt.figure(figsize=(8, 6))
    plt.scatter(subdf["ra_deg"], subdf["dec_deg"], s=25)

    for _, row in subdf.iterrows():
        label = row["object"] if pd.notna(row["object"]) and row["object"] else row["filename"]
        plt.text(row["ra_deg"], row["dec_deg"], label, fontsize=7)

    plt.xlabel("RA [deg]")
    plt.ylabel("Dec [deg]")
    plt.title(f"Sky positions: {group_name}")
    plt.gca().invert_xaxis()
    plt.grid(True, alpha=0.3)
    plt.show()

# %%
import matplotlib.pyplot as plt

groups = df.dropna(subset=["ra_deg", "dec_deg"]).groupby("object_group")

for group_name, subdf in groups:
    fig = plt.figure(figsize=(8, 6))
    ax = fig.add_subplot(1, 1, 1, projection=wcs)

    ax.scatter(
        subdf["ra_deg"],
        subdf["dec_deg"],
        s=25,
        transform=ax.get_transform("world")
    )

#    for _, row in subdf.iterrows():
#        label = row["object"] if pd.notna(row["object"]) and row["object"] else row["filename"]
#        ax.text(
#            row["ra_deg"],
#            row["dec_deg"],
#            label,
#            fontsize=7,
#            transform=ax.get_transform("world")
#        )

    ax.set_title(f"Sky positions: {group_name}")
    ax.coords[0].set_axislabel("Right Ascension")
    ax.coords[1].set_axislabel("Declination")
    ax.grid(color="gray", alpha=0.3, linestyle="--")

    plt.show()
