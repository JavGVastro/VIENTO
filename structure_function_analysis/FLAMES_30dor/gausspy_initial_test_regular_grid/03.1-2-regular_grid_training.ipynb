# %%
import gausspy.gp as gp

FILENAME_TRAIN = "flames30dor_training_data_composition.pkl"

snr_thresh = 5.0
alpha1_initial = 0.5
alpha2_initial = 2.0

g = gp.GaussianDecomposer()
g.load_training_data(FILENAME_TRAIN)

g.set("phase", "two")
g.set("SNR_thresh", [snr_thresh, snr_thresh])

g.train(alpha1_initial=alpha1_initial, alpha2_initial=alpha2_initial)
# Out:
# Training...
#
# 0.5 0.9 -0.068499846086157 0.0
# iter 0: F1=62.1%, alpha=[0.5, 2.0], p=[0.00, 0.00]  (Convergence testing begins in 20 iterations)
#
# 0.5616498614775413 0.9 -0.023046088694276712 0.049319889182033005
# iter 1: F1=60.6%, alpha=[0.56, 1.92], p=[0.05, -0.06]  (Convergence testing begins in 19 iterations)
#
# 0.6317112304844233 0.9 -0.08779240608802485 0.056049095205505675
# iter 2: F1=60.8%, alpha=[0.63, 1.8], p=[0.06, -0.10]  (Convergence testing begins in 18 iterations)
#
# 0.7667734911691514 0.9 -0.04181336963862725 0.10804980854778244
# iter 3: F1=60.6%, alpha=[0.77, 1.71], p=[0.11, -0.07]  (Convergence testing begins in 17 iterations)
#
# 0.9124553323916984 0.9 0.0769874095213281 0.11654547297803762
# iter 4: F1=62.4%, alpha=[0.91, 1.63], p=[0.12, -0.07]  (Convergence testing begins in 16 iterations)
#
# 0.9597121368005408 0.9 0.03204169781721111 0.03780544352707391
# ...

# %%
#print(g.p)

# %%
print(dir(g))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'batch_decomposition', 'decompose', 'decompose_double', 'dump_hdf5_data', 'load_hdf5_data', 'load_training_data', 'p', 'save_state', 'set', 'status', 'train']

# %%
print(g.__dict__.keys())
# Out:
# dict_keys(['p'])

# %%
print("alpha1:", g.p.get("alpha1"))
print("alpha2:", g.p.get("alpha2"))
print("training_results:", g.p.get("training_results"))
# Out:
# alpha1: 0.822237832788756
# alpha2: 1.766182847446493
# training_results: <gausspy.gradient_descent.gradient_descent object at 0x112822460>

# %%
import pickle

with open("gausspy_training_FLAMES_30Dor_two_phase.pkl", "wb") as f:
    pickle.dump(g.p, f)

# %%
training_summary = {
    "alpha1": 0.90,
    "alpha2": 1.72,
    "F1_final": 62.6,
    "converged_iteration": 221,
    "SNR_thresh": [10, 10],
    "training_sample": "composition-preserving synthetic sample from Stage A",
    "notes": "First successful two-phase GaussPy training for FLAMES 30 Dor synthetic spectra."
}

with open("training_summary_FLAMES_30Dor.pkl", "wb") as f:
    pickle.dump(training_summary, f)
