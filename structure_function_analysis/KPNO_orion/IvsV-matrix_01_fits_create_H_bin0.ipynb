# %%
import json
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from astropy.io import fits
from astropy.io import fits
from astropy.table import Table
import json
import sys

# %%
sys.path.append(str(Path().resolve() / 'py_modules')) 

from rebin_utils import downsample

# %% [raw]
# # Original PhD Jupyter notebook
#
# https://github.com/JavGVastro/orion_muse

# %% [markdown]
# #  H II region Data

# %%
line        = r'H$\alpha$'
lambda_rest = 6562.8
line_id     = 'H'
line_id2   = 'KPech-Orion-H-m'

# %% [raw]
# line        = r'[N II] $\lambda$6584'
# lambda_rest = 6583.45
# line_id     = 'N'
# line_id2    = 'KPech-Orion-N-m'

# %% [raw]
# line        = r'[S II] $\lambda$6731'
# lambda_rest = 6730.8
# line_id     = 'S'
# line_id2   = 'KPech-Orion-S-m'

# %% [raw]
# line        = r'[O III] $\lambda$5007'
# lambda_rest = 5006.9
# line_id     = 'O'
# line_id2   = 'KPech-Orion-O-m'

# %% [raw]
# line        = r'[Ar III] $\lambda$7136'
# lambda_rest = 7135.8
# line_id     = 'Ar'
# line_id2   = "Ar_III-7136"

# %% [raw]
# line        = r'[S III] $\lambda$9069'
# lambda_rest = 9069.1
# line_id     = 'S'
# line_id2   = "S_III-9069"

# %%
# Data from observations
bins        = 0

region     = 'M 42'
name_reg   = 'Orion'
reg_id     = 'M42'
inst       = 'Echelle'
inst_id    = 'KPNO'
type_obj   = 'H II region'

pix        = 0.534  # Instrument resolution [arcsec/pix]
dist       = 410 # Distance [parsecs]
s0_        = 0.9    # proposed seeing

pc         = dist*(2*np.pi) / (360 * 60 * 60) # value in parsecs of each arcsec
s0         = (s0_*pc) / 2.355    # RMS seeing [parsecs]

#Since we are working with matrix data binning can be applied
#name_file    =  inst_id + '-' + reg_id + '-' + line_id 
name_file    =  line_id2 
name_id      =  inst_id + '-' + reg_id + '-' + line_id + '-' + 'bin' + str(bins) + '-ivsv'
print(name_file)
print(name_id)
# Out:
# KPech-Orion-H-m
# KPNO-M42-H-bin0-ivsv

# %%
_data = json.load(open('observations/'+ name_file + '.json'))
sb    = np.array(_data['sb'])
vv    = np.array(_data['vv'])
#ss    = np.array(_data['ss'])

# %% [raw]
# sb = flux[0].data.astype(float)
# vv = rad_vel[0].data.astype(float)
# #ss    = np.array(_data['ss'])

# %%
## Replace spurious values in the arrays
m = ~np.isfinite(sb*vv) | (sb < 0.0)
#m = m | (sb > 6e4) 
sb[m] = 0.0
vv[m] = np.nanmean(vv)
#ss[m] = 0.0
#sb   /= sb.max()

mu = vv.mean()
sigma = vv.std()
n = 3

good = (~m) & (sb > 1e-3) & (vv > (mu - n*sigma)) & (vv < (mu + n*sigma))

# %%
vv_m = np.where(good, vv, mu)     
sb_m = np.where(good, sb, 0)     
#ss_m = np.where(good, ss, np.nan)

# %%
fig, (axx, ax) = plt.subplots(
    1,
    2,
    sharey=True,
    figsize=(10, 4),
)
imshow_kwds = dict(origin="lower", cmap="RdBu_r")
imshow_kwds2 = dict(origin="lower", cmap="magma")
im = ax.imshow((vv_m-np.nanmean(vv)), **imshow_kwds)
cbar = fig.colorbar(im, ax=[ax], shrink=0.7)
cbar.set_label("$\sigma$ (-)", rotation=270, labelpad=15)
im = axx.imshow(sb_m, **imshow_kwds2)
cbar = fig.colorbar(im, ax=[axx], shrink=0.7)
cbar.set_label("$a$ (-)", rotation=270, labelpad=15)
fig.suptitle(line, y=1.0)

plt.savefig('Imgs/' + name_id + '.jpg', bbox_inches='tight')
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\s'
# <>:11: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\javas\AppData\Local\Temp\ipykernel_36452\2324990547.py:11: SyntaxWarning: invalid escape sequence '\s'
#   cbar.set_label("$\sigma$ (-)", rotation=270, labelpad=15)

# %%
trim = (slice(0, 513), slice(0, 355))

# %%
fig, (axx, ax) = plt.subplots(
    1,
    2,
    sharey=True,
    figsize=(10, 4),
)
imshow_kwds = dict(origin="lower", cmap="RdBu_r")
imshow_kwds2 = dict(origin="lower", cmap="magma")

im = ax.imshow((vv_m-np.nanmean(vv_m))[trim], **imshow_kwds)
cbar = fig.colorbar(im, ax=[ax])
cbar.set_label("radial vel. (km/s)", rotation=270, labelpad=15)

im = axx.imshow(sb_m[trim], **imshow_kwds2)
cbar = fig.colorbar(im, ax=[axx])
cbar.set_label("surface brightness (-)", rotation=270, labelpad=15)
ax.set_xlabel('pix')
axx.set_xlabel('pix')
axx.set_ylabel('pix')

fig.suptitle(line)

plt.savefig('Imgs/' + name_id + '.jpg', bbox_inches='tight')

# %%
N = np.sqrt(vv_m[trim].shape[0] * vv_m[trim].shape[1]) * pix * pc
N
# Out:
# 0.45297354603160866

# %% [raw]
# N = np.sqrt(vv_m.shape[0] * vv_m.shape[1]) * pix * pc
# N

# %%
sig = np.nanstd(vv_m[trim])
sig
# Out:
# 2.9377313172273603

# %% [raw]
# sig = np.nanstd(vv_m)
# sig

# %%
sb = sb[trim]
vv = vv[trim]

# %% [markdown]
# # Downsample

# %%
prod_map  = sb * vv
sb_       = pd.notna(sb)
vv_       = pd.notna(vv)
prod_map_ = sb_ * vv_

# %%
mingoods  = [1]*bins

for mingood in zip(mingoods):
 [sb], sb_= downsample([sb], sb_, mingood=mingood)

for mingood in zip(mingoods):
 [prod_map], prod_map_= downsample([prod_map], prod_map_, mingood=mingood)

# Velocity binned map
vv = prod_map/sb
# Out:
# C:\Users\javas\AppData\Local\Temp\ipykernel_36452\707597441.py:10: RuntimeWarning: invalid value encountered in divide
#   vv = prod_map/sb

# %%
fig, (axx, ax) = plt.subplots(
    1,
    2,
    sharey=True,
    figsize=(10, 4),
)
imshow_kwds = dict(origin="lower", cmap="RdBu_r")
imshow_kwds2 = dict(origin="lower", cmap="magma")
im = ax.imshow(vv, **imshow_kwds)
cbar = fig.colorbar(im, ax=[ax])
cbar.set_label("$\sigma$ (-)", rotation=270, labelpad=15)
im = axx.imshow(sb, **imshow_kwds2)
cbar = fig.colorbar(im, ax=[axx])
cbar.set_label("$a$ (-)", rotation=270, labelpad=15)
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\s'
# <>:11: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\javas\AppData\Local\Temp\ipykernel_36452\850342921.py:11: SyntaxWarning: invalid escape sequence '\s'
#   cbar.set_label("$\sigma$ (-)", rotation=270, labelpad=15)

# %%
## Replace spurious values in the arrays
m = ~np.isfinite(sb*vv) | (sb < 0.0)
#m = m | (sb > 6e4) 
sb[m] = 0.0
vv[m] = np.nanmean(vv)
#ss[m] = 0.0
#sb /= sb.max()

mu = vv.mean()
sigma = vv.std()
n = 3

good = (~m) & (sb > 1e-3) & (vv > (mu - n*sigma)) & (vv < (mu + n*sigma))

# %%
vv_m = np.where(good, vv, mu)     
sb_m = np.where(good, sb, 0)     
#ss_m = np.where(good, ss, np.nan)

# %%
fig, (axx, ax) = plt.subplots(
    1,
    2,
    sharey=True,
    figsize=(10, 4),
)
imshow_kwds = dict(origin="lower", cmap="RdBu_r")
imshow_kwds2 = dict(origin="lower", cmap="magma")
im = ax.imshow((vv_m-np.nanmean(vv)), **imshow_kwds)
cbar = fig.colorbar(im, ax=[ax])
cbar.set_label("$\sigma$ (-)", rotation=270, labelpad=15)
im = axx.imshow(sb_m, **imshow_kwds2)
cbar = fig.colorbar(im, ax=[axx])
cbar.set_label("$a$ (-)", rotation=270, labelpad=15)
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\s'
# <>:11: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\javas\AppData\Local\Temp\ipykernel_36452\3798436418.py:11: SyntaxWarning: invalid escape sequence '\s'
#   cbar.set_label("$\sigma$ (-)", rotation=270, labelpad=15)

# %% [raw]
# trim = (slice(int(20/2**bins), int(315/2**bins)), slice(int(10/2**bins), int(330/2**bins)))

# %%
fig, (axx, ax) = plt.subplots(
    1,
    2,
    sharey=True,
    figsize=(10, 4),
)
imshow_kwds = dict(origin="lower", cmap="RdBu_r")
imshow_kwds2 = dict(origin="lower", cmap="magma")
im = ax.imshow((vv_m-np.nanmean(vv_m))[trim], **imshow_kwds)
cbar = fig.colorbar(im, ax=[ax])
cbar.set_label("radial vel. (km/s)", rotation=270, labelpad=15)
im = axx.imshow(sb_m[trim], **imshow_kwds2)
cbar = fig.colorbar(im, ax=[axx])
cbar.set_label("surface brightness (-)", rotation=270, labelpad=15)

ax.set_xlabel('pix')
axx.set_xlabel('pix')
axx.set_ylabel('pix')

fig.suptitle(line)

plt.savefig('Imgs/' + name_id + '.jpg', bbox_inches='tight')

# %%
N = np.sqrt(vv.shape[0] * vv.shape[1]) * pix * pc
N
# Out:
# 0.45297354603160866

# %% [raw]
# sig = np.nanstd(vv)
# sig

# %%
fig, (axx, ax) = plt.subplots(
    1,
    2,
    sharey=True,
    figsize=(10, 4),
)
imshow_kwds = dict(origin="lower", cmap="RdBu_r")
imshow_kwds2 = dict(origin="lower", cmap="magma")
im = ax.imshow(vv, **imshow_kwds)
cbar = fig.colorbar(im, ax=[ax])
cbar.set_label("radial vel. (km/s)", rotation=270, labelpad=15)
im = axx.imshow(sb, **imshow_kwds2)
cbar = fig.colorbar(im, ax=[axx])
cbar.set_label("surface brightness (-)", rotation=270, labelpad=15)

ax.set_xlabel('pix')
axx.set_xlabel('pix')
axx.set_ylabel('pix')

fig.suptitle(line)

#plt.savefig('Imgs/' + name_id + '.jpg', bbox_inches='tight')
# Out:
# Text(0.5, 0.98, 'H$\\alpha$')

# %%
name_id
# Out:
# 'KPNO-M42-H-bin0-ivsv'

# %% [markdown]
# # Export

# %%
primary = fits.PrimaryHDU()
primary.header["FILE"]       = (name_file, "Fits file name")
primary.header["NAME_ID"]    = (name_id, "pipeline identifier")
primary.header["REG"]        = (region, "Region catalog name")
primary.header["NAME_REG"]   = (name_reg, "Region name")
primary.header["REG_ID"]     = (reg_id, "Region identifier")
primary.header["TYPE_OBJ"]   = (type_obj, "Type object")
primary.header["DIST"]       = (dist, "Distance in parsecs")
primary.header["INSTR"]      = (inst, "Instrument")
primary.header["LINE"]       = (line, "Emission line name")
primary.header["LINE_ID"]    = (line_id, "Emission line identifier")
primary.header["L_REST"]= (lambda_rest, "Emission line name")
primary.header["SIG"]        = (sig, "Standard deviation vel map")
primary.header["SIG2"]       = (sig**2, "Vel Variance map")
primary.header["S0"]         = (s0, "Atmospheric seeing")
primary.header["BOX_SIZE"]   = (N, "Observational box_size")
primary.header["PC"]         = (pc, "parsec convertion")
primary.header["PIX"]        = (pix* (2**bins), "Instrument pixel scale")
primary.header["BINSIZE"]    = (bins, "Spatial binning factor")
#hdr["noise"]     = (noise, "Instrumental noise")
#hdr["m3D"]       = (m3D, "k = 3 + m3D")
#hdr["ra"]        = (ra, "Artificial correlation length")
#primary.header["SEED1"]     = (randomseed_vv, "Random seed velocity")
#primary.header["SEED2"]     = (randomseed_sb, "Random seed surfavebrightness")
primary.header["AUTHOR"]     = ("J. Garcia-Vazquez", "File creator")

# %%
hdu_m0 = fits.ImageHDU(data=sb,  name='MOM0')
hdu_m1 = fits.ImageHDU(data=vv,  name='MOM1')
#hdu_m2 = fits.ImageHDU(data=ss_m[trim],  name='MOM2')
#hdu_mk = fits.ImageHDU(data=good[trim].astype(np.uint8) ,  name='MASK')

# %%
hdul = fits.HDUList([primary, hdu_m0, hdu_m1])
hdul.writeto('fits_ready/' + name_id + '.fits', overwrite=True)

# %%
pc*pix
# Out:
# 0.001061451073421218

# %%
pc*pix* (2**bins)
# Out:
# 0.001061451073421218

# %%
with fits.open("fits_ready/" + name_id + ".fits") as hdul:
    hdul.info()
    
hdr = hdul[0].header
print(hdr)
# Out:
# Filename: fits_ready/KPNO-M42-H-bin0-ivsv.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      23   ()
#   1  MOM0          1 ImageHDU         8   (355, 513)   float64
#   2  MOM1          1 ImageHDU         8   (355, 513)   float64
# SIMPLE  =                    T / conforms to FITS standard                      BITPIX  =                    8 / array data type                                NAXIS   =                    0 / number of array dimensions                     EXTEND  =                    T                                                  FILE    = 'KPech-Orion-H-m'    / Fits file name                                 NAME_ID = 'KPNO-M42-H-bin0-ivsv' / pipeline identifier                          REG     = 'M 42    '           / Region catalog name                            NAME_REG= 'Orion   '           / Region name                                    REG_ID  = 'M42     '           / Region identifier                              TYPE_OBJ= 'H II region'        / Type object                                    DIST    =                  410 / Distance in parsecs                            INSTR   = 'Echelle '           / Instrument                                     LINE    = 'H$\alpha$'          / Emission line name                             LINE_ID = 'H       '           / Emission line identifier                       L_REST  =               6562.8 / Emission line name                             SIG     =   2.9377313172273603 / Standard deviation vel map                     SIG2    =    8.630265292218402 / Vel Variance map                               S0      = 0.000759644366579272 / Atmospheric seeing                             BOX_SIZE=  0.45297354603160866 / Observational box_size                         PC      = 0.001987736092549097 / parsec convertion                              PIX     =                0.534 / Instrument pixel scale                         BINSIZE =                    0 / Spatial binning factor                         AUTHOR  = 'J. Garcia-Vazquez'  / File creator                                   END
# SIMPLE  =                    T / conforms to FITS standard                      BITPIX  =                    8 / array data type                                NAXIS   =                    0 / number of array dimensions                     EXTEND  =                    T                                                  FILE    = 'H_I-6563'           / Fits file name                                 NAME_ID = 'MUSE-M42-H-bin0'    / pipeline identifier                            REG     = 'M 42    '           / Region catalog name                            NAME_REG= 'Orion   '           / Region name                                    REG_ID  = 'M42     '           / Region identifier                              TYPE_OBJ= 'H II region'        / Type object                                    DIST    =                  410 / Distance in parsecs                            INSTR   = 'MUSE    '           / Instrument                                     LINE    = 'H$\alpha$'          / Emission line name                             LINE_ID = 'H       '           / Emission line identifier                       L_REST  =               6562.8 / Emission line name                             SIG     =    2.880602639321363 / Standard deviation vel map                     SIG2    =    8.297871565665202 / Vel Variance map                               S0      = 0.000759644366579272 / Atmospheric seeing                             BOX_SIZE=   0.6418406922107823 / Observational box_size                         PC      = 0.001987736092549097 / parsec convertion                              PIX     =                  0.2 / Instrument pixel scale                         BINSIZE =                    0 / Spatial binning factor                         AUTHOR  = 'J. Garcia-Vazquez'  / File creator                                   END
