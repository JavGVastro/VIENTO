# %%
import numpy as np
import seaborn as sns
import pandas as pd
import sys
from pathlib import Path
from matplotlib import pyplot as plt

from lmfit.model import load_modelresult

# %%
ROOT = Path.cwd()  

sys.path.insert(0, str(ROOT))
sys.path.insert(0, str(ROOT / "py_modules"))

from pipeline_config import MAPS_DIR, FIGS_DIR 
import results_comp
import ci_results_compiler
import plot_fit_params
import list_maps_plots

# %% [markdown]
# # Loading files

# %%
filelist = "fits_ready/filelist_results.txt"

with open(filelist, "r", encoding="utf-8") as f:
    names = [line.strip() for line in f if line.strip()]

# %%
bundles = {}

for name in names:
    bundles[name] = results_comp.load_line_bundle(
        name, name, MAPS_DIR, read_header=True
    )

# %%
#bundles["LVM-30Dor-6563_subrot"]

# %%
dfs_obs  = {name: bundle["obs"]  for name, bundle in bundles.items()}
dfs_fit  = {name: bundle["fit"]  for name, bundle in bundles.items()}
meta_all = {name: bundle["meta"] for name, bundle in bundles.items()}

# %%
#dfs_obs["LVM-30Dor-6563_subrot"]

# %%
fig, ax, stats_df = list_maps_plots.plot_list_pdfs_circles(
    dfs_obs,
    col="V_mean",
    center="mean",
    method="kde",
    cmap="viridis",
    legend_mode="none",
    annotate=False,
    figsize=(9, 4),
    bw_scale=1.0
)

# %%
stats_df
# Out:
#                      name      N        mean       std        var       xmin  \
# 0   LVM-30Dor-6563_subrot  20746   -3.130492  7.147537  51.087290 -43.539765
# 1      LVM-30Dor-6563_rot  20746  266.929611  6.996529  48.951423 -43.390511
# 2   LVM-30Dor-6583_subrot  20680   -3.212239  6.870807  47.207986 -26.671569
# 3      LVM-30Dor-6583_rot  20680  266.848107  6.713659  45.073217 -26.419707
# 4   LVM-30Dor-3729_subrot  20678   -6.428276  7.069710  49.980795 -23.405206
# 5      LVM-30Dor-3729_rot  20678  263.632212  6.930397  48.030396 -23.400312
# 6   LVM-30Dor-5007_subrot  20625   -4.991127  6.973751  48.633209 -25.633439
# 7      LVM-30Dor-5007_rot  20625  265.069495  6.794545  46.165845 -24.941195
# 8   LVM-30Dor-6731_subrot  20698    0.087583  6.673770  44.539211 -32.634657
# 9      LVM-30Dor-6731_rot  20698  270.147754  6.557596  43.002063 -32.820954
# 10  LVM-30Dor-9069_subrot  20687   -2.355911  7.264796  52.777267 -27.893441
# 11     LVM-30Dor-9069_rot  20687  267.704303  7.110434  50.558277 -27.690803
#
#          xmax
# 0   50.891223
# 1   50.881889
# 2   27.373212
# 3   27.254393
# 4   24.327150
# 5   23.363788
# 6   25.515826
# 7   24.853305
# 8   25.311953
# 9   24.846846
# 10  27.948382
# 11  27.117497

# %%
#dfs_fit['LVM-30Dor-6563_subrot']

# %%
#labels = ['H_corr', 'H']
labels = [name.replace("LVM-30Dor-", "") for name in names]
labels
# Out:
# ['6563_subrot',
#  '6563_rot',
#  '6583_subrot',
#  '6583_rot',
#  '3729_subrot',
#  '3729_rot',
#  '5007_subrot',
#  '5007_rot',
#  '6731_subrot',
#  '6731_rot',
#  '9069_subrot',
#  '9069_rot']

# %%
#obs_var = [dfs_obs["LVM-30Dor-6563_subrot"]['V_mean'].var(), 
#           dfs_obs["LVM-30Dor-6563_rot"]['V_mean'].var()
#          ]
#obs_var
obs_var = [meta_all[name]["SIG2"] for name in names]

# %%
fit_tables = [dfs_fit[name] for name in names]

# %%
plot_fit_params.plot_param_comp_obs(
    *fit_tables,
    labels=labels,
    obs=obs_var
)

# %%
plot_fit_params.plot_param(
    *fit_tables,
    labels=labels,
    decimals=4
)

# %%
#plot_fit_params.plot_param(dfs_fit['LVM-30Dor-6563_rot'],
#                                    dfs_fit['LVM-30Dor-6563_subrot'], 
#                                    labels=labels,
#                                decimals=4)
