# %%
# Parameters
name      = ""
fits_path = ""

# %%
# Parameters
name = "LVM-30Dor-6563_G5"
fits_path = "fits_ready/LVM-30Dor-6563_G5.fits"

# %%
import time
start_time = time.time()

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import sys
from pathlib import Path
import astropy.units as u
from matplotlib import pyplot as plt
import corner
import json
from astropy.io import fits
import lmfit
from lmfit.model import save_modelresult

# %%
# Add path to py_modules 
sys.path.append(str(Path().resolve() / 'py_modules')) # 1 level up = project root
#import strucfunc                   
import bfunc
import bplot
from reduced_chi2 import make_weights, tune_relative_uncertainty
import fit_diagnostic_utils as fdu

# %%
with fits.open("fits_ready/" + name + ".fits") as hdul:
    hdr = hdul[0].header

#m3D      = hdul[0].header['M3D']
#ra       = hdul[0].header['RA']
sig      = hdul[0].header['SIG']
sig2     = hdul[0].header['SIG2']
s0       = hdul[0].header['S0']
#noise    = hdul[0].header['NOISE']
box_size = hdul[0].header['BOX_SIZE']
pc       = hdul[0].header['PC']
pix      = hdul[0].header['PIX']
line     = hdul[0].header['LINE']
binsize  = hdul[0].header['BINSIZE']

# %%
hdul.info()
# Out:
# Filename: fits_ready/LVM-30Dor-6563_G5.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      29   ()

# %%
pc_per_arcsec = pc
data = name

# %%
from astropy.table import Table
t = Table.read(fits_path, hdu="TABLE")
data_in = t.to_pandas()


B        = np.array(data_in['Unweighted B(r)'])#[mask]
r        = np.array(10 ** np.array(data_in['log10 r']))#[mask]

# %% [markdown]
# # Fit and Confidence intervals

# %% [markdown]
# ## Non-Linear Least-Squares Fitting

# %%
# Merging point

K = 3
r[K] = np.mean(r[: K + 1])
B[K] = np.mean(B[: K + 1])
r = r[K:]
B = B[K:]

# %%
# Define some scales for turning points in sf

r_local_peak = 2.5
r_local_minimum = 4.5

# %%
# Weights

#relative_uncertainty = 0.035
#weights = 1.0 / (relative_uncertainty * B)
#large_scale = r > 0.10 * box_size
#weights[large_scale] /= 2.0
#weights[:3] /= 2.0

#to_fit = r <= 0.15 * box_size
#to_fit = ~large_scale

# %%
# Weight configuration

weight_config = dict(
    large_scale_limit=0.35,
    fit_limit=0.5,
    large_scale_factor=2.0,
    first_points_factor=2.0,
    n_first_points=5,
)

initial_relative_uncertainty = 0.05

# %%
to_fit = r <= weight_config["fit_limit"] * box_size
large_scale = r > weight_config["large_scale_limit"] * box_size

# %%
model = lmfit.Model(bfunc.bfunc03s)
model.param_names
# Out:
# ['r0', 'sig2', 'm', 's0', 'noise']

# %%
# Correlation length between 1/10 and 2 x box_size
model.set_param_hint("r0", value=0.1 * box_size, min=0.01 * box_size, max=1.0 * box_size)

# sig2 between 1/4 and 2 x max value of B(r)
#model.set_param_hint("sig2", value=0.5 * B.max(), min=0.25 * B.max(), max=2 * B.max())
model.set_param_hint("sig2", 
                     value = 0.50 * B[to_fit].max(), 
                     min   = 0.25 * B[to_fit].max(), 
                     max   = 2.00 * B[to_fit].max()) 

# m between 1/2 and 5/3
model.set_param_hint("m", value=1.0, min=0.5, max=2.0)

# Seeing RMS between 0.1 and 1.5 arcsec
model.set_param_hint(
    "s0", value=0.5 * pc_per_arcsec, min=0.1 * pc_per_arcsec, max=1.5 * pc_per_arcsec
)

# Noise cannot be much larger than smallest B(r)
model.set_param_hint("noise", value=0.5 * B.min(), min=0.0, max=3 * B.min())

# box_size is fixed
# model.set_param_hint("box_size", value=box_size, vary=False)

# %%
pd.DataFrame(model.param_hints)
# Out:
#                r0        sig2    m        s0      noise
# value   16.269683   38.550514  1.0  0.121203  15.119476
# min      1.626968   19.275257  0.5  0.024241   0.000000
# max    162.696831  154.202056  2.0  0.363610  90.716854

# %%
#result = model.fit(B[to_fit], weights=weights[to_fit], r=r[to_fit])

# %%
def fit_function(r_fit, B_fit, weights_fit):
    return model.fit(
        B_fit,
        weights=weights_fit,
        r=r_fit,
    )


result, relative_uncertainty, history = tune_relative_uncertainty(
    fit_function,
    r,
    B,
    box_size,
    initial_relative_uncertainty=initial_relative_uncertainty,
    target_redchi_min=0.5,
    target_redchi_max=1.0,
    step_factor=1.15,
    **weight_config,
)
# Out:
# iter 00: relative_uncertainty = 0.05000, redchi = 0.4498
# iter 01: relative_uncertainty = 0.04348, redchi = 0.5948
# Accepted relative_uncertainty.

# %%
weights_fit, to_fit, weights, large_scale = make_weights(
    r,
    B,
    box_size,
    relative_uncertainty=relative_uncertainty,
    **weight_config,
)

print("Accepted relative_uncertainty:", relative_uncertainty)
print("Final reduced chi-square:", result.redchi)
# Out:
# Accepted relative_uncertainty: 0.04347826086956522
# Final reduced chi-square: 0.5948061871728955

# %%
result
# Out:
# <h2>Fit Result</h2> <p>Model: Model(bfunc03s)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>919</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>22</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>5</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 10.1117052</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 0.59480619</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'>-7.10167298</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'>-1.64646071</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.97141821</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>r0</td><td style='text-align:left'> 6.57739511</td><td style='text-align:left'> 58.6349675</td><td style='text-align:left'>(891.46%)</td><td style='text-align:left'>16.269683147365026</td><td style='text-align:left'> 1.62696831</td><td style='text-align:left'> 162.696831</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>sig2</td><td style='text-align:left'> 40.9872982</td><td style='text-align:left'> 173.535623</td><td style='text-align:left'>(423.39%)</td><td style='text-align:left'>38.55051410807029</td><td style='text-align:left'> 19.2752571</td><td style='text-align:left'> 154.202056</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>m</td><td style='text-align:left'> 0.61469124</td><td style='text-align:left'> 2.18013644</td><td style='text-align:left'>(354.67%)</td><td style='text-align:left'>1.0</td><td style='text-align:left'> 0.50000000</td><td style='text-align:left'> 2.00000000</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>s0</td><td style='text-align:left'> 0.36361026</td><td style='text-align:left'> 23.9945960</td><td style='text-align:left'>(6598.99%)</td><td style='text-align:left'>0.12120342027738398</td><td style='text-align:left'> 0.02424068</td><td style='text-align:left'> 0.36361026</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>noise</td><td style='text-align:left'> 3.6895e-05</td><td style='text-align:left'> 465.487668</td><td style='text-align:left'>(1261659112.61%)</td><td style='text-align:left'>15.119475710122499</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'> 90.7168543</td><td style='text-align:right'>True</td></tr></table><table class="jp-toc-ignore"><caption>Correlations (unreported values are < 0.100)</caption><tr><th style='text-align:left'>Parameter1</th><th style='text-align:left'>Parameter 2</th><th style='text-align:right'>Correlation</th></tr><tr><td style='text-align:left'>r0</td><td style='text-align:left'>noise</td><td style='text-align:right'>+0.9998</td></tr><tr><td style='text-align:left'>sig2</td><td style='text-align:left'>m</td><td style='text-align:right'>-0.9992</td></tr><tr><td style='text-align:left'>r0</td><td style='text-align:left'>sig2</td><td style='text-align:right'>-0.9989</td></tr><tr><td style='text-align:left'>s0</td><td style='text-align:left'>noise</td><td style='text-align:right'>-0.9985</td></tr><tr><td style='text-align:left'>sig2</td><td style='text-align:left'>noise</td><td style='text-align:righ ...

# %%
fig, ax = plt.subplots(figsize=(10, 10))

# Plot the underlying model without instrumental effects
Bu = bfunc.bfunc00s(
    r, result.params["r0"].value, result.params["sig2"].value, result.params["m"].value
)
ax.plot(r, Bu, color="k", linestyle="dashed", label="underlying")

# Plot the fit results
result.plot_fit(ax=ax)

# Add in the points not included in fit
ax.plot(r[~to_fit], B[~to_fit], "o")

# Dotted lines for 2 x rms seeing and for box size
ax.axvline(2 * result.params["s0"].value, color="k", linestyle="dotted")
ax.axvline(box_size, color="k", linestyle="dotted")

# Dashed lines for best-fit r0 and sig2
ax.axvline(result.params["r0"].value, color="k", linestyle="dashed")
ax.axhline(result.params["sig2"].value, color="k", linestyle="dashed")

# Gray box to indicate the large scale values that are excluded from the fit
ax.axvspan(box_size / 2, r[-1], color="k", alpha=0.05, zorder=-1)

ax.set(
    xscale="log",
    yscale="log",
    xlabel="r [pc]",
    ylabel=r"B(r) [km$^{2}$/s$^{2}$]",
)
sns.despine()

# %% [markdown]
# ## emcee

# %%
emcee_kws = dict(
    steps=35000, burn=1000, thin=50, is_weighted=True, progress=False, workers=1
)
emcee_params = result.params.copy()
# emcee_params.add('__lnsigma', value=np.log(0.1), min=np.log(0.001), max=np.log(2.0))

# %%
result_emcee = model.fit(
    data=B[to_fit],
    r=r[to_fit],
    weights=weights[to_fit],
    params=emcee_params,
    method="emcee",
    nan_policy="omit",
    fit_kws=emcee_kws,
)
# Out:
# /Users/javier/miniconda3/envs/viento/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]

# %%
result_emcee
# Out:
# <h2>Fit Result</h2> <p>Model: Model(bfunc03s)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>emcee</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>3500000</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>22</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>5</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 11.8037820</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 0.69434012</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'>-3.69769424</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'> 1.75751802</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.97387866</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>r0</td><td style='text-align:left'> 9.51995106</td><td style='text-align:left'> 2.84329228</td><td style='text-align:left'>(29.87%)</td><td style='text-align:left'>6.5773951097382986</td><td style='text-align:left'> 1.62696831</td><td style='text-align:left'> 162.696831</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>sig2</td><td style='text-align:left'> 35.5501006</td><td style='text-align:left'> 6.11476428</td><td style='text-align:left'>(17.20%)</td><td style='text-align:left'>40.98729815839828</td><td style='text-align:left'> 19.2752571</td><td style='text-align:left'> 154.202056</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>m</td><td style='text-align:left'> 0.71239787</td><td style='text-align:left'> 0.16402800</td><td style='text-align:left'>(23.02%)</td><td style='text-align:left'>0.6146912448447972</td><td style='text-align:left'> 0.50000000</td><td style='text-align:left'> 2.00000000</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>s0</td><td style='text-align:left'> 0.20924049</td><td style='text-align:left'> 0.11599125</td><td style='text-align:left'>(55.43%)</td><td style='text-align:left'>0.3636102566983928</td><td style='text-align:left'> 0.02424068</td><td style='text-align:left'> 0.36361026</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>noise</td><td style='text-align:left'> 9.29183611</td><td style='text-align:left'> 7.03474405</td><td style='text-align:left'>(75.71%)</td><td style='text-align:left'>3.689488412714367e-05</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'> 90.7168543</td><td style='text-align:right'>True</td></tr></table><table class="jp-toc-ignore"><caption>Correlations (unreported values are < 0.100)</caption><tr><th style='text-align:left'>Parameter1</th><th style='text-align:left'>Parameter 2</th><th style='text-align:right'>Correlation</th></tr><tr><td style='text-align:left'>sig2</td><td style='text-align:left'>m</td><td style='text-align:right'>-0.8340</td></tr><tr><td style='text-align:left'>m</td><td style='text-align:left'>noise</td><td style='text-align:right'>+0.6424</td></tr><tr><td style='text-align:left'>sig2</td><td style='text-align:left'>noise</td><td style='text-align:right'>-0.5651</td></tr><tr><td style='text-align:left'>r0</td><td style='text-align:left'>sig2</td><td style='text-align:right'>+0.5499</td></tr><tr><td style='text-align:left'>r0</td><td style='text-align:left'>noise</td><td style='text-align ...

# %%
plt.plot(result_emcee.acceptance_fraction, "o")
plt.xlabel("walker")
plt.ylabel("acceptance fraction")
# Out:
# Text(0, 0.5, 'acceptance fraction')

# %%
if hasattr(result_emcee, "acor"):
    print("Autocorrelation time for the parameters:")
    print("----------------------------------------")
    for i, p in enumerate(result_emcee.params):
        try:
            print(f"{p} = {result_emcee.acor[i]:.3f}")
        except IndexError:
            pass
# Out:
# Autocorrelation time for the parameters:
# ----------------------------------------
# r0 = 519.168
# sig2 = 347.558
# m = 222.077
# s0 = 125.825
# noise = 182.447

# %%
bplot.corner_plot(
    result_emcee, result, name, data, data_ranges=[0.95, 0.95, 0.995, 0.999, 0.999]
)
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %%
bplot.STYLE["data label element"] = 4
bplot.STYLE["model label element"] = 0
bplot.STYLE["model label offset"] = (-60, 40)
bplot.STYLE["true model label element"] = 7
bplot.STYLE["true model label offset"] = (30, -60)
bplot.strucfunc_plot(
    result_emcee, result, r, B, to_fit, name, data, box_size, large_scale
)

# %%
LM = {
    'sig2': [result.params['sig2'].value,result.params['sig2'].stderr],
    'r0': [result.params['r0'].value,result.params['r0'].stderr],
    'm' : [result.params['m'].value,result.params['m'].stderr],
    's0': [result.params['s0'].value,result.params['s0'].stderr],
    'noise' : [result.params['noise'].value,result.params['noise'].stderr]
}

# %%
MCMC = {
    'sig2': [result_emcee.params['sig2'].value,result_emcee.params['sig2'].stderr],
    'r0': [result_emcee.params['r0'].value,result_emcee.params['r0'].stderr],
    'm' : [result_emcee.params['m'].value,result_emcee.params['m'].stderr],
    's0': [result_emcee.params['s0'].value,result_emcee.params['s0'].stderr],
    'noise' : [result_emcee.params['noise'].value,result_emcee.params['noise'].stderr]
}

# %%
sig2s2 = np.percentile(result_emcee.flatchain['sig2'],[2.5, 97.5])
r0s2 = np.percentile(result_emcee.flatchain['r0'],[2.5, 97.5])
ms2 = np.percentile(result_emcee.flatchain['m'],[2.5, 97.5])
s0s2 = np.percentile(result_emcee.flatchain['s0'],[2.5, 97.5])
b0s2 = np.percentile(result_emcee.flatchain['noise'],[2.5, 97.5])

# %%
sig2s2p = sig2s2[1]-result.params['sig2'].value
sig2s2m = result.params['sig2'].value-sig2s2[0]

r0s2p = r0s2[1]-result.params['r0'].value
r0s2m = result.params['r0'].value-r0s2[0]

ms2p = ms2[1]-result.params['m'].value
ms2m = result.params['m'].value-ms2[0]

s0s2p = s0s2[1]-result.params['s0'].value
s0s2m = result.params['s0'].value-s0s2[0]

b0s2p = b0s2[1]-result.params['noise'].value
b0s2m = result.params['noise'].value-b0s2[0]

# %%
# MCMC 1 sigma confidence interval

sig2s1 = np.percentile(result_emcee.flatchain['sig2'],[16, 85])
r0s1 = np.percentile(result_emcee.flatchain['r0'],[16, 85])
ms1 = np.percentile(result_emcee.flatchain['m'],[16, 85])
s0s1 = np.percentile(result_emcee.flatchain['s0'],[16, 85])
b0s1 = np.percentile(result_emcee.flatchain['noise'],[16, 85])

sig2s1p = sig2s1[1]-result.params['sig2'].value
sig2s1m = result.params['sig2'].value-sig2s1[0]

r0s1p = r0s1[1]-result.params['r0'].value
r0s1m = result.params['r0'].value-r0s1[0]

ms1p = ms1[1]-result.params['m'].value
ms1m = result.params['m'].value-ms1[0]

s0s1p = s0s1[1]-result.params['s0'].value
s0s1m = result.params['s0'].value-s0s1[0]

b0s1p = b0s1[1]-result.params['noise'].value
b0s1m = result.params['noise'].value-b0s1[0]

# %%
#  LM + MCMC 2 sigma

results_2sig = {
    'sig2': [result.params['sig2'].value,sig2s2p,sig2s2m],
    'r0': [result.params['r0'].value,r0s2p,r0s2m],
    'm' : [result.params['m'].value,ms2p,ms2m],
    's0': [result.params['s0'].value,s0s2p,s0s2m],
    'noise' : [result.params['noise'].value,b0s2p,b0s2m] 
    
}

results_2sig
# Out:
# {'sig2': [40.98729815839828,
#   np.float64(8.416194353395355),
#   np.float64(16.59314576903519)],
#  'r0': [6.5773951097382986,
#   np.float64(18.560236050378155),
#   np.float64(0.3092071782211212)],
#  'm': [0.6146912448447972,
#   np.float64(0.5359785932110455),
#   np.float64(0.102396991715478)],
#  's0': [0.3636102566983928,
#   np.float64(-0.006609710763087695),
#   np.float64(0.32943343359267185)],
#  'noise': [3.689488412714367e-05,
#   np.float64(24.050087106281335),
#   np.float64(-0.4847139532867434)]}

# %% [markdown]
# # Diagnostic

# %%
import importlib
importlib.reload(fdu)
# Out:
# <module 'fit_diagnostic_utils' from '/Users/javier/LVM_30dor/subfields_subrot/r50pc-HI-6563/py_modules/fit_diagnostic_utils.py'>

# %%
params_to_check = ["r0", "sig2", "m", "s0", "noise"]

bound_flags = fdu.get_bound_flags(
    result.params,
    param_names=params_to_check,
    frac=0.05,
)

# Use a relative bound criterion for r0 because its allowed range is wide
bound_flags["r0"] = fdu.near_bound_relative(
    result.params["r0"],
    lower_factor=1.5,
    upper_fraction=0.9,
)

bound_flags
# Out:
# {'r0': False, 'sig2': np.False_, 'm': False, 's0': True, 'noise': np.True_}

# %%
n_params_near_bounds = sum(bound_flags.values())

n_params_near_bounds
# Out:
# np.int64(2)

# %%
# Fractional uncertainty diagnostics from 2-sigma MCMC intervals

r0_frac_uncertainty = fdu.frac_uncertainty(
    value=results_2sig["r0"][0],
    err_plus=results_2sig["r0"][1],
    err_minus=results_2sig["r0"][2],
)

sig2_frac_uncertainty = fdu.frac_uncertainty(
    value=results_2sig["sig2"][0],
    err_plus=results_2sig["sig2"][1],
    err_minus=results_2sig["sig2"][2],
)

s0_frac_uncertainty = fdu.frac_uncertainty(
    value=results_2sig["s0"][0],
    err_plus=results_2sig["s0"][1],
    err_minus=results_2sig["s0"][2],
)

noise_frac_uncertainty = fdu.frac_uncertainty(
    value=results_2sig["noise"][0],
    err_plus=results_2sig["noise"][1],
    err_minus=results_2sig["noise"][2],
)

m_abs_uncertainty = max(
    abs(results_2sig["m"][1]),
    abs(results_2sig["m"][2]),
)

# %%
r0_frac_uncertainty, sig2_frac_uncertainty, s0_frac_uncertainty, noise_frac_uncertainty, m_abs_uncertainty
# Out:
# (np.float64(2.8218216696300353),
#  np.float64(0.40483629110925573),
#  np.float64(0.9060069883175217),
#  np.float64(651854.2522969361),
#  np.float64(0.5359785932110455))

# %%
# Uncertainty quality flags

uncertainty_flags = {}

uncertainty_flags["large_r0_uncertainty"] = r0_frac_uncertainty > 0.5
uncertainty_flags["large_sig2_uncertainty"] = sig2_frac_uncertainty > 0.5
uncertainty_flags["large_s0_uncertainty"] = s0_frac_uncertainty > 0.75
uncertainty_flags["large_noise_uncertainty"] = noise_frac_uncertainty > 1.0
uncertainty_flags["large_m_uncertainty"] = m_abs_uncertainty > 0.3

uncertainty_flags
# Out:
# {'large_r0_uncertainty': np.True_,
#  'large_sig2_uncertainty': np.False_,
#  'large_s0_uncertainty': np.True_,
#  'large_noise_uncertainty': np.True_,
#  'large_m_uncertainty': np.True_}

# %%
n_large_uncertainties = sum(uncertainty_flags.values())

n_large_uncertainties
# Out:
# np.int64(4)

# %%
# Reduced chi-square quality flags

redchi_flags = {}

redchi_flags["redchi_too_low"] = result.redchi < 0.3
redchi_flags["redchi_too_high"] = result.redchi > 1.2

redchi_flags
# Out:
# {'redchi_too_low': np.False_, 'redchi_too_high': np.False_}

# %%
# Physical / interpretive diagnostics

r_fit_max = np.max(r[to_fit])
n_fit_points = np.sum(to_fit)

r0_value = result.params["r0"].value
s0_value = result.params["s0"].value
noise_value = result.params["noise"].value

r0_over_rfitmax = r0_value / r_fit_max
s0_arcsec = s0_value / pc_per_arcsec

n_small = min(3, np.sum(to_fit))
B_small = np.median(B[to_fit][:n_small])
noise_fraction = noise_value / B_small

physical_flags = {}

physical_flags["r0_larger_than_fit_range"] = r0_over_rfitmax > 1.0
physical_flags["r0_much_larger_than_fit_range"] = r0_over_rfitmax > 2.0
physical_flags["large_s0_arcsec"] = s0_arcsec > 1.2
physical_flags["large_noise_fraction"] = noise_fraction > 0.5

physical_flags
# Out:
# {'r0_larger_than_fit_range': np.False_,
#  'r0_much_larger_than_fit_range': np.False_,
#  'large_s0_arcsec': True,
#  'large_noise_fraction': np.False_}

# %%
r_fit_max, r0_over_rfitmax, s0_arcsec, noise_fraction
# Out:
# (np.float64(72.51075746912142),
#  np.float64(0.09070923183417676),
#  1.4999999829470194,
#  np.float64(1.1588155528798456e-06))

# %%
fdu.max_run_same_sign([1, 2, -1, -3, -4, 2])
# Out:
# 3

# %%
# Residual-pattern diagnostic

B_model = result.eval(r=r)

residuals = B - B_model
residuals_fit = residuals[to_fit]

max_residual_run = fdu.max_run_same_sign(residuals_fit)

max_residual_run
# Out:
# 6

# %%
residual_flags = {}

residual_flags["systematic_residuals"] = max_residual_run >= 4

residual_flags
# Out:
# {'systematic_residuals': True}

# %%
# Collect all diagnostic flags

all_flags = {}

all_flags.update(bound_flags)
all_flags.update(uncertainty_flags)
all_flags.update(redchi_flags)
all_flags.update(physical_flags)
all_flags.update(residual_flags)

all_flags
# Out:
# {'r0': False,
#  'sig2': np.False_,
#  'm': False,
#  's0': True,
#  'noise': np.True_,
#  'large_r0_uncertainty': np.True_,
#  'large_sig2_uncertainty': np.False_,
#  'large_s0_uncertainty': np.True_,
#  'large_noise_uncertainty': np.True_,
#  'large_m_uncertainty': np.True_,
#  'redchi_too_low': np.False_,
#  'redchi_too_high': np.False_,
#  'r0_larger_than_fit_range': np.False_,
#  'r0_much_larger_than_fit_range': np.False_,
#  'large_s0_arcsec': True,
#  'large_noise_fraction': np.False_,
#  'systematic_residuals': True}

# %%
# Rename bound flags for clarity

bound_flags_named = {
    f"{param_name}_near_bound": value
    for param_name, value in bound_flags.items()
}

bound_flags_named
# Out:
# {'r0_near_bound': False,
#  'sig2_near_bound': np.False_,
#  'm_near_bound': False,
#  's0_near_bound': True,
#  'noise_near_bound': np.True_}

# %%
# Collect all diagnostic flags

all_flags = {}

all_flags.update(bound_flags_named)
all_flags.update(uncertainty_flags)
all_flags.update(redchi_flags)
all_flags.update(physical_flags)
all_flags.update(residual_flags)

all_flags
# Out:
# {'r0_near_bound': False,
#  'sig2_near_bound': np.False_,
#  'm_near_bound': False,
#  's0_near_bound': True,
#  'noise_near_bound': np.True_,
#  'large_r0_uncertainty': np.True_,
#  'large_sig2_uncertainty': np.False_,
#  'large_s0_uncertainty': np.True_,
#  'large_noise_uncertainty': np.True_,
#  'large_m_uncertainty': np.True_,
#  'redchi_too_low': np.False_,
#  'redchi_too_high': np.False_,
#  'r0_larger_than_fit_range': np.False_,
#  'r0_much_larger_than_fit_range': np.False_,
#  'large_s0_arcsec': True,
#  'large_noise_fraction': np.False_,
#  'systematic_residuals': True}

# %%
active_flags = [key for key, value in all_flags.items() if value]

active_flags
# Out:
# ['s0_near_bound',
#  'noise_near_bound',
#  'large_r0_uncertainty',
#  'large_s0_uncertainty',
#  'large_noise_uncertainty',
#  'large_m_uncertainty',
#  'large_s0_arcsec',
#  'systematic_residuals']

# %%
# Diagnostic quality score

quality_score = 0

# Reduced chi-square flags
if all_flags["redchi_too_low"]:
    quality_score += 1

if all_flags["redchi_too_high"]:
    quality_score += 2

# Bound flags
if all_flags["r0_near_bound"]:
    quality_score += 2

if all_flags["sig2_near_bound"]:
    quality_score += 1

if all_flags["m_near_bound"]:
    quality_score += 2

if all_flags["s0_near_bound"]:
    quality_score += 2

if all_flags["noise_near_bound"]:
    quality_score += 1

# Uncertainty flags
if all_flags["large_r0_uncertainty"]:
    quality_score += 2

if all_flags["large_sig2_uncertainty"]:
    quality_score += 1

if all_flags["large_s0_uncertainty"]:
    quality_score += 1

if all_flags["large_noise_uncertainty"]:
    quality_score += 1

if all_flags["large_m_uncertainty"]:
    quality_score += 2

# Physical / interpretive flags
if all_flags["r0_larger_than_fit_range"]:
    quality_score += 1

if all_flags["r0_much_larger_than_fit_range"]:
    quality_score += 2

if all_flags["large_s0_arcsec"]:
    quality_score += 2

if all_flags["large_noise_fraction"]:
    quality_score += 2

# Residual-pattern flag
if all_flags["systematic_residuals"]:
    quality_score += 2

quality_score
# Out:
# 13

# %%
# Diagnostic quality class

if quality_score <= 1:
    quality_class = "A"
elif quality_score <= 3:
    quality_class = "B"
elif quality_score <= 6:
    quality_class = "C"
else:
    quality_class = "D"

quality_class
# Out:
# 'D'

# %%
# Diagnostic summary for current fit

diagnostics = {
    # Basic identifiers
    "name": name,
#    "data": data,
#    "line": line,
#    "binsize": binsize,

    # Fit setup
    "box_size": box_size,
    "pc_per_arcsec": pc_per_arcsec,
    "n_fit_points": n_fit_points,
    "relative_uncertainty": relative_uncertainty,

    # Fit quality
    "redchi": result.redchi,
    "quality_score": quality_score,
    "quality_class": quality_class,

    # Best-fit parameters
    "r0": result.params["r0"].value,
    "sig2": result.params["sig2"].value,
    "m": result.params["m"].value,
    "s0": result.params["s0"].value,
    "noise": result.params["noise"].value,

    # Interpretive diagnostics
    "r_fit_max": r_fit_max,
    "r0_over_rfitmax": r0_over_rfitmax,
    "s0_arcsec": s0_arcsec,
    "noise_fraction": noise_fraction,

    # Uncertainty diagnostics
    "r0_frac_uncertainty": r0_frac_uncertainty,
    "sig2_frac_uncertainty": sig2_frac_uncertainty,
    "s0_frac_uncertainty": s0_frac_uncertainty,
    "noise_frac_uncertainty": noise_frac_uncertainty,
    "m_abs_uncertainty": m_abs_uncertainty,

    # Residual diagnostics
    "max_residual_run": max_residual_run,

    # Flags
    "n_active_flags": len(active_flags),
    "active_flags": "; ".join(active_flags),
}

diagnostics
# Out:
# {'name': 'LVM-30Dor-6563_G5',
#  'box_size': 162.69683147365026,
#  'pc_per_arcsec': 0.24240684055476797,
#  'n_fit_points': np.int64(22),
#  'relative_uncertainty': 0.04347826086956522,
#  'redchi': np.float64(0.5948061871728955),
#  'quality_score': 13,
#  'quality_class': 'D',
#  'r0': 6.5773951097382986,
#  'sig2': 40.98729815839828,
#  'm': 0.6146912448447972,
#  's0': 0.3636102566983928,
#  'noise': 3.689488412714367e-05,
#  'r_fit_max': np.float64(72.51075746912142),
#  'r0_over_rfitmax': np.float64(0.09070923183417676),
#  's0_arcsec': 1.4999999829470194,
#  'noise_fraction': np.float64(1.1588155528798456e-06),
#  'r0_frac_uncertainty': np.float64(2.8218216696300353),
#  'sig2_frac_uncertainty': np.float64(0.40483629110925573),
#  's0_frac_uncertainty': np.float64(0.9060069883175217),
#  'noise_frac_uncertainty': np.float64(651854.2522969361),
#  'm_abs_uncertainty': np.float64(0.5359785932110455),
#  'max_residual_run': 6,
#  'n_active_flags': 8,
#  'active_flags': 's0_near_bound; noise_near_bound; large_r0_uncertainty; large_s0_uncertainty; large_noise_uncertainty; large_m_uncertainty; large_s0_arcsec; systematic_residuals'}

# %%
diagnostics_df = pd.DataFrame([diagnostics])

diagnostics_df
# Out:
#                 name    box_size  pc_per_arcsec  n_fit_points  \
# 0  LVM-30Dor-6563_G5  162.696831       0.242407            22
#
#    relative_uncertainty    redchi  quality_score quality_class        r0  \
# 0              0.043478  0.594806             13             D  6.577395
#
#         sig2  ...  s0_arcsec  noise_fraction  r0_frac_uncertainty  \
# 0  40.987298  ...        1.5        0.000001             2.821822
#
#    sig2_frac_uncertainty  s0_frac_uncertainty  noise_frac_uncertainty  \
# 0               0.404836             0.906007           651854.252297
#
#    m_abs_uncertainty  max_residual_run  n_active_flags  \
# 0           0.535979                 6               8
#
#                                         active_flags
# 0  s0_near_bound; noise_near_bound; large_r0_unce...
#
# [1 rows x 25 columns]

# %%
diagnostics_df[[
    "name",
    "redchi",
    "quality_score",
    "quality_class",
    "r0_over_rfitmax",
    "s0_arcsec",
    "noise_fraction",
    "max_residual_run",
    "n_active_flags",
    "active_flags",
]]
# Out:
#                 name    redchi  quality_score quality_class  r0_over_rfitmax  \
# 0  LVM-30Dor-6563_G5  0.594806             13             D         0.090709
#
#    s0_arcsec  noise_fraction  max_residual_run  n_active_flags  \
# 0        1.5        0.000001                 6               8
#
#                                         active_flags
# 0  s0_near_bound; noise_near_bound; large_r0_unce...

# %%
# Add individual diagnostic flag columns to diagnostics_df

for flag_name, flag_value in all_flags.items():
    diagnostics_df[flag_name] = flag_value

diagnostics_df
# Out:
#                 name    box_size  pc_per_arcsec  n_fit_points  \
# 0  LVM-30Dor-6563_G5  162.696831       0.242407            22
#
#    relative_uncertainty    redchi  quality_score quality_class        r0  \
# 0              0.043478  0.594806             13             D  6.577395
#
#         sig2  ...  large_s0_uncertainty  large_noise_uncertainty  \
# 0  40.987298  ...                  True                     True
#
#    large_m_uncertainty  redchi_too_low  redchi_too_high  \
# 0                 True           False            False
#
#    r0_larger_than_fit_range  r0_much_larger_than_fit_range  large_s0_arcsec  \
# 0                     False                          False             True
#
#    large_noise_fraction  systematic_residuals
# 0                 False                  True
#
# [1 rows x 42 columns]

# %%
flag_columns = list(all_flags.keys())

diagnostics_df[["name", "quality_class", "quality_score"] + flag_columns]
# Out:
#                 name quality_class  quality_score  r0_near_bound  \
# 0  LVM-30Dor-6563_G5             D             13          False
#
#    sig2_near_bound  m_near_bound  s0_near_bound  noise_near_bound  \
# 0            False         False           True              True
#
#    large_r0_uncertainty  large_sig2_uncertainty  large_s0_uncertainty  \
# 0                  True                   False                  True
#
#    large_noise_uncertainty  large_m_uncertainty  redchi_too_low  \
# 0                     True                 True           False
#
#    redchi_too_high  r0_larger_than_fit_range  r0_much_larger_than_fit_range  \
# 0            False                     False                          False
#
#    large_s0_arcsec  large_noise_fraction  systematic_residuals
# 0             True                 False                  True

# %%
from pathlib import Path

diagnostics_csv_path = Path("fits_ready/fit_diagnostics_summary.csv")

if diagnostics_csv_path.exists():
    diagnostics_all_df = pd.read_csv(diagnostics_csv_path)

    # Remove previous entry for the same run/sample
    diagnostics_all_df = diagnostics_all_df[
        diagnostics_all_df["name"] != diagnostics_df.loc[0, "name"]
    ]

    # Add the updated row
    diagnostics_all_df = pd.concat(
        [diagnostics_all_df, diagnostics_df],
        ignore_index=True,
    )

else:
    diagnostics_all_df = diagnostics_df.copy()

# Optional: sort alphabetically by sample name
diagnostics_all_df = diagnostics_all_df.sort_values("name").reset_index(drop=True)

# Save updated cumulative table
diagnostics_all_df.to_csv(diagnostics_csv_path, index=False)

diagnostics_all_df.tail()
# Out:
#                   name    box_size  pc_per_arcsec  n_fit_points  \
# 138  LVM-30Dor-6563_H5  164.105705       0.242407            21
# 139  LVM-30Dor-6563_H6  162.614191       0.242407            20
# 140  LVM-30Dor-6563_H7  138.150973       0.242407            20
# 141  LVM-30Dor-6563_H8  144.975654       0.242407            24
# 142  LVM-30Dor-6563_H9  164.544688       0.242407            21
#
#      relative_uncertainty    redchi  quality_score quality_class          r0  \
# 138              0.043478  0.570886             17             D  161.227634
# 139              0.021616  0.571832             17             D   90.973800
# 140              0.028588  0.556038             11             D   16.862526
# 141              0.232620  0.785392             15             D    8.169684
# 142              0.028588  0.586693             13             D    4.130532
#
#            sig2  ...  large_s0_uncertainty  large_noise_uncertainty  \
# 138  138.641857  ...                  True                    False
# 139   27.534840  ...                  True                    False
# 140   10.275883  ...                  True                    False
# 141   26.136315  ...                  True                     True
# 142   16.677505  ...                  True                    False
#
#      large_m_uncertainty  redchi_too_low  redchi_too_high  \
# 138                 True           False            False
# 139                 True           False            False
# 140                 True           False            False
# 141                 True           False            False
# 142                 True           False            False
#
#      r0_larger_than_fit_range  r0_much_larger_than_fit_range  large_s0_arcsec  \
# 138                      True                          False             True
# 139                      True                          False             True
# 140                     False                          False            False
# 141                     False                          False             True
# 142                     False                          False            False
#
#      large_noise_fraction  systematic_residuals
# 138                  True                  True
# 139                  True                  True
# 140                  True                  True
# 141                 False                  True
# 142                  True                  True
#
# [5 rows x 42 columns]

# %%
# Read cumulative diagnostics table

diagnostics_all_df = pd.read_csv(diagnostics_csv_path)

review_columns = [
    "name",
    "quality_class",
    "quality_score",
    "redchi",
    "r0_over_rfitmax",
    "s0_arcsec",
    "noise_fraction",
    "max_residual_run",
    "n_active_flags",
    "active_flags",
]

review_df = diagnostics_all_df[review_columns].copy()

review_df
# Out:
#                   name quality_class  quality_score    redchi  \
# 0     LVM-30Dor-6563_A             D              9  0.831565
# 1    LVM-30Dor-6563_B1             C              6  0.966211
# 2    LVM-30Dor-6563_B2             D              8  0.651435
# 3    LVM-30Dor-6563_B3             D              7  0.719106
# 4    LVM-30Dor-6563_B4             D             12  0.563527
# ..                 ...           ...            ...       ...
# 138  LVM-30Dor-6563_H5             D             17  0.570886
# 139  LVM-30Dor-6563_H6             D             17  0.571832
# 140  LVM-30Dor-6563_H7             D             11  0.556038
# 141  LVM-30Dor-6563_H8             D             15  0.785392
# 142  LVM-30Dor-6563_H9             D             13  0.586693
#
#      r0_over_rfitmax  s0_arcsec  noise_fraction  max_residual_run  \
# 0           0.160999   0.100000    4.504734e-01                 8
# 1           0.097836   0.100000    1.398719e-01                 4
# 2           0.161860   1.500000    9.283966e-02                 4
# 3           0.179584   1.500000    2.063994e-01                 4
# 4           0.892969   1.500000    3.208215e-11                 8
# ..               ...        ...             ...               ...
# 138         1.982299   1.499865    6.351315e-01                 8
# 139         1.255014   1.499948    5.732857e-01                 5
# 140         0.261033   0.100001    7.432026e-01                 5
# 141         0.126465   1.500000    2.177192e-01                 6
# 142         0.050743   0.100000    5.382716e-01                 4
#
#      n_active_flags                                       active_flags
# 0                 5  m_near_bound; s0_near_bound; large_s0_uncertai...
# 1                 4  s0_near_bound; large_s0_uncertainty; large_noi...
# 2                 5  s0_near_bound; large_s0_uncertainty; large_noi...
# 3                 4  s0_near_bound; large_s0_uncertainty; large_s0_...
# 4                 8  s0_near_bound; noise_near_bound; large_r0_unce...
# ..              ...                                                ...
# 138              10  r0_near_bound; s0_near_bound; large_r0_uncerta...
# 139              10  m_near_bound; s0_near_bound; large_r0_uncertai...
# 140               7  sig2_near_bound; s0_near_bound; large_sig2_unc...
# 141               9  m_near_bound; s0_near_bound; large_r0_uncertai...
# 142               8  sig2_near_bound; s0_near_bound; large_r0_uncer...
#
# [143 rows x 10 columns]

# %%
review_df_sorted = review_df.sort_values(
    by=["quality_score", "n_active_flags"],
    ascending=False,
).reset_index(drop=True)

review_df_sorted
# Out:
#                    name quality_class  quality_score    redchi  \
# 0     LVM-30Dor-6563_E8             D             19  0.767761
# 1    LVM-30Dor-6563_G34             D             19  0.857535
# 2     LVM-30Dor-6563_G6             D             19  0.506288
# 3    LVM-30Dor-6563_D11             D             17  0.842200
# 4    LVM-30Dor-6563_F19             D             17  0.983931
# ..                  ...           ...            ...       ...
# 138  LVM-30Dor-6563_G12             C              5  0.525290
# 139  LVM-30Dor-6563_C12             C              5  0.521427
# 140   LVM-30Dor-6563_C2             C              5  0.657243
# 141   LVM-30Dor-6563_E6             C              5  0.795781
# 142   LVM-30Dor-6563_G2             C              5  0.544671
#
#      r0_over_rfitmax  s0_arcsec  noise_fraction  max_residual_run  \
# 0           2.029686   1.500000        0.662434                 9
# 1           2.224643   1.499984        0.583919                 5
# 2           2.026295   1.500000        1.018592                10
# 3           2.038872   1.499995        0.050063                10
# 4           2.049500   1.499997        0.564041                 9
# ..               ...        ...             ...               ...
# 138         0.413709   0.611080        0.079072                 5
# 139         0.176939   0.100000        0.326014                 7
# 140         0.186342   0.100000        0.209987                 8
# 141         0.142493   0.100000        0.382568                 6
# 142         0.153542   0.243965        0.640892                 6
#
#      n_active_flags                                       active_flags
# 0                11  r0_near_bound; s0_near_bound; large_r0_uncerta...
# 1                11  r0_near_bound; s0_near_bound; large_r0_uncerta...
# 2                11  r0_near_bound; m_near_bound; s0_near_bound; la...
# 3                11  r0_near_bound; s0_near_bound; noise_near_bound...
# 4                10  r0_near_bound; s0_near_bound; large_r0_uncerta...
# ..              ...                                                ...
# 138               4  noise_near_bound; large_s0_uncertainty; large_...
# 139               3  s0_near_bound; large_s0_uncertainty; systemati...
# 140               3  s0_near_bound; large_s0_uncertainty; systemati...
# 141               3  s0_near_bound; large_s0_uncertainty; systemati...
# 142               3  large_s0_uncertainty; large_noise_fraction; sy...
#
# [143 rows x 10 columns]

# %%
review_csv_path = Path("fits_ready") / "fit_diagnostics_short.csv"

review_df_sorted.to_csv(review_csv_path, index=False)

review_csv_path
# Out:
# PosixPath('fits_ready/fit_diagnostics_short.csv')

# %% [markdown]
# # Export

# %%
#save_modelresult(result, "results_fit/" + name + "result_ideal.sav")
#save_modelresult(result_emcee, "results_fit/" + name + "result_emcee_ideal.sav")

# %%
df = pd.DataFrame(results_2sig)

# Flatten MultiIndex columns
if isinstance(df.columns, pd.MultiIndex):
    df.columns = ["_".join(map(str, col)).strip() for col in df.columns.to_flat_index()]
else:
    df.columns = [str(c) for c in df.columns]

df = df.reset_index(drop=True)

t = Table.from_pandas(df)
new_hdu = fits.BinTableHDU(t, name="PARAMETERS")

with fits.open(fits_path, memmap=False) as hdul:
    hdus = [h.copy() for h in hdul]

# FITS EXTNAMEs are effectively case-insensitive; astropy reports them uppercase.
target = "PARAMETERS"
idxs = [i for i, h in enumerate(hdus) if h.name.upper() == target]

if idxs:
    i0 = idxs[0]
    # Optional: preserve existing header cards (metadata) from old PARAMETERS
    old_hdr = hdus[i0].header.copy()
    hdus[i0] = new_hdu
    # Keep old metadata, then ensure EXTNAME stays correct
    hdus[i0].header.update(old_hdr)
    hdus[i0].name = target
    # Remove any additional duplicates if they exist
    for j in reversed(idxs[1:]):
        del hdus[j]
else:
    # If it doesn't exist, add it
    hdus.append(new_hdu)

fits.HDUList(hdus).writeto(fits_path, overwrite=True)

# %%
# Test import

from astropy.table import Table
t = Table.read(fits_path, hdu="PARAMETERS")
df_loaded = t.to_pandas()
df_loaded
# Out:
#         sig2         r0         m        s0      noise
# 0  40.987298   6.577395  0.614691  0.363610   0.000037
# 1   8.416194  18.560236  0.535979 -0.006610  24.050087
# 2  16.593146   0.309207  0.102397  0.329433  -0.484714

# %%
with fits.open(fits_path) as hdul:
    hdul.info()
# Out:
# Filename: fits_ready/LVM-30Dor-6563_G5.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      29   ()
#   1  LVM-30DOR-6563_G5    1 BinTableHDU     23   966R x 7C   [D, D, D, D, D, D, D]
#   2  TABLE         1 BinTableHDU     19   28R x 5C   [D, D, D, D, D]
#   3  PARAMETERS    1 BinTableHDU     19   3R x 5C   [D, D, D, D, D]

# %%
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 79.50489401817322 seconds ---
