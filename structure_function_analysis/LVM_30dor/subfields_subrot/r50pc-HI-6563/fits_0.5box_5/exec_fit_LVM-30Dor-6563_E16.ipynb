# %%
# Parameters
name      = ""
fits_path = ""

# %%
# Parameters
name = "LVM-30Dor-6563_E16"
fits_path = "fits_ready/LVM-30Dor-6563_E16.fits"

# %%
import time
start_time = time.time()

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import sys
from pathlib import Path
import astropy.units as u
from matplotlib import pyplot as plt
import corner
import json
from astropy.io import fits
import lmfit
from lmfit.model import save_modelresult

# %%
# Add path to py_modules 
sys.path.append(str(Path().resolve() / 'py_modules')) # 1 level up = project root
#import strucfunc                   
import bfunc
import bplot
from reduced_chi2 import make_weights, tune_relative_uncertainty
import fit_diagnostic_utils as fdu

# %%
with fits.open("fits_ready/" + name + ".fits") as hdul:
    hdr = hdul[0].header

#m3D      = hdul[0].header['M3D']
#ra       = hdul[0].header['RA']
sig      = hdul[0].header['SIG']
sig2     = hdul[0].header['SIG2']
s0       = hdul[0].header['S0']
#noise    = hdul[0].header['NOISE']
box_size = hdul[0].header['BOX_SIZE']
pc       = hdul[0].header['PC']
pix      = hdul[0].header['PIX']
line     = hdul[0].header['LINE']
binsize  = hdul[0].header['BINSIZE']

# %%
hdul.info()
# Out:
# Filename: fits_ready/LVM-30Dor-6563_E16.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      29   ()

# %%
pc_per_arcsec = pc
data = name

# %%
from astropy.table import Table
t = Table.read(fits_path, hdu="TABLE")
data_in = t.to_pandas()


B        = np.array(data_in['Unweighted B(r)'])#[mask]
r        = np.array(10 ** np.array(data_in['log10 r']))#[mask]

# %% [markdown]
# # Fit and Confidence intervals

# %% [markdown]
# ## Non-Linear Least-Squares Fitting

# %%
# Merging point

K = 5
r[K] = np.mean(r[: K + 1])
B[K] = np.mean(B[: K + 1])
r = r[K:]
B = B[K:]

# %%
# Define some scales for turning points in sf

r_local_peak = 2.5
r_local_minimum = 4.5

# %%
# Weights

#relative_uncertainty = 0.035
#weights = 1.0 / (relative_uncertainty * B)
#large_scale = r > 0.10 * box_size
#weights[large_scale] /= 2.0
#weights[:3] /= 2.0

#to_fit = r <= 0.15 * box_size
#to_fit = ~large_scale

# %%
# Weight configuration

weight_config = dict(
    large_scale_limit=0.35,
    fit_limit=0.5,
    large_scale_factor=2.0,
    first_points_factor=2.0,
    n_first_points=3,
)

initial_relative_uncertainty = 0.05

# %%
to_fit = r <= weight_config["fit_limit"] * box_size
large_scale = r > weight_config["large_scale_limit"] * box_size

# %%
model = lmfit.Model(bfunc.bfunc03s)
model.param_names
# Out:
# ['r0', 'sig2', 'm', 's0', 'noise']

# %%
# Correlation length between 1/10 and 2 x box_size
model.set_param_hint("r0", value=0.1 * box_size, min=0.01 * box_size, max=1.0 * box_size)

# sig2 between 1/4 and 2 x max value of B(r)
#model.set_param_hint("sig2", value=0.5 * B.max(), min=0.25 * B.max(), max=2 * B.max())
model.set_param_hint("sig2", 
                     value = 0.50 * B[to_fit].max(), 
                     min   = 0.25 * B[to_fit].max(), 
                     max   = 2.00 * B[to_fit].max()) 

# m between 1/2 and 5/3
model.set_param_hint("m", value=1.0, min=0.5, max=2.0)

# Seeing RMS between 0.1 and 1.5 arcsec
model.set_param_hint(
    "s0", value=0.5 * pc_per_arcsec, min=0.1 * pc_per_arcsec, max=1.5 * pc_per_arcsec
)

# Noise cannot be much larger than smallest B(r)
model.set_param_hint("noise", value=0.5 * B.min(), min=0.0, max=3 * B.min())

# box_size is fixed
# model.set_param_hint("box_size", value=box_size, vary=False)

# %%
pd.DataFrame(model.param_hints)
# Out:
#                r0         sig2    m        s0       noise
# value   16.705117   358.852974  1.0  0.121203   49.088074
# min      1.670512   179.426487  0.5  0.024241    0.000000
# max    167.051170  1435.411896  2.0  0.363610  294.528447

# %%
#result = model.fit(B[to_fit], weights=weights[to_fit], r=r[to_fit])

# %%
def fit_function(r_fit, B_fit, weights_fit):
    return model.fit(
        B_fit,
        weights=weights_fit,
        r=r_fit,
    )


result, relative_uncertainty, history = tune_relative_uncertainty(
    fit_function,
    r,
    B,
    box_size,
    initial_relative_uncertainty=initial_relative_uncertainty,
    target_redchi_min=0.5,
    target_redchi_max=1.0,
    step_factor=1.15,
    **weight_config,
)
# Out:
# iter 00: relative_uncertainty = 0.05000, redchi = 1.8399
# iter 01: relative_uncertainty = 0.05750, redchi = 1.3912
# iter 02: relative_uncertainty = 0.06612, redchi = 1.0519
# iter 03: relative_uncertainty = 0.07604, redchi = 0.7954
# Accepted relative_uncertainty.

# %%
weights_fit, to_fit, weights, large_scale = make_weights(
    r,
    B,
    box_size,
    relative_uncertainty=relative_uncertainty,
    **weight_config,
)

print("Accepted relative_uncertainty:", relative_uncertainty)
print("Final reduced chi-square:", result.redchi)
# Out:
# Accepted relative_uncertainty: 0.07604374999999998
# Final reduced chi-square: 0.7954207664285022

# %%
result
# Out:
# <h2>Fit Result</h2> <p>Model: Model(bfunc03s)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>leastsq</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>517</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>26</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>5</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 16.7038361</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 0.79542077</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'>-1.50391161</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'> 4.78657108</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.92281991</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>r0</td><td style='text-align:left'> 16.2321686</td><td style='text-align:left'> 29.6791928</td><td style='text-align:left'>(182.84%)</td><td style='text-align:left'>16.705117021966547</td><td style='text-align:left'> 1.67051170</td><td style='text-align:left'> 167.051170</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>sig2</td><td style='text-align:left'> 295.074741</td><td style='text-align:left'> 352.892216</td><td style='text-align:left'>(119.59%)</td><td style='text-align:left'>358.8529740437224</td><td style='text-align:left'> 179.426487</td><td style='text-align:left'> 1435.41190</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>m</td><td style='text-align:left'> 0.84250185</td><td style='text-align:left'> 1.48084805</td><td style='text-align:left'>(175.77%)</td><td style='text-align:left'>1.0</td><td style='text-align:left'> 0.50000000</td><td style='text-align:left'> 2.00000000</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>s0</td><td style='text-align:left'> 0.36361026</td><td style='text-align:left'> 41.7637375</td><td style='text-align:left'>(11485.85%)</td><td style='text-align:left'>0.12120342027738398</td><td style='text-align:left'> 0.02424068</td><td style='text-align:left'> 0.36361026</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>noise</td><td style='text-align:left'> 1.5719e-08</td><td style='text-align:left'> 2433.53291</td><td style='text-align:left'>(15481063045938.97%)</td><td style='text-align:left'>49.08807447848065</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'> 294.528447</td><td style='text-align:right'>True</td></tr></table><table class="jp-toc-ignore"><caption>Correlations (unreported values are < 0.100)</caption><tr><th style='text-align:left'>Parameter1</th><th style='text-align:left'>Parameter 2</th><th style='text-align:right'>Correlation</th></tr><tr><td style='text-align:left'>s0</td><td style='text-align:left'>noise</td><td style='text-align:right'>-0.9991</td></tr><tr><td style='text-align:left'>sig2</td><td style='text-align:left'>m</td><td style='text-align:right'>-0.9982</td></tr><tr><td style='text-align:left'>m</td><td style='text-align:left'>noise</td><td style='text-align:right'>+0.9930</td></tr><tr><td style='text-align:left'>r0</td><td style='text-align:left'>s0</td><td style='text-align:right'>-0.9927</td></tr><tr><td style='text-align:left'>r0</td><td style='text-align:left'>noise</td><td style='text-align:right ...

# %%
fig, ax = plt.subplots(figsize=(10, 10))

# Plot the underlying model without instrumental effects
Bu = bfunc.bfunc00s(
    r, result.params["r0"].value, result.params["sig2"].value, result.params["m"].value
)
ax.plot(r, Bu, color="k", linestyle="dashed", label="underlying")

# Plot the fit results
result.plot_fit(ax=ax)

# Add in the points not included in fit
ax.plot(r[~to_fit], B[~to_fit], "o")

# Dotted lines for 2 x rms seeing and for box size
ax.axvline(2 * result.params["s0"].value, color="k", linestyle="dotted")
ax.axvline(box_size, color="k", linestyle="dotted")

# Dashed lines for best-fit r0 and sig2
ax.axvline(result.params["r0"].value, color="k", linestyle="dashed")
ax.axhline(result.params["sig2"].value, color="k", linestyle="dashed")

# Gray box to indicate the large scale values that are excluded from the fit
ax.axvspan(box_size / 2, r[-1], color="k", alpha=0.05, zorder=-1)

ax.set(
    xscale="log",
    yscale="log",
    xlabel="r [pc]",
    ylabel=r"B(r) [km$^{2}$/s$^{2}$]",
)
sns.despine()

# %% [markdown]
# ## emcee

# %%
emcee_kws = dict(
    steps=35000, burn=1000, thin=50, is_weighted=True, progress=False, workers=1
)
emcee_params = result.params.copy()
# emcee_params.add('__lnsigma', value=np.log(0.1), min=np.log(0.001), max=np.log(2.0))

# %%
result_emcee = model.fit(
    data=B[to_fit],
    r=r[to_fit],
    weights=weights[to_fit],
    params=emcee_params,
    method="emcee",
    nan_policy="omit",
    fit_kws=emcee_kws,
)
# Out:
# /Users/javier/miniconda3/envs/viento/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# The chain is shorter than 50 times the integrated autocorrelation time for 3 parameter(s). Use this estimate with caution and run a longer chain!
# N/50 = 700;
# tau: [1181.57647499 1158.75150892  769.22255011  196.69466919  337.98451621]

# %%
result_emcee
# Out:
# <h2>Fit Result</h2> <p>Model: Model(bfunc03s)</p> <table class="jp-toc-ignore"><caption class="jp-toc-ignore">Fit Statistics</caption><tr><td style='text-align:left'>fitting method</td><td style='text-align:right'>emcee</td></tr><tr><td style='text-align:left'># function evals</td><td style='text-align:right'>3500000</td></tr><tr><td style='text-align:left'># data points</td><td style='text-align:right'>26</td></tr><tr><td style='text-align:left'># variables</td><td style='text-align:right'>5</td></tr><tr><td style='text-align:left'>chi-square</td><td style='text-align:right'> 19.2454150</td></tr><tr><td style='text-align:left'>reduced chi-square</td><td style='text-align:right'> 0.91644833</td></tr><tr><td style='text-align:left'>Akaike info crit.</td><td style='text-align:right'> 2.17858411</td></tr><tr><td style='text-align:left'>Bayesian info crit.</td><td style='text-align:right'> 8.46906680</td></tr><tr><td style='text-align:left'>R-squared</td><td style='text-align:right'> 0.93902957</td></tr></table><table class="jp-toc-ignore"><caption>Parameters</caption><tr><th style='text-align:left'>name</th><th style='text-align:left'>value</th><th style='text-align:left'>standard error</th><th style='text-align:left'>relative error</th><th style='text-align:left'>initial value</th><th style='text-align:left'>min</th><th style='text-align:left'>max</th><th style='text-align:right'>vary</th></tr><tr><td style='text-align:left'>r0</td><td style='text-align:left'> 21.1161970</td><td style='text-align:left'> 22.5057283</td><td style='text-align:left'>(106.58%)</td><td style='text-align:left'>16.232168604981375</td><td style='text-align:left'> 1.67051170</td><td style='text-align:left'> 167.051170</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>sig2</td><td style='text-align:left'> 312.747524</td><td style='text-align:left'> 139.989899</td><td style='text-align:left'>(44.76%)</td><td style='text-align:left'>295.074740923942</td><td style='text-align:left'> 179.426487</td><td style='text-align:left'> 1435.41190</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>m</td><td style='text-align:left'> 0.84140796</td><td style='text-align:left'> 0.15812907</td><td style='text-align:left'>(18.79%)</td><td style='text-align:left'>0.8425018542995121</td><td style='text-align:left'> 0.50000000</td><td style='text-align:left'> 2.00000000</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>s0</td><td style='text-align:left'> 0.21952361</td><td style='text-align:left'> 0.11548237</td><td style='text-align:left'>(52.61%)</td><td style='text-align:left'>0.3636102606574134</td><td style='text-align:left'> 0.02424068</td><td style='text-align:left'> 0.36361026</td><td style='text-align:right'>True</td></tr><tr><td style='text-align:left'>noise</td><td style='text-align:left'> 13.9519162</td><td style='text-align:left'> 15.0076825</td><td style='text-align:left'>(107.57%)</td><td style='text-align:left'>1.5719417317053045e-08</td><td style='text-align:left'> 0.00000000</td><td style='text-align:left'> 294.528447</td><td style='text-align:right'>True</td></tr></table><table class="jp-toc-ignore"><caption>Correlations (unreported values are < 0.100)</caption><tr><th style='text-align:left'>Parameter1</th><th style='text-align:left'>Parameter 2</th><th style='text-align:right'>Correlation</th></tr><tr><td style='text-align:left'>r0</td><td style='text-align:left'>sig2</td><td style='text-align:right'>+0.9778</td></tr><tr><td style='text-align:left'>sig2</td><td style='text-align:left'>m</td><td style='text-align:right'>-0.7781</td></tr><tr><td style='text-align:left'>r0</td><td style='text-align:left'>m</td><td style='text-align:right'>-0.6734</td></tr><tr><td style='text-align:left'>m</td><td style='text-align:left'>noise</td><td style='text-align:right'>+0.6164</td></tr><tr><td style='text-align:left'>sig2</td><td style='text-align:left'>noise</td><td style='text-align:r ...

# %%
plt.plot(result_emcee.acceptance_fraction, "o")
plt.xlabel("walker")
plt.ylabel("acceptance fraction")
# Out:
# Text(0, 0.5, 'acceptance fraction')

# %%
if hasattr(result_emcee, "acor"):
    print("Autocorrelation time for the parameters:")
    print("----------------------------------------")
    for i, p in enumerate(result_emcee.params):
        try:
            print(f"{p} = {result_emcee.acor[i]:.3f}")
        except IndexError:
            pass

# %%
bplot.corner_plot(
    result_emcee, result, name, data, data_ranges=[0.95, 0.95, 0.995, 0.999, 0.999]
)
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %%
bplot.STYLE["data label element"] = 4
bplot.STYLE["model label element"] = 0
bplot.STYLE["model label offset"] = (-60, 40)
bplot.STYLE["true model label element"] = 7
bplot.STYLE["true model label offset"] = (30, -60)
bplot.strucfunc_plot(
    result_emcee, result, r, B, to_fit, name, data, box_size, large_scale
)

# %%
LM = {
    'sig2': [result.params['sig2'].value,result.params['sig2'].stderr],
    'r0': [result.params['r0'].value,result.params['r0'].stderr],
    'm' : [result.params['m'].value,result.params['m'].stderr],
    's0': [result.params['s0'].value,result.params['s0'].stderr],
    'noise' : [result.params['noise'].value,result.params['noise'].stderr]
}

# %%
MCMC = {
    'sig2': [result_emcee.params['sig2'].value,result_emcee.params['sig2'].stderr],
    'r0': [result_emcee.params['r0'].value,result_emcee.params['r0'].stderr],
    'm' : [result_emcee.params['m'].value,result_emcee.params['m'].stderr],
    's0': [result_emcee.params['s0'].value,result_emcee.params['s0'].stderr],
    'noise' : [result_emcee.params['noise'].value,result_emcee.params['noise'].stderr]
}

# %%
sig2s2 = np.percentile(result_emcee.flatchain['sig2'],[2.5, 97.5])
r0s2 = np.percentile(result_emcee.flatchain['r0'],[2.5, 97.5])
ms2 = np.percentile(result_emcee.flatchain['m'],[2.5, 97.5])
s0s2 = np.percentile(result_emcee.flatchain['s0'],[2.5, 97.5])
b0s2 = np.percentile(result_emcee.flatchain['noise'],[2.5, 97.5])

# %%
sig2s2p = sig2s2[1]-result.params['sig2'].value
sig2s2m = result.params['sig2'].value-sig2s2[0]

r0s2p = r0s2[1]-result.params['r0'].value
r0s2m = result.params['r0'].value-r0s2[0]

ms2p = ms2[1]-result.params['m'].value
ms2m = result.params['m'].value-ms2[0]

s0s2p = s0s2[1]-result.params['s0'].value
s0s2m = result.params['s0'].value-s0s2[0]

b0s2p = b0s2[1]-result.params['noise'].value
b0s2m = result.params['noise'].value-b0s2[0]

# %%
# MCMC 1 sigma confidence interval

sig2s1 = np.percentile(result_emcee.flatchain['sig2'],[16, 85])
r0s1 = np.percentile(result_emcee.flatchain['r0'],[16, 85])
ms1 = np.percentile(result_emcee.flatchain['m'],[16, 85])
s0s1 = np.percentile(result_emcee.flatchain['s0'],[16, 85])
b0s1 = np.percentile(result_emcee.flatchain['noise'],[16, 85])

sig2s1p = sig2s1[1]-result.params['sig2'].value
sig2s1m = result.params['sig2'].value-sig2s1[0]

r0s1p = r0s1[1]-result.params['r0'].value
r0s1m = result.params['r0'].value-r0s1[0]

ms1p = ms1[1]-result.params['m'].value
ms1m = result.params['m'].value-ms1[0]

s0s1p = s0s1[1]-result.params['s0'].value
s0s1m = result.params['s0'].value-s0s1[0]

b0s1p = b0s1[1]-result.params['noise'].value
b0s1m = result.params['noise'].value-b0s1[0]

# %%
#  LM + MCMC 2 sigma

results_2sig = {
    'sig2': [result.params['sig2'].value,sig2s2p,sig2s2m],
    'r0': [result.params['r0'].value,r0s2p,r0s2m],
    'm' : [result.params['m'].value,ms2p,ms2m],
    's0': [result.params['s0'].value,s0s2p,s0s2m],
    'noise' : [result.params['noise'].value,b0s2p,b0s2m] 
    
}

results_2sig
# Out:
# {'sig2': [295.074740923942, 533.5197712576917, 71.8989527295158],
#  'r0': [16.232168604981375, 129.4168834819537, 3.5248287376593037],
#  'm': [0.8425018542995121, 0.3433861597167821, 0.22211538984248713],
#  's0': [0.3636102606574134, -0.006147049279606243, 0.32872277653137966],
#  'noise': [1.5719417317053045e-08, 56.95060864171822, -0.4415657304729844]}

# %% [markdown]
# # Diagnostic

# %%
import importlib
importlib.reload(fdu)
# Out:
# <module 'fit_diagnostic_utils' from '/Users/javier/LVM_30dor/subfields_subrot/r50pc-HI-6563/py_modules/fit_diagnostic_utils.py'>

# %%
params_to_check = ["r0", "sig2", "m", "s0", "noise"]

bound_flags = fdu.get_bound_flags(
    result.params,
    param_names=params_to_check,
    frac=0.05,
)

# Use a relative bound criterion for r0 because its allowed range is wide
bound_flags["r0"] = fdu.near_bound_relative(
    result.params["r0"],
    lower_factor=1.5,
    upper_fraction=0.9,
)

bound_flags
# Out:
# {'r0': False, 'sig2': False, 'm': False, 's0': True, 'noise': True}

# %%
n_params_near_bounds = sum(bound_flags.values())

n_params_near_bounds
# Out:
# 2

# %%
# Fractional uncertainty diagnostics from 2-sigma MCMC intervals

r0_frac_uncertainty = fdu.frac_uncertainty(
    value=results_2sig["r0"][0],
    err_plus=results_2sig["r0"][1],
    err_minus=results_2sig["r0"][2],
)

sig2_frac_uncertainty = fdu.frac_uncertainty(
    value=results_2sig["sig2"][0],
    err_plus=results_2sig["sig2"][1],
    err_minus=results_2sig["sig2"][2],
)

s0_frac_uncertainty = fdu.frac_uncertainty(
    value=results_2sig["s0"][0],
    err_plus=results_2sig["s0"][1],
    err_minus=results_2sig["s0"][2],
)

noise_frac_uncertainty = fdu.frac_uncertainty(
    value=results_2sig["noise"][0],
    err_plus=results_2sig["noise"][1],
    err_minus=results_2sig["noise"][2],
)

m_abs_uncertainty = max(
    abs(results_2sig["m"][1]),
    abs(results_2sig["m"][2]),
)

# %%
r0_frac_uncertainty, sig2_frac_uncertainty, s0_frac_uncertainty, noise_frac_uncertainty, m_abs_uncertainty
# Out:
# (7.9728646634583304,
#  1.8080835031393314,
#  0.9040525312378243,
#  3622946543.9495616,
#  0.3433861597167821)

# %%
# Uncertainty quality flags

uncertainty_flags = {}

uncertainty_flags["large_r0_uncertainty"] = r0_frac_uncertainty > 0.5
uncertainty_flags["large_sig2_uncertainty"] = sig2_frac_uncertainty > 0.5
uncertainty_flags["large_s0_uncertainty"] = s0_frac_uncertainty > 0.75
uncertainty_flags["large_noise_uncertainty"] = noise_frac_uncertainty > 1.0
uncertainty_flags["large_m_uncertainty"] = m_abs_uncertainty > 0.3

uncertainty_flags
# Out:
# {'large_r0_uncertainty': True,
#  'large_sig2_uncertainty': True,
#  'large_s0_uncertainty': True,
#  'large_noise_uncertainty': True,
#  'large_m_uncertainty': True}

# %%
n_large_uncertainties = sum(uncertainty_flags.values())

n_large_uncertainties
# Out:
# 5

# %%
# Reduced chi-square quality flags

redchi_flags = {}

redchi_flags["redchi_too_low"] = result.redchi < 0.3
redchi_flags["redchi_too_high"] = result.redchi > 1.2

redchi_flags
# Out:
# {'redchi_too_low': False, 'redchi_too_high': False}

# %%
# Physical / interpretive diagnostics

r_fit_max = np.max(r[to_fit])
n_fit_points = np.sum(to_fit)

r0_value = result.params["r0"].value
s0_value = result.params["s0"].value
noise_value = result.params["noise"].value

r0_over_rfitmax = r0_value / r_fit_max
s0_arcsec = s0_value / pc_per_arcsec

n_small = min(3, np.sum(to_fit))
B_small = np.median(B[to_fit][:n_small])
noise_fraction = noise_value / B_small

physical_flags = {}

physical_flags["r0_larger_than_fit_range"] = r0_over_rfitmax > 1.0
physical_flags["r0_much_larger_than_fit_range"] = r0_over_rfitmax > 2.0
physical_flags["large_s0_arcsec"] = s0_arcsec > 1.2
physical_flags["large_noise_fraction"] = noise_fraction > 0.5

physical_flags
# Out:
# {'r0_larger_than_fit_range': False,
#  'r0_much_larger_than_fit_range': False,
#  'large_s0_arcsec': True,
#  'large_noise_fraction': False}

# %%
r_fit_max, r0_over_rfitmax, s0_arcsec, noise_fraction
# Out:
# (81.33250023603323,
#  0.19957788778009236,
#  1.4999999992791517,
#  1.4880785269388832e-10)

# %%
fdu.max_run_same_sign([1, 2, -1, -3, -4, 2])
# Out:
# 3

# %%
# Residual-pattern diagnostic

B_model = result.eval(r=r)

residuals = B - B_model
residuals_fit = residuals[to_fit]

max_residual_run = fdu.max_run_same_sign(residuals_fit)

max_residual_run
# Out:
# 9

# %%
residual_flags = {}

residual_flags["systematic_residuals"] = max_residual_run >= 4

residual_flags
# Out:
# {'systematic_residuals': True}

# %%
# Collect all diagnostic flags

all_flags = {}

all_flags.update(bound_flags)
all_flags.update(uncertainty_flags)
all_flags.update(redchi_flags)
all_flags.update(physical_flags)
all_flags.update(residual_flags)

all_flags
# Out:
# {'r0': False,
#  'sig2': False,
#  'm': False,
#  's0': True,
#  'noise': True,
#  'large_r0_uncertainty': True,
#  'large_sig2_uncertainty': True,
#  'large_s0_uncertainty': True,
#  'large_noise_uncertainty': True,
#  'large_m_uncertainty': True,
#  'redchi_too_low': False,
#  'redchi_too_high': False,
#  'r0_larger_than_fit_range': False,
#  'r0_much_larger_than_fit_range': False,
#  'large_s0_arcsec': True,
#  'large_noise_fraction': False,
#  'systematic_residuals': True}

# %%
# Rename bound flags for clarity

bound_flags_named = {
    f"{param_name}_near_bound": value
    for param_name, value in bound_flags.items()
}

bound_flags_named
# Out:
# {'r0_near_bound': False,
#  'sig2_near_bound': False,
#  'm_near_bound': False,
#  's0_near_bound': True,
#  'noise_near_bound': True}

# %%
# Collect all diagnostic flags

all_flags = {}

all_flags.update(bound_flags_named)
all_flags.update(uncertainty_flags)
all_flags.update(redchi_flags)
all_flags.update(physical_flags)
all_flags.update(residual_flags)

all_flags
# Out:
# {'r0_near_bound': False,
#  'sig2_near_bound': False,
#  'm_near_bound': False,
#  's0_near_bound': True,
#  'noise_near_bound': True,
#  'large_r0_uncertainty': True,
#  'large_sig2_uncertainty': True,
#  'large_s0_uncertainty': True,
#  'large_noise_uncertainty': True,
#  'large_m_uncertainty': True,
#  'redchi_too_low': False,
#  'redchi_too_high': False,
#  'r0_larger_than_fit_range': False,
#  'r0_much_larger_than_fit_range': False,
#  'large_s0_arcsec': True,
#  'large_noise_fraction': False,
#  'systematic_residuals': True}

# %%
active_flags = [key for key, value in all_flags.items() if value]

active_flags
# Out:
# ['s0_near_bound',
#  'noise_near_bound',
#  'large_r0_uncertainty',
#  'large_sig2_uncertainty',
#  'large_s0_uncertainty',
#  'large_noise_uncertainty',
#  'large_m_uncertainty',
#  'large_s0_arcsec',
#  'systematic_residuals']

# %%
# Diagnostic quality score

quality_score = 0

# Reduced chi-square flags
if all_flags["redchi_too_low"]:
    quality_score += 1

if all_flags["redchi_too_high"]:
    quality_score += 2

# Bound flags
if all_flags["r0_near_bound"]:
    quality_score += 2

if all_flags["sig2_near_bound"]:
    quality_score += 1

if all_flags["m_near_bound"]:
    quality_score += 2

if all_flags["s0_near_bound"]:
    quality_score += 2

if all_flags["noise_near_bound"]:
    quality_score += 1

# Uncertainty flags
if all_flags["large_r0_uncertainty"]:
    quality_score += 2

if all_flags["large_sig2_uncertainty"]:
    quality_score += 1

if all_flags["large_s0_uncertainty"]:
    quality_score += 1

if all_flags["large_noise_uncertainty"]:
    quality_score += 1

if all_flags["large_m_uncertainty"]:
    quality_score += 2

# Physical / interpretive flags
if all_flags["r0_larger_than_fit_range"]:
    quality_score += 1

if all_flags["r0_much_larger_than_fit_range"]:
    quality_score += 2

if all_flags["large_s0_arcsec"]:
    quality_score += 2

if all_flags["large_noise_fraction"]:
    quality_score += 2

# Residual-pattern flag
if all_flags["systematic_residuals"]:
    quality_score += 2

quality_score
# Out:
# 14

# %%
# Diagnostic quality class

if quality_score <= 1:
    quality_class = "A"
elif quality_score <= 3:
    quality_class = "B"
elif quality_score <= 6:
    quality_class = "C"
else:
    quality_class = "D"

quality_class
# Out:
# 'D'

# %%
# Diagnostic summary for current fit

diagnostics = {
    # Basic identifiers
    "name": name,
#    "data": data,
#    "line": line,
#    "binsize": binsize,

    # Fit setup
    "box_size": box_size,
    "pc_per_arcsec": pc_per_arcsec,
    "n_fit_points": n_fit_points,
    "relative_uncertainty": relative_uncertainty,

    # Fit quality
    "redchi": result.redchi,
    "quality_score": quality_score,
    "quality_class": quality_class,

    # Best-fit parameters
    "r0": result.params["r0"].value,
    "sig2": result.params["sig2"].value,
    "m": result.params["m"].value,
    "s0": result.params["s0"].value,
    "noise": result.params["noise"].value,

    # Interpretive diagnostics
    "r_fit_max": r_fit_max,
    "r0_over_rfitmax": r0_over_rfitmax,
    "s0_arcsec": s0_arcsec,
    "noise_fraction": noise_fraction,

    # Uncertainty diagnostics
    "r0_frac_uncertainty": r0_frac_uncertainty,
    "sig2_frac_uncertainty": sig2_frac_uncertainty,
    "s0_frac_uncertainty": s0_frac_uncertainty,
    "noise_frac_uncertainty": noise_frac_uncertainty,
    "m_abs_uncertainty": m_abs_uncertainty,

    # Residual diagnostics
    "max_residual_run": max_residual_run,

    # Flags
    "n_active_flags": len(active_flags),
    "active_flags": "; ".join(active_flags),
}

diagnostics
# Out:
# {'name': 'LVM-30Dor-6563_E16',
#  'box_size': 167.05117021966547,
#  'pc_per_arcsec': 0.24240684055476797,
#  'n_fit_points': 26,
#  'relative_uncertainty': 0.07604374999999998,
#  'redchi': 0.7954207664285022,
#  'quality_score': 14,
#  'quality_class': 'D',
#  'r0': 16.232168604981375,
#  'sig2': 295.074740923942,
#  'm': 0.8425018542995121,
#  's0': 0.3636102606574134,
#  'noise': 1.5719417317053045e-08,
#  'r_fit_max': 81.33250023603323,
#  'r0_over_rfitmax': 0.19957788778009236,
#  's0_arcsec': 1.4999999992791517,
#  'noise_fraction': 1.4880785269388832e-10,
#  'r0_frac_uncertainty': 7.9728646634583304,
#  'sig2_frac_uncertainty': 1.8080835031393314,
#  's0_frac_uncertainty': 0.9040525312378243,
#  'noise_frac_uncertainty': 3622946543.9495616,
#  'm_abs_uncertainty': 0.3433861597167821,
#  'max_residual_run': 9,
#  'n_active_flags': 9,
#  'active_flags': 's0_near_bound; noise_near_bound; large_r0_uncertainty; large_sig2_uncertainty; large_s0_uncertainty; large_noise_uncertainty; large_m_uncertainty; large_s0_arcsec; systematic_residuals'}

# %%
diagnostics_df = pd.DataFrame([diagnostics])

diagnostics_df
# Out:
#                  name   box_size  pc_per_arcsec  n_fit_points  \
# 0  LVM-30Dor-6563_E16  167.05117       0.242407            26
#
#    relative_uncertainty    redchi  quality_score quality_class         r0  \
# 0              0.076044  0.795421             14             D  16.232169
#
#          sig2  ...  s0_arcsec  noise_fraction  r0_frac_uncertainty  \
# 0  295.074741  ...        1.5    1.488079e-10             7.972865
#
#    sig2_frac_uncertainty  s0_frac_uncertainty  noise_frac_uncertainty  \
# 0               1.808084             0.904053            3.622947e+09
#
#    m_abs_uncertainty  max_residual_run  n_active_flags  \
# 0           0.343386                 9               9
#
#                                         active_flags
# 0  s0_near_bound; noise_near_bound; large_r0_unce...
#
# [1 rows x 25 columns]

# %%
diagnostics_df[[
    "name",
    "redchi",
    "quality_score",
    "quality_class",
    "r0_over_rfitmax",
    "s0_arcsec",
    "noise_fraction",
    "max_residual_run",
    "n_active_flags",
    "active_flags",
]]
# Out:
#                  name    redchi  quality_score quality_class  r0_over_rfitmax  \
# 0  LVM-30Dor-6563_E16  0.795421             14             D         0.199578
#
#    s0_arcsec  noise_fraction  max_residual_run  n_active_flags  \
# 0        1.5    1.488079e-10                 9               9
#
#                                         active_flags
# 0  s0_near_bound; noise_near_bound; large_r0_unce...

# %%
# Add individual diagnostic flag columns to diagnostics_df

for flag_name, flag_value in all_flags.items():
    diagnostics_df[flag_name] = flag_value

diagnostics_df
# Out:
#                  name   box_size  pc_per_arcsec  n_fit_points  \
# 0  LVM-30Dor-6563_E16  167.05117       0.242407            26
#
#    relative_uncertainty    redchi  quality_score quality_class         r0  \
# 0              0.076044  0.795421             14             D  16.232169
#
#          sig2  ...  large_s0_uncertainty  large_noise_uncertainty  \
# 0  295.074741  ...                  True                     True
#
#    large_m_uncertainty  redchi_too_low  redchi_too_high  \
# 0                 True           False            False
#
#    r0_larger_than_fit_range  r0_much_larger_than_fit_range  large_s0_arcsec  \
# 0                     False                          False             True
#
#    large_noise_fraction  systematic_residuals
# 0                 False                  True
#
# [1 rows x 42 columns]

# %%
flag_columns = list(all_flags.keys())

diagnostics_df[["name", "quality_class", "quality_score"] + flag_columns]
# Out:
#                  name quality_class  quality_score  r0_near_bound  \
# 0  LVM-30Dor-6563_E16             D             14          False
#
#    sig2_near_bound  m_near_bound  s0_near_bound  noise_near_bound  \
# 0            False         False           True              True
#
#    large_r0_uncertainty  large_sig2_uncertainty  large_s0_uncertainty  \
# 0                  True                    True                  True
#
#    large_noise_uncertainty  large_m_uncertainty  redchi_too_low  \
# 0                     True                 True           False
#
#    redchi_too_high  r0_larger_than_fit_range  r0_much_larger_than_fit_range  \
# 0            False                     False                          False
#
#    large_s0_arcsec  large_noise_fraction  systematic_residuals
# 0             True                 False                  True

# %%
from pathlib import Path

diagnostics_csv_path = Path("fits_ready/fit_diagnostics_summary.csv")

if diagnostics_csv_path.exists():
    diagnostics_all_df = pd.read_csv(diagnostics_csv_path)

    # Remove previous entry for the same run/sample
    diagnostics_all_df = diagnostics_all_df[
        diagnostics_all_df["name"] != diagnostics_df.loc[0, "name"]
    ]

    # Add the updated row
    diagnostics_all_df = pd.concat(
        [diagnostics_all_df, diagnostics_df],
        ignore_index=True,
    )

else:
    diagnostics_all_df = diagnostics_df.copy()

# Optional: sort alphabetically by sample name
diagnostics_all_df = diagnostics_all_df.sort_values("name").reset_index(drop=True)

# Save updated cumulative table
diagnostics_all_df.to_csv(diagnostics_csv_path, index=False)

diagnostics_all_df.tail()
# Out:
#                  name    box_size  pc_per_arcsec  n_fit_points  \
# 48  LVM-30Dor-6563_E5  165.104863       0.242407            26
# 49  LVM-30Dor-6563_E6  165.384912       0.242407            26
# 50  LVM-30Dor-6563_E7  165.170613       0.242407            26
# 51  LVM-30Dor-6563_E8  165.082289       0.242407            21
# 52  LVM-30Dor-6563_E9  165.444826       0.242407            21
#
#     relative_uncertainty    redchi  quality_score quality_class          r0  \
# 48              0.050000  0.651114             10             D   39.716157
# 49              0.057500  0.787047              7             D   11.740397
# 50              0.175894  0.882065             13             D   29.569691
# 51              0.076044  0.831887             19             D  165.081877
# 52              0.032876  0.552941             11             D    8.414653
#
#           sig2  ...  large_s0_uncertainty  large_noise_uncertainty  \
# 48   31.819118  ...                  True                     True
# 49   29.931214  ...                  True                    False
# 50   63.547939  ...                  True                    False
# 51  145.444140  ...                  True                    False
# 52   23.578724  ...                  True                     True
#
#     large_m_uncertainty  redchi_too_low  redchi_too_high  \
# 48                False           False            False
# 49                 True           False            False
# 50                 True           False            False
# 51                 True           False            False
# 52                 True           False            False
#
#     r0_larger_than_fit_range  r0_much_larger_than_fit_range  large_s0_arcsec  \
# 48                     False                          False            False
# 49                     False                          False            False
# 50                     False                          False            False
# 51                      True                           True             True
# 52                     False                          False             True
#
#     large_noise_fraction  systematic_residuals
# 48                 False                  True
# 49                 False                  True
# 50                  True                  True
# 51                  True                  True
# 52                 False                  True
#
# [5 rows x 42 columns]

# %%
# Read cumulative diagnostics table

diagnostics_all_df = pd.read_csv(diagnostics_csv_path)

review_columns = [
    "name",
    "quality_class",
    "quality_score",
    "redchi",
    "r0_over_rfitmax",
    "s0_arcsec",
    "noise_fraction",
    "max_residual_run",
    "n_active_flags",
    "active_flags",
]

review_df = diagnostics_all_df[review_columns].copy()

review_df
# Out:
#                   name quality_class  quality_score    redchi  \
# 0     LVM-30Dor-6563_A             D              9  0.903346
# 1    LVM-30Dor-6563_B1             C              6  0.787893
# 2    LVM-30Dor-6563_B2             D              9  0.678354
# 3    LVM-30Dor-6563_B3             D              8  0.748781
# 4    LVM-30Dor-6563_B4             D             12  0.531988
# 5    LVM-30Dor-6563_B5             D             14  0.765202
# 6    LVM-30Dor-6563_B6             D             11  0.932811
# 7    LVM-30Dor-6563_B7             D              9  0.548805
# 8    LVM-30Dor-6563_C1             D             16  0.777968
# 9   LVM-30Dor-6563_C10             D             12  0.893776
# 10  LVM-30Dor-6563_C11             D             11  0.972298
# 11  LVM-30Dor-6563_C12             C              5  0.632089
# 12  LVM-30Dor-6563_C13             D              9  0.973883
# 13   LVM-30Dor-6563_C2             C              6  0.524491
# 14   LVM-30Dor-6563_C3             D             12  0.809339
# 15   LVM-30Dor-6563_C4             D              9  0.710336
# 16   LVM-30Dor-6563_C5             D             12  0.758747
# 17   LVM-30Dor-6563_C6             D             14  0.933376
# 18   LVM-30Dor-6563_C7             D             11  0.960455
# 19   LVM-30Dor-6563_C8             D              8  0.931987
# 20   LVM-30Dor-6563_C9             D             11  0.855625
# 21   LVM-30Dor-6563_D1             D             12  0.933788
# 22  LVM-30Dor-6563_D10             D             11  0.862973
# 23  LVM-30Dor-6563_D11             D             16  0.996618
# 24  LVM-30Dor-6563_D12             D             12  0.905099
# 25  LVM-30Dor-6563_D13             D             11  0.997689
# 26  LVM-30Dor-6563_D14             D             13  0.770699
# 27  LVM-30Dor-6563_D15             D             11  0.839325
# 28  LVM-30Dor-6563_D16             D              9  0.990975
# 29  LVM-30Dor-6563_D17             D              9  0.914766
# 30  LVM-30Dor-6563_D18             D             11  0.880598
# 31  LVM-30Dor-6563_D19             D              9  0.508865
# 32   LVM-30Dor-6563_D2             D             12  0.817371
# 33   LVM-30Dor-6563_D3             D             15  0.876233
# 34   LVM-30Dor-6563_D4             C              5  0.653719
# 35   LVM-30Dor-6563_D5             D              9  0.892636
# 36   LVM-30Dor-6563_D6             D             14  0.785119
# 37   LVM-30Dor-6563_D7             D              9  0.760922
# 38   LVM-30Dor-6563_D8             D              7  0.802210
# 39   LVM-30Dor-6563_D9             D             12  0.883005
# 40   LVM-30Dor-6563_E1             D             12  0.901010
# 41  LVM-30Dor-6563_E10             D             14  0.864599
# 42  LVM-30Dor-6563_E14             D             14  0.503126
# 43  LVM-30Dor-6563_E15             D              7  0.975474
# 44  LVM-30Dor-6563_E16             D             14  0.795421
# 45   LVM-30Dor-6563_E2             D             10  0.692273
# 46   LVM-30Dor-6563_E3             D             12  0.995133
# 47   LVM-30Dor-6563_E4             D             12  0.772994
# 48   LVM-30Dor-6563_E5             D             10  0.651114
# 49   LVM-30Dor-6563_E6             D              7  0.787047
# 50   LVM-30Dor-6563_E7             D             13  0.882065
# 51   LVM-30Dor-6563_E8             D             19  0.831887
# 52   LVM-30Dor-6563_E9             D             11  0.552941
#
#     r0_over_rfitmax  s0_arcsec  noise_fraction  max_residual_run  \
# 0          0.161363   0.100000    2.884545e-01                 8
# 1          0.098646   0.100000    1.273463e-01                 4
# 2          0.161672   1.500000    7.703418e-02                 4
# 3          0.180072   1.500000    1.307237e-01                 5
# 4          0.964978   1.500000    2.917766e-11                 8
# 5          0.246199   1.500000    2.562296e-08                 8
# 6          0.097035   1.500000    1.025388e-01                 5
# 7          0.126835   1.500000    1.160369e-11                 6
# 8          2.023180   1.500000    2.826893e-02                10
# 9          0.556483   1.499997    2.651904e-11                10
# 10         0.106408   1.500000    4.079140e-01                 6
# 11         0.177612   0.100000    2.581559e-01                 7
# 12         0.240043   1.500000    1.873131e-06                 9
# 13         0.187477   0.100003    1.825791e-01                 8
# 14         0.401187   1.500000    2.812950e-11                 7
# 15         0.257709   1.500000    2.452141e-09                 6
# 16         0.324539   1.500000    3.035995e-11                 5
# 17         0.129331   1.500000    2.555293e-06                 6
# 18         0.180251   1.500000    5.321314e-07                 7
# 19         0.208444   1.500000    8.325938e-02                 8
# 20         0.131532   1.500000    4.644991e-08                 7
# 21         0.569599   1.500000    2.464778e-11                 5
# 22         0.095201   0.100000    3.303226e-02                 6
# 23         2.039104   1.499997    3.059647e-01                10
# 24         0.312974   1.500000    4.467640e-09                10
# 25         0.146270   1.500000    1.309746e-08                 8
# 26         1.126035   1.499970    2.127761e-11                 9
# 27         0.084956   1.500000    8.169439e-08                 8
# 28         0.183549   1.500000    2.049524e-11                 5
# 29         0.182644   1.500000    2.443133e-11                10
# 30         0.080772   1.500000    4.246241e-07                 9
# 31         0.166573   1.500000    3.335997e-02                 4
# 32         0.201393   0.100000    8.185434e-02                 6
# 33         1.986554   1.499933    5.492081e-01                 8
# 34         0.192760   0.486766    9.153614e-08                 4
# 35         0.444542   1.500000    7.014723e-10                 6
# 36         0.378998   1.500000    1.194964e-09                 9
# 37         0.177411   1.500000    7.332665e-10                10
# 38         0.212438   0.100000    1.299730e-02                 5
# 39         0.516255   1.500000    2.595989e-09                 7
# 40         0.313837   1.500000    2.767329e-11                10
# 41         0.294227   1.500000    3.155921e-11                 7
# 42         1.889276   1.500000    3.593730e-07                 9
# 43         0.147420   0.100000    1.430979e-01                 6
# 44         0.199578   1.500000    1.488079e-10                 9
# 45         0.358373   0.100000    1.067070e-01                 4
# 46         0.169179   0.100000    6.659855e-06                 6
# 47         0.050937   1.500000    2.077249e-07                 9
# 48         0.488319   0.100000    7.056331e-02                 6
# 49         0.144351   0.100002    4.063753e-01                 5
# 50         0.363566   0.100119    1.069315e+00                 7
# 51         2.029718   1.500000    6.498004e-01                 9
# 52         0.103373   1.500000    2.766342e-10                 5
#
#     n_active_flags                                       active_flags
# 0                5  m_near_bound; s0_near_bound; large_s0_uncertai...
# 1                4  s0_near_bound; large_s0_uncertainty; large_noi...
# 2                6  s0_near_bound; noise_near_bound; large_s0_unce...
# 3                5  s0_near_bound; large_s0_uncertainty; large_noi...
# 4                8  s0_near_bound; noise_near_bound; large_r0_unce...
# 5                9  s0_near_bound; noise_near_bound; large_r0_unce...
# 6                7  sig2_near_bound; s0_near_bound; large_s0_uncer...
# 7                6  s0_near_bound; noise_near_bound; large_s0_unce...
# 8               10  r0_near_bound; s0_near_bound; noise_near_bound...
# 9                8  s0_near_bound; noise_near_bound; large_r0_unce...
# 10               6  m_near_bound; s0_near_bound; large_s0_uncertai...
# 11               3  s0_near_bound; large_s0_uncertainty; systemati...
# 12               6  s0_near_bound; noise_near_bound; large_s0_unce...
# 13               4  s0_near_bound; large_s0_uncertainty; large_noi...
# 14               8  s0_near_bound; noise_near_bound; large_r0_unce...
# 15               6  s0_near_bound; noise_near_bound; large_s0_unce...
# 16               8  s0_near_bound; noise_near_bound; large_r0_unce...
# 17               9  s0_near_bound; noise_near_bound; large_r0_unce...
# 18               7  m_near_bound; s0_near_bound; noise_near_bound;...
# 19               5  s0_near_bound; large_s0_uncertainty; large_noi...
# 20               7  s0_near_bound; noise_near_bound; large_s0_unce...
# 21               8  s0_near_bound; noise_near_bound; large_r0_unce...
# 22               7  m_near_bound; s0_near_bound; noise_near_bound;...
# 23              10  r0_near_bound; s0_near_bound; large_r0_uncerta...
# 24               8  s0_near_bound; noise_near_bound; large_r0_unce...
# 25               7  s0_near_bound; noise_near_bound; large_s0_unce...
# 26               9  s0_near_bound; noise_near_bound; large_r0_unce...
# 27               7  s0_near_bound; noise_near_bound; large_s0_unce...
# 28               6  s0_near_bound; noise_near_bound; large_s0_unce...
# 29               6  s0_near_bound; noise_near_bound; large_s0_unce...
# 30               7  s0_near_bound; noise_near_bound; large_s0_unce...
# 31               6  s0_near_bound; noise_near_bound; large_s0_unce...
# 32               8  s0_near_bound; noise_near_bound; large_r0_unce...
# 33               9  r0_near_bound; s0_near_bound; large_r0_uncerta...
# 34               4  noise_near_bound; large_s0_uncertainty; large_...
# 35               6  s0_near_bound; noise_near_bound; large_s0_unce...
# 36               9  s0_near_bound; noise_near_bound; large_r0_unce...
# 37               6  s0_near_bound; noise_near_bound; large_s0_unce...
# 38               5  s0_near_bound; noise_near_bound; large_s0_unce...
# 39               8  s0_near_bound; noise_near_bound; large_r0_unce...
# 40               8  s0_near_bound; noise_near_bound; large_r0_unce...
# 41               9  m_near_bound; s0_near_bound; noise_near_bound;...
# 42              10  r0_near_bound; sig2_near_bound; s0_near_bound;...
# 43               4  m_near_bound; s0_near_bound; large_s0_uncertai...
# 44               9  s0_near_bound; noise_near_bound; large_r0_unce...
# 45               7  s0_near_bound; noise_near_bound; large_r0_unce...
# 46               8  s0_near_bound; noise_near_bound; large_r0_unce...
# 47               8  sig2_near_bound; s0_near_bound; noise_near_bou...
# 48               7  s0_near_bound; noise_near_bound; large_r0_unce...
# 49               4  s0_near_bound; large_s0_uncertainty; large_m_u...
# 50               8  sig2_near_bound; s0_near_bound; large_r0_uncer...
# 51              11  r0_near_bound; s0_near_bound; large_r0_uncerta...
# 52               7  s0_near_bound; noise_near_bound; large_s0_unce...

# %%
review_df_sorted = review_df.sort_values(
    by=["quality_score", "n_active_flags"],
    ascending=False,
).reset_index(drop=True)

review_df_sorted
# Out:
#                   name quality_class  quality_score    redchi  \
# 0    LVM-30Dor-6563_E8             D             19  0.831887
# 1    LVM-30Dor-6563_C1             D             16  0.777968
# 2   LVM-30Dor-6563_D11             D             16  0.996618
# 3    LVM-30Dor-6563_D3             D             15  0.876233
# 4   LVM-30Dor-6563_E14             D             14  0.503126
# 5    LVM-30Dor-6563_B5             D             14  0.765202
# 6    LVM-30Dor-6563_C6             D             14  0.933376
# 7    LVM-30Dor-6563_D6             D             14  0.785119
# 8   LVM-30Dor-6563_E10             D             14  0.864599
# 9   LVM-30Dor-6563_E16             D             14  0.795421
# 10  LVM-30Dor-6563_D14             D             13  0.770699
# 11   LVM-30Dor-6563_E7             D             13  0.882065
# 12   LVM-30Dor-6563_B4             D             12  0.531988
# 13  LVM-30Dor-6563_C10             D             12  0.893776
# 14   LVM-30Dor-6563_C3             D             12  0.809339
# 15   LVM-30Dor-6563_C5             D             12  0.758747
# 16   LVM-30Dor-6563_D1             D             12  0.933788
# 17  LVM-30Dor-6563_D12             D             12  0.905099
# 18   LVM-30Dor-6563_D2             D             12  0.817371
# 19   LVM-30Dor-6563_D9             D             12  0.883005
# 20   LVM-30Dor-6563_E1             D             12  0.901010
# 21   LVM-30Dor-6563_E3             D             12  0.995133
# 22   LVM-30Dor-6563_E4             D             12  0.772994
# 23   LVM-30Dor-6563_B6             D             11  0.932811
# 24   LVM-30Dor-6563_C7             D             11  0.960455
# 25   LVM-30Dor-6563_C9             D             11  0.855625
# 26  LVM-30Dor-6563_D10             D             11  0.862973
# 27  LVM-30Dor-6563_D13             D             11  0.997689
# 28  LVM-30Dor-6563_D15             D             11  0.839325
# 29  LVM-30Dor-6563_D18             D             11  0.880598
# 30   LVM-30Dor-6563_E9             D             11  0.552941
# 31  LVM-30Dor-6563_C11             D             11  0.972298
# 32   LVM-30Dor-6563_E2             D             10  0.692273
# 33   LVM-30Dor-6563_E5             D             10  0.651114
# 34   LVM-30Dor-6563_B2             D              9  0.678354
# 35   LVM-30Dor-6563_B7             D              9  0.548805
# 36  LVM-30Dor-6563_C13             D              9  0.973883
# 37   LVM-30Dor-6563_C4             D              9  0.710336
# 38  LVM-30Dor-6563_D16             D              9  0.990975
# 39  LVM-30Dor-6563_D17             D              9  0.914766
# 40  LVM-30Dor-6563_D19             D              9  0.508865
# 41   LVM-30Dor-6563_D5             D              9  0.892636
# 42   LVM-30Dor-6563_D7             D              9  0.760922
# 43    LVM-30Dor-6563_A             D              9  0.903346
# 44   LVM-30Dor-6563_B3             D              8  0.748781
# 45   LVM-30Dor-6563_C8             D              8  0.931987
# 46   LVM-30Dor-6563_D8             D              7  0.802210
# 47  LVM-30Dor-6563_E15             D              7  0.975474
# 48   LVM-30Dor-6563_E6             D              7  0.787047
# 49   LVM-30Dor-6563_B1             C              6  0.787893
# 50   LVM-30Dor-6563_C2             C              6  0.524491
# 51   LVM-30Dor-6563_D4             C              5  0.653719
# 52  LVM-30Dor-6563_C12             C              5  0.632089
#
#     r0_over_rfitmax  s0_arcsec  noise_fraction  max_residual_run  \
# 0          2.029718   1.500000    6.498004e-01                 9
# 1          2.023180   1.500000    2.826893e-02                10
# 2          2.039104   1.499997    3.059647e-01                10
# 3          1.986554   1.499933    5.492081e-01                 8
# 4          1.889276   1.500000    3.593730e-07                 9
# 5          0.246199   1.500000    2.562296e-08                 8
# 6          0.129331   1.500000    2.555293e-06                 6
# 7          0.378998   1.500000    1.194964e-09                 9
# 8          0.294227   1.500000    3.155921e-11                 7
# 9          0.199578   1.500000    1.488079e-10                 9
# 10         1.126035   1.499970    2.127761e-11                 9
# 11         0.363566   0.100119    1.069315e+00                 7
# 12         0.964978   1.500000    2.917766e-11                 8
# 13         0.556483   1.499997    2.651904e-11                10
# 14         0.401187   1.500000    2.812950e-11                 7
# 15         0.324539   1.500000    3.035995e-11                 5
# 16         0.569599   1.500000    2.464778e-11                 5
# 17         0.312974   1.500000    4.467640e-09                10
# 18         0.201393   0.100000    8.185434e-02                 6
# 19         0.516255   1.500000    2.595989e-09                 7
# 20         0.313837   1.500000    2.767329e-11                10
# 21         0.169179   0.100000    6.659855e-06                 6
# 22         0.050937   1.500000    2.077249e-07                 9
# 23         0.097035   1.500000    1.025388e-01                 5
# 24         0.180251   1.500000    5.321314e-07                 7
# 25         0.131532   1.500000    4.644991e-08                 7
# 26         0.095201   0.100000    3.303226e-02                 6
# 27         0.146270   1.500000    1.309746e-08                 8
# 28         0.084956   1.500000    8.169439e-08                 8
# 29         0.080772   1.500000    4.246241e-07                 9
# 30         0.103373   1.500000    2.766342e-10                 5
# 31         0.106408   1.500000    4.079140e-01                 6
# 32         0.358373   0.100000    1.067070e-01                 4
# 33         0.488319   0.100000    7.056331e-02                 6
# 34         0.161672   1.500000    7.703418e-02                 4
# 35         0.126835   1.500000    1.160369e-11                 6
# 36         0.240043   1.500000    1.873131e-06                 9
# 37         0.257709   1.500000    2.452141e-09                 6
# 38         0.183549   1.500000    2.049524e-11                 5
# 39         0.182644   1.500000    2.443133e-11                10
# 40         0.166573   1.500000    3.335997e-02                 4
# 41         0.444542   1.500000    7.014723e-10                 6
# 42         0.177411   1.500000    7.332665e-10                10
# 43         0.161363   0.100000    2.884545e-01                 8
# 44         0.180072   1.500000    1.307237e-01                 5
# 45         0.208444   1.500000    8.325938e-02                 8
# 46         0.212438   0.100000    1.299730e-02                 5
# 47         0.147420   0.100000    1.430979e-01                 6
# 48         0.144351   0.100002    4.063753e-01                 5
# 49         0.098646   0.100000    1.273463e-01                 4
# 50         0.187477   0.100003    1.825791e-01                 8
# 51         0.192760   0.486766    9.153614e-08                 4
# 52         0.177612   0.100000    2.581559e-01                 7
#
#     n_active_flags                                       active_flags
# 0               11  r0_near_bound; s0_near_bound; large_r0_uncerta...
# 1               10  r0_near_bound; s0_near_bound; noise_near_bound...
# 2               10  r0_near_bound; s0_near_bound; large_r0_uncerta...
# 3                9  r0_near_bound; s0_near_bound; large_r0_uncerta...
# 4               10  r0_near_bound; sig2_near_bound; s0_near_bound;...
# 5                9  s0_near_bound; noise_near_bound; large_r0_unce...
# 6                9  s0_near_bound; noise_near_bound; large_r0_unce...
# 7                9  s0_near_bound; noise_near_bound; large_r0_unce...
# 8                9  m_near_bound; s0_near_bound; noise_near_bound;...
# 9                9  s0_near_bound; noise_near_bound; large_r0_unce...
# 10               9  s0_near_bound; noise_near_bound; large_r0_unce...
# 11               8  sig2_near_bound; s0_near_bound; large_r0_uncer...
# 12               8  s0_near_bound; noise_near_bound; large_r0_unce...
# 13               8  s0_near_bound; noise_near_bound; large_r0_unce...
# 14               8  s0_near_bound; noise_near_bound; large_r0_unce...
# 15               8  s0_near_bound; noise_near_bound; large_r0_unce...
# 16               8  s0_near_bound; noise_near_bound; large_r0_unce...
# 17               8  s0_near_bound; noise_near_bound; large_r0_unce...
# 18               8  s0_near_bound; noise_near_bound; large_r0_unce...
# 19               8  s0_near_bound; noise_near_bound; large_r0_unce...
# 20               8  s0_near_bound; noise_near_bound; large_r0_unce...
# 21               8  s0_near_bound; noise_near_bound; large_r0_unce...
# 22               8  sig2_near_bound; s0_near_bound; noise_near_bou...
# 23               7  sig2_near_bound; s0_near_bound; large_s0_uncer...
# 24               7  m_near_bound; s0_near_bound; noise_near_bound;...
# 25               7  s0_near_bound; noise_near_bound; large_s0_unce...
# 26               7  m_near_bound; s0_near_bound; noise_near_bound;...
# 27               7  s0_near_bound; noise_near_bound; large_s0_unce...
# 28               7  s0_near_bound; noise_near_bound; large_s0_unce...
# 29               7  s0_near_bound; noise_near_bound; large_s0_unce...
# 30               7  s0_near_bound; noise_near_bound; large_s0_unce...
# 31               6  m_near_bound; s0_near_bound; large_s0_uncertai...
# 32               7  s0_near_bound; noise_near_bound; large_r0_unce...
# 33               7  s0_near_bound; noise_near_bound; large_r0_unce...
# 34               6  s0_near_bound; noise_near_bound; large_s0_unce...
# 35               6  s0_near_bound; noise_near_bound; large_s0_unce...
# 36               6  s0_near_bound; noise_near_bound; large_s0_unce...
# 37               6  s0_near_bound; noise_near_bound; large_s0_unce...
# 38               6  s0_near_bound; noise_near_bound; large_s0_unce...
# 39               6  s0_near_bound; noise_near_bound; large_s0_unce...
# 40               6  s0_near_bound; noise_near_bound; large_s0_unce...
# 41               6  s0_near_bound; noise_near_bound; large_s0_unce...
# 42               6  s0_near_bound; noise_near_bound; large_s0_unce...
# 43               5  m_near_bound; s0_near_bound; large_s0_uncertai...
# 44               5  s0_near_bound; large_s0_uncertainty; large_noi...
# 45               5  s0_near_bound; large_s0_uncertainty; large_noi...
# 46               5  s0_near_bound; noise_near_bound; large_s0_unce...
# 47               4  m_near_bound; s0_near_bound; large_s0_uncertai...
# 48               4  s0_near_bound; large_s0_uncertainty; large_m_u...
# 49               4  s0_near_bound; large_s0_uncertainty; large_noi...
# 50               4  s0_near_bound; large_s0_uncertainty; large_noi...
# 51               4  noise_near_bound; large_s0_uncertainty; large_...
# 52               3  s0_near_bound; large_s0_uncertainty; systemati...

# %%
review_csv_path = Path("fits_ready") / "fit_diagnostics_short.csv"

review_df_sorted.to_csv(review_csv_path, index=False)

review_csv_path
# Out:
# PosixPath('fits_ready/fit_diagnostics_short.csv')

# %% [markdown]
# # Export

# %%
#save_modelresult(result, "results_fit/" + name + "result_ideal.sav")
#save_modelresult(result_emcee, "results_fit/" + name + "result_emcee_ideal.sav")

# %%
df = pd.DataFrame(results_2sig)

# Flatten MultiIndex columns
if isinstance(df.columns, pd.MultiIndex):
    df.columns = ["_".join(map(str, col)).strip() for col in df.columns.to_flat_index()]
else:
    df.columns = [str(c) for c in df.columns]

df = df.reset_index(drop=True)

t = Table.from_pandas(df)
new_hdu = fits.BinTableHDU(t, name="PARAMETERS")

with fits.open(fits_path, memmap=False) as hdul:
    hdus = [h.copy() for h in hdul]

# FITS EXTNAMEs are effectively case-insensitive; astropy reports them uppercase.
target = "PARAMETERS"
idxs = [i for i, h in enumerate(hdus) if h.name.upper() == target]

if idxs:
    i0 = idxs[0]
    # Optional: preserve existing header cards (metadata) from old PARAMETERS
    old_hdr = hdus[i0].header.copy()
    hdus[i0] = new_hdu
    # Keep old metadata, then ensure EXTNAME stays correct
    hdus[i0].header.update(old_hdr)
    hdus[i0].name = target
    # Remove any additional duplicates if they exist
    for j in reversed(idxs[1:]):
        del hdus[j]
else:
    # If it doesn't exist, add it
    hdus.append(new_hdu)

fits.HDUList(hdus).writeto(fits_path, overwrite=True)

# %%
# Test import

from astropy.table import Table
t = Table.read(fits_path, hdu="PARAMETERS")
df_loaded = t.to_pandas()
df_loaded
# Out:
#          sig2          r0         m        s0         noise
# 0  295.074741   16.232169  0.842502  0.363610  1.571942e-08
# 1  533.519771  129.416883  0.343386 -0.006147  5.695061e+01
# 2   71.898953    3.524829  0.222115  0.328723 -4.415657e-01

# %%
with fits.open(fits_path) as hdul:
    hdul.info()
# Out:
# Filename: fits_ready/LVM-30Dor-6563_E16.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      29   ()
#   1  LVM-30DOR-6563_E16    1 BinTableHDU     23   1159R x 7C   [D, D, D, D, D, D, D]
#   2  TABLE         1 BinTableHDU     19   33R x 5C   [D, D, D, D, D]
#   3  PARAMETERS    1 BinTableHDU     19   3R x 5C   [D, D, D, D, D]

# %%
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 96.53587198257446 seconds ---
