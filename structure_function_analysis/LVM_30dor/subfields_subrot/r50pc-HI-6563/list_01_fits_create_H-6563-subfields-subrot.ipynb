# %%
import json
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from astropy.io import fits
from astropy.io import fits
from astropy.table import Table
import json
import sys

# %%
sys.path.append(str(Path().resolve() / 'py_modules')) 

import list_maps_plots
from spectral_lines import LINES, print_available_lines

# %% [raw]
# # Original Dr. Will Jupyter notebook
#
# https://github.com/will-henney/lvm-turbulence/blob/main/lvm-tarantula-explore-122.ipynb

# %% [markdown]
# #  Data

# %%
cfg = LINES["Halpha"]

plot_label_line      = cfg.plot_label
rest_wavelength = cfg.rest_wavelength
wavelength_id    = cfg.wavelength_id
element         = cfg.element
ion             = cfg.ion
transition_id   = cfg.transition_id

# %%
print(plot_label_line)
print(rest_wavelength)
print(wavelength_id)
print(element)
print(ion)
print(transition_id)
# Out:
# H$\alpha$
# 6562.8
# 6563
# H
# H_I
# H_I-6563

# %%
#line        = r'H$\alpha$'
#lambda_rest = 6562.8
#line_id     = 'H'
#line_id2   = "6563"

# %%
# Data from observations
bins        = 0

region     = 'NGC 2070'
name_reg   = '30 Doradus'
reg_id     = '30Dor'
inst       = 'LVM'
inst_id    = 'LVM'
type_obj   = 'H II region'

pix        = 0   # Instrument resolution [arcsec/pix]
dist       = 50000 # Distance [parsecs]
s0_        = 0.9    # proposed seeing

pc         = dist*(2*np.pi) / (360 * 60 * 60)
s0         = (s0_*pc)

#Since we are working with scatter adata there is no binning that can be applied
name_file    =  inst_id + '-' + reg_id + '-' + str(wavelength_id)
name_id      =  inst_id + '-' + reg_id + '-' + element + "-X"
print(name_file)
print(name_id)
# Out:
# LVM-30Dor-6563
# LVM-30Dor-H-X

# %%
_data = json.load(open('observations/'+ name_file + '-l.json'))
_line = pd.DataFrame(_data['data'])
_line.columns = ['RAdeg', 'DEdeg', 'V_mean','log_F','sigma']
#_line = _line[0:3500]

# %%
from astropy.coordinates import SkyCoord
import astropy.units as u
from astropy.wcs import WCS

c0 = SkyCoord.from_name("Tarantula")
c0
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (84.675, -69.1)>

# %%
fov_deg = 1.0  # Total field of view in degrees (width and height)
pix_scale = 1 / 3600
npix = int(fov_deg / pix_scale)

# Create WCS for TAN projection centered at 'center'
wcs = WCS(naxis=2)
wcs.wcs.ctype = ["RA---TAN", "DEC--TAN"]
wcs.wcs.crval = [c0.ra.deg, c0.dec.deg]
wcs.wcs.crpix = [npix, npix]  # center of your "image"
wcs.wcs.cdelt = [-pix_scale, pix_scale]  # field size / pixel count

# %%
ra0  = c0.ra.deg
dec0 = c0.dec.deg
#ra0 = _line["RAdeg"].median()
#dec0 = _line["DEdeg"].median()
print(ra0, dec0)
# Out:
# 84.675 -69.1

# %%
centro = SkyCoord(ra=ra0*u.deg, dec=dec0*u.deg, frame='icrs')

coords = SkyCoord(
    ra=_line["RAdeg"].values * u.deg,
    dec=_line["DEdeg"].values * u.deg,
    frame='icrs'
)

radio = 3305 * u.arcsec   
sep = coords.separation(centro)

line_rad = _line[sep <= radio]

# %%
fig, ax = plt.subplots()
plt.hist(line_rad["V_mean"] , bins=200)
ax.set_yscale("log")

# %%
mask = (line_rad["V_mean"] > 220) & (line_rad["V_mean"]<330) & (line_rad["log_F"] > 100)  & (line_rad["sigma"] < 1.5) 
line_mask = line_rad[mask]

# %%
fig, ax = plt.subplots()
plt.hist(line_rad["V_mean"][mask] , bins=200)
ax.set_yscale("log")

# %% [markdown]
# Plot flux and radial velocity

# %%
fig, ax = list_maps_plots.plot_panels_log_title(line_mask,
                                                s=1.0,
                                                figsize=(10, 4.25),
                                                titles=("Flux", "V_mean - <V_mean>"),
                                                figure_title=plot_label_line)
plt.show()
#plt.savefig('Imgs/' + name_file + '.jpg', bbox_inches='tight')

# %% [markdown]
# Plot flux and radial velocity in WCS

# %%
fig, ax = list_maps_plots.plot_panels_wcs(line_mask,
                                          wcs,
                                          s=1.0,
                                          figsize=(10, 4.25),
                                          invert_ra=False, 
                                          titles=("Flux", "V_mean - <V_mean>"),
                                          figure_title=plot_label_line)
plt.show()

#plt.savefig('Imgs/' + name_file + '.jpg', bbox_inches='tight')

# %% [markdown]
# # Rotation substraction

# %%
import lmc_model

# %%
df =  line_mask
c = SkyCoord(ra=df["RAdeg"].to_numpy() * u.deg, dec=df["DEdeg"].to_numpy() * u.deg)
c
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     [(84.65      , -69.33053993), (84.67528433, -69.325388  ),
#      (84.70055662, -69.32023239), ..., (85.91216393, -68.76577774),
#      (85.88921811, -68.77182839), (85.86617408, -68.77787917)]>

# %%
vmod = lmc_model.vmodel_lmc(c)

# %%
df.insert(
    loc=5,
    column="v_mod",
    value=vmod.value,
)

# %%
col = df.pop('V_mean')
df.insert(4, 'v_', col)

# %%
df.insert(
    loc=2,
    column="V_mean",
    value= df.v_-df.v_mod,
)

# %%
df.describe()
# Out:
#                RAdeg          DEdeg         V_mean         log_F  \
# count  222020.000000  222020.000000  222020.000000  2.220200e+05
# mean       84.743434     -69.080949       0.165502  9.276494e+03
# std         1.275231       0.427281      11.138730  3.407694e+04
# min        82.101852     -70.012179     -52.172066  1.059342e+02
# 25%        83.781267     -69.404202      -6.514036  1.006186e+03
# 50%        84.708755     -69.094773       0.487416  2.636627e+03
# 75%        85.798398     -68.761121       7.111555  6.775874e+03
# max        87.248872     -68.182110      62.430357  1.710726e+06
#
#                sigma             v_          v_mod
# count  222020.000000  222020.000000  222020.000000
# mean        0.841440     270.401268     270.235766
# std         0.129093      12.448334       3.247174
# min         0.237300     220.023700     263.693627
# 25%         0.752300     262.501525     267.669202
# 50%         0.811500     270.608900     270.289599
# 75%         0.893100     278.533000     272.806889
# max         1.499700     329.997900     276.681591

# %%
line_mask = df

# %%
fig, ax = list_maps_plots.plot_panels_wcs(line_mask,
                                          wcs,
                                          s=1.0,
                                          figsize=(10, 4.25),
                                          invert_ra=False, 
                                          titles=("Flux", "V_subrot"),
                                          figure_title=plot_label_line)
plt.show()

#plt.savefig('Imgs/' + name_file + '.jpg', bbox_inches='tight')

# %% [markdown]
# # Creating and plotting subfields

# %% [markdown]
# Plotting subfields

# %% [markdown]
# Automatic

# %%
from circle_tools import make_circles_auto

# %% [markdown]
# Creatings subfields data

# %%
field_radius = 3305 * u.arcsec
radius = 0.5*413 * u.arcsec

# %%
circles = make_circles_auto(
    centro,
    radius,
    field_radius,
)

# %% [markdown]
# Plotting subfields

# %%
import matplotlib.pyplot as plt
from astropy.visualization.wcsaxes.patches import SphericalCircle

v1 = line_mask["V_mean"] - line_mask["V_mean"].mean()

fig = plt.figure(figsize=(7, 6), constrained_layout=True)
ax = fig.add_subplot(1, 1, 1, projection=wcs)

sc = ax.scatter(
    line_mask["RAdeg"],
    line_mask["DEdeg"],
    s=1.0,
    c=v1,
    cmap="RdBu_r",
    transform=ax.get_transform("world")
)

for item in circles:
    circle = SphericalCircle(
        (item["center"].ra, item["center"].dec),
        item["radius_arcsec"] * u.arcsec,
        edgecolor="black",
        facecolor="none",
        linewidth=1,
        transform=ax.get_transform("world")
    )
    ax.add_patch(circle)

    ax.text(
        item["ra_deg"],
        item["dec_deg"],
        item["label"],
        transform=ax.get_transform("world"),
        ha="center",
        va="center",
        fontsize=7,
        color="black"
    )

ax.set_xlabel("RA")
ax.set_ylabel("Dec")
ax.set_title(plot_label_line)

cbar = fig.colorbar(sc, ax=ax)
cbar.set_label("V_mean")

# %%
circles[4]
# Out:
# {'label': 'B4',
#  'ring': 'B',
#  'ring_index': 1,
#  'angle_deg': 154.28571428571428,
#  'center': <SkyCoord (ICRS): (ra, dec) in deg
#      (84.81519348, -69.20330425)>,
#  'ra_deg': 84.8151934811899,
#  'dec_deg': -69.20330424731559,
#  'radius_arcsec': 206.5}

# %% [markdown]
# # Data for each circle

# %%
coords_all = SkyCoord(
    ra=line_mask["RAdeg"].values * u.deg,
    dec=line_mask["DEdeg"].values * u.deg,
    frame="icrs"
)

# %%
regions_data = {}

for circle in circles:
    radius_u = circle["radius_arcsec"] * u.arcsec
    sep = coords_all.separation(circle["center"])
    
    df_circle = line_mask.loc[sep <= radius_u].copy()
    
    regions_data[circle["label"]] = df_circle

# %% [markdown]
# # Export subfields

# %%
for circle in circles:
    label = circle["label"]
    ring = circle["ring"]
    angle_deg = circle["angle_deg"]
    circle_center = circle["center"]
    circle_radius = circle["radius_arcsec"] * u.arcsec

    # mask data inside this circle
    sep = coords_all.separation(circle_center)
    df_circle = line_mask.loc[sep <= circle_radius].copy()

    # skip empty regions
    if df_circle.empty:
        print(f"Skipping {label}: no data points inside circle.")
        continue

    # compute region-specific parameters
    N = np.sqrt(
        (df_circle.RAdeg.max() - df_circle.RAdeg.min()) *
        (df_circle.DEdeg.max() - df_circle.DEdeg.min())
    ) * pc * 3600

    sig = df_circle["V_mean"].std()

    # define output name
    circle_name_file = f"{name_file}_{label}"
    circle_name_id = f"{name_id}_{label}"

    # table HDU
    t = Table.from_pandas(df_circle.reset_index(drop=True))
    table_hdu = fits.BinTableHDU(t, name=circle_name_file)

    # primary HDU
    primary = fits.PrimaryHDU()
    hdr = primary.header

    hdr["FILE"]      = (circle_name_file, "Fits file name")
    hdr["NAME_ID"]   = (circle_name_id, "pipeline identifier")
    hdr["REG"]       = (region, "Region catalog name")
    hdr["NAME_REG"]  = (name_reg, "Region name")
    hdr["REG_ID"]    = (reg_id, "Region identifier")
    hdr["TYPE_OBJ"]  = (type_obj, "Type object")
    hdr["DIST"]      = (dist, "Distance in parsecs")
    hdr["INSTR"]     = (inst, "Instrument")
    hdr["LINE"]      = (plot_label_line, "Emission line name")
    hdr["LINE_ID"]   = (element, "Emission line identifier")
    hdr["L_REST"]    = (rest_wavelength, "Emission line rest wavelength")
    hdr["SIG"]       = (sig, "Standard deviation vel map")
    hdr["SIG2"]      = (sig**2, "Vel variance map")
    hdr["S0"]        = (s0, "Atmospheric seeing")
    hdr["BOX_SIZE"]  = (N, "Observational box_size")
    hdr["PC"]        = (pc, "parsec conversion")
    hdr["PIX"]       = (pix, "Instrument pixel scale")
    hdr["BINSIZE"]   = (bins, "Spatial binning factor")

    # circle metadata
    hdr["CIRC_ID"]   = (label, "Circle identifier")
    hdr["CIRCRING"]  = (ring, "Circle ring")
    hdr["CIRC_RA"]   = (circle_center.ra.deg, "Circle center RA deg")
    hdr["CIRC_DEC"]  = (circle_center.dec.deg, "Circle center Dec deg")
    hdr["CIRC_RAD"]  = (circle_radius.to(u.arcsec).value, "Circle radius arcsec")
    hdr["AUTHOR"]    = ("J. Garcia-Vazquez", "File creator")

    if angle_deg is not None:
        hdr["CIRC_PA"] = (angle_deg, "Circle position angle deg")

    hdul = fits.HDUList([primary, table_hdu])
    hdul.writeto(f"fits_ready/{circle_name_file}.fits", overwrite=True)

    print(f"Saved: fits_ready/{circle_name_file}.fits  ({len(df_circle)} rows)")
# Out:
# Saved: fits_ready/LVM-30Dor-6563_A.fits  (1449 rows)
# Saved: fits_ready/LVM-30Dor-6563_B1.fits  (1407 rows)
# Saved: fits_ready/LVM-30Dor-6563_B2.fits  (1332 rows)
# Saved: fits_ready/LVM-30Dor-6563_B3.fits  (1410 rows)
# Saved: fits_ready/LVM-30Dor-6563_B4.fits  (1225 rows)
# Saved: fits_ready/LVM-30Dor-6563_B5.fits  (1183 rows)
# Saved: fits_ready/LVM-30Dor-6563_B6.fits  (1305 rows)
# Saved: fits_ready/LVM-30Dor-6563_B7.fits  (1219 rows)
# Saved: fits_ready/LVM-30Dor-6563_C1.fits  (1404 rows)
# Saved: fits_ready/LVM-30Dor-6563_C2.fits  (1199 rows)
# Saved: fits_ready/LVM-30Dor-6563_C3.fits  (1247 rows)
# Saved: fits_ready/LVM-30Dor-6563_C4.fits  (1138 rows)
# Saved: fits_ready/LVM-30Dor-6563_C5.fits  (1355 rows)
# Saved: fits_ready/LVM-30Dor-6563_C6.fits  (1054 rows)
# Saved: fits_ready/LVM-30Dor-6563_C7.fits  (1084 rows)
# Saved: fits_ready/LVM-30Dor-6563_C8.fits  (1071 rows)
# Saved: fits_ready/LVM-30Dor-6563_C9.fits  (1243 rows)
# Saved: fits_ready/LVM-30Dor-6563_C10.fits  (1307 rows)
# Saved: fits_ready/LVM-30Dor-6563_C11.fits  (1088 rows)
# Saved: fits_ready/LVM-30Dor-6563_C12.fits  (1144 rows)
# Saved: fits_ready/LVM-30Dor-6563_C13.fits  (1107 rows)
# Saved: fits_ready/LVM-30Dor-6563_D1.fits  (897 rows)
# Saved: fits_ready/LVM-30Dor-6563_D2.fits  (1171 rows)
# Saved: fits_ready/LVM-30Dor-6563_D3.fits  (1113 rows)
# Saved: fits_ready/LVM-30Dor-6563_D4.fits  (1101 rows)
# Saved: fits_ready/LVM-30Dor-6563_D5.fits  (1112 rows)
# Saved: fits_ready/LVM-30Dor-6563_D6.fits  (1160 rows)
# Saved: fits_ready/LVM-30Dor-6563_D7.fits  (1002 rows)
# Saved: fits_ready/LVM-30Dor-6563_D8.fits  (1136 rows)
# Saved: fits_ready/LVM-30Dor-6563_D9.fits  (978 rows)
# Saved: fits_ready/LVM-30Dor-6563_D10.fits  (958 rows)
# Saved: fits_ready/LVM-30Dor-6563_D11.fits  (1078 rows)
# Saved: fits_ready/LVM-30Dor-6563_D12.fits  (1183 rows)
# Saved: fits_ready/LVM-30Dor-6563_D13.fits  (992 rows)
# Saved: fits_ready/LVM-30Dor-6563_D14.fits  (994 rows)
# Saved: fits_ready/LVM-30Dor-6563_D15.fits  (1180 rows)
# Saved: fits_ready/LVM-30Dor-6563_D16.fits  (963 rows)
# Saved: fits_ready/LVM-30Dor-6563_D17.fits  (986 rows)
# Saved: fits_ready/LVM-30Dor-6563_D18.fits  (1003 rows)
# Saved: fits_ready/LVM-30Dor-6563_D19.fits  (1096 rows)
# Saved: fits_ready/LVM-30Dor-6563_E1.fits  (900 rows)
# Saved: fits_ready/LVM-30Dor-6563_E2.fits  (876 rows)
# Saved: fits_ready/LVM-30Dor-6563_E3.fits  (1268 rows)
# Saved: fits_ready/LVM-30Dor-6563_E4.fits  (1228 rows)
# Saved: fits_ready/LVM-30Dor-6563_E5.fits  (1171 rows)
# Saved: fits_ready/LVM-30Dor-6563_E6.fits  (1220 rows)
# Saved: fits_ready/LVM-30Dor-6563_E7.fits  (1177 rows)
# Saved: fits_ready/LVM-30Dor-6563_E8.fits  (999 rows)
# Saved: fits_ready/LVM-30Dor-6563_E9.fits  (979 rows)
# Saved: fits_ready/LVM-30Dor-6563_E10.fits  (984 rows)
# Saved: fits_ready/LVM-30Dor-6563_E11.fits  (469 rows)
# Saved: fits_ready/LVM-30Dor-6563_E12.fits  (97 rows)
# Saved: fits_ready/LVM-30Dor-6563_E13.fits  (427 rows)
# Saved: fits_ready/LVM-30Dor-6563_E14.fits  (1144 rows)
# Saved: fits_ready/LVM-30Dor-6563_E15.fits  (1005 rows)
# Saved: fits_ready/LVM-30Dor-6563_E16.fits  (1159 rows)
# Saved: fits_ready/LVM-30Dor-6563_E17.fits  (958 rows)
# Saved: fits_ready/LVM-30Dor-6563_E18.fits  (1001 rows)
# Saved: fits_ready/LVM-30Dor-6563_E19.fits  (989 rows)
# Saved: fits_ready/LVM-30Dor-6563_E20.fits  (890 rows)
# Saved: fits_ready/LVM-30Dor-6563_E21.fits  (457 rows)
# Saved: fits_ready/LVM-30Dor-6563_E22.fits  (703 rows)
# Saved: fits_ready/LVM-30Dor-6563_E23.fits  (803 rows)
# Saved: fits_ready/LVM-30Dor-6563_E24.fits  (617 rows)
# Saved: fits_ready/LVM-30Dor-6563_E25.fits  (841 rows)
# Saved: fits_ready/LVM-30Dor-6563_E26.fits  (877 rows)
# Saved: fits_ready/LVM-30Dor-6563_F1.fits  (887 rows)
# Saved: fits_ready/LVM-30Dor-6563_F2.fits  (879 rows)
# Saved: fits_ready/LVM-30Dor-6563_F3.fits  (1093 rows)
# Saved: fits_ready/LVM-30Dor-6563_F4.fits  (976 rows)
# Saved: fits_ready/LVM-30Dor-6563_F5.fits  (940 rows)
# Saved: fits_ready/LVM-30Dor-6563_F6.fits  (1149 rows)
# Saved: fits_ready/LVM-30Dor-6563_F7.fits  (988 rows)
# Saved: fits_ready/LVM-30Dor-6563_F8.fits  (989 rows)
# Saved: fits_ready/LVM-30Dor-6563_F9.fits  (1105 rows)
# Saved: fits_ready/LVM-30Dor-6563_F10.fits  (961 rows)
# Saved: fits_ready/LVM-30Dor-6563_F11.fits  (1011 rows)
# Saved: fits_ready/LVM-30Dor-6563_F12.fits  (943 rows)
# Saved: fits_ready/LVM-30Dor-6563_F13.fits  (286 rows)
# Skipping F14: no data points inside circle.
# Skipping F15: no data points inside circle.
# Saved: fits_ready/LVM-30Dor-6563_F16.fits  (218 rows)
# Saved: fits_ready/LVM-30Dor-6563_F17.fits  (990 rows)
# Saved: fits_ready/LVM-30Dor-6563_F18.fits  (1002 rows)
# Saved: fits_ready/LVM-30Dor-6563_F19.fits  (983 rows)
# Saved: fits_ready/LVM-30Dor-6563_F20.fits  (1181 rows)
# Saved: fits_ready/LVM-30Dor-6563_F21.fits  (1060 rows)
# Saved: fits_ready/LVM-30Dor-6563_F22.fits  (972 rows)
# Saved: fits_ready/LVM-30Dor-6563_F23.fits  (1033 rows)
# Saved: fits_ready/LVM-30Dor-6563_F24.fits  (839 rows)
# Saved: fits_ready/LVM-30Dor-6563_F25.fits  (440 rows)
# Saved: fits_ready/LVM-30Dor-6563_F26.fits  (451 rows)
# Saved: fits_ready/LVM-30Dor-6563_F27.fits  (445 rows)
# Saved: fits_ready/LVM-30Dor-6563_F28.fits  (387 rows)
# Saved: fits_ready/LVM-30Dor-6563_F29.fits  (338 rows)
# Saved: fits_ready/LVM-30Dor-6563_F30.fits  (332 rows)
# Saved: fits_ready/LVM-30Dor-6563_F31.fits  (758 rows)
# Saved: fits_ready/LVM-30Dor-6563_F32.fits  (875 rows)
# Saved: fits_ready/LVM-30Dor-6563_G1.fits  (949 rows)
# Saved: fits_ready/LVM-30Dor-6563_G2.fits  (1056 rows)
# Saved: fits_ready/LVM-30Dor-6563_G3.fits  (1138 rows)
# Saved: fits_ready/LVM-30Dor-6563_G4.fits  (948 rows)
# Saved: fits_ready/LVM-30Dor-6563_G5.fits  (966 rows)
# Saved: fits_ready/LVM-30Dor-6563_G6.fits  (997 rows)
# Saved: fits_ready/LVM-30Dor-6563_G7.fits  (1121 rows)
# Saved: fits_ready/LVM-30Dor-6563_G8.fits  (1003 rows)
# Saved: fits_ready/LVM-30Dor-6563_G9.fits  (999 rows)
# Saved: fits_ready/LVM-30Dor-6563_G10.fits  (898 rows)
# Saved: fits_ready/LVM-30Dor-6563_G11.fits  (1217 rows)
# Saved: fits_ready/LVM-30Dor-6563_G12.fits  (1152 rows)
# Saved: fits_ready/LVM-30Dor-6563_G13.fits  (1145 rows)
# Saved: fits_ready/LVM-30Dor-6563_G14.fits  (1134 rows)
# Saved: fits_ready/LVM-30Dor-6563_G15.fits  (749 rows)
# Skipping G16: no data points inside circle.
# Skipping G17: no data points inside circle.
# Skipping G18: no data points inside circle.
# Saved: fits_ready/LVM-30Dor-6563_G19.fits  (224 rows)
# Saved: fits_ready/LVM-30Dor-6563_G20.fits  (982 rows)
# Saved: fits_ready/LVM-30Dor-6563_G21.fits  (1005 rows)
# Saved: fits_ready/LVM-30Dor-6563_G22.fits  (993 rows)
# Saved: fits_ready/LVM-30Dor-6563_G23.fits  (1138 rows)
# Saved: fits_ready/LVM-30Dor-6563_G24.fits  (1000 rows)
# Saved: fits_ready/LVM-30Dor-6563_G25.fits  (1086 rows)
# Saved: fits_ready/LVM-30Dor-6563_G26.fits  (1189 rows)
# Saved: fits_ready/LVM-30Dor-6563_G27.fits  (1052 rows)
# Saved: fits_ready/LVM-30Dor-6563_G28.fits  (995 rows)
# Saved: fits_ready/LVM-30Dor-6563_G29.fits  (603 rows)
# Saved: fits_ready/LVM-30Dor-6563_G30.fits  (446 rows)
# Saved: fits_ready/LVM-30Dor-6563_G31.fits  (432 rows)
# Saved: fits_ready/LVM-30Dor-6563_G32.fits  (477 rows)
# Saved: fits_ready/LVM-30Dor-6563_G33.fits  (377 rows)
# Saved: fits_ready/LVM-30Dor-6563_G34.fits  (327 rows)
# Saved: fits_ready/LVM-30Dor-6563_G35.fits  (335 rows)
# Saved: fits_ready/LVM-30Dor-6563_G36.fits  (353 rows)
# Saved: fits_ready/LVM-30Dor-6563_G37.fits  (816 rows)
# Saved: fits_ready/LVM-30Dor-6563_G38.fits  (927 rows)
# Saved: fits_ready/LVM-30Dor-6563_H1.fits  (1080 rows)
# Saved: fits_ready/LVM-30Dor-6563_H2.fits  (988 rows)
# Saved: fits_ready/LVM-30Dor-6563_H3.fits  (943 rows)
# Saved: fits_ready/LVM-30Dor-6563_H4.fits  (1106 rows)
# Saved: fits_ready/LVM-30Dor-6563_H5.fits  (991 rows)
# Saved: fits_ready/LVM-30Dor-6563_H6.fits  (975 rows)
# Saved: fits_ready/LVM-30Dor-6563_H7.fits  (689 rows)
# Saved: fits_ready/LVM-30Dor-6563_H8.fits  (550 rows)
# Saved: fits_ready/LVM-30Dor-6563_H9.fits  (983 rows)
# Saved: fits_ready/LVM-30Dor-6563_H10.fits  (993 rows)
# Saved: fits_ready/LVM-30Dor-6563_H11.fits  (1072 rows)
# Saved: fits_ready/LVM-30Dor-6563_H12.fits  (970 rows)
# Saved: fits_ready/LVM-30Dor-6563_H13.fits  (992 rows)
# Saved: fits_ready/LVM-30Dor-6563_H14.fits  (980 rows)
# Saved: fits_ready/LVM-30Dor-6563_H15.fits  (1141 rows)
# Saved: fits_ready/LVM-30Dor-6563_H16.fits  (999 rows)
# Saved: fits_ready/LVM-30Dor-6563_H17.fits  (984 rows)
# Saved: fits_ready/LVM-30Dor-6563_H18.fits  (826 rows)
# Saved: fits_ready/LVM-30Dor-6563_H19.fits  (259 rows)
# Saved: fits_ready/LVM-30Dor-6563_H20.fits  (160 rows)
# Skipping H21: no data points inside circle.
# Skipping H22: no data points inside circle.
# Saved: fits_ready/LVM-30Dor-6563_H23.fits  (158 rows)
# Saved: fits_ready/LVM-30Dor-6563_H24.fits  (962 rows)
# Saved: fits_ready/LVM-30Dor-6563_H25.fits  (1093 rows)
# Saved: fits_ready/LVM-30Dor-6563_H26.fits  (1209 rows)
# Saved: fits_ready/LVM-30Dor-6563_H27.fits  (993 rows)
# Saved: fits_ready/LVM-30Dor-6563_H28.fits  (1001 rows)
# Saved: fits_ready/LVM-30Dor-6563_H29.fits  (990 rows)
# Saved: fits_ready/LVM-30Dor-6563_H30.fits  (1088 rows)
# Saved: fits_ready/LVM-30Dor-6563_H31.fits  (971 rows)
# Saved: fits_ready/LVM-30Dor-6563_H32.fits  (726 rows)
# Saved: fits_ready/LVM-30Dor-6563_H33.fits  (800 rows)
# Saved: fits_ready/LVM-30Dor-6563_H34.fits  (636 rows)
# Saved: fits_ready/LVM-30Dor-6563_H35.fits  (541 rows)
# Saved: fits_ready/LVM-30Dor-6563_H36.fits  (675 rows)
# Saved: fits_ready/LVM-30Dor-6563_H37.fits  (1028 rows)
# Saved: fits_ready/LVM-30Dor-6563_H38.fits  (964 rows)
# Saved: fits_ready/LVM-30Dor-6563_H39.fits  (476 rows)
# Saved: fits_ready/LVM-30Dor-6563_H40.fits  (318 rows)
# Saved: fits_ready/LVM-30Dor-6563_H41.fits  (428 rows)
# Saved: fits_ready/LVM-30Dor-6563_H42.fits  (659 rows)
# Saved: fits_ready/LVM-30Dor-6563_H43.fits  (658 rows)
# Saved: fits_ready/LVM-30Dor-6563_H44.fits  (654 rows)

# %%
import pandas as pd

circles_df = pd.DataFrame([
    {
        "label": c["label"],
        "ring": c["ring"],
        "angle_deg": c["angle_deg"],
        "ra_deg": c["ra_deg"],
        "dec_deg": c["dec_deg"],
        "radius_arcsec": c["radius_arcsec"],
    }
    for c in circles
])

circles_df.to_csv("fits_ready/circle_catalog.csv", index=False)

# %%
export_names = [f"{name_file}_{circle['label']}" for circle in circles]

with open("fits_ready/filelist_circles.txt", "w", encoding="utf-8") as f:
    f.write("\n".join(export_names) + "\n")
