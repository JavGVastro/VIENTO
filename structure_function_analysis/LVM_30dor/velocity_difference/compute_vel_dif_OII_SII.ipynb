# %%
import json
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from astropy.io import fits
from astropy.io import fits
from astropy.table import Table
import json
import sys

# %%
sys.path.append(str(Path().resolve() / 'py_modules')) 

import list_maps_plots
from spectral_lines import LINES, print_available_lines

# %% [raw]
# # Original Dr. Will Jupyter notebook
#
# https://github.com/will-henney/lvm-turbulence/blob/main/lvm-tarantula-explore-122.ipynb

# %%
# Data from observations
bins        = 0

region     = 'NGC 2070'
name_reg   = '30 Doradus'
reg_id     = '30Dor'
inst       = 'LVM'
inst_id    = 'LVM'
type_obj   = 'H II region'

pix        = 0   # Instrument resolution [arcsec/pix]
dist       = 50000 # Distance [parsecs]
s0_        = 0.9    # proposed seeing

pc         = dist*(2*np.pi) / (360 * 60 * 60)
s0         = (s0_*pc)

# %%
from astropy.coordinates import SkyCoord
import astropy.units as u
from astropy.wcs import WCS

c0 = SkyCoord.from_name("Tarantula")
c0
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (84.675, -69.1)>

# %%
fov_deg = 1.0  # Total field of view in degrees (width and height)
pix_scale = 1 / 3600
npix = int(fov_deg / pix_scale)

# Create WCS for TAN projection centered at 'center'
wcs = WCS(naxis=2)
wcs.wcs.ctype = ["RA---TAN", "DEC--TAN"]
wcs.wcs.crval = [c0.ra.deg, c0.dec.deg]
wcs.wcs.crpix = [npix, npix]  # center of your "image"
wcs.wcs.cdelt = [-pix_scale, pix_scale]  # field size / pixel count

# %%
ra0  = c0.ra.deg
dec0 = c0.dec.deg
#ra0 = _line["RAdeg"].median()
#dec0 = _line["DEdeg"].median()
print(ra0, dec0)
# Out:
# 84.675 -69.1

# %% [markdown]
# #  Data Ha

# %%
cfg = LINES["Halpha"]

plot_label_line      = cfg.plot_label
rest_wavelength = cfg.rest_wavelength
wavelength_id    = cfg.wavelength_id
element         = cfg.element
ion             = cfg.ion
transition_id   = cfg.transition_id

# %%
print(plot_label_line)
print(rest_wavelength)
print(wavelength_id)
print(element)
print(ion)
print(transition_id)
# Out:
# H$\alpha$
# 6562.8
# 6563
# H
# Ha
# H_I-6563

# %%
#line        = r'H$\alpha$'
#lambda_rest = 6562.8
#line_id     = 'H'
#line_id2   = "6563"

# %%
#Since we are working with scatter adata there is no binning that can be applied
name_file    =  inst_id + '-' + reg_id + '-' + str(wavelength_id)
name_id      =  inst_id + '-' + reg_id + '-' + element + "-X"
print(name_file)
print(name_id)
# Out:
# LVM-30Dor-6563
# LVM-30Dor-H-X

# %%
_data = json.load(open('observations/'+ name_file + '-l.json'))
_line = pd.DataFrame(_data['data'])
_line.columns = ['RAdeg', 'DEdeg', 'V_mean','log_F','sigma']
#_line = _line[0:3500]

# %%
centro = SkyCoord(ra=ra0*u.deg, dec=dec0*u.deg, frame='icrs')

coords = SkyCoord(
    ra=_line["RAdeg"].values * u.deg,
    dec=_line["DEdeg"].values * u.deg,
    frame='icrs'
)

# %%
radio = 3305 * u.arcsec   
sep = coords.separation(centro)

line_rad = _line[sep <= radio]

# %%
fig, ax = plt.subplots()
plt.hist(line_rad["V_mean"] , bins=200)
ax.set_yscale("log")

# %%
mask = (line_rad["V_mean"] > 220) & (line_rad["V_mean"]<330) & (line_rad["log_F"] > 100)  & (line_rad["sigma"] < 1.5) 
line_mask = line_rad[mask]

# %%
fig, ax = plt.subplots()
plt.hist(line_rad["V_mean"][mask] , bins=200)
ax.set_yscale("log")

# %%
fig, ax = plt.subplots()
plt.hist(line_mask["V_mean"] , bins=200)
ax.set_yscale("log")

# %% [markdown]
# Plot flux and radial velocity

# %%
fig, ax = list_maps_plots.plot_panels_log_title(line_mask,
                                                s=1.0,
                                                figsize=(10, 4.25),
                                                titles=("Flux", "V_mean - <V_mean>"),
                                                figure_title=plot_label_line)
plt.show()
#plt.savefig('Imgs/' + name_file + '.jpg', bbox_inches='tight')

# %% [markdown]
# Plot flux and radial velocity in WCS

# %%
fig, ax = list_maps_plots.plot_panels_wcs(line_mask,
                                          wcs,
                                          s=1.0,
                                          figsize=(10, 4.25),
                                          invert_ra=False, 
                                          titles=("Flux", "V_mean - <V_mean>"),
                                          figure_title=plot_label_line)
plt.show()

#plt.savefig('Imgs/' + name_file + '.jpg', bbox_inches='tight')

# %%
df_Ha = line_mask.copy()

# %%
df_Ha.describe()
# Out:
#                RAdeg          DEdeg         V_mean         log_F  \
# count  222020.000000  222020.000000  222020.000000  2.220200e+05
# mean       84.743434     -69.080949     270.401268  9.276494e+03
# std         1.275231       0.427281      12.448334  3.407694e+04
# min        82.101852     -70.012179     220.023700  1.059342e+02
# 25%        83.781267     -69.404202     262.501525  1.006186e+03
# 50%        84.708755     -69.094773     270.608900  2.636627e+03
# 75%        85.798398     -68.761121     278.533000  6.775874e+03
# max        87.248872     -68.182110     329.997900  1.710726e+06
#
#                sigma
# count  222020.000000
# mean        0.841440
# std         0.129093
# min         0.237300
# 25%         0.752300
# 50%         0.811500
# 75%         0.893100
# max         1.499700

# %% [markdown]
# ## Rotation substraction

# %% [raw]
# import lmc_model

# %% [raw]
# df =  line_mask
# c = SkyCoord(ra=df["RAdeg"].to_numpy() * u.deg, dec=df["DEdeg"].to_numpy() * u.deg)
# c

# %% [raw]
# vmod = lmc_model.vmodel_lmc(c)

# %% [raw]
# df.insert(
#     loc=5,
#     column="v_mod",
#     value=vmod.value,
# )

# %% [raw]
# col = df.pop('V_mean')
# df.insert(4, 'v_', col)

# %% [raw]
# df.insert(
#     loc=2,
#     column="V_mean",
#     value= df.v_-df.v_mod,
# )

# %% [raw]
# df.describe()

# %% [raw]
# df_Ha_subrot = df.copy()

# %% [raw]
# fig, ax = list_maps_plots.plot_panels_wcs(df_Ha_subrot,
#                                           wcs,
#                                           s=1.0,
#                                           figsize=(10, 4.25),
#                                           invert_ra=False,
#                                           titles=("Flux", "V_subrot"),
#                                           figure_title=plot_label_line)
# plt.show()
#
# #plt.savefig('Imgs/' + name_file + '.jpg', bbox_inches='tight')

# %% [markdown]
# # Data [O II]

# %%
cfg = LINES["OII_3729"]

plot_label_line      = cfg.plot_label
rest_wavelength = cfg.rest_wavelength
wavelength_id    = cfg.wavelength_id
element         = cfg.element
ion             = cfg.ion
transition_id   = cfg.transition_id

# %%
#Since we are working with scatter adata there is no binning that can be applied
name_file    =  inst_id + '-' + reg_id + '-' + str(wavelength_id)
name_id      =  inst_id + '-' + reg_id + '-' + element + "-X"
print(name_file)
print(name_id)
# Out:
# LVM-30Dor-3729
# LVM-30Dor-O-X

# %%
_data = json.load(open('observations/'+ name_file + '-l.json'))
_line = pd.DataFrame(_data['data'])
_line.columns = ['RAdeg', 'DEdeg', 'V_mean','log_F','sigma']
#_line = _line[0:3500]

# %%
radio = 3305 * u.arcsec   
sep = coords.separation(centro)

line_rad_O = _line[sep <= radio]

# %%
fig, ax = plt.subplots()
plt.hist(line_rad["V_mean"] , bins=200)
ax.set_yscale("log")

# %%
mask_O = (line_rad_O["V_mean"] > 220) & \
         (line_rad_O["V_mean"]<330) & \
         (line_rad_O["log_F"] > 100)  & (line_rad_O["sigma"] < 1.5) 
line_mask_O = line_rad_O[mask_O].copy()

# %%
fig, ax = plt.subplots()
plt.hist(line_rad_O["V_mean"][mask_O] , bins=200)
ax.set_yscale("log")

# %%
fig, ax = list_maps_plots.plot_panels_log_title(line_mask_O,
                                                s=1.0,
                                                figsize=(10, 4.25),
                                                titles=("Flux", "V_mean - <V_mean>"),
                                                figure_title=plot_label_line)
plt.show()
#plt.savefig('Imgs/' + name_file + '.jpg', bbox_inches='tight')

# %%
df_OIII = line_mask_O.copy()

# %% [markdown]
# # [S II]

# %%
cfg = LINES["SII_6731"]

plot_label_line      = cfg.plot_label
rest_wavelength = cfg.rest_wavelength
wavelength_id    = cfg.wavelength_id
element         = cfg.element
ion             = cfg.ion
transition_id   = cfg.transition_id

# %%
print(plot_label_line)
print(rest_wavelength)
print(wavelength_id)
print(element)
print(ion)
print(transition_id)
# Out:
# [S II]$\ \lambda$6731
# 6730.8
# 6731
# S
# S_II
# S_II-6731

# %%
#Since we are working with scatter adata there is no binning that can be applied
name_file    =  inst_id + '-' + reg_id + '-' + str(wavelength_id)
name_id      =  inst_id + '-' + reg_id + '-' + element + "-X"
print(name_file)
print(name_id)
# Out:
# LVM-30Dor-6731
# LVM-30Dor-S-X

# %%
_data = json.load(open('observations/'+ name_file + '-l.json'))
_line_N = pd.DataFrame(_data['data'])
_line_N.columns = ['RAdeg', 'DEdeg', 'V_mean','log_F','sigma']

# %%
radio = 3305 * u.arcsec   
sep = coords.separation(centro)

line_rad_N = _line_N[sep <= radio].copy()

# %%
mask_N = (line_rad_N["V_mean"] > 220) & \
         (line_rad_N["V_mean"]<330)   & \
         (line_rad_N["log_F"] > 100)  & (line_rad_N["sigma"] < 1.5) 

line_mask_N = line_rad_N[mask_N].copy()

# %%
fig, ax = plt.subplots()
plt.hist(line_rad_N["V_mean"][mask_N] , bins=200)
ax.set_yscale("log")

# %%
fig, ax = list_maps_plots.plot_panels_log_title(line_mask_N,
                                                s=1.0,
                                                figsize=(10, 4.25),
                                                titles=("Flux", "V_mean - <V_mean>"),
                                                figure_title=plot_label_line)
plt.show()
#plt.savefig('Imgs/' + name_file + '.jpg', bbox_inches='tight')

# %%
df_NII = line_mask_N.copy()

# %% [markdown]
# # Line Comparison

# %%
line_rad.describe()
# Out:
#                RAdeg          DEdeg         V_mean         log_F  \
# count  226758.000000  226758.000000  226758.000000  2.267580e+05
# mean       84.739355     -69.079535     269.215663  9.139823e+03
# std         1.293269       0.426873      51.541669  3.386645e+04
# min        82.101852     -70.012179    -664.132500 -3.867703e+02
# 25%        83.762614     -69.401805     262.389625  9.716659e+02
# 50%        84.710111     -69.093216     270.647800  2.555530e+03
# 75%        85.814621     -68.759558     278.703875  6.643355e+03
# max        87.248872     -68.182110    1129.646700  1.710726e+06
#
#                sigma
# count  226758.000000
# mean        0.854972
# std         0.178388
# min         0.180000
# 25%         0.752700
# 50%         0.813100
# 75%         0.897800
# max         2.187500

# %%
line_rad_N.describe()
# Out:
#                RAdeg          DEdeg         V_mean         log_F  \
# count  226758.000000  226758.000000  226758.000000  2.267580e+05
# mean       84.739355     -69.079535     271.757522 -3.549918e+10
# std         1.293269       0.426873      50.492443  1.541074e+13
# min        82.101852     -70.012179    -686.399600 -7.300079e+15
# 25%        83.762614     -69.401805     263.680575  1.847653e+02
# 50%        84.710111     -69.093216     272.551000  4.165004e+02
# 75%        85.814621     -68.759558     281.744400  8.796857e+02
# max        87.248872     -68.182110     996.217100  5.420890e+06
#
#                sigma
# count  226758.000000
# mean        0.841456
# std         0.251018
# min         0.187500
# 25%         0.706700
# 50%         0.769100
# 75%         0.877300
# max         2.187500

# %%
line_rad_O.describe()
# Out:
#                RAdeg          DEdeg         V_mean          log_F  \
# count  226758.000000  226758.000000  226758.000000  226758.000000
# mean       84.739355     -69.079535     264.509633    4217.199146
# std         1.293269       0.426873      49.058708    8933.086503
# min        82.101852     -70.012179    -686.205900 -127606.644800
# 25%        83.762614     -69.401805     257.029425     736.399850
# 50%        84.710111     -69.093216     265.172850    1817.107600
# 75%        85.814621     -68.759558     274.176300    4137.946975
# max        87.248872     -68.182110    1033.194000  246476.276100
#
#                sigma
# count  226758.000000
# mean        0.776096
# std         0.158955
# min         0.250000
# 25%         0.709200
# 50%         0.750800
# 75%         0.810500
# max         1.700000

# %%
with sns.axes_style(
    "darkgrid",
    rc={
        "axes.facecolor": "0.75",
        "figure.facecolor": "0.75",
        "grid.color": "0.55",
    }
):
    fig, ax = plt.subplots(figsize=(6,5), constrained_layout=True)
    dif_vel1 = ax.scatter(line_rad['RAdeg'], line_rad['DEdeg'],
                             s=1.0, 
                             c=line_rad['V_mean']-line_rad_O['V_mean'], 
                             cmap='RdBu_r')
    ax.invert_xaxis()
    ax.set_xlabel("RA (deg)")
    ax.set_ylabel("Dec (deg)")
    ax.set_title(r'H$\alpha$ - [O II]')
    fig.colorbar(dif_vel1, ax=ax, label='km/s')
    plt.show()

# %%
fig, ax = plt.subplots()
plt.hist(line_rad['V_mean']-line_rad_O['V_mean'] , bins=200)
ax.set_yscale("log")
ax.set_title(r'H$\alpha$ - [O II]')
# Out:
# Text(0.5, 1.0, 'H$\\alpha$ - [O II]')

# %%
with sns.axes_style(
    "darkgrid",
    rc={
        "axes.facecolor": "0.75",
        "figure.facecolor": "0.75",
        "grid.color": "0.55",
    }
):
    fig, ax = plt.subplots(figsize=(6,5), constrained_layout=True)
    dif_vel1 = ax.scatter(line_rad['RAdeg'], line_rad['DEdeg'],
                             s=1.0, 
                             c=line_rad['V_mean']-line_rad_N['V_mean'], 
                             cmap='RdBu_r')
    ax.invert_xaxis()
    ax.set_xlabel("RA (deg)")
    ax.set_ylabel("Dec (deg)")
    ax.set_title(r'H$\alpha$ - [S II]')
    fig.colorbar(dif_vel1, ax=ax, label='km/s')
    plt.show()

# %%
fig, ax = plt.subplots()
plt.hist(line_rad['V_mean']-line_rad_N['V_mean'] , bins=200)
ax.set_yscale("log")
ax.set_title(r'H$\alpha$ - [S II]')
# Out:
# Text(0.5, 1.0, 'H$\\alpha$ - [S II]')
