# %%
# Parameters
name      = ""
fits_path = ""

# %%
# Parameters
name = "MUSE-M42-O-bin2_trim"
fits_path = "fits_ready/MUSE-M42-O-bin2_trim.fits"

# %% [raw]
# name      = 'MUSE-Dor-H'
# fits_path = "fits_ready/" + name + ".fits"

# %%
import time
start_time=time.time()

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import sys
from pathlib import Path
import astropy.units as u
from matplotlib import pyplot as plt
import corner
import json
from astropy.io import fits
from lmfit.model import save_modelresult


# Add path to py_modules 
sys.path.append(str(Path().resolve() / 'py_modules')) # 1 level up = project root

#import strucfunc                   
import strucfunc
import fit_structure_function
import ci_results_compiler
import bfunc
import bplot

# %% [markdown]
# # Velocity Field

# %%
# Loading obs
hdul = fits.open(fits_path)
hdr = hdul[0].header
print(hdul.info())
print(hdr)
sb = hdul['MOM0'].data.astype(float)
vv= hdul['MOM1'].data.astype(float)
# Out:
# Filename: fits_ready/MUSE-M42-O-bin2_trim.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      23   ()
#   1  MOM0          1 ImageHDU         8   (231, 343)   float64
#   2  MOM1          1 ImageHDU         8   (231, 343)   float64
#   3  MASK          1 ImageHDU         8   (231, 343)   uint8
# None
# SIMPLE  =                    T / conforms to FITS standard                      BITPIX  =                    8 / array data type                                NAXIS   =                    0 / number of array dimensions                     EXTEND  =                    T                                                  FILE    = 'O_III-5007'         / Fits file name                                 NAME_ID = 'MUSE-M42-O-bin2_trim' / pipeline identifier                          REG     = 'M 42    '           / Region catalog name                            NAME_REG= 'Orion   '           / Region name                                    REG_ID  = 'M42     '           / Region identifier                              TYPE_OBJ= 'H II region'        / Type object                                    DIST    =                  410 / Distance in parsecs                            INSTR   = 'MUSE    '           / Instrument                                     LINE    = '[O III]$\ \lambda$5007' / Emission line name                         LINE_ID = 'O_III-5007'         / Emission line identifier                       L_REST  =               5006.9 / Emission line name                             SIG     =    2.860382533376228 / Standard deviation vel map                     SIG2    =    8.181788237243808 / Vel Variance map                               S0      = 0.000759644366579272 / Atmospheric seeing                             BOX_SIZE=   0.4476120407305737 / Observational box_size                         PC      = 0.001987736092549097 / parsec convertion                              PIX     =                  0.8 / Instrument pixel scale                         BINSIZE =                    2 / Spatial binning factor                         AUTHOR  = 'J. Garcia-Vazquez'  / File creator                                   END

# %%
with fits.open(fits_path) as hdul:
    hdr = hdul[0].header

hdr
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# FILE    = 'O_III-5007'         / Fits file name
# NAME_ID = 'MUSE-M42-O-bin2_trim' / pipeline identifier
# REG     = 'M 42    '           / Region catalog name
# NAME_REG= 'Orion   '           / Region name
# REG_ID  = 'M42     '           / Region identifier
# TYPE_OBJ= 'H II region'        / Type object
# DIST    =                  410 / Distance in parsecs
# INSTR   = 'MUSE    '           / Instrument
# LINE    = '[O III]$\ \lambda$5007' / Emission line name
# LINE_ID = 'O_III-5007'         / Emission line identifier
# L_REST  =               5006.9 / Emission line name
# SIG     =    2.860382533376228 / Standard deviation vel map
# SIG2    =    8.181788237243808 / Vel Variance map
# S0      = 0.000759644366579272 / Atmospheric seeing
# BOX_SIZE=   0.4476120407305737 / Observational box_size
# PC      = 0.001987736092549097 / parsec convertion
# PIX     =                  0.8 / Instrument pixel scale
# BINSIZE =                    2 / Spatial binning factor
# AUTHOR  = 'J. Garcia-Vazquez'  / File creator

# %%
#m3D      = hdul[0].header['M3D']
#ra       = hdul[0].header['RA']
sig      = hdul[0].header['SIG']
sig2     = hdul[0].header['SIG2']
s0       = hdul[0].header['S0']
#noise    = hdul[0].header['NOISE']
box_size = hdul[0].header['BOX_SIZE']
pc       = hdul[0].header['PC']
pix      = hdul[0].header['PIX']
line     = hdul[0].header['LINE']
binsize  = hdul[0].header['BINSIZE']

# %%
fig, (ax, axx) = plt.subplots(
    1,
    2,
    sharey=True,
    figsize=(10, 4),
)
imshow_kwds = dict(origin="lower", cmap="RdBu_r")
imshow_kwds2 = dict(origin="lower", cmap="magma")
im = ax.imshow(vv, **imshow_kwds)
cbar = fig.colorbar(im, ax=[ax])
cbar.set_label("$\sigma$ (-)", rotation=270, labelpad=15)
im = axx.imshow(sb, **imshow_kwds2)
cbar = fig.colorbar(im, ax=[axx])
cbar.set_label("rad. vel. (km/s)", rotation=270, labelpad=15)

ax.set_xlabel("pix")
ax.set_ylabel("pix")
axx.set_xlabel("pix")
ax.set_title("Moment 1")
axx.set_title("Moment 0")
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\s'
# <>:11: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\javas\AppData\Local\Temp\ipykernel_10868\669126516.py:11: SyntaxWarning: invalid escape sequence '\s'
#   cbar.set_label("$\sigma$ (-)", rotation=270, labelpad=15)
# Text(0.5, 1.0, 'Moment 0')

# %% [markdown]
# # Structure function

# %%
rslt = strucfunc.strucfunc_numba_parallel(vv, wmap=sb, dlogr=0.05)
# Out:
# C:\Users\javas\Dropbox\GitHub\VIENTO\structure_function_analysis\MUSE_orion\MUSE_orion_global_mask\py_modules\strucfunc.py:83: RuntimeWarning: invalid value encountered in divide
#   'Unweighted B(r)': sf/nsf,
# C:\Users\javas\Dropbox\GitHub\VIENTO\structure_function_analysis\MUSE_orion\MUSE_orion_global_mask\py_modules\strucfunc.py:84: RuntimeWarning: invalid value encountered in divide
#   'Weighted B(r)': wsf/weight}

# %%
rslt_ = pd.DataFrame(rslt)

# %%
rslt["Unweighted mean velocity"] = np.mean(vv)
rslt["Unweighted sigma^2"] = np.var(vv)
v0w = rslt["Weighted mean velocity"] = np.average(vv, weights=sb)
rslt["Weighted sigma^2"] = np.average((vv - v0w)**2, weights=sb)

# %%
b2    = rslt['Unweighted B(r)']
b2w   = rslt['Weighted B(r)']
e_b2  = b2  *.1
e_b2w = b2w  *.1

s     = 10**rslt['log10 r'] * pix * pc
e_s   = s  *.1
sig2  = rslt['Unweighted sigma^2']
sig2w = rslt['Weighted sigma^2']

sig   = sig2**0.5

# %%
r0    = np.interp(sig2, b2[1:35], s[1:35])
ra = r0
m     = 1
noise = 0

rgrid = np.linspace(s[0], s[:-1])

fig, ax = plt.subplots(figsize=(8, 6))

ax.errorbar(s, b2, yerr=e_b2, xerr=e_s, fmt='o', alpha=0.4,color="blue")
ax.errorbar(s, b2w, yerr=e_b2w, xerr=e_s, fmt='x', alpha=0.4,color="green")

ax.axhline(sig2, ls='-')
ax.axvline(r0, ls='-')

ax.plot(rgrid, bfunc.bfunc00s(rgrid, r0, sig2, m), color="0.8")
ax.plot(rgrid, bfunc.bfunc03s(rgrid, r0, sig2, m, s0, noise), color="black")
#ax.plot(rgrid, bfunc.bfunc04s(rgrid, r0, sig2, m, s0, noise, box_size), color="black")


ax.set(xscale='log', yscale='log', 
       xlabel='separation,pc',
       ylabel=r'$b^2,\ \mathrm{km^2\ s^{-2}}$'
      )
None

plt.show()

# %% [markdown]
# # Export

# %%
from astropy.table import Table


df =  rslt_.copy()

# Flatten MultiIndex columns like ('s','count') -> "s_count"
if isinstance(df.columns, pd.MultiIndex):
    df.columns = ["_".join(map(str, col)).strip() for col in df.columns.to_flat_index()]
else:
    df.columns = [str(c) for c in df.columns]

# (Optional) drop index to avoid it becoming an extra column
df = df.reset_index(drop=True)

t = Table.from_pandas(df)
new_hdu = fits.BinTableHDU(t, name="TABLE")

# %%
with fits.open(fits_path, mode="readonly") as hdul:
    hdus = [h.copy() for h in hdul]   # copy existing HDUs

hdus.append(new_hdu)
fits.HDUList(hdus).writeto(fits_path, overwrite=True)

# %%
# Test import

from astropy.table import Table
t = Table.read(fits_path, hdu="TABLE")
df_loaded = t.to_pandas()
df_loaded
# Out:
#     log10 r      Sum dv^2   Sum weights  Sum w * dv^2    N pairs  \
# 0      0.00  5.318402e+04  2.378573e+03  1.792827e+03      75284
# 1      0.05  0.000000e+00  0.000000e+00  0.000000e+00          0
# 2      0.10  0.000000e+00  0.000000e+00  0.000000e+00          0
# 3      0.15  1.497985e+05  4.745485e+03  5.710234e+03     149962
# 4      0.20  0.000000e+00  0.000000e+00  0.000000e+00          0
# 5      0.25  0.000000e+00  0.000000e+00  0.000000e+00          0
# 6      0.30  4.455479e+05  1.180506e+04  1.809948e+04     373009
# 7      0.35  0.000000e+00  0.000000e+00  0.000000e+00          0
# 8      0.40  0.000000e+00  0.000000e+00  0.000000e+00          0
# 9      0.45  3.059332e+05  7.050127e+03  1.290621e+04     222716
# 10     0.50  4.401630e+05  9.387393e+03  1.881671e+04     296620
# 11     0.55  4.926178e+05  9.358390e+03  2.134601e+04     295381
# 12     0.60  9.096857e+05  1.632321e+04  3.953005e+04     515930
# 13     0.65  1.307990e+06  2.089841e+04  5.719057e+04     660070
# 14     0.70  1.234643e+06  1.853236e+04  5.414222e+04     586070
# 15     0.75  1.796019e+06  2.536699e+04  7.924112e+04     802239
# 16     0.80  3.397831e+06  4.361377e+04  1.503004e+05    1379222
# 17     0.85  3.121490e+06  3.656101e+04  1.379721e+05    1155159
# 18     0.90  4.781454e+06  5.231050e+04  2.117804e+05    1655188
# 19     0.95  6.982890e+06  7.010504e+04  3.098529e+05    2218166
# 20     1.00  1.129965e+07  1.033476e+05  5.014165e+05    3273255
# 21     1.05  1.266594e+07  1.048950e+05  5.591769e+05    3318556
# 22     1.10  1.755505e+07  1.330037e+05  7.732550e+05    4208889
# 23     1.15  2.744309e+07  1.869622e+05  1.196392e+06    5909253
# 24     1.20  3.386205e+07  2.093183e+05  1.462081e+06    6617688
# 25     1.25  4.849257e+07  2.720652e+05  2.068138e+06    8594025
# 26     1.30  6.986078e+07  3.521474e+05  2.943481e+06   11133048
# 27     1.35  9.472137e+07  4.272516e+05  3.936871e+06   13506870
# 28     1.40  1.282976e+08  5.201041e+05  5.272270e+06   16463092
# 29     1.45  1.744052e+08  6.366216e+05  7.069144e+06   20184045
# 30     1.50  2.497844e+08  8.234521e+05  9.969374e+06   26187897
# 31     1.55  3.175600e+08  9.503076e+05  1.255890e+07   30333228
# 32     1.60  4.509940e+08  1.226030e+06  1.774020e+07   39324097
# 33     1.65  5.920690e+08  1.458989e+06  2.313912e+07   47085232
# 34     1.70  7.985222e+08  1.784738e+06  3.084104e+07   58065390
# 35     1.75  1.052968e+09  2.128735e+06  4.009562e+07   70112550
# 36     1.80  1.376060e+09  2.508797e+06  5.166562e+07   84082700
# 37     1.85  1.815851e+09  2.979111e+06  6.654886e+07  102358035
# 38     1.90  2.300552e+09  3.383394e+06  8.121806e+07  120078907
# 39     1.95  2.897915e+09  3.834427e+06  9.660095e+07  141738554
# 40     2.00  3.576230e+09  4.279802e+06  1.098151e+08  166396399
# 41     2.05  4.234145e+09  4.601687e+06  1.159033e+08  189908534
# 42     2.10  4.922403e+09  4.862050e+06  1.168103e+08  215759983
# 43     2.15  5.377653e+09  4.856625e+06  1.085326e+08  236224302
# 44     2.20  5.359685e+09  4.530937e+06  8.870071e+07  249831193
# 45     2.25  4.859254e+09  3.893748e+06  6.958938e+07  250984195
# 46     2.30  3.856773e+09  2.946239e+06  5.110989e+07  231239473
# 47     2.35  2.370596e+09  1.906681e+06  2.414646e+07  194422075
# 48     2.40  1.230012e+09  1.034379e+06  8.270270e+06  155052630
# 49     2.45  5.607288e+08  4.113565e+05  2.423256e+06  107716361
# 50     2.50  1.718509e+08  1.088264e+05  4.062028e+05   43989193
# 51     2.55  2.270498e+07  1.005812e+04  3.797835e+04    5098931
#
#     Unweighted B(r)  Weighted B(r)
# 0          0.706445       0.753741
# 1               NaN            NaN
# 2               NaN            NaN
# 3          0.998910       1.203298
# 4               NaN            NaN
# 5               NaN            NaN
# 6          1.194470       1.533198
# 7               NaN            NaN
# 8               NaN            NaN
# 9          1.373647       1.830635
# 10         1.483929       2.004466
# 11         1.667737       2.280949
# 12         1.763196       2.421708
# 13         1.981594       2.736599
# 14         2.106648       2.921496
# 15         2.238758       3.123788
# 16         2.463585       3.446170
# 17         2.702216       3.773750
# 18         2.888768       4.048525
# 19         3.148047       4.419838
# 20         3.452114       4.851746
# 21         3.816703       5.330827
# 22         4.170945       5.813785
# 23         4.644089       6.399111
# 24         5.116900       6.984963
# 25         5.642591       7.601625
# 26         6.275081       8.358663
# 27         7.012829       9.214410
# 28         7.793042      10.136952
# 29         8.640747      11.104154
# 30         9.538162      12.106804
# 31        10.469048      13.215616
# 32        11.468642      14.469625
# 33        12.574409      15.859698
# 34        13.752120      17.280434
# 35        15.018253      18.835424
# 36        16.365557      20.593782
# 37        17.740188      22.338496
# 38        19.158673      24.004905
# 39        20.445497      25.193059
# 40        21.492230      25.658929
# 41        22.295709      25.187132
# 42        22.814255      24.024906
# 43        22.765027      22.347323
# 44        21.453224      19.576680
# 45        19.360797      17.872081
# 46        16.678695      17.347503
# 47        12.193038      12.664128
# 48         7.932867       7.995394
# 49         5.205604       5.890889
# 50         3.906662       3.732576
# 51         4.452889       3.775890

# %%
print("--- %s seconds ---" % (time.time()-start_time))
# Out:
# --- 24.679219484329224 seconds ---
