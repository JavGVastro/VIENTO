# %%
# Parameters
name      = ""
fits_path = ""

# %%
# Parameters
name = "MUSE-M42-S-bin2"
fits_path = "fits_ready/MUSE-M42-S-bin2.fits"

# %% [raw]
# name      = 'MUSE-Dor-H'
# fits_path = "fits_ready/" + name + ".fits"

# %%
import time
start_time=time.time()

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import sys
from pathlib import Path
import astropy.units as u
from matplotlib import pyplot as plt
import corner
import json
from astropy.io import fits
from lmfit.model import save_modelresult


# Add path to py_modules 
sys.path.append(str(Path().resolve() / 'py_modules')) # 1 level up = project root

#import strucfunc                   
import strucfunc
import fit_structure_function
import ci_results_compiler
import bfunc
import bplot

# %% [markdown]
# # Velocity Field

# %%
# Loading obs
hdul = fits.open(fits_path)
hdr = hdul[0].header
print(hdul.info())
print(hdr)
sb = hdul['MOM0'].data.astype(float)
vv= hdul['MOM1'].data.astype(float)
# Out:
# Filename: fits_ready/MUSE-M42-S-bin2.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      23   ()
#   1  MOM0          1 ImageHDU         8   (441, 369)   float64
#   2  MOM1          1 ImageHDU         8   (441, 369)   float64
#   3  MASK          1 ImageHDU         8   (441, 369)   uint8
# None
# SIMPLE  =                    T / conforms to FITS standard                      BITPIX  =                    8 / array data type                                NAXIS   =                    0 / number of array dimensions                     EXTEND  =                    T                                                  FILE    = 'S_III-9069'         / Fits file name                                 NAME_ID = 'MUSE-M42-S-bin2'    / pipeline identifier                            REG     = 'M 42    '           / Region catalog name                            NAME_REG= 'Orion   '           / Region name                                    REG_ID  = 'M42     '           / Region identifier                              TYPE_OBJ= 'H II region'        / Type object                                    DIST    =                  410 / Distance in parsecs                            INSTR   = 'MUSE    '           / Instrument                                     LINE    = '[S III]$\ \lambda$9069' / Emission line name                         LINE_ID = 'S_III-9069'         / Emission line identifier                       L_REST  =               9069.1 / Emission line name                             SIG     =   2.6135522376698863 / Standard deviation vel map                     SIG2    =     6.83065529902927 / Vel Variance map                               S0      = 0.000759644366579272 / Atmospheric seeing                             BOX_SIZE=    0.641477146051788 / Observational box_size                         PC      = 0.001987736092549097 / parsec convertion                              PIX     =                  0.8 / Instrument pixel scale                         BINSIZE =                    2 / Spatial binning factor                         AUTHOR  = 'J. Garcia-Vazquez'  / File creator                                   END

# %%
with fits.open(fits_path) as hdul:
    hdr = hdul[0].header

hdr
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# FILE    = 'S_III-9069'         / Fits file name
# NAME_ID = 'MUSE-M42-S-bin2'    / pipeline identifier
# REG     = 'M 42    '           / Region catalog name
# NAME_REG= 'Orion   '           / Region name
# REG_ID  = 'M42     '           / Region identifier
# TYPE_OBJ= 'H II region'        / Type object
# DIST    =                  410 / Distance in parsecs
# INSTR   = 'MUSE    '           / Instrument
# LINE    = '[S III]$\ \lambda$9069' / Emission line name
# LINE_ID = 'S_III-9069'         / Emission line identifier
# L_REST  =               9069.1 / Emission line name
# SIG     =   2.6135522376698863 / Standard deviation vel map
# SIG2    =     6.83065529902927 / Vel Variance map
# S0      = 0.000759644366579272 / Atmospheric seeing
# BOX_SIZE=    0.641477146051788 / Observational box_size
# PC      = 0.001987736092549097 / parsec convertion
# PIX     =                  0.8 / Instrument pixel scale
# BINSIZE =                    2 / Spatial binning factor
# AUTHOR  = 'J. Garcia-Vazquez'  / File creator

# %%
#m3D      = hdul[0].header['M3D']
#ra       = hdul[0].header['RA']
sig      = hdul[0].header['SIG']
sig2     = hdul[0].header['SIG2']
s0       = hdul[0].header['S0']
#noise    = hdul[0].header['NOISE']
box_size = hdul[0].header['BOX_SIZE']
pc       = hdul[0].header['PC']
pix      = hdul[0].header['PIX']
line     = hdul[0].header['LINE']
binsize  = hdul[0].header['BINSIZE']

# %%
fig, (ax, axx) = plt.subplots(
    1,
    2,
    sharey=True,
    figsize=(10, 4),
)
imshow_kwds = dict(origin="lower", cmap="RdBu_r")
imshow_kwds2 = dict(origin="lower", cmap="magma")
im = ax.imshow(vv, **imshow_kwds)
cbar = fig.colorbar(im, ax=[ax])
cbar.set_label("$\sigma$ (-)", rotation=270, labelpad=15)
im = axx.imshow(sb, **imshow_kwds2)
cbar = fig.colorbar(im, ax=[axx])
cbar.set_label("rad. vel. (km/s)", rotation=270, labelpad=15)

ax.set_xlabel("pix")
ax.set_ylabel("pix")
axx.set_xlabel("pix")
ax.set_title("Moment 1")
axx.set_title("Moment 0")
# Out:
# Text(0.5, 1.0, 'Moment 0')

# %% [markdown]
# # Structure function

# %%
rslt = strucfunc.strucfunc_numba_parallel(vv, wmap=sb, dlogr=0.05)
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# /Users/javier/MUSE_orion_global_mask/py_modules/strucfunc.py:83: RuntimeWarning: invalid value encountered in divide
#   'Unweighted B(r)': sf/nsf,
# /Users/javier/MUSE_orion_global_mask/py_modules/strucfunc.py:84: RuntimeWarning: invalid value encountered in divide
#   'Weighted B(r)': wsf/weight}

# %%
rslt_ = pd.DataFrame(rslt)

# %%
rslt["Unweighted mean velocity"] = np.mean(vv)
rslt["Unweighted sigma^2"] = np.var(vv)
v0w = rslt["Weighted mean velocity"] = np.average(vv, weights=sb)
rslt["Weighted sigma^2"] = np.average((vv - v0w)**2, weights=sb)

# %%
b2    = rslt['Unweighted B(r)']
b2w   = rslt['Weighted B(r)']
e_b2  = b2  *.1
e_b2w = b2w  *.1

s     = 10**rslt['log10 r'] * pix * pc
e_s   = s  *.1
sig2  = rslt['Unweighted sigma^2']
sig2w = rslt['Weighted sigma^2']

sig   = sig2**0.5

# %%
r0    = np.interp(sig2, b2[1:35], s[1:35])
ra = r0
m     = 1
noise = 0

rgrid = np.linspace(s[0], s[:-1])

fig, ax = plt.subplots(figsize=(8, 6))

ax.errorbar(s, b2, yerr=e_b2, xerr=e_s, fmt='o', alpha=0.4,color="blue")
ax.errorbar(s, b2w, yerr=e_b2w, xerr=e_s, fmt='x', alpha=0.4,color="green")

ax.axhline(sig2, ls='-')
ax.axvline(r0, ls='-')

ax.plot(rgrid, bfunc.bfunc00s(rgrid, r0, sig2, m), color="0.8")
ax.plot(rgrid, bfunc.bfunc03s(rgrid, r0, sig2, m, s0, noise), color="black")
#ax.plot(rgrid, bfunc.bfunc04s(rgrid, r0, sig2, m, s0, noise, box_size), color="black")


ax.set(xscale='log', yscale='log', 
       xlabel='separation,pc',
       ylabel=r'$b^2,\ \mathrm{km^2\ s^{-2}}$'
      )
None

plt.show()

# %% [markdown]
# # Export

# %%
from astropy.table import Table


df =  rslt_.copy()

# Flatten MultiIndex columns like ('s','count') -> "s_count"
if isinstance(df.columns, pd.MultiIndex):
    df.columns = ["_".join(map(str, col)).strip() for col in df.columns.to_flat_index()]
else:
    df.columns = [str(c) for c in df.columns]

# (Optional) drop index to avoid it becoming an extra column
df = df.reset_index(drop=True)

t = Table.from_pandas(df)
new_hdu = fits.BinTableHDU(t, name="TABLE")

# %%
with fits.open(fits_path, mode="readonly") as hdul:
    hdus = [h.copy() for h in hdul]   # copy existing HDUs

hdus.append(new_hdu)
fits.HDUList(hdus).writeto(fits_path, overwrite=True)

# %%
# Test import

from astropy.table import Table
t = Table.read(fits_path, hdu="TABLE")
df_loaded = t.to_pandas()
df_loaded
# Out:
#     log10 r      Sum dv^2   Sum weights  Sum w * dv^2    N pairs  \
# 0      0.00  9.869617e+04  5.814959e+03  4.423523e+03     137576
# 1      0.05  0.000000e+00  0.000000e+00  0.000000e+00          0
# 2      0.10  0.000000e+00  0.000000e+00  0.000000e+00          0
# 3      0.15  2.462965e+05  1.160137e+04  1.376100e+04     274033
# 4      0.20  0.000000e+00  0.000000e+00  0.000000e+00          0
# 5      0.25  0.000000e+00  0.000000e+00  0.000000e+00          0
# 6      0.30  7.297795e+05  2.888957e+04  4.629034e+04     682395
# 7      0.35  0.000000e+00  0.000000e+00  0.000000e+00          0
# 8      0.40  0.000000e+00  0.000000e+00  0.000000e+00          0
# 9      0.45  5.004161e+05  1.727311e+04  3.369627e+04     408028
# 10     0.50  7.242364e+05  2.299112e+04  4.957038e+04     542969
# 11     0.55  7.923334e+05  2.293737e+04  5.567539e+04     541280
# 12     0.60  1.483718e+06  4.003864e+04  1.027820e+05     945936
# 13     0.65  2.113747e+06  5.131541e+04  1.478969e+05    1211598
# 14     0.70  2.025452e+06  4.549849e+04  1.397343e+05    1075030
# 15     0.75  2.963040e+06  6.236495e+04  2.071385e+05    1473832
# 16     0.80  5.622690e+06  1.073172e+05  3.914180e+05    2535691
# 17     0.85  5.162305e+06  9.004297e+04  3.583699e+05    2125693
# 18     0.90  7.982472e+06  1.289451e+05  5.481046e+05    3047811
# 19     0.95  1.173775e+07  1.730104e+05  7.997433e+05    4088802
# 20     1.00  1.908120e+07  2.553846e+05  1.288208e+06    6039177
# 21     1.05  2.139303e+07  2.595921e+05  1.426917e+06    6131458
# 22     1.10  2.963990e+07  3.296403e+05  1.959959e+06    7786471
# 23     1.15  4.621397e+07  4.641452e+05  3.007791e+06   10950598
# 24     1.20  5.709787e+07  5.205152e+05  3.661603e+06   12284241
# 25     1.25  8.198135e+07  6.777631e+05  5.154098e+06   15988823
# 26     1.30  1.174903e+08  8.787903e+05  7.241288e+06   20757231
# 27     1.35  1.583333e+08  1.068834e+06  9.526841e+06   25265774
# 28     1.40  2.131765e+08  1.304631e+06  1.259511e+07   30896932
# 29     1.45  2.882292e+08  1.603247e+06  1.666775e+07   38041072
# 30     1.50  4.114835e+08  2.084084e+06  2.316248e+07   49601294
# 31     1.55  5.230194e+08  2.418626e+06  2.862890e+07   57777809
# 32     1.60  7.440925e+08  3.142040e+06  3.955648e+07   75391751
# 33     1.65  9.795634e+08  3.772446e+06  5.058981e+07   90966084
# 34     1.70  1.324684e+09  4.667026e+06  6.659739e+07  113172406
# 35     1.75  1.748648e+09  5.650003e+06  8.568965e+07  138028847
# 36     1.80  2.289888e+09  6.790193e+06  1.095514e+08  167516023
# 37     1.85  3.031973e+09  8.265236e+06  1.407017e+08  206889652
# 38     1.90  3.858801e+09  9.684053e+06  1.723793e+08  246968618
# 39     1.95  4.890085e+09  1.140199e+07  2.086808e+08  297949733
# 40     2.00  6.138708e+09  1.333637e+07  2.490647e+08  359475420
# 41     2.05  7.517397e+09  1.523390e+07  2.864631e+08  424849064
# 42     2.10  9.207130e+09  1.736304e+07  3.227974e+08  505053420
# 43     2.15  1.108518e+10  1.914317e+07  3.510165e+08  587690445
# 44     2.20  1.318597e+10  2.027258e+07  3.699312e+08  673246038
# 45     2.25  1.497537e+10  2.040685e+07  3.665892e+08  755375935
# 46     2.30  1.613183e+10  1.915112e+07  3.477740e+08  821234119
# 47     2.35  1.650514e+10  1.664345e+07  2.909421e+08  870095781
# 48     2.40  1.448591e+10  1.304630e+07  1.938131e+08  876741509
# 49     2.45  1.136822e+10  8.836698e+06  1.192462e+08  815482051
# 50     2.50  7.444377e+09  4.813917e+06  5.682138e+07  651288529
# 51     2.55  3.522376e+09  1.856054e+06  1.698820e+07  395356773
# 52     2.60  1.110505e+09  5.143518e+05  3.308434e+06  170882497
# 53     2.65  1.857898e+08  7.586614e+04  3.784068e+05   36420139
# 54     2.70  8.057925e+06  3.768382e+03  1.180190e+04    2608223
#
#     Unweighted B(r)  Weighted B(r)
# 0          0.717394       0.760714
# 1               NaN            NaN
# 2               NaN            NaN
# 3          0.898784       1.186153
# 4               NaN            NaN
# 5               NaN            NaN
# 6          1.069439       1.602320
# 7               NaN            NaN
# 8               NaN            NaN
# 9          1.226426       1.950794
# 10         1.333845       2.156066
# 11         1.463814       2.427278
# 12         1.568518       2.567070
# 13         1.744595       2.882114
# 14         1.884089       3.071186
# 15         2.010433       3.321394
# 16         2.217419       3.647299
# 17         2.428528       3.979988
# 18         2.619084       4.250680
# 19         2.870705       4.622515
# 20         3.159570       5.044188
# 21         3.489061       5.496764
# 22         3.806590       5.945748
# 23         4.220224       6.480281
# 24         4.648058       7.034574
# 25         5.127416       7.604571
# 26         5.660209       8.240064
# 27         6.266711       8.913302
# 28         6.899601       9.654156
# 29         7.576790      10.396246
# 30         8.295823      11.113985
# 31         9.052254      11.836846
# 32         9.869681      12.589427
# 33        10.768447      13.410346
# 34        11.705009      14.269771
# 35        12.668717      15.166301
# 36        13.669663      16.133774
# 37        14.655026      17.023318
# 38        15.624661      17.800330
# 39        16.412449      18.302143
# 40        17.076851      18.675605
# 41        17.694276      18.804318
# 42        18.230012      18.591065
# 43        18.862269      18.336382
# 44        19.585668      18.247863
# 45        19.825053      17.964023
# 46        19.643399      18.159458
# 47        18.969342      17.480878
# 48        16.522445      14.855795
# 49        13.940495      13.494429
# 50        11.430229      11.803566
# 51         8.909361       9.152860
# 52         6.498646       6.432239
# 53         5.101292       4.987822
# 54         3.089431       3.131823

# %%
print("--- %s seconds ---" % (time.time()-start_time))
# Out:
# --- 19.000431060791016 seconds ---
